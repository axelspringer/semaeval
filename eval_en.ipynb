# %%
import semaeval.util as util
util.clean_storage("en")
# Out:
# Deleting: input/en/bicotest_153.yml
# Deleting: input/en/bicotest_192.yml
# Deleting: input/en/bicotest_195.yml
# Deleting: input/en/bicotest_416.yml
# Deleting: input/en/bicotest_443.yml
# Deleting: input/en/bicotest_457.yml
# Deleting: input/en/bicotest_490.yml
# Deleting: input/en/bicotest_505.yml
# Deleting: input/en/bicotest_515.yml
# Deleting: input/en/bicotest_533.yml
# Deleting: input/en/bicotest_536.yml
# Deleting: input/en/bicotest_548.yml
# Deleting: input/en/bicotest_566.yml
# Deleting: input/en/bicotest_583.yml
# Deleting: input/en/bicotest_588.yml
# Deleting: input/en/weonetest_055.yml
# Deleting: input/en/weonetest_092.yml
# Deleting: input/en/weonetest_1029.yml
# Deleting: input/en/weonetest_1044.yml
# Deleting: input/en/weonetest_1081.yml
# Deleting: input/en/weonetest_1124.yml
# Deleting: input/en/weonetest_1132.yml
# Deleting: input/en/weonetest_1187.yml
# Deleting: input/en/weonetest_1205.yml
# Deleting: input/en/weonetest_141.yml
# Deleting: input/en/weonetest_157.yml
# Deleting: input/en/weonetest_198.yml
# Deleting: input/en/weonetest_240.yml
# Deleting: input/en/weonetest_317.yml
# Deleting: input/en/weonetest_359.yml
# Deleting: input/en/weonetest_393.yml
# Deleting: input/en/weonetest_430.yml
# Deleting: input/en/weonetest_506.yml
# Deleting: input/en/weonetest_549.yml
# Deleting: input/en/weonetest_659.yml
# Deleting: input/en/weonetest_676.yml
# Deleting: input/en/weonetest_702.yml
# Deleting: input/en/weonetest_711.yml
# Deleting: input/en/weonetest_734.yml
# Deleting: input/en/weonetest_737.yml
# Deleting: input/en/weonetest_738.yml
# Deleting: input/en/weonetest_744.yml
# Deleting: input/en/weonetest_769.yml
# Deleting: input/en/weonetest_835.yml
# Deleting: input/en/weonetest_842.yml
# Deleting: input/en/weonetest_872.yml
# Deleting: input/en/weonetest_889.yml
# Deleting: input/en/weonetest_923.yml
# Deleting: input/en/weonetest_943.yml
# Deleting: input/en/weonetest_982.yml
# Deleting: output/en/bicotest_153_alchemy.yml
# Deleting: output/en/bicotest_153_basistech.yml
# Deleting: output/en/bicotest_153_bitext.yml
# Deleting: output/en/bicotest_153_meaningcloud.yml
# Deleting: output/en/bicotest_153_retresco.yml
# Deleting: output/en/bicotest_153_semant.yml
# Deleting: output/en/bicotest_153_simple.yml
# Deleting: output/en/bicotest_153_txtrazor.yml
# Deleting: output/en/bicotest_192_alchemy.yml
# Deleting: output/en/bicotest_192_basistech.yml
# Deleting: output/en/bicotest_192_bitext.yml
# Deleting: output/en/bicotest_192_meaningcloud.yml
# Deleting: output/en/bicotest_192_retresco.yml
# Deleting: output/en/bicotest_192_semant.yml
# Deleting: output/en/bicotest_192_simple.yml
# Deleting: output/en/bicotest_192_txtrazor.yml
# Deleting: output/en/bicotest_195_alchemy.yml
# Deleting: output/en/bicotest_195_basistech.yml
# Deleting: output/en/bicotest_195_bitext.yml
# Deleting: output/en/bicotest_195_meaningcloud.yml
# Deleting: output/en/bicotest_195_retresco.yml
# Deleting: output/en/bicotest_195_semant.yml
# Deleting: output/en/bicotest_195_simple.yml
# Deleting: output/en/bicotest_195_txtrazor.yml
# Deleting: output/en/bicotest_416_alchemy.yml
# Deleting: output/en/bicotest_416_basistech.yml
# Deleting: output/en/bicotest_416_bitext.yml
# Deleting: output/en/bicotest_416_meaningcloud.yml
# Deleting: output/en/bicotest_416_retresco.yml
# Deleting: output/en/bicotest_416_semant.yml
# Deleting: output/en/bicotest_416_simple.yml
# Deleting: output/en/bicotest_416_txtrazor.yml
# Deleting: output/en/bicotest_443_alchemy.yml
# Deleting: output/en/bicotest_443_basistech.yml
# Deleting: output/en/bicotest_443_bitext.yml
# Deleting: output/en/bicotest_443_meaningcloud.yml
# Deleting: output/en/bicotest_443_retresco.yml
# Deleting: output/en/bicotest_443_semant.yml
# Deleting: output/en/bicotest_443_simple.yml
# Deleting: output/en/bicotest_443_txtrazor.yml
# Deleting: output/en/bicotest_457_alchemy.yml
# Deleting: output/en/bicotest_457_basistech.yml
# Deleting: output/en/bicotest_457_bitext.yml
# Deleting: output/en/bicotest_457_meaningcloud.yml
# Deleting: output/en/bicotest_457_retresco.yml
# Deleting: output/en/bicotest_457_semant.yml
# Deleting: output/en/bicotest_457_simple.yml
# Deleting: output/en/bicotest_457_txtrazor.yml
# Deleting: output/en/bicotest_490_alchemy.yml
# Deleting: output/en/bicotest_490_basistech.yml
# Deleting: output/en/bicotest_490_bitext.yml
# Deleting: output/en/bicotest_490_meaningcloud.yml
# Deleting: output/en/bicotest_490_retresco.yml
# Deleting: output/en/bicotest_490_semant.yml
# Deleting: output/en/bicotest_490_simple.yml
# Deleting: output/en/bicotest_490_txtrazor.yml
# Deleting: output/en/bicotest_505_alchemy.yml
# Deleting: output/en/bicotest_505_basistech.yml
# Deleting: output/en/bicotest_505_bitext.yml
# Deleting: output/en/bicotest_505_meaningcloud.yml
# Deleting: output/en/bicotest_505_retresco.yml
# Deleting: output/en/bicotest_505_semant.yml
# Deleting: output/en/bicotest_505_simple.yml
# Deleting: output/en/bicotest_505_txtrazor.yml
# Deleting: output/en/bicotest_515_alchemy.yml
# Deleting: output/en/bicotest_515_basistech.yml
# Deleting: output/en/bicotest_515_bitext.yml
# Deleting: output/en/bicotest_515_meaningcloud.yml
# Deleting: output/en/bicotest_515_retresco.yml
# Deleting: output/en/bicotest_515_semant.yml
# Deleting: output/en/bicotest_515_simple.yml
# Deleting: output/en/bicotest_515_txtrazor.yml
# Deleting: output/en/bicotest_533_alchemy.yml
# Deleting: output/en/bicotest_533_basistech.yml
# Deleting: output/en/bicotest_533_bitext.yml
# Deleting: output/en/bicotest_533_meaningcloud.yml
# Deleting: output/en/bicotest_533_retresco.yml
# Deleting: output/en/bicotest_533_semant.yml
# Deleting: output/en/bicotest_533_simple.yml
# Deleting: output/en/bicotest_533_txtrazor.yml
# Deleting: output/en/bicotest_536_alchemy.yml
# Deleting: output/en/bicotest_536_basistech.yml
# Deleting: output/en/bicotest_536_bitext.yml
# Deleting: output/en/bicotest_536_meaningcloud.yml
# Deleting: output/en/bicotest_536_retresco.yml
# Deleting: output/en/bicotest_536_semant.yml
# Deleting: output/en/bicotest_536_simple.yml
# Deleting: output/en/bicotest_536_txtrazor.yml
# Deleting: output/en/bicotest_548_alchemy.yml
# Deleting: output/en/bicotest_548_basistech.yml
# Deleting: output/en/bicotest_548_bitext.yml
# Deleting: output/en/bicotest_548_meaningcloud.yml
# Deleting: output/en/bicotest_548_retresco.yml
# Deleting: output/en/bicotest_548_semant.yml
# Deleting: output/en/bicotest_548_simple.yml
# Deleting: output/en/bicotest_548_txtrazor.yml
# Deleting: output/en/bicotest_566_alchemy.yml
# Deleting: output/en/bicotest_566_basistech.yml
# Deleting: output/en/bicotest_566_bitext.yml
# Deleting: output/en/bicotest_566_meaningcloud.yml
# Deleting: output/en/bicotest_566_retresco.yml
# Deleting: output/en/bicotest_566_semant.yml
# Deleting: output/en/bicotest_566_simple.yml
# Deleting: output/en/bicotest_566_txtrazor.yml
# Deleting: output/en/bicotest_583_alchemy.yml
# Deleting: output/en/bicotest_583_basistech.yml
# Deleting: output/en/bicotest_583_bitext.yml
# Deleting: output/en/bicotest_583_meaningcloud.yml
# Deleting: output/en/bicotest_583_retresco.yml
# Deleting: output/en/bicotest_583_semant.yml
# Deleting: output/en/bicotest_583_simple.yml
# Deleting: output/en/bicotest_583_txtrazor.yml
# Deleting: output/en/bicotest_588_alchemy.yml
# Deleting: output/en/bicotest_588_basistech.yml
# Deleting: output/en/bicotest_588_bitext.yml
# Deleting: output/en/bicotest_588_meaningcloud.yml
# Deleting: output/en/bicotest_588_retresco.yml
# Deleting: output/en/bicotest_588_semant.yml
# Deleting: output/en/bicotest_588_simple.yml
# Deleting: output/en/bicotest_588_txtrazor.yml
# Deleting: output/en/weonetest_055_alchemy.yml
# Deleting: output/en/weonetest_055_basistech.yml
# Deleting: output/en/weonetest_055_bitext.yml
# Deleting: output/en/weonetest_055_meaningcloud.yml
# Deleting: output/en/weonetest_055_retresco.yml
# Deleting: output/en/weonetest_055_semant.yml
# Deleting: output/en/weonetest_055_simple.yml
# Deleting: output/en/weonetest_055_txtrazor.yml
# Deleting: output/en/weonetest_092_alchemy.yml
# Deleting: output/en/weonetest_092_basistech.yml
# Deleting: output/en/weonetest_092_bitext.yml
# Deleting: output/en/weonetest_092_meaningcloud.yml
# Deleting: output/en/weonetest_092_retresco.yml
# Deleting: output/en/weonetest_092_semant.yml
# Deleting: output/en/weonetest_092_simple.yml
# Deleting: output/en/weonetest_092_txtrazor.yml
# Deleting: output/en/weonetest_1029_alchemy.yml
# Deleting: output/en/weonetest_1029_basistech.yml
# Deleting: output/en/weonetest_1029_bitext.yml
# Deleting: output/en/weonetest_1029_meaningcloud.yml
# Deleting: output/en/weonetest_1029_retresco.yml
# Deleting: output/en/weonetest_1029_semant.yml
# Deleting: output/en/weonetest_1029_simple.yml
# Deleting: output/en/weonetest_1029_txtrazor.yml
# Deleting: output/en/weonetest_1044_alchemy.yml
# Deleting: output/en/weonetest_1044_basistech.yml
# Deleting: output/en/weonetest_1044_bitext.yml
# Deleting: output/en/weonetest_1044_meaningcloud.yml
# Deleting: output/en/weonetest_1044_retresco.yml
# Deleting: output/en/weonetest_1044_semant.yml
# Deleting: output/en/weonetest_1044_simple.yml
# Deleting: output/en/weonetest_1044_txtrazor.yml
# Deleting: output/en/weonetest_1081_alchemy.yml
# Deleting: output/en/weonetest_1081_basistech.yml
# Deleting: output/en/weonetest_1081_bitext.yml
# Deleting: output/en/weonetest_1081_meaningcloud.yml
# Deleting: output/en/weonetest_1081_retresco.yml
# Deleting: output/en/weonetest_1081_semant.yml
# Deleting: output/en/weonetest_1081_simple.yml
# Deleting: output/en/weonetest_1081_txtrazor.yml
# Deleting: output/en/weonetest_1124_alchemy.yml
# Deleting: output/en/weonetest_1124_basistech.yml
# Deleting: output/en/weonetest_1124_bitext.yml
# Deleting: output/en/weonetest_1124_meaningcloud.yml
# Deleting: output/en/weonetest_1124_retresco.yml
# Deleting: output/en/weonetest_1124_semant.yml
# Deleting: output/en/weonetest_1124_simple.yml
# Deleting: output/en/weonetest_1124_txtrazor.yml
# Deleting: output/en/weonetest_1132_alchemy.yml
# Deleting: output/en/weonetest_1132_basistech.yml
# Deleting: output/en/weonetest_1132_bitext.yml
# Deleting: output/en/weonetest_1132_meaningcloud.yml
# Deleting: output/en/weonetest_1132_retresco.yml
# Deleting: output/en/weonetest_1132_semant.yml
# Deleting: output/en/weonetest_1132_simple.yml
# Deleting: output/en/weonetest_1132_txtrazor.yml
# Deleting: output/en/weonetest_1187_alchemy.yml
# Deleting: output/en/weonetest_1187_basistech.yml
# Deleting: output/en/weonetest_1187_bitext.yml
# Deleting: output/en/weonetest_1187_meaningcloud.yml
# Deleting: output/en/weonetest_1187_retresco.yml
# Deleting: output/en/weonetest_1187_semant.yml
# Deleting: output/en/weonetest_1187_simple.yml
# Deleting: output/en/weonetest_1187_txtrazor.yml
# Deleting: output/en/weonetest_1205_alchemy.yml
# Deleting: output/en/weonetest_1205_basistech.yml
# Deleting: output/en/weonetest_1205_bitext.yml
# Deleting: output/en/weonetest_1205_meaningcloud.yml
# Deleting: output/en/weonetest_1205_retresco.yml
# Deleting: output/en/weonetest_1205_semant.yml
# Deleting: output/en/weonetest_1205_simple.yml
# Deleting: output/en/weonetest_1205_txtrazor.yml
# Deleting: output/en/weonetest_141_alchemy.yml
# Deleting: output/en/weonetest_141_basistech.yml
# Deleting: output/en/weonetest_141_bitext.yml
# Deleting: output/en/weonetest_141_meaningcloud.yml
# Deleting: output/en/weonetest_141_retresco.yml
# Deleting: output/en/weonetest_141_semant.yml
# Deleting: output/en/weonetest_141_simple.yml
# Deleting: output/en/weonetest_141_txtrazor.yml
# Deleting: output/en/weonetest_157_alchemy.yml
# Deleting: output/en/weonetest_157_basistech.yml
# Deleting: output/en/weonetest_157_bitext.yml
# Deleting: output/en/weonetest_157_meaningcloud.yml
# Deleting: output/en/weonetest_157_retresco.yml
# Deleting: output/en/weonetest_157_semant.yml
# Deleting: output/en/weonetest_157_simple.yml
# Deleting: output/en/weonetest_157_txtrazor.yml
# Deleting: output/en/weonetest_198_alchemy.yml
# Deleting: output/en/weonetest_198_basistech.yml
# Deleting: output/en/weonetest_198_bitext.yml
# Deleting: output/en/weonetest_198_meaningcloud.yml
# Deleting: output/en/weonetest_198_retresco.yml
# Deleting: output/en/weonetest_198_semant.yml
# Deleting: output/en/weonetest_198_simple.yml
# Deleting: output/en/weonetest_198_txtrazor.yml
# Deleting: output/en/weonetest_240_alchemy.yml
# Deleting: output/en/weonetest_240_basistech.yml
# Deleting: output/en/weonetest_240_bitext.yml
# Deleting: output/en/weonetest_240_meaningcloud.yml
# Deleting: output/en/weonetest_240_retresco.yml
# Deleting: output/en/weonetest_240_semant.yml
# Deleting: output/en/weonetest_240_simple.yml
# Deleting: output/en/weonetest_240_txtrazor.yml
# Deleting: output/en/weonetest_317_alchemy.yml
# Deleting: output/en/weonetest_317_basistech.yml
# Deleting: output/en/weonetest_317_bitext.yml
# Deleting: output/en/weonetest_317_meaningcloud.yml
# Deleting: output/en/weonetest_317_retresco.yml
# Deleting: output/en/weonetest_317_semant.yml
# Deleting: output/en/weonetest_317_simple.yml
# Deleting: output/en/weonetest_317_txtrazor.yml
# Deleting: output/en/weonetest_359_alchemy.yml
# Deleting: output/en/weonetest_359_basistech.yml
# Deleting: output/en/weonetest_359_bitext.yml
# Deleting: output/en/weonetest_359_meaningcloud.yml
# Deleting: output/en/weonetest_359_retresco.yml
# Deleting: output/en/weonetest_359_semant.yml
# Deleting: output/en/weonetest_359_simple.yml
# Deleting: output/en/weonetest_359_txtrazor.yml
# Deleting: output/en/weonetest_393_alchemy.yml
# Deleting: output/en/weonetest_393_basistech.yml
# Deleting: output/en/weonetest_393_bitext.yml
# Deleting: output/en/weonetest_393_meaningcloud.yml
# Deleting: output/en/weonetest_393_retresco.yml
# Deleting: output/en/weonetest_393_semant.yml
# Deleting: output/en/weonetest_393_simple.yml
# Deleting: output/en/weonetest_393_txtrazor.yml
# Deleting: output/en/weonetest_430_alchemy.yml
# Deleting: output/en/weonetest_430_basistech.yml
# Deleting: output/en/weonetest_430_bitext.yml
# Deleting: output/en/weonetest_430_meaningcloud.yml
# Deleting: output/en/weonetest_430_retresco.yml
# Deleting: output/en/weonetest_430_semant.yml
# Deleting: output/en/weonetest_430_simple.yml
# Deleting: output/en/weonetest_430_txtrazor.yml
# Deleting: output/en/weonetest_506_alchemy.yml
# Deleting: output/en/weonetest_506_basistech.yml
# Deleting: output/en/weonetest_506_bitext.yml
# Deleting: output/en/weonetest_506_meaningcloud.yml
# Deleting: output/en/weonetest_506_retresco.yml
# Deleting: output/en/weonetest_506_semant.yml
# Deleting: output/en/weonetest_506_simple.yml
# Deleting: output/en/weonetest_506_txtrazor.yml
# Deleting: output/en/weonetest_549_alchemy.yml
# Deleting: output/en/weonetest_549_basistech.yml
# Deleting: output/en/weonetest_549_bitext.yml
# Deleting: output/en/weonetest_549_meaningcloud.yml
# Deleting: output/en/weonetest_549_retresco.yml
# Deleting: output/en/weonetest_549_semant.yml
# Deleting: output/en/weonetest_549_simple.yml
# Deleting: output/en/weonetest_549_txtrazor.yml
# Deleting: output/en/weonetest_659_alchemy.yml
# Deleting: output/en/weonetest_659_basistech.yml
# Deleting: output/en/weonetest_659_bitext.yml
# Deleting: output/en/weonetest_659_meaningcloud.yml
# Deleting: output/en/weonetest_659_retresco.yml
# Deleting: output/en/weonetest_659_semant.yml
# Deleting: output/en/weonetest_659_simple.yml
# Deleting: output/en/weonetest_659_txtrazor.yml
# Deleting: output/en/weonetest_676_alchemy.yml
# Deleting: output/en/weonetest_676_basistech.yml
# Deleting: output/en/weonetest_676_bitext.yml
# Deleting: output/en/weonetest_676_meaningcloud.yml
# Deleting: output/en/weonetest_676_retresco.yml
# Deleting: output/en/weonetest_676_semant.yml
# Deleting: output/en/weonetest_676_simple.yml
# Deleting: output/en/weonetest_676_txtrazor.yml
# Deleting: output/en/weonetest_702_alchemy.yml
# Deleting: output/en/weonetest_702_basistech.yml
# Deleting: output/en/weonetest_702_bitext.yml
# Deleting: output/en/weonetest_702_meaningcloud.yml
# Deleting: output/en/weonetest_702_retresco.yml
# Deleting: output/en/weonetest_702_semant.yml
# Deleting: output/en/weonetest_702_simple.yml
# Deleting: output/en/weonetest_702_txtrazor.yml
# Deleting: output/en/weonetest_711_alchemy.yml
# Deleting: output/en/weonetest_711_basistech.yml
# Deleting: output/en/weonetest_711_bitext.yml
# Deleting: output/en/weonetest_711_meaningcloud.yml
# Deleting: output/en/weonetest_711_retresco.yml
# Deleting: output/en/weonetest_711_semant.yml
# Deleting: output/en/weonetest_711_simple.yml
# Deleting: output/en/weonetest_711_txtrazor.yml
# Deleting: output/en/weonetest_734_alchemy.yml
# Deleting: output/en/weonetest_734_basistech.yml
# Deleting: output/en/weonetest_734_bitext.yml
# Deleting: output/en/weonetest_734_meaningcloud.yml
# Deleting: output/en/weonetest_734_retresco.yml
# Deleting: output/en/weonetest_734_semant.yml
# Deleting: output/en/weonetest_734_simple.yml
# Deleting: output/en/weonetest_734_txtrazor.yml
# Deleting: output/en/weonetest_737_alchemy.yml
# Deleting: output/en/weonetest_737_basistech.yml
# Deleting: output/en/weonetest_737_bitext.yml
# Deleting: output/en/weonetest_737_meaningcloud.yml
# Deleting: output/en/weonetest_737_retresco.yml
# Deleting: output/en/weonetest_737_semant.yml
# Deleting: output/en/weonetest_737_simple.yml
# Deleting: output/en/weonetest_737_txtrazor.yml
# Deleting: output/en/weonetest_738_alchemy.yml
# Deleting: output/en/weonetest_738_basistech.yml
# Deleting: output/en/weonetest_738_bitext.yml
# Deleting: output/en/weonetest_738_meaningcloud.yml
# Deleting: output/en/weonetest_738_retresco.yml
# Deleting: output/en/weonetest_738_semant.yml
# Deleting: output/en/weonetest_738_simple.yml
# Deleting: output/en/weonetest_738_txtrazor.yml
# Deleting: output/en/weonetest_744_alchemy.yml
# Deleting: output/en/weonetest_744_basistech.yml
# Deleting: output/en/weonetest_744_bitext.yml
# Deleting: output/en/weonetest_744_meaningcloud.yml
# Deleting: output/en/weonetest_744_retresco.yml
# Deleting: output/en/weonetest_744_semant.yml
# Deleting: output/en/weonetest_744_simple.yml
# Deleting: output/en/weonetest_744_txtrazor.yml
# Deleting: output/en/weonetest_769_alchemy.yml
# Deleting: output/en/weonetest_769_basistech.yml
# Deleting: output/en/weonetest_769_bitext.yml
# Deleting: output/en/weonetest_769_meaningcloud.yml
# Deleting: output/en/weonetest_769_retresco.yml
# Deleting: output/en/weonetest_769_semant.yml
# Deleting: output/en/weonetest_769_simple.yml
# Deleting: output/en/weonetest_769_txtrazor.yml
# Deleting: output/en/weonetest_835_alchemy.yml
# Deleting: output/en/weonetest_835_basistech.yml
# Deleting: output/en/weonetest_835_bitext.yml
# Deleting: output/en/weonetest_835_meaningcloud.yml
# Deleting: output/en/weonetest_835_retresco.yml
# Deleting: output/en/weonetest_835_semant.yml
# Deleting: output/en/weonetest_835_simple.yml
# Deleting: output/en/weonetest_835_txtrazor.yml
# Deleting: output/en/weonetest_842_alchemy.yml
# Deleting: output/en/weonetest_842_basistech.yml
# Deleting: output/en/weonetest_842_bitext.yml
# Deleting: output/en/weonetest_842_meaningcloud.yml
# Deleting: output/en/weonetest_842_retresco.yml
# Deleting: output/en/weonetest_842_semant.yml
# Deleting: output/en/weonetest_842_simple.yml
# Deleting: output/en/weonetest_842_txtrazor.yml
# Deleting: output/en/weonetest_872_alchemy.yml
# Deleting: output/en/weonetest_872_basistech.yml
# Deleting: output/en/weonetest_872_bitext.yml
# Deleting: output/en/weonetest_872_meaningcloud.yml
# Deleting: output/en/weonetest_872_retresco.yml
# Deleting: output/en/weonetest_872_semant.yml
# Deleting: output/en/weonetest_872_simple.yml
# Deleting: output/en/weonetest_872_txtrazor.yml
# Deleting: output/en/weonetest_889_alchemy.yml
# Deleting: output/en/weonetest_889_basistech.yml
# Deleting: output/en/weonetest_889_bitext.yml
# Deleting: output/en/weonetest_889_meaningcloud.yml
# Deleting: output/en/weonetest_889_retresco.yml
# Deleting: output/en/weonetest_889_semant.yml
# Deleting: output/en/weonetest_889_simple.yml
# Deleting: output/en/weonetest_889_txtrazor.yml
# Deleting: output/en/weonetest_923_alchemy.yml
# Deleting: output/en/weonetest_923_basistech.yml
# Deleting: output/en/weonetest_923_bitext.yml
# Deleting: output/en/weonetest_923_meaningcloud.yml
# Deleting: output/en/weonetest_923_retresco.yml
# Deleting: output/en/weonetest_923_semant.yml
# Deleting: output/en/weonetest_923_simple.yml
# Deleting: output/en/weonetest_923_txtrazor.yml
# Deleting: output/en/weonetest_943_alchemy.yml
# Deleting: output/en/weonetest_943_basistech.yml
# Deleting: output/en/weonetest_943_bitext.yml
# Deleting: output/en/weonetest_943_meaningcloud.yml
# Deleting: output/en/weonetest_943_retresco.yml
# Deleting: output/en/weonetest_943_semant.yml
# Deleting: output/en/weonetest_943_simple.yml
# Deleting: output/en/weonetest_943_txtrazor.yml
# Deleting: output/en/weonetest_982_alchemy.yml
# Deleting: output/en/weonetest_982_basistech.yml
# Deleting: output/en/weonetest_982_bitext.yml
# Deleting: output/en/weonetest_982_meaningcloud.yml
# Deleting: output/en/weonetest_982_retresco.yml
# Deleting: output/en/weonetest_982_semant.yml
# Deleting: output/en/weonetest_982_simple.yml
# Deleting: output/en/weonetest_982_txtrazor.yml
# [Errno 2] No such file or directory: 'result/en'

# %%
import semaeval.source.syndication as synd

# %%
help(synd)
# Out:
# Help on module semaeval.source.syndication in semaeval.source:
#
# NAME
#     semaeval.source.syndication - # -*- coding: utf-8 -*-
#
# FILE
#     /Users/amaier1/git/semaeval/semaeval/source/syndication.py
#
# FUNCTIONS
#     article_from_path(path)
#
#     articles_from_dir(dir)
#
#     load_articles(prefix)
#
#     store_articles(articles, prefix)
#
# DATA
#     store_dir = 'input/'
#     url_regex = <_sre.SRE_Pattern object>

# %%
bild = synd.articles_from_dir("/Users/amaier1/Documents/semeval/bicotest")

# %%
welt = synd.articles_from_dir("/Users/amaier1/Documents/semeval/weonetest")

# %%
wild = bild + welt

# %%
import random
articles = random.sample(wild,50)

# %%
synd.store_articles(articles,"en")
# Out:
# Storing file:  input/en/weonetest_089.yml
# Storing file:  input/en/bicotest_080.yml
# Storing file:  input/en/bicotest_172.yml
# Storing file:  input/en/weonetest_165.yml
# Storing file:  input/en/bicotest_285.yml
# Storing file:  input/en/bicotest_218.yml
# Storing file:  input/en/bicotest_108.yml
# Storing file:  input/en/weonetest_883.yml
# Storing file:  input/en/weonetest_673.yml
# Storing file:  input/en/weonetest_790.yml
# Storing file:  input/en/weonetest_363.yml
# Storing file:  input/en/weonetest_416.yml
# Storing file:  input/en/weonetest_399.yml
# Storing file:  input/en/weonetest_624.yml
# Storing file:  input/en/weonetest_776.yml
# Storing file:  input/en/weonetest_1003.yml
# Storing file:  input/en/bicotest_008.yml
# Storing file:  input/en/bicotest_136.yml
# Storing file:  input/en/weonetest_581.yml
# Storing file:  input/en/weonetest_703.yml
# Storing file:  input/en/weonetest_902.yml
# Storing file:  input/en/weonetest_501.yml
# Storing file:  input/en/weonetest_528.yml
# Storing file:  input/en/weonetest_522.yml
# Storing file:  input/en/weonetest_041.yml
# Storing file:  input/en/bicotest_476.yml
# Storing file:  input/en/weonetest_467.yml
# Storing file:  input/en/weonetest_623.yml
# Storing file:  input/en/weonetest_383.yml
# Storing file:  input/en/weonetest_583.yml
# Storing file:  input/en/weonetest_448.yml
# Storing file:  input/en/bicotest_415.yml
# Storing file:  input/en/bicotest_280.yml
# Storing file:  input/en/weonetest_829.yml
# Storing file:  input/en/bicotest_003.yml
# Storing file:  input/en/bicotest_039.yml
# Storing file:  input/en/weonetest_469.yml
# Storing file:  input/en/bicotest_044.yml
# Storing file:  input/en/weonetest_258.yml
# Storing file:  input/en/bicotest_524.yml
# Storing file:  input/en/weonetest_417.yml
# Storing file:  input/en/bicotest_504.yml
# Storing file:  input/en/bicotest_356.yml
# Storing file:  input/en/weonetest_1165.yml
# Storing file:  input/en/weonetest_742.yml
# Storing file:  input/en/weonetest_805.yml
# Storing file:  input/en/weonetest_574.yml
# Storing file:  input/en/weonetest_890.yml
# Storing file:  input/en/weonetest_286.yml
# Storing file:  input/en/bicotest_324.yml

# %%
import semaeval.evaluate as eval

# %%
articles_enriched = eval.detect_entities(articles,"en")
# Out:
# Filename: weonetest_089.yml
# Collecting results:
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-football/2010/03/30/bastian-schweinsteiger/jogi-loew-wont-change-mind-on-kevin-kuranyi.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-football/2010/04/28/bayern-munich-start-final-countdown/olic-the-hero-of-latest-win-in-europe.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# textrazor: [u'I-Person']
# Filename: weonetest_165.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.netowl
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/06/04/gulf-of-mexico-oil-slick/could-bp-go-bust-urgent-shareholder-meeting-spill.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# bitext: 130
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/05/18/world-cup-terror-plot/iraq-al-qaeda-arrest-iraq-over-south-africa-threat.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/04/09/kim-kardashian/sexy-fhm-shoot-it-girl-leaves-paris-hilton-in-shade.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: weonetest_883.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# textrazor: [u'Device', u'InformationAppliance']
# Filename: weonetest_673.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# textrazor:bitext:alchemy: Movie
#  [u'Award']
#  4
# textrazor: [u'Award']
# textrazor: [u'Instrument']
# textrazor: [u'Award']
# textrazor: [u'Award']
# textrazor: [u'Award']
# Filename: weonetest_790.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: weonetest_363.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# semaeval.engine.basistech
# textrazor: [u'Colour']
# Filename: weonetest_416.yml
# Collecting results:
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.bitext
# semaeval.engine.retresco
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: weonetest_399.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# alchemy: OperatingSystem
# Filename: weonetest_624.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.netowl
# Filename: weonetest_776.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.netowl
# bitext: 130
# URL: http://www.welt.de/international/article3877504/Hezbollah-faces-U-S-backed-rivals-in-close-race.html#reqRSS
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-football/2010/03/04/germany-lose-to-argentina/jogi-loew-under-pressure-as-world-cup-fears-mount.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/04/19/iceland-volcano-eruption-chaos/no-respite-for-passengers-stranded-by-europe-ash-cloud.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: weonetest_581.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: weonetest_703.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: weonetest_902.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# semantria: Beverage
# Filename: weonetest_501.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.meaningcloud
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: weonetest_528.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: weonetest_522.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.basistech
# semaeval.engine.simple
# meaningcloud:TextRazor API:alchemy: Top>Process>Motion
#  Movie
#  TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
# alchemy: Movie
#
# alchemy: Movie
# Filename: weonetest_041.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.netowl
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/07/13/referee-howard-webb/world-cup-final-most-difficult-two-hours-of-my-career.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_467.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_623.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.netowl
# bitext:TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#  130
#
# Filename: weonetest_383.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.basistech
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_583.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API:basistech: IDENTIFIER:LATITUDE_LONGITUDE
#  TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_448.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/07/01/vogues-hommes-photo-shoot/is-this-really-lady-gaga-in-disguise-as-a-man.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/06/03/bka-at-team-hotel/police-protecting-germany-world-cup-stars.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_829.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/more-sport/2010/02/04/michael-schumacher-f1-setback/schumi-help-my-mercedes-car-is-too-slow.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-football/2010/03/17/barca-stuttgart-champions-league/is-it-jens-lehmanns-last-big-show.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_469.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.netowl
# TextRazor API:semantria: Sports
#  TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/03/18/angela-merkel-bundestag-debate/bild-reveals-what-chancellor-really-thinks-of-westerwelle.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# bitext:TextRazor API: 130
#  TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_258.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.netowl
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/more-sport/2010/07/22/top-earners/tiger-woods-no-1-on-sports-illustrated-2010-list-with-90m.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.txtrazor
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_417.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/07/19/oil-spill-disaster-in-gulf-of-mexico/seabed-seepage-sparks-new-leak-fears-for-bp.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/06/18/sexy-germany-wags/dfb-hires-bodyguards-as-security-in-south-africa.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.welt.de/international/article4082379/Critis-praise-loved-filled-Harry-Potter-film.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_742.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_805.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_574.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.basistech
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_890.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.alchemy
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# Filename: weonetest_286.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/06/14/sexy-world-cup-fans/looking-good-in-the-stands-in-south-africa.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.netowl
# TextRazor API:alchemy: Automobile
#  TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}

# %%
eval.store_articles(articles_enriched,"en")
# Out:
# Storing file:  output/en/weonetest_089_simple.yml
# Storing file:  output/en/weonetest_089_meaningcloud.yml
# Storing file:  output/en/weonetest_089_netowl.yml
# Storing file:  output/en/weonetest_089_retresco.yml
# Storing file:  output/en/weonetest_089_bitext.yml
# Storing file:  output/en/weonetest_089_alchemy.yml
# Storing file:  output/en/weonetest_089_txtrazor.yml
# Storing file:  output/en/weonetest_089_semant.yml
# Storing file:  output/en/weonetest_089_basistech.yml
# Storing file:  output/en/bicotest_080_simple.yml
# Storing file:  output/en/bicotest_080_meaningcloud.yml
# Storing file:  output/en/bicotest_080_netowl.yml
# Storing file:  output/en/bicotest_080_retresco.yml
# Storing file:  output/en/bicotest_080_bitext.yml
# Storing file:  output/en/bicotest_080_alchemy.yml
# Storing file:  output/en/bicotest_080_txtrazor.yml
# Storing file:  output/en/bicotest_080_semant.yml
# Storing file:  output/en/bicotest_080_basistech.yml
# Storing file:  output/en/bicotest_172_simple.yml
# Storing file:  output/en/bicotest_172_meaningcloud.yml
# Storing file:  output/en/bicotest_172_netowl.yml
# Storing file:  output/en/bicotest_172_retresco.yml
# Storing file:  output/en/bicotest_172_bitext.yml
# Storing file:  output/en/bicotest_172_alchemy.yml
# Storing file:  output/en/bicotest_172_txtrazor.yml
# Storing file:  output/en/bicotest_172_semant.yml
# Storing file:  output/en/bicotest_172_basistech.yml
# Storing file:  output/en/weonetest_165_simple.yml
# Storing file:  output/en/weonetest_165_meaningcloud.yml
# Storing file:  output/en/weonetest_165_netowl.yml
# Storing file:  output/en/weonetest_165_retresco.yml
# Storing file:  output/en/weonetest_165_bitext.yml
# Storing file:  output/en/weonetest_165_alchemy.yml
# Storing file:  output/en/weonetest_165_txtrazor.yml
# Storing file:  output/en/weonetest_165_semant.yml
# Storing file:  output/en/weonetest_165_basistech.yml
# Storing file:  output/en/bicotest_285_simple.yml
# Storing file:  output/en/bicotest_285_meaningcloud.yml
# Storing file:  output/en/bicotest_285_netowl.yml
# Storing file:  output/en/bicotest_285_retresco.yml
# Storing file:  output/en/bicotest_285_bitext.yml
# Storing file:  output/en/bicotest_285_alchemy.yml
# Storing file:  output/en/bicotest_285_txtrazor.yml
# Storing file:  output/en/bicotest_285_semant.yml
# Storing file:  output/en/bicotest_285_basistech.yml
# Storing file:  output/en/bicotest_218_simple.yml
# Storing file:  output/en/bicotest_218_meaningcloud.yml
# Storing file:  output/en/bicotest_218_netowl.yml
# Storing file:  output/en/bicotest_218_retresco.yml
# Storing file:  output/en/bicotest_218_bitext.yml
# Storing file:  output/en/bicotest_218_alchemy.yml
# Storing file:  output/en/bicotest_218_txtrazor.yml
# Storing file:  output/en/bicotest_218_semant.yml
# Storing file:  output/en/bicotest_218_basistech.yml
# Storing file:  output/en/bicotest_108_simple.yml
# Storing file:  output/en/bicotest_108_meaningcloud.yml
# Storing file:  output/en/bicotest_108_netowl.yml
# Storing file:  output/en/bicotest_108_retresco.yml
# Storing file:  output/en/bicotest_108_bitext.yml
# Storing file:  output/en/bicotest_108_alchemy.yml
# Storing file:  output/en/bicotest_108_txtrazor.yml
# Storing file:  output/en/bicotest_108_semant.yml
# Storing file:  output/en/bicotest_108_basistech.yml
# Storing file:  output/en/weonetest_883_simple.yml
# Storing file:  output/en/weonetest_883_meaningcloud.yml
# Storing file:  output/en/weonetest_883_netowl.yml
# Storing file:  output/en/weonetest_883_retresco.yml
# Storing file:  output/en/weonetest_883_bitext.yml
# Storing file:  output/en/weonetest_883_alchemy.yml
# Storing file:  output/en/weonetest_883_txtrazor.yml
# Storing file:  output/en/weonetest_883_semant.yml
# Storing file:  output/en/weonetest_883_basistech.yml
# Storing file:  output/en/weonetest_673_simple.yml
# Storing file:  output/en/weonetest_673_meaningcloud.yml
# Storing file:  output/en/weonetest_673_netowl.yml
# Storing file:  output/en/weonetest_673_retresco.yml
# Storing file:  output/en/weonetest_673_bitext.yml
# Storing file:  output/en/weonetest_673_alchemy.yml
# Storing file:  output/en/weonetest_673_txtrazor.yml
# Storing file:  output/en/weonetest_673_semant.yml
# Storing file:  output/en/weonetest_673_basistech.yml
# Storing file:  output/en/weonetest_790_simple.yml
# Storing file:  output/en/weonetest_790_meaningcloud.yml
# Storing file:  output/en/weonetest_790_netowl.yml
# Storing file:  output/en/weonetest_790_retresco.yml
# Storing file:  output/en/weonetest_790_bitext.yml
# Storing file:  output/en/weonetest_790_alchemy.yml
# Storing file:  output/en/weonetest_790_txtrazor.yml
# Storing file:  output/en/weonetest_790_semant.yml
# Storing file:  output/en/weonetest_790_basistech.yml
# Storing file:  output/en/weonetest_363_simple.yml
# Storing file:  output/en/weonetest_363_meaningcloud.yml
# Storing file:  output/en/weonetest_363_netowl.yml
# Storing file:  output/en/weonetest_363_retresco.yml
# Storing file:  output/en/weonetest_363_bitext.yml
# Storing file:  output/en/weonetest_363_alchemy.yml
# Storing file:  output/en/weonetest_363_txtrazor.yml
# Storing file:  output/en/weonetest_363_semant.yml
# Storing file:  output/en/weonetest_363_basistech.yml
# Storing file:  output/en/weonetest_416_simple.yml
# Storing file:  output/en/weonetest_416_meaningcloud.yml
# Storing file:  output/en/weonetest_416_netowl.yml
# Storing file:  output/en/weonetest_416_retresco.yml
# Storing file:  output/en/weonetest_416_bitext.yml
# Storing file:  output/en/weonetest_416_alchemy.yml
# Storing file:  output/en/weonetest_416_txtrazor.yml
# Storing file:  output/en/weonetest_416_semant.yml
# Storing file:  output/en/weonetest_416_basistech.yml
# Storing file:  output/en/weonetest_399_simple.yml
# Storing file:  output/en/weonetest_399_meaningcloud.yml
# Storing file:  output/en/weonetest_399_netowl.yml
# Storing file:  output/en/weonetest_399_retresco.yml
# Storing file:  output/en/weonetest_399_bitext.yml
# Storing file:  output/en/weonetest_399_alchemy.yml
# Storing file:  output/en/weonetest_399_txtrazor.yml
# Storing file:  output/en/weonetest_399_semant.yml
# Storing file:  output/en/weonetest_399_basistech.yml
# Storing file:  output/en/weonetest_624_simple.yml
# Storing file:  output/en/weonetest_624_meaningcloud.yml
# Storing file:  output/en/weonetest_624_netowl.yml
# Storing file:  output/en/weonetest_624_retresco.yml
# Storing file:  output/en/weonetest_624_bitext.yml
# Storing file:  output/en/weonetest_624_alchemy.yml
# Storing file:  output/en/weonetest_624_txtrazor.yml
# Storing file:  output/en/weonetest_624_semant.yml
# Storing file:  output/en/weonetest_624_basistech.yml
# Storing file:  output/en/weonetest_776_simple.yml
# Storing file:  output/en/weonetest_776_meaningcloud.yml
# Storing file:  output/en/weonetest_776_netowl.yml
# Storing file:  output/en/weonetest_776_retresco.yml
# Storing file:  output/en/weonetest_776_bitext.yml
# Storing file:  output/en/weonetest_776_alchemy.yml
# Storing file:  output/en/weonetest_776_txtrazor.yml
# Storing file:  output/en/weonetest_776_semant.yml
# Storing file:  output/en/weonetest_776_basistech.yml
# Storing file:  output/en/weonetest_1003_simple.yml
# Storing file:  output/en/weonetest_1003_meaningcloud.yml
# Storing file:  output/en/weonetest_1003_netowl.yml
# Storing file:  output/en/weonetest_1003_retresco.yml
# Storing file:  output/en/weonetest_1003_bitext.yml
# Storing file:  output/en/weonetest_1003_alchemy.yml
# Storing file:  output/en/weonetest_1003_txtrazor.yml
# Storing file:  output/en/weonetest_1003_semant.yml
# Storing file:  output/en/weonetest_1003_basistech.yml
# Storing file:  output/en/bicotest_008_simple.yml
# Storing file:  output/en/bicotest_008_meaningcloud.yml
# Storing file:  output/en/bicotest_008_netowl.yml
# Storing file:  output/en/bicotest_008_retresco.yml
# Storing file:  output/en/bicotest_008_bitext.yml
# Storing file:  output/en/bicotest_008_alchemy.yml
# Storing file:  output/en/bicotest_008_txtrazor.yml
# Storing file:  output/en/bicotest_008_semant.yml
# Storing file:  output/en/bicotest_008_basistech.yml
# Storing file:  output/en/bicotest_136_simple.yml
# Storing file:  output/en/bicotest_136_meaningcloud.yml
# Storing file:  output/en/bicotest_136_netowl.yml
# Storing file:  output/en/bicotest_136_retresco.yml
# Storing file:  output/en/bicotest_136_bitext.yml
# Storing file:  output/en/bicotest_136_alchemy.yml
# Storing file:  output/en/bicotest_136_txtrazor.yml
# Storing file:  output/en/bicotest_136_semant.yml
# Storing file:  output/en/bicotest_136_basistech.yml
# Storing file:  output/en/weonetest_581_simple.yml
# Storing file:  output/en/weonetest_581_meaningcloud.yml
# Storing file:  output/en/weonetest_581_netowl.yml
# Storing file:  output/en/weonetest_581_retresco.yml
# Storing file:  output/en/weonetest_581_bitext.yml
# Storing file:  output/en/weonetest_581_alchemy.yml
# Storing file:  output/en/weonetest_581_txtrazor.yml
# Storing file:  output/en/weonetest_581_semant.yml
# Storing file:  output/en/weonetest_581_basistech.yml
# Storing file:  output/en/weonetest_703_simple.yml
# Storing file:  output/en/weonetest_703_meaningcloud.yml
# Storing file:  output/en/weonetest_703_netowl.yml
# Storing file:  output/en/weonetest_703_retresco.yml
# Storing file:  output/en/weonetest_703_bitext.yml
# Storing file:  output/en/weonetest_703_alchemy.yml
# Storing file:  output/en/weonetest_703_txtrazor.yml
# Storing file:  output/en/weonetest_703_semant.yml
# Storing file:  output/en/weonetest_703_basistech.yml
# Storing file:  output/en/weonetest_902_simple.yml
# Storing file:  output/en/weonetest_902_meaningcloud.yml
# Storing file:  output/en/weonetest_902_netowl.yml
# Storing file:  output/en/weonetest_902_retresco.yml
# Storing file:  output/en/weonetest_902_bitext.yml
# Storing file:  output/en/weonetest_902_alchemy.yml
# Storing file:  output/en/weonetest_902_txtrazor.yml
# Storing file:  output/en/weonetest_902_semant.yml
# Storing file:  output/en/weonetest_902_basistech.yml
# Storing file:  output/en/weonetest_501_simple.yml
# Storing file:  output/en/weonetest_501_meaningcloud.yml
# Storing file:  output/en/weonetest_501_netowl.yml
# Storing file:  output/en/weonetest_501_retresco.yml
# Storing file:  output/en/weonetest_501_bitext.yml
# Storing file:  output/en/weonetest_501_alchemy.yml
# Storing file:  output/en/weonetest_501_txtrazor.yml
# Storing file:  output/en/weonetest_501_semant.yml
# Storing file:  output/en/weonetest_501_basistech.yml
# Storing file:  output/en/weonetest_528_simple.yml
# Storing file:  output/en/weonetest_528_meaningcloud.yml
# Storing file:  output/en/weonetest_528_netowl.yml
# Storing file:  output/en/weonetest_528_retresco.yml
# Storing file:  output/en/weonetest_528_bitext.yml
# Storing file:  output/en/weonetest_528_alchemy.yml
# Storing file:  output/en/weonetest_528_txtrazor.yml
# Storing file:  output/en/weonetest_528_semant.yml
# Storing file:  output/en/weonetest_528_basistech.yml
# Storing file:  output/en/weonetest_522_simple.yml
# Storing file:  output/en/weonetest_522_meaningcloud.yml
# Storing file:  output/en/weonetest_522_netowl.yml
# Storing file:  output/en/weonetest_522_retresco.yml
# Storing file:  output/en/weonetest_522_bitext.yml
# Storing file:  output/en/weonetest_522_alchemy.yml
# Storing file:  output/en/weonetest_522_txtrazor.yml
# Storing file:  output/en/weonetest_522_semant.yml
# Storing file:  output/en/weonetest_522_basistech.yml
# Storing file:  output/en/weonetest_041_simple.yml
# Storing file:  output/en/weonetest_041_meaningcloud.yml
# Storing file:  output/en/weonetest_041_netowl.yml
# Storing file:  output/en/weonetest_041_retresco.yml
# Storing file:  output/en/weonetest_041_bitext.yml
# Storing file:  output/en/weonetest_041_alchemy.yml
# Storing file:  output/en/weonetest_041_txtrazor.yml
# Storing file:  output/en/weonetest_041_semant.yml
# Storing file:  output/en/weonetest_041_basistech.yml
# Storing file:  output/en/bicotest_476_simple.yml
# Storing file:  output/en/bicotest_476_meaningcloud.yml
# Storing file:  output/en/bicotest_476_netowl.yml
# Storing file:  output/en/bicotest_476_retresco.yml
# Storing file:  output/en/bicotest_476_bitext.yml
# Storing file:  output/en/bicotest_476_alchemy.yml
# Storing file:  output/en/bicotest_476_txtrazor.yml
# Storing file:  output/en/bicotest_476_semant.yml
# Storing file:  output/en/bicotest_476_basistech.yml
# Storing file:  output/en/weonetest_467_simple.yml
# Storing file:  output/en/weonetest_467_meaningcloud.yml
# Storing file:  output/en/weonetest_467_netowl.yml
# Storing file:  output/en/weonetest_467_retresco.yml
# Storing file:  output/en/weonetest_467_bitext.yml
# Storing file:  output/en/weonetest_467_alchemy.yml
# Storing file:  output/en/weonetest_467_txtrazor.yml
# Storing file:  output/en/weonetest_467_semant.yml
# Storing file:  output/en/weonetest_467_basistech.yml
# Storing file:  output/en/weonetest_623_simple.yml
# Storing file:  output/en/weonetest_623_meaningcloud.yml
# Storing file:  output/en/weonetest_623_netowl.yml
# Storing file:  output/en/weonetest_623_retresco.yml
# Storing file:  output/en/weonetest_623_bitext.yml
# Storing file:  output/en/weonetest_623_alchemy.yml
# Storing file:  output/en/weonetest_623_txtrazor.yml
# Storing file:  output/en/weonetest_623_semant.yml
# Storing file:  output/en/weonetest_623_basistech.yml
# Storing file:  output/en/weonetest_383_simple.yml
# Storing file:  output/en/weonetest_383_meaningcloud.yml
# Storing file:  output/en/weonetest_383_netowl.yml
# Storing file:  output/en/weonetest_383_retresco.yml
# Storing file:  output/en/weonetest_383_bitext.yml
# Storing file:  output/en/weonetest_383_alchemy.yml
# Storing file:  output/en/weonetest_383_txtrazor.yml
# Storing file:  output/en/weonetest_383_semant.yml
# Storing file:  output/en/weonetest_383_basistech.yml
# Storing file:  output/en/weonetest_583_simple.yml
# Storing file:  output/en/weonetest_583_meaningcloud.yml
# Storing file:  output/en/weonetest_583_netowl.yml
# Storing file:  output/en/weonetest_583_retresco.yml
# Storing file:  output/en/weonetest_583_bitext.yml
# Storing file:  output/en/weonetest_583_alchemy.yml
# Storing file:  output/en/weonetest_583_txtrazor.yml
# Storing file:  output/en/weonetest_583_semant.yml
# Storing file:  output/en/weonetest_583_basistech.yml
# Storing file:  output/en/weonetest_448_simple.yml
# Storing file:  output/en/weonetest_448_meaningcloud.yml
# Storing file:  output/en/weonetest_448_netowl.yml
# Storing file:  output/en/weonetest_448_retresco.yml
# Storing file:  output/en/weonetest_448_bitext.yml
# Storing file:  output/en/weonetest_448_alchemy.yml
# Storing file:  output/en/weonetest_448_txtrazor.yml
# Storing file:  output/en/weonetest_448_semant.yml
# Storing file:  output/en/weonetest_448_basistech.yml
# Storing file:  output/en/bicotest_415_simple.yml
# Storing file:  output/en/bicotest_415_meaningcloud.yml
# Storing file:  output/en/bicotest_415_netowl.yml
# Storing file:  output/en/bicotest_415_retresco.yml
# Storing file:  output/en/bicotest_415_bitext.yml
# Storing file:  output/en/bicotest_415_alchemy.yml
# Storing file:  output/en/bicotest_415_txtrazor.yml
# Storing file:  output/en/bicotest_415_semant.yml
# Storing file:  output/en/bicotest_415_basistech.yml
# Storing file:  output/en/bicotest_280_simple.yml
# Storing file:  output/en/bicotest_280_meaningcloud.yml
# Storing file:  output/en/bicotest_280_netowl.yml
# Storing file:  output/en/bicotest_280_retresco.yml
# Storing file:  output/en/bicotest_280_bitext.yml
# Storing file:  output/en/bicotest_280_alchemy.yml
# Storing file:  output/en/bicotest_280_txtrazor.yml
# Storing file:  output/en/bicotest_280_semant.yml
# Storing file:  output/en/bicotest_280_basistech.yml
# Storing file:  output/en/weonetest_829_simple.yml
# Storing file:  output/en/weonetest_829_meaningcloud.yml
# Storing file:  output/en/weonetest_829_netowl.yml
# Storing file:  output/en/weonetest_829_retresco.yml
# Storing file:  output/en/weonetest_829_bitext.yml
# Storing file:  output/en/weonetest_829_alchemy.yml
# Storing file:  output/en/weonetest_829_txtrazor.yml
# Storing file:  output/en/weonetest_829_semant.yml
# Storing file:  output/en/weonetest_829_basistech.yml
# Storing file:  output/en/bicotest_003_simple.yml
# Storing file:  output/en/bicotest_003_meaningcloud.yml
# Storing file:  output/en/bicotest_003_netowl.yml
# Storing file:  output/en/bicotest_003_retresco.yml
# Storing file:  output/en/bicotest_003_bitext.yml
# Storing file:  output/en/bicotest_003_alchemy.yml
# Storing file:  output/en/bicotest_003_txtrazor.yml
# Storing file:  output/en/bicotest_003_semant.yml
# Storing file:  output/en/bicotest_003_basistech.yml
# Storing file:  output/en/bicotest_039_simple.yml
# Storing file:  output/en/bicotest_039_meaningcloud.yml
# Storing file:  output/en/bicotest_039_netowl.yml
# Storing file:  output/en/bicotest_039_retresco.yml
# Storing file:  output/en/bicotest_039_bitext.yml
# Storing file:  output/en/bicotest_039_alchemy.yml
# Storing file:  output/en/bicotest_039_txtrazor.yml
# Storing file:  output/en/bicotest_039_semant.yml
# Storing file:  output/en/bicotest_039_basistech.yml
# Storing file:  output/en/weonetest_469_simple.yml
# Storing file:  output/en/weonetest_469_meaningcloud.yml
# Storing file:  output/en/weonetest_469_netowl.yml
# Storing file:  output/en/weonetest_469_retresco.yml
# Storing file:  output/en/weonetest_469_bitext.yml
# Storing file:  output/en/weonetest_469_alchemy.yml
# Storing file:  output/en/weonetest_469_txtrazor.yml
# Storing file:  output/en/weonetest_469_semant.yml
# Storing file:  output/en/weonetest_469_basistech.yml
# Storing file:  output/en/bicotest_044_simple.yml
# Storing file:  output/en/bicotest_044_meaningcloud.yml
# Storing file:  output/en/bicotest_044_netowl.yml
# Storing file:  output/en/bicotest_044_retresco.yml
# Storing file:  output/en/bicotest_044_bitext.yml
# Storing file:  output/en/bicotest_044_alchemy.yml
# Storing file:  output/en/bicotest_044_txtrazor.yml
# Storing file:  output/en/bicotest_044_semant.yml
# Storing file:  output/en/bicotest_044_basistech.yml
# Storing file:  output/en/weonetest_258_simple.yml
# Storing file:  output/en/weonetest_258_meaningcloud.yml
# Storing file:  output/en/weonetest_258_netowl.yml
# Storing file:  output/en/weonetest_258_retresco.yml
# Storing file:  output/en/weonetest_258_bitext.yml
# Storing file:  output/en/weonetest_258_alchemy.yml
# Storing file:  output/en/weonetest_258_txtrazor.yml
# Storing file:  output/en/weonetest_258_semant.yml
# Storing file:  output/en/weonetest_258_basistech.yml
# Storing file:  output/en/bicotest_524_simple.yml
# Storing file:  output/en/bicotest_524_meaningcloud.yml
# Storing file:  output/en/bicotest_524_netowl.yml
# Storing file:  output/en/bicotest_524_retresco.yml
# Storing file:  output/en/bicotest_524_bitext.yml
# Storing file:  output/en/bicotest_524_alchemy.yml
# Storing file:  output/en/bicotest_524_txtrazor.yml
# Storing file:  output/en/bicotest_524_semant.yml
# Storing file:  output/en/bicotest_524_basistech.yml
# Storing file:  output/en/weonetest_417_simple.yml
# Storing file:  output/en/weonetest_417_meaningcloud.yml
# Storing file:  output/en/weonetest_417_netowl.yml
# Storing file:  output/en/weonetest_417_retresco.yml
# Storing file:  output/en/weonetest_417_bitext.yml
# Storing file:  output/en/weonetest_417_alchemy.yml
# Storing file:  output/en/weonetest_417_txtrazor.yml
# Storing file:  output/en/weonetest_417_semant.yml
# Storing file:  output/en/weonetest_417_basistech.yml
# Storing file:  output/en/bicotest_504_simple.yml
# Storing file:  output/en/bicotest_504_meaningcloud.yml
# Storing file:  output/en/bicotest_504_netowl.yml
# Storing file:  output/en/bicotest_504_retresco.yml
# Storing file:  output/en/bicotest_504_bitext.yml
# Storing file:  output/en/bicotest_504_alchemy.yml
# Storing file:  output/en/bicotest_504_txtrazor.yml
# Storing file:  output/en/bicotest_504_semant.yml
# Storing file:  output/en/bicotest_504_basistech.yml
# Storing file:  output/en/bicotest_356_simple.yml
# Storing file:  output/en/bicotest_356_meaningcloud.yml
# Storing file:  output/en/bicotest_356_netowl.yml
# Storing file:  output/en/bicotest_356_retresco.yml
# Storing file:  output/en/bicotest_356_bitext.yml
# Storing file:  output/en/bicotest_356_alchemy.yml
# Storing file:  output/en/bicotest_356_txtrazor.yml
# Storing file:  output/en/bicotest_356_semant.yml
# Storing file:  output/en/bicotest_356_basistech.yml
# Storing file:  output/en/weonetest_1165_simple.yml
# Storing file:  output/en/weonetest_1165_meaningcloud.yml
# Storing file:  output/en/weonetest_1165_netowl.yml
# Storing file:  output/en/weonetest_1165_retresco.yml
# Storing file:  output/en/weonetest_1165_bitext.yml
# Storing file:  output/en/weonetest_1165_alchemy.yml
# Storing file:  output/en/weonetest_1165_txtrazor.yml
# Storing file:  output/en/weonetest_1165_semant.yml
# Storing file:  output/en/weonetest_1165_basistech.yml
# Storing file:  output/en/weonetest_742_simple.yml
# Storing file:  output/en/weonetest_742_meaningcloud.yml
# Storing file:  output/en/weonetest_742_netowl.yml
# Storing file:  output/en/weonetest_742_retresco.yml
# Storing file:  output/en/weonetest_742_bitext.yml
# Storing file:  output/en/weonetest_742_alchemy.yml
# Storing file:  output/en/weonetest_742_txtrazor.yml
# Storing file:  output/en/weonetest_742_semant.yml
# Storing file:  output/en/weonetest_742_basistech.yml
# Storing file:  output/en/weonetest_805_simple.yml
# Storing file:  output/en/weonetest_805_meaningcloud.yml
# Storing file:  output/en/weonetest_805_netowl.yml
# Storing file:  output/en/weonetest_805_retresco.yml
# Storing file:  output/en/weonetest_805_bitext.yml
# Storing file:  output/en/weonetest_805_alchemy.yml
# Storing file:  output/en/weonetest_805_txtrazor.yml
# Storing file:  output/en/weonetest_805_semant.yml
# Storing file:  output/en/weonetest_805_basistech.yml
# Storing file:  output/en/weonetest_574_simple.yml
# Storing file:  output/en/weonetest_574_meaningcloud.yml
# Storing file:  output/en/weonetest_574_netowl.yml
# Storing file:  output/en/weonetest_574_retresco.yml
# Storing file:  output/en/weonetest_574_bitext.yml
# Storing file:  output/en/weonetest_574_alchemy.yml
# Storing file:  output/en/weonetest_574_txtrazor.yml
# Storing file:  output/en/weonetest_574_semant.yml
# Storing file:  output/en/weonetest_574_basistech.yml
# Storing file:  output/en/weonetest_890_simple.yml
# Storing file:  output/en/weonetest_890_meaningcloud.yml
# Storing file:  output/en/weonetest_890_netowl.yml
# Storing file:  output/en/weonetest_890_retresco.yml
# Storing file:  output/en/weonetest_890_bitext.yml
# Storing file:  output/en/weonetest_890_alchemy.yml
# Storing file:  output/en/weonetest_890_txtrazor.yml
# Storing file:  output/en/weonetest_890_semant.yml
# Storing file:  output/en/weonetest_890_basistech.yml
# Storing file:  output/en/weonetest_286_simple.yml
# Storing file:  output/en/weonetest_286_meaningcloud.yml
# Storing file:  output/en/weonetest_286_netowl.yml
# Storing file:  output/en/weonetest_286_retresco.yml
# Storing file:  output/en/weonetest_286_bitext.yml
# Storing file:  output/en/weonetest_286_alchemy.yml
# Storing file:  output/en/weonetest_286_txtrazor.yml
# Storing file:  output/en/weonetest_286_semant.yml
# Storing file:  output/en/weonetest_286_basistech.yml
# Storing file:  output/en/bicotest_324_simple.yml
# Storing file:  output/en/bicotest_324_meaningcloud.yml
# Storing file:  output/en/bicotest_324_netowl.yml
# Storing file:  output/en/bicotest_324_retresco.yml
# Storing file:  output/en/bicotest_324_bitext.yml
# Storing file:  output/en/bicotest_324_alchemy.yml
# Storing file:  output/en/bicotest_324_txtrazor.yml
# Storing file:  output/en/bicotest_324_semant.yml
# Storing file:  output/en/bicotest_324_basistech.yml

# %%
import semaeval.statistics as stats

# %%
data=stats.collect_data(articles_enriched)
# Out:
# meaningcloud weonetest_089.yml float division by zero
# bitext weonetest_089.yml float division by zero
# semant weonetest_089.yml float division by zero
# meaningcloud bicotest_080.yml float division by zero
# semant bicotest_080.yml float division by zero
# meaningcloud bicotest_172.yml float division by zero
# semant bicotest_172.yml float division by zero
# meaningcloud weonetest_165.yml float division by zero
# retresco weonetest_165.yml float division by zero
# semant weonetest_165.yml float division by zero
# simple bicotest_218.yml float division by zero
# meaningcloud bicotest_218.yml float division by zero
# retresco bicotest_218.yml float division by zero
# bitext bicotest_218.yml float division by zero
# txtrazor bicotest_218.yml float division by zero
# semant bicotest_218.yml float division by zero
# meaningcloud bicotest_108.yml float division by zero
# retresco bicotest_108.yml float division by zero
# retresco bicotest_108.yml float division by zero
# bitext bicotest_108.yml float division by zero
# semant bicotest_108.yml float division by zero
# semant bicotest_108.yml float division by zero
# semant weonetest_883.yml float division by zero
# meaningcloud weonetest_673.yml float division by zero
# retresco weonetest_673.yml float division by zero
# semant weonetest_673.yml float division by zero
# meaningcloud weonetest_790.yml float division by zero
# retresco weonetest_790.yml float division by zero
# semant weonetest_790.yml float division by zero
# semant weonetest_363.yml float division by zero
# meaningcloud weonetest_399.yml float division by zero
# retresco weonetest_399.yml float division by zero
# retresco weonetest_399.yml float division by zero
# semant weonetest_399.yml float division by zero
# semant weonetest_399.yml float division by zero
# simple weonetest_624.yml float division by zero
# retresco weonetest_624.yml float division by zero
# semant weonetest_624.yml float division by zero
# meaningcloud weonetest_776.yml float division by zero
# meaningcloud weonetest_776.yml float division by zero
# bitext weonetest_776.yml float division by zero
# bitext weonetest_776.yml float division by zero
# semant weonetest_776.yml float division by zero
# semant weonetest_1003.yml float division by zero
# txtrazor bicotest_008.yml float division by zero
# semant bicotest_008.yml float division by zero
# meaningcloud bicotest_136.yml float division by zero
# simple weonetest_581.yml float division by zero
# meaningcloud weonetest_581.yml float division by zero
# meaningcloud weonetest_581.yml float division by zero
# netowl weonetest_581.yml float division by zero
# retresco weonetest_581.yml float division by zero
# bitext weonetest_581.yml float division by zero
# alchemy weonetest_581.yml float division by zero
# txtrazor weonetest_581.yml float division by zero
# semant weonetest_581.yml float division by zero
# basistech weonetest_581.yml float division by zero
# meaningcloud weonetest_703.yml float division by zero
# retresco weonetest_703.yml float division by zero
# semant weonetest_703.yml float division by zero
# meaningcloud weonetest_902.yml float division by zero
# retresco weonetest_902.yml float division by zero
# retresco weonetest_902.yml float division by zero
# bitext weonetest_902.yml float division by zero
# bitext weonetest_902.yml float division by zero
# txtrazor weonetest_902.yml float division by zero
# semant weonetest_902.yml float division by zero
# semant weonetest_902.yml float division by zero
# basistech weonetest_902.yml float division by zero
# meaningcloud weonetest_501.yml float division by zero
# retresco weonetest_501.yml float division by zero
# semant weonetest_501.yml float division by zero
# semant weonetest_501.yml float division by zero
# txtrazor weonetest_528.yml float division by zero
# txtrazor weonetest_528.yml float division by zero
# txtrazor weonetest_528.yml float division by zero
# bitext weonetest_522.yml float division by zero
# txtrazor weonetest_522.yml float division by zero
# txtrazor weonetest_522.yml float division by zero
# txtrazor weonetest_522.yml float division by zero
# semant weonetest_522.yml float division by zero
# simple weonetest_041.yml float division by zero
# meaningcloud weonetest_041.yml float division by zero
# netowl weonetest_041.yml float division by zero
# retresco weonetest_041.yml float division by zero
# bitext weonetest_041.yml float division by zero
# txtrazor weonetest_041.yml float division by zero
# txtrazor weonetest_041.yml float division by zero
# txtrazor weonetest_041.yml float division by zero
# semant weonetest_041.yml float division by zero
# meaningcloud bicotest_476.yml float division by zero
# alchemy bicotest_476.yml float division by zero
# txtrazor bicotest_476.yml float division by zero
# txtrazor bicotest_476.yml float division by zero
# txtrazor bicotest_476.yml float division by zero
# semant bicotest_476.yml float division by zero
# meaningcloud weonetest_467.yml float division by zero
# retresco weonetest_467.yml float division by zero
# txtrazor weonetest_467.yml float division by zero
# txtrazor weonetest_467.yml float division by zero
# txtrazor weonetest_467.yml float division by zero
# txtrazor weonetest_623.yml float division by zero
# txtrazor weonetest_623.yml float division by zero
# txtrazor weonetest_623.yml float division by zero
# semant weonetest_623.yml float division by zero
# semant weonetest_623.yml float division by zero
# simple weonetest_383.yml float division by zero
# meaningcloud weonetest_383.yml float division by zero
# retresco weonetest_383.yml float division by zero
# retresco weonetest_383.yml float division by zero
# bitext weonetest_383.yml float division by zero
# alchemy weonetest_383.yml float division by zero
# txtrazor weonetest_383.yml float division by zero
# txtrazor weonetest_383.yml float division by zero
# txtrazor weonetest_383.yml float division by zero
# semant weonetest_383.yml float division by zero
# semant weonetest_383.yml float division by zero
# basistech weonetest_383.yml float division by zero
# meaningcloud weonetest_583.yml float division by zero
# txtrazor weonetest_583.yml float division by zero
# txtrazor weonetest_583.yml float division by zero
# txtrazor weonetest_583.yml float division by zero
# txtrazor weonetest_448.yml float division by zero
# txtrazor weonetest_448.yml float division by zero
# txtrazor weonetest_448.yml float division by zero
# semant weonetest_448.yml float division by zero
# semant weonetest_448.yml float division by zero
# meaningcloud bicotest_415.yml float division by zero
# meaningcloud bicotest_415.yml float division by zero
# netowl bicotest_415.yml float division by zero
# retresco bicotest_415.yml float division by zero
# bitext bicotest_415.yml float division by zero
# alchemy bicotest_415.yml float division by zero
# txtrazor bicotest_415.yml float division by zero
# txtrazor bicotest_415.yml float division by zero
# txtrazor bicotest_415.yml float division by zero
# semant bicotest_415.yml float division by zero
# semant bicotest_415.yml float division by zero
# meaningcloud bicotest_280.yml float division by zero
# bitext bicotest_280.yml float division by zero
# txtrazor bicotest_280.yml float division by zero
# txtrazor bicotest_280.yml float division by zero
# txtrazor bicotest_280.yml float division by zero
# meaningcloud weonetest_829.yml float division by zero
# txtrazor weonetest_829.yml float division by zero
# txtrazor weonetest_829.yml float division by zero
# txtrazor weonetest_829.yml float division by zero
# meaningcloud bicotest_003.yml float division by zero
# txtrazor bicotest_003.yml float division by zero
# txtrazor bicotest_003.yml float division by zero
# txtrazor bicotest_003.yml float division by zero
# meaningcloud bicotest_039.yml float division by zero
# txtrazor bicotest_039.yml float division by zero
# txtrazor bicotest_039.yml float division by zero
# txtrazor bicotest_039.yml float division by zero
# semant bicotest_039.yml float division by zero
# meaningcloud weonetest_469.yml float division by zero
# retresco weonetest_469.yml float division by zero
# retresco weonetest_469.yml float division by zero
# retresco weonetest_469.yml float division by zero
# bitext weonetest_469.yml float division by zero
# bitext weonetest_469.yml float division by zero
# txtrazor weonetest_469.yml float division by zero
# txtrazor weonetest_469.yml float division by zero
# txtrazor weonetest_469.yml float division by zero
# semant weonetest_469.yml float division by zero
# semant weonetest_469.yml float division by zero
# semant weonetest_469.yml float division by zero
# basistech weonetest_469.yml float division by zero
# simple bicotest_044.yml float division by zero
# meaningcloud bicotest_044.yml float division by zero
# meaningcloud bicotest_044.yml float division by zero
# netowl bicotest_044.yml float division by zero
# retresco bicotest_044.yml float division by zero
# bitext bicotest_044.yml float division by zero
# bitext bicotest_044.yml float division by zero
# alchemy bicotest_044.yml float division by zero
# txtrazor bicotest_044.yml float division by zero
# txtrazor bicotest_044.yml float division by zero
# txtrazor bicotest_044.yml float division by zero
# semant bicotest_044.yml float division by zero
# semant bicotest_044.yml float division by zero
# basistech bicotest_044.yml float division by zero
# retresco weonetest_258.yml float division by zero
# bitext weonetest_258.yml float division by zero
# txtrazor weonetest_258.yml float division by zero
# txtrazor weonetest_258.yml float division by zero
# txtrazor weonetest_258.yml float division by zero
# semant weonetest_258.yml float division by zero
# simple bicotest_524.yml float division by zero
# meaningcloud bicotest_524.yml float division by zero
# meaningcloud bicotest_524.yml float division by zero
# retresco bicotest_524.yml float division by zero
# bitext bicotest_524.yml float division by zero
# bitext bicotest_524.yml float division by zero
# alchemy bicotest_524.yml float division by zero
# txtrazor bicotest_524.yml float division by zero
# txtrazor bicotest_524.yml float division by zero
# txtrazor bicotest_524.yml float division by zero
# semant bicotest_524.yml float division by zero
# basistech bicotest_524.yml float division by zero
# meaningcloud weonetest_417.yml float division by zero
# retresco weonetest_417.yml float division by zero
# txtrazor weonetest_417.yml float division by zero
# txtrazor weonetest_417.yml float division by zero
# txtrazor weonetest_417.yml float division by zero
# simple bicotest_504.yml float division by zero
# meaningcloud bicotest_504.yml float division by zero
# retresco bicotest_504.yml float division by zero
# txtrazor bicotest_504.yml float division by zero
# txtrazor bicotest_504.yml float division by zero
# txtrazor bicotest_504.yml float division by zero
# semant bicotest_504.yml float division by zero
# meaningcloud bicotest_356.yml float division by zero
# netowl bicotest_356.yml float division by zero
# bitext bicotest_356.yml float division by zero
# txtrazor bicotest_356.yml float division by zero
# txtrazor bicotest_356.yml float division by zero
# txtrazor bicotest_356.yml float division by zero
# semant bicotest_356.yml float division by zero
# meaningcloud weonetest_1165.yml float division by zero
# bitext weonetest_1165.yml float division by zero
# txtrazor weonetest_1165.yml float division by zero
# txtrazor weonetest_1165.yml float division by zero
# txtrazor weonetest_1165.yml float division by zero
# semant weonetest_1165.yml float division by zero
# semant weonetest_1165.yml float division by zero
# txtrazor weonetest_742.yml float division by zero
# txtrazor weonetest_742.yml float division by zero
# txtrazor weonetest_742.yml float division by zero
# simple weonetest_805.yml float division by zero
# simple weonetest_805.yml float division by zero
# meaningcloud weonetest_805.yml float division by zero
# meaningcloud weonetest_805.yml float division by zero
# netowl weonetest_805.yml float division by zero
# retresco weonetest_805.yml float division by zero
# bitext weonetest_805.yml float division by zero
# alchemy weonetest_805.yml float division by zero
# txtrazor weonetest_805.yml float division by zero
# txtrazor weonetest_805.yml float division by zero
# txtrazor weonetest_805.yml float division by zero
# semant weonetest_805.yml float division by zero
# semant weonetest_805.yml float division by zero
# basistech weonetest_805.yml float division by zero
# meaningcloud weonetest_574.yml float division by zero
# txtrazor weonetest_574.yml float division by zero
# txtrazor weonetest_574.yml float division by zero
# txtrazor weonetest_574.yml float division by zero
# semant weonetest_574.yml float division by zero
# semant weonetest_574.yml float division by zero
# txtrazor weonetest_890.yml float division by zero
# txtrazor weonetest_890.yml float division by zero
# txtrazor weonetest_890.yml float division by zero
# semant weonetest_890.yml float division by zero
# txtrazor weonetest_286.yml float division by zero
# txtrazor weonetest_286.yml float division by zero
# txtrazor weonetest_286.yml float division by zero
# semant weonetest_286.yml float division by zero
# meaningcloud bicotest_324.yml float division by zero
# netowl bicotest_324.yml float division by zero
# retresco bicotest_324.yml float division by zero
# retresco bicotest_324.yml float division by zero
# bitext bicotest_324.yml float division by zero
# txtrazor bicotest_324.yml float division by zero
# txtrazor bicotest_324.yml float division by zero
# txtrazor bicotest_324.yml float division by zero
# semant bicotest_324.yml float division by zero
# basistech bicotest_324.yml float division by zero

# %%
results=stats.aggregate_result(data)

# %%
results.extend(stats.compute_total(results))

# %%
# %matplotlib inline

# %%
stats.plot_results(results)

# %%
stats.store_results(results,"en")
# Out:
# Storing file:  en_results.yml
