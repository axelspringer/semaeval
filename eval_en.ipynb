# %%
import semaeval.util as util
util.clean_storage("en")
# Out:
# Deleting: input/en/bicotest_054.yml
# Deleting: input/en/bicotest_059.yml
# Deleting: input/en/bicotest_065.yml
# Deleting: input/en/bicotest_182.yml
# Deleting: input/en/bicotest_191.yml
# Deleting: input/en/bicotest_234.yml
# Deleting: input/en/bicotest_235.yml
# Deleting: input/en/bicotest_279.yml
# Deleting: input/en/bicotest_286.yml
# Deleting: input/en/bicotest_331.yml
# Deleting: input/en/bicotest_360.yml
# Deleting: input/en/bicotest_399.yml
# Deleting: input/en/bicotest_475.yml
# Deleting: input/en/bicotest_546.yml
# Deleting: input/en/bicotest_551.yml
# Deleting: input/en/bicotest_587.yml
# Deleting: input/en/weonetest_082.yml
# Deleting: input/en/weonetest_105.yml
# Deleting: input/en/weonetest_1076.yml
# Deleting: input/en/weonetest_1125.yml
# Deleting: input/en/weonetest_1149.yml
# Deleting: input/en/weonetest_1157.yml
# Deleting: input/en/weonetest_1217.yml
# Deleting: input/en/weonetest_177.yml
# Deleting: input/en/weonetest_188.yml
# Deleting: input/en/weonetest_409.yml
# Deleting: input/en/weonetest_439.yml
# Deleting: input/en/weonetest_481.yml
# Deleting: input/en/weonetest_509.yml
# Deleting: input/en/weonetest_556.yml
# Deleting: input/en/weonetest_583.yml
# Deleting: input/en/weonetest_611.yml
# Deleting: input/en/weonetest_626.yml
# Deleting: input/en/weonetest_661.yml
# Deleting: input/en/weonetest_674.yml
# Deleting: input/en/weonetest_685.yml
# Deleting: input/en/weonetest_711.yml
# Deleting: input/en/weonetest_751.yml
# Deleting: input/en/weonetest_755.yml
# Deleting: input/en/weonetest_772.yml
# Deleting: input/en/weonetest_776.yml
# Deleting: input/en/weonetest_802.yml
# Deleting: input/en/weonetest_821.yml
# Deleting: input/en/weonetest_826.yml
# Deleting: input/en/weonetest_873.yml
# Deleting: input/en/weonetest_887.yml
# Deleting: input/en/weonetest_895.yml
# Deleting: input/en/weonetest_897.yml
# Deleting: input/en/weonetest_980.yml
# Deleting: input/en/weonetest_982.yml
# Deleting: output/en/bicotest_054_alchemy.yml
# Deleting: output/en/bicotest_054_bitext.yml
# Deleting: output/en/bicotest_054_linguasys.yml
# Deleting: output/en/bicotest_054_meaningcloud.yml
# Deleting: output/en/bicotest_054_retresco.yml
# Deleting: output/en/bicotest_054_semant.yml
# Deleting: output/en/bicotest_054_simple.yml
# Deleting: output/en/bicotest_054_txtrazor.yml
# Deleting: output/en/bicotest_059_alchemy.yml
# Deleting: output/en/bicotest_059_bitext.yml
# Deleting: output/en/bicotest_059_linguasys.yml
# Deleting: output/en/bicotest_059_meaningcloud.yml
# Deleting: output/en/bicotest_059_retresco.yml
# Deleting: output/en/bicotest_059_semant.yml
# Deleting: output/en/bicotest_059_simple.yml
# Deleting: output/en/bicotest_059_txtrazor.yml
# Deleting: output/en/bicotest_065_alchemy.yml
# Deleting: output/en/bicotest_065_bitext.yml
# Deleting: output/en/bicotest_065_linguasys.yml
# Deleting: output/en/bicotest_065_meaningcloud.yml
# Deleting: output/en/bicotest_065_retresco.yml
# Deleting: output/en/bicotest_065_semant.yml
# Deleting: output/en/bicotest_065_simple.yml
# Deleting: output/en/bicotest_065_txtrazor.yml
# Deleting: output/en/bicotest_182_alchemy.yml
# Deleting: output/en/bicotest_182_bitext.yml
# Deleting: output/en/bicotest_182_linguasys.yml
# Deleting: output/en/bicotest_182_meaningcloud.yml
# Deleting: output/en/bicotest_182_retresco.yml
# Deleting: output/en/bicotest_182_semant.yml
# Deleting: output/en/bicotest_182_simple.yml
# Deleting: output/en/bicotest_182_txtrazor.yml
# Deleting: output/en/bicotest_191_alchemy.yml
# Deleting: output/en/bicotest_191_bitext.yml
# Deleting: output/en/bicotest_191_linguasys.yml
# Deleting: output/en/bicotest_191_meaningcloud.yml
# Deleting: output/en/bicotest_191_retresco.yml
# Deleting: output/en/bicotest_191_semant.yml
# Deleting: output/en/bicotest_191_simple.yml
# Deleting: output/en/bicotest_191_txtrazor.yml
# Deleting: output/en/bicotest_234_alchemy.yml
# Deleting: output/en/bicotest_234_bitext.yml
# Deleting: output/en/bicotest_234_linguasys.yml
# Deleting: output/en/bicotest_234_meaningcloud.yml
# Deleting: output/en/bicotest_234_retresco.yml
# Deleting: output/en/bicotest_234_semant.yml
# Deleting: output/en/bicotest_234_simple.yml
# Deleting: output/en/bicotest_234_txtrazor.yml
# Deleting: output/en/bicotest_235_alchemy.yml
# Deleting: output/en/bicotest_235_bitext.yml
# Deleting: output/en/bicotest_235_linguasys.yml
# Deleting: output/en/bicotest_235_meaningcloud.yml
# Deleting: output/en/bicotest_235_retresco.yml
# Deleting: output/en/bicotest_235_semant.yml
# Deleting: output/en/bicotest_235_simple.yml
# Deleting: output/en/bicotest_235_txtrazor.yml
# Deleting: output/en/bicotest_279_alchemy.yml
# Deleting: output/en/bicotest_279_bitext.yml
# Deleting: output/en/bicotest_279_linguasys.yml
# Deleting: output/en/bicotest_279_meaningcloud.yml
# Deleting: output/en/bicotest_279_retresco.yml
# Deleting: output/en/bicotest_279_semant.yml
# Deleting: output/en/bicotest_279_simple.yml
# Deleting: output/en/bicotest_279_txtrazor.yml
# Deleting: output/en/bicotest_286_alchemy.yml
# Deleting: output/en/bicotest_286_bitext.yml
# Deleting: output/en/bicotest_286_linguasys.yml
# Deleting: output/en/bicotest_286_meaningcloud.yml
# Deleting: output/en/bicotest_286_retresco.yml
# Deleting: output/en/bicotest_286_semant.yml
# Deleting: output/en/bicotest_286_simple.yml
# Deleting: output/en/bicotest_286_txtrazor.yml
# Deleting: output/en/bicotest_331_alchemy.yml
# Deleting: output/en/bicotest_331_bitext.yml
# Deleting: output/en/bicotest_331_linguasys.yml
# Deleting: output/en/bicotest_331_meaningcloud.yml
# Deleting: output/en/bicotest_331_retresco.yml
# Deleting: output/en/bicotest_331_semant.yml
# Deleting: output/en/bicotest_331_simple.yml
# Deleting: output/en/bicotest_331_txtrazor.yml
# Deleting: output/en/bicotest_360_alchemy.yml
# Deleting: output/en/bicotest_360_bitext.yml
# Deleting: output/en/bicotest_360_linguasys.yml
# Deleting: output/en/bicotest_360_meaningcloud.yml
# Deleting: output/en/bicotest_360_retresco.yml
# Deleting: output/en/bicotest_360_semant.yml
# Deleting: output/en/bicotest_360_simple.yml
# Deleting: output/en/bicotest_360_txtrazor.yml
# Deleting: output/en/bicotest_399_alchemy.yml
# Deleting: output/en/bicotest_399_bitext.yml
# Deleting: output/en/bicotest_399_linguasys.yml
# Deleting: output/en/bicotest_399_meaningcloud.yml
# Deleting: output/en/bicotest_399_retresco.yml
# Deleting: output/en/bicotest_399_semant.yml
# Deleting: output/en/bicotest_399_simple.yml
# Deleting: output/en/bicotest_399_txtrazor.yml
# Deleting: output/en/bicotest_475_alchemy.yml
# Deleting: output/en/bicotest_475_bitext.yml
# Deleting: output/en/bicotest_475_linguasys.yml
# Deleting: output/en/bicotest_475_meaningcloud.yml
# Deleting: output/en/bicotest_475_retresco.yml
# Deleting: output/en/bicotest_475_semant.yml
# Deleting: output/en/bicotest_475_simple.yml
# Deleting: output/en/bicotest_475_txtrazor.yml
# Deleting: output/en/bicotest_546_alchemy.yml
# Deleting: output/en/bicotest_546_bitext.yml
# Deleting: output/en/bicotest_546_linguasys.yml
# Deleting: output/en/bicotest_546_meaningcloud.yml
# Deleting: output/en/bicotest_546_retresco.yml
# Deleting: output/en/bicotest_546_semant.yml
# Deleting: output/en/bicotest_546_simple.yml
# Deleting: output/en/bicotest_546_txtrazor.yml
# Deleting: output/en/bicotest_551_alchemy.yml
# Deleting: output/en/bicotest_551_bitext.yml
# Deleting: output/en/bicotest_551_linguasys.yml
# Deleting: output/en/bicotest_551_meaningcloud.yml
# Deleting: output/en/bicotest_551_retresco.yml
# Deleting: output/en/bicotest_551_semant.yml
# Deleting: output/en/bicotest_551_simple.yml
# Deleting: output/en/bicotest_551_txtrazor.yml
# Deleting: output/en/bicotest_587_alchemy.yml
# Deleting: output/en/bicotest_587_bitext.yml
# Deleting: output/en/bicotest_587_linguasys.yml
# Deleting: output/en/bicotest_587_meaningcloud.yml
# Deleting: output/en/bicotest_587_retresco.yml
# Deleting: output/en/bicotest_587_semant.yml
# Deleting: output/en/bicotest_587_simple.yml
# Deleting: output/en/bicotest_587_txtrazor.yml
# Deleting: output/en/weonetest_082_alchemy.yml
# Deleting: output/en/weonetest_082_bitext.yml
# Deleting: output/en/weonetest_082_linguasys.yml
# Deleting: output/en/weonetest_082_meaningcloud.yml
# Deleting: output/en/weonetest_082_retresco.yml
# Deleting: output/en/weonetest_082_semant.yml
# Deleting: output/en/weonetest_082_simple.yml
# Deleting: output/en/weonetest_082_txtrazor.yml
# Deleting: output/en/weonetest_105_alchemy.yml
# Deleting: output/en/weonetest_105_bitext.yml
# Deleting: output/en/weonetest_105_linguasys.yml
# Deleting: output/en/weonetest_105_meaningcloud.yml
# Deleting: output/en/weonetest_105_retresco.yml
# Deleting: output/en/weonetest_105_semant.yml
# Deleting: output/en/weonetest_105_simple.yml
# Deleting: output/en/weonetest_105_txtrazor.yml
# Deleting: output/en/weonetest_1076_alchemy.yml
# Deleting: output/en/weonetest_1076_bitext.yml
# Deleting: output/en/weonetest_1076_linguasys.yml
# Deleting: output/en/weonetest_1076_meaningcloud.yml
# Deleting: output/en/weonetest_1076_retresco.yml
# Deleting: output/en/weonetest_1076_semant.yml
# Deleting: output/en/weonetest_1076_simple.yml
# Deleting: output/en/weonetest_1076_txtrazor.yml
# Deleting: output/en/weonetest_1125_alchemy.yml
# Deleting: output/en/weonetest_1125_bitext.yml
# Deleting: output/en/weonetest_1125_linguasys.yml
# Deleting: output/en/weonetest_1125_meaningcloud.yml
# Deleting: output/en/weonetest_1125_retresco.yml
# Deleting: output/en/weonetest_1125_semant.yml
# Deleting: output/en/weonetest_1125_simple.yml
# Deleting: output/en/weonetest_1125_txtrazor.yml
# Deleting: output/en/weonetest_1149_alchemy.yml
# Deleting: output/en/weonetest_1149_bitext.yml
# Deleting: output/en/weonetest_1149_linguasys.yml
# Deleting: output/en/weonetest_1149_meaningcloud.yml
# Deleting: output/en/weonetest_1149_retresco.yml
# Deleting: output/en/weonetest_1149_semant.yml
# Deleting: output/en/weonetest_1149_simple.yml
# Deleting: output/en/weonetest_1149_txtrazor.yml
# Deleting: output/en/weonetest_1157_alchemy.yml
# Deleting: output/en/weonetest_1157_bitext.yml
# Deleting: output/en/weonetest_1157_linguasys.yml
# Deleting: output/en/weonetest_1157_meaningcloud.yml
# Deleting: output/en/weonetest_1157_retresco.yml
# Deleting: output/en/weonetest_1157_semant.yml
# Deleting: output/en/weonetest_1157_simple.yml
# Deleting: output/en/weonetest_1157_txtrazor.yml
# Deleting: output/en/weonetest_1217_alchemy.yml
# Deleting: output/en/weonetest_1217_bitext.yml
# Deleting: output/en/weonetest_1217_linguasys.yml
# Deleting: output/en/weonetest_1217_meaningcloud.yml
# Deleting: output/en/weonetest_1217_retresco.yml
# Deleting: output/en/weonetest_1217_semant.yml
# Deleting: output/en/weonetest_1217_simple.yml
# Deleting: output/en/weonetest_1217_txtrazor.yml
# Deleting: output/en/weonetest_177_alchemy.yml
# Deleting: output/en/weonetest_177_bitext.yml
# Deleting: output/en/weonetest_177_linguasys.yml
# Deleting: output/en/weonetest_177_meaningcloud.yml
# Deleting: output/en/weonetest_177_retresco.yml
# Deleting: output/en/weonetest_177_semant.yml
# Deleting: output/en/weonetest_177_simple.yml
# Deleting: output/en/weonetest_177_txtrazor.yml
# Deleting: output/en/weonetest_188_alchemy.yml
# Deleting: output/en/weonetest_188_bitext.yml
# Deleting: output/en/weonetest_188_linguasys.yml
# Deleting: output/en/weonetest_188_meaningcloud.yml
# Deleting: output/en/weonetest_188_retresco.yml
# Deleting: output/en/weonetest_188_semant.yml
# Deleting: output/en/weonetest_188_simple.yml
# Deleting: output/en/weonetest_188_txtrazor.yml
# Deleting: output/en/weonetest_409_alchemy.yml
# Deleting: output/en/weonetest_409_bitext.yml
# Deleting: output/en/weonetest_409_linguasys.yml
# Deleting: output/en/weonetest_409_meaningcloud.yml
# Deleting: output/en/weonetest_409_retresco.yml
# Deleting: output/en/weonetest_409_semant.yml
# Deleting: output/en/weonetest_409_simple.yml
# Deleting: output/en/weonetest_409_txtrazor.yml
# Deleting: output/en/weonetest_439_alchemy.yml
# Deleting: output/en/weonetest_439_bitext.yml
# Deleting: output/en/weonetest_439_linguasys.yml
# Deleting: output/en/weonetest_439_meaningcloud.yml
# Deleting: output/en/weonetest_439_retresco.yml
# Deleting: output/en/weonetest_439_semant.yml
# Deleting: output/en/weonetest_439_simple.yml
# Deleting: output/en/weonetest_439_txtrazor.yml
# Deleting: output/en/weonetest_481_alchemy.yml
# Deleting: output/en/weonetest_481_bitext.yml
# Deleting: output/en/weonetest_481_linguasys.yml
# Deleting: output/en/weonetest_481_meaningcloud.yml
# Deleting: output/en/weonetest_481_retresco.yml
# Deleting: output/en/weonetest_481_semant.yml
# Deleting: output/en/weonetest_481_simple.yml
# Deleting: output/en/weonetest_481_txtrazor.yml
# Deleting: output/en/weonetest_509_alchemy.yml
# Deleting: output/en/weonetest_509_bitext.yml
# Deleting: output/en/weonetest_509_linguasys.yml
# Deleting: output/en/weonetest_509_meaningcloud.yml
# Deleting: output/en/weonetest_509_retresco.yml
# Deleting: output/en/weonetest_509_semant.yml
# Deleting: output/en/weonetest_509_simple.yml
# Deleting: output/en/weonetest_509_txtrazor.yml
# Deleting: output/en/weonetest_583_alchemy.yml
# Deleting: output/en/weonetest_583_bitext.yml
# Deleting: output/en/weonetest_583_linguasys.yml
# Deleting: output/en/weonetest_583_meaningcloud.yml
# Deleting: output/en/weonetest_583_retresco.yml
# Deleting: output/en/weonetest_583_semant.yml
# Deleting: output/en/weonetest_583_simple.yml
# Deleting: output/en/weonetest_583_txtrazor.yml
# Deleting: output/en/weonetest_611_alchemy.yml
# Deleting: output/en/weonetest_611_bitext.yml
# Deleting: output/en/weonetest_611_linguasys.yml
# Deleting: output/en/weonetest_611_meaningcloud.yml
# Deleting: output/en/weonetest_611_retresco.yml
# Deleting: output/en/weonetest_611_semant.yml
# Deleting: output/en/weonetest_611_simple.yml
# Deleting: output/en/weonetest_611_txtrazor.yml
# Deleting: output/en/weonetest_626_alchemy.yml
# Deleting: output/en/weonetest_626_bitext.yml
# Deleting: output/en/weonetest_626_linguasys.yml
# Deleting: output/en/weonetest_626_meaningcloud.yml
# Deleting: output/en/weonetest_626_retresco.yml
# Deleting: output/en/weonetest_626_semant.yml
# Deleting: output/en/weonetest_626_simple.yml
# Deleting: output/en/weonetest_626_txtrazor.yml
# Deleting: output/en/weonetest_661_alchemy.yml
# Deleting: output/en/weonetest_661_bitext.yml
# Deleting: output/en/weonetest_661_linguasys.yml
# Deleting: output/en/weonetest_661_meaningcloud.yml
# Deleting: output/en/weonetest_661_retresco.yml
# Deleting: output/en/weonetest_661_semant.yml
# Deleting: output/en/weonetest_661_simple.yml
# Deleting: output/en/weonetest_661_txtrazor.yml
# Deleting: output/en/weonetest_674_alchemy.yml
# Deleting: output/en/weonetest_674_bitext.yml
# Deleting: output/en/weonetest_674_linguasys.yml
# Deleting: output/en/weonetest_674_meaningcloud.yml
# Deleting: output/en/weonetest_674_retresco.yml
# Deleting: output/en/weonetest_674_semant.yml
# Deleting: output/en/weonetest_674_simple.yml
# Deleting: output/en/weonetest_674_txtrazor.yml
# Deleting: output/en/weonetest_711_alchemy.yml
# Deleting: output/en/weonetest_711_bitext.yml
# Deleting: output/en/weonetest_711_linguasys.yml
# Deleting: output/en/weonetest_711_meaningcloud.yml
# Deleting: output/en/weonetest_711_retresco.yml
# Deleting: output/en/weonetest_711_semant.yml
# Deleting: output/en/weonetest_711_simple.yml
# Deleting: output/en/weonetest_711_txtrazor.yml
# Deleting: output/en/weonetest_751_alchemy.yml
# Deleting: output/en/weonetest_751_bitext.yml
# Deleting: output/en/weonetest_751_linguasys.yml
# Deleting: output/en/weonetest_751_meaningcloud.yml
# Deleting: output/en/weonetest_751_retresco.yml
# Deleting: output/en/weonetest_751_semant.yml
# Deleting: output/en/weonetest_751_simple.yml
# Deleting: output/en/weonetest_751_txtrazor.yml
# Deleting: output/en/weonetest_755_alchemy.yml
# Deleting: output/en/weonetest_755_bitext.yml
# Deleting: output/en/weonetest_755_linguasys.yml
# Deleting: output/en/weonetest_755_meaningcloud.yml
# Deleting: output/en/weonetest_755_retresco.yml
# Deleting: output/en/weonetest_755_semant.yml
# Deleting: output/en/weonetest_755_simple.yml
# Deleting: output/en/weonetest_755_txtrazor.yml
# Deleting: output/en/weonetest_772_alchemy.yml
# Deleting: output/en/weonetest_772_bitext.yml
# Deleting: output/en/weonetest_772_linguasys.yml
# Deleting: output/en/weonetest_772_meaningcloud.yml
# Deleting: output/en/weonetest_772_retresco.yml
# Deleting: output/en/weonetest_772_semant.yml
# Deleting: output/en/weonetest_772_simple.yml
# Deleting: output/en/weonetest_772_txtrazor.yml
# Deleting: output/en/weonetest_776_alchemy.yml
# Deleting: output/en/weonetest_776_bitext.yml
# Deleting: output/en/weonetest_776_linguasys.yml
# Deleting: output/en/weonetest_776_meaningcloud.yml
# Deleting: output/en/weonetest_776_retresco.yml
# Deleting: output/en/weonetest_776_semant.yml
# Deleting: output/en/weonetest_776_simple.yml
# Deleting: output/en/weonetest_776_txtrazor.yml
# Deleting: output/en/weonetest_802_alchemy.yml
# Deleting: output/en/weonetest_802_bitext.yml
# Deleting: output/en/weonetest_802_linguasys.yml
# Deleting: output/en/weonetest_802_meaningcloud.yml
# Deleting: output/en/weonetest_802_retresco.yml
# Deleting: output/en/weonetest_802_semant.yml
# Deleting: output/en/weonetest_802_simple.yml
# Deleting: output/en/weonetest_802_txtrazor.yml
# Deleting: output/en/weonetest_821_alchemy.yml
# Deleting: output/en/weonetest_821_bitext.yml
# Deleting: output/en/weonetest_821_linguasys.yml
# Deleting: output/en/weonetest_821_meaningcloud.yml
# Deleting: output/en/weonetest_821_retresco.yml
# Deleting: output/en/weonetest_821_semant.yml
# Deleting: output/en/weonetest_821_simple.yml
# Deleting: output/en/weonetest_821_txtrazor.yml
# Deleting: output/en/weonetest_826_alchemy.yml
# Deleting: output/en/weonetest_826_bitext.yml
# Deleting: output/en/weonetest_826_linguasys.yml
# Deleting: output/en/weonetest_826_meaningcloud.yml
# Deleting: output/en/weonetest_826_retresco.yml
# Deleting: output/en/weonetest_826_semant.yml
# Deleting: output/en/weonetest_826_simple.yml
# Deleting: output/en/weonetest_826_txtrazor.yml
# Deleting: output/en/weonetest_873_alchemy.yml
# Deleting: output/en/weonetest_873_bitext.yml
# Deleting: output/en/weonetest_873_linguasys.yml
# Deleting: output/en/weonetest_873_meaningcloud.yml
# Deleting: output/en/weonetest_873_retresco.yml
# Deleting: output/en/weonetest_873_semant.yml
# Deleting: output/en/weonetest_873_simple.yml
# Deleting: output/en/weonetest_873_txtrazor.yml
# Deleting: output/en/weonetest_887_alchemy.yml
# Deleting: output/en/weonetest_887_bitext.yml
# Deleting: output/en/weonetest_887_linguasys.yml
# Deleting: output/en/weonetest_887_meaningcloud.yml
# Deleting: output/en/weonetest_887_retresco.yml
# Deleting: output/en/weonetest_887_semant.yml
# Deleting: output/en/weonetest_887_simple.yml
# Deleting: output/en/weonetest_887_txtrazor.yml
# Deleting: output/en/weonetest_895_alchemy.yml
# Deleting: output/en/weonetest_895_bitext.yml
# Deleting: output/en/weonetest_895_linguasys.yml
# Deleting: output/en/weonetest_895_meaningcloud.yml
# Deleting: output/en/weonetest_895_retresco.yml
# Deleting: output/en/weonetest_895_semant.yml
# Deleting: output/en/weonetest_895_simple.yml
# Deleting: output/en/weonetest_895_txtrazor.yml
# Deleting: output/en/weonetest_897_alchemy.yml
# Deleting: output/en/weonetest_897_bitext.yml
# Deleting: output/en/weonetest_897_linguasys.yml
# Deleting: output/en/weonetest_897_meaningcloud.yml
# Deleting: output/en/weonetest_897_retresco.yml
# Deleting: output/en/weonetest_897_semant.yml
# Deleting: output/en/weonetest_897_simple.yml
# Deleting: output/en/weonetest_897_txtrazor.yml
# Deleting: output/en/weonetest_980_alchemy.yml
# Deleting: output/en/weonetest_980_bitext.yml
# Deleting: output/en/weonetest_980_linguasys.yml
# Deleting: output/en/weonetest_980_meaningcloud.yml
# Deleting: output/en/weonetest_980_retresco.yml
# Deleting: output/en/weonetest_980_semant.yml
# Deleting: output/en/weonetest_980_simple.yml
# Deleting: output/en/weonetest_980_txtrazor.yml
# Deleting: output/en/weonetest_982_alchemy.yml
# Deleting: output/en/weonetest_982_bitext.yml
# Deleting: output/en/weonetest_982_linguasys.yml
# Deleting: output/en/weonetest_982_meaningcloud.yml
# Deleting: output/en/weonetest_982_retresco.yml
# Deleting: output/en/weonetest_982_semant.yml
# Deleting: output/en/weonetest_982_simple.yml
# Deleting: output/en/weonetest_982_txtrazor.yml
# [Errno 2] No such file or directory: 'result/en'

# %%
import semaeval.source.syndication as synd

# %%
help(synd)
# Out:
# Help on module semaeval.source.syndication in semaeval.source:
#
# NAME
#     semaeval.source.syndication - # -*- coding: utf-8 -*-
#
# FILE
#     /Users/amaier1/git/semaeval/semaeval/source/syndication.py
#
# FUNCTIONS
#     article_from_path(path)
#
#     articles_from_dir(dir)
#
#     load_articles(prefix)
#
#     store_articles(articles, prefix)
#
# DATA
#     store_dir = 'input/'
#     url_regex = <_sre.SRE_Pattern object>

# %%
bild = synd.articles_from_dir("/Users/amaier1/Documents/semeval/bicotest")

# %%
welt = synd.articles_from_dir("/Users/amaier1/Documents/semeval/weonetest")

# %%
wild = bild + welt

# %%
import random
articles = random.sample(wild,50)

# %%
synd.store_articles(articles,"en")
# Out:
# Storing file:  input/en/bicotest_443.yml
# Storing file:  input/en/weonetest_549.yml
# Storing file:  input/en/bicotest_566.yml
# Storing file:  input/en/weonetest_982.yml
# Storing file:  input/en/weonetest_923.yml
# Storing file:  input/en/bicotest_195.yml
# Storing file:  input/en/bicotest_583.yml
# Storing file:  input/en/weonetest_889.yml
# Storing file:  input/en/bicotest_416.yml
# Storing file:  input/en/bicotest_192.yml
# Storing file:  input/en/weonetest_659.yml
# Storing file:  input/en/weonetest_1029.yml
# Storing file:  input/en/weonetest_769.yml
# Storing file:  input/en/weonetest_744.yml
# Storing file:  input/en/weonetest_835.yml
# Storing file:  input/en/bicotest_536.yml
# Storing file:  input/en/weonetest_702.yml
# Storing file:  input/en/weonetest_359.yml
# Storing file:  input/en/weonetest_943.yml
# Storing file:  input/en/weonetest_430.yml
# Storing file:  input/en/weonetest_198.yml
# Storing file:  input/en/bicotest_588.yml
# Storing file:  input/en/bicotest_457.yml
# Storing file:  input/en/bicotest_533.yml
# Storing file:  input/en/weonetest_1187.yml
# Storing file:  input/en/bicotest_548.yml
# Storing file:  input/en/weonetest_506.yml
# Storing file:  input/en/weonetest_1205.yml
# Storing file:  input/en/bicotest_153.yml
# Storing file:  input/en/weonetest_141.yml
# Storing file:  input/en/bicotest_490.yml
# Storing file:  input/en/weonetest_1081.yml
# Storing file:  input/en/bicotest_505.yml
# Storing file:  input/en/bicotest_515.yml
# Storing file:  input/en/weonetest_393.yml
# Storing file:  input/en/weonetest_157.yml
# Storing file:  input/en/weonetest_676.yml
# Storing file:  input/en/weonetest_738.yml
# Storing file:  input/en/weonetest_734.yml
# Storing file:  input/en/weonetest_055.yml
# Storing file:  input/en/weonetest_1044.yml
# Storing file:  input/en/weonetest_240.yml
# Storing file:  input/en/weonetest_1124.yml
# Storing file:  input/en/weonetest_872.yml
# Storing file:  input/en/weonetest_092.yml
# Storing file:  input/en/weonetest_737.yml
# Storing file:  input/en/weonetest_317.yml
# Storing file:  input/en/weonetest_842.yml
# Storing file:  input/en/weonetest_1132.yml
# Storing file:  input/en/weonetest_711.yml

# %%
import semaeval.evaluate as eval

# %%
articles_enriched = eval.detect_entities(articles,"en")
# Out:
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/07/06/germany-vs-spain/20-things-you-need-to-know-for-semi-final.html
# Collecting results:
# Filename: weonetest_549.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/08/03/supermodel-alessandra-ambrosio/al-ass-andra-and-her-booty-full-beach-butt.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# meaningcloud: Top>OtherEntity>MethodSystem
# URL: http://www.welt.de/english-news/article3843754/Chances-of-finding-survivors-from-missing-jet-tiny.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.simple
# semantria: List
# Filename: weonetest_923.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/05/10/lena-meyer-landrut-tv-show/i-kissed-germany-eurovision-star-naked-in-pool.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# textrazor: [u'Award']
# textrazor: [u'Award']
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-football/2010/08/09/louis-van-gaal-confesses/bayern-coach-i-was-for-germany-at-world-cup.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# textrazor: [u'MeanOfTransportation', u'SpaceStation']
# URL: http://www.welt.de/english-news/article3804596/Abbas-to-seek-U-S-pressure-on-Jewish-settlements.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# meaningcloud: Top>Product>CulturalProduct>Printing
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/07/01/schweini-world-cup-warning/germany-argentina-will-there-be-more-hate-like-2006.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.semant
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/05/06/oil-catastrophe-worse-than-feared/bp-admits-much-more-oil-could-spill-into-gulf-of-mexico.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: weonetest_659.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.welt.de/international/article3889499/Why-we-know-Darwin.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# bitext: 130
# Filename: weonetest_769.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.bitext
# semaeval.engine.basistech
# semaeval.engine.simple
# meaningcloud:alchemy: Top>Event
#  OperatingSystem
# Filename: weonetest_744.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.welt.de/english-news/article3778413/Four-suspects-arrested-in-New-York-City-terror-plot.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/07/26/love-parade-victims/tears-for-19-dead-in-duisburg-crush.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# meaningcloud:textrazor: Top>Timex>Date
#  [u'Device', u'Weapon']
# textrazor: [u'Device', u'Weapon']
# Filename: weonetest_702.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.alchemy
# semaeval.engine.simple
# Filename: weonetest_359.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# alchemy: OperatingSystem
# Filename: weonetest_943.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.retresco
# meaningcloud: Top>OtherEntity>MethodSystem
# Filename: weonetest_430.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_198.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/08/10/princess-victoria-accused-of-corruption/swedish-royal-criticised-over-billionaires-wedding-presents.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.alchemy
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/07/08/heartbroken-world-cup-fans/s-painful-defeat-leaves-germany-in-tears.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/more-sport/2010/07/23/f1-german-grand-prix/schumi-to-help-vettel-against-webber-on-home-soil.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.semant
# semaeval.engine.simple
# URL: http://www.welt.de/international/article4107222/Sotomayor-confirmation-all-but-assured.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# meaningcloud: Top>Product
# meaningcloud: Top>Event>Occasion>Games
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/07/28/sex-drugs-and-bon-jovi/classic-rock-photo-shoot-in-new-book.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: weonetest_506.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.bitext
# URL: http://www.welt.de/international/article4123875/Nigerian-militant-group-declares-a-60-day-ceasefire.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.simple
# meaningcloud: Top>OtherEntity>MethodSystem
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/04/22/david-hasselhoff-autobiography/hoff-first-sex-we-were-drunk-she-fell-asleep.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# textrazor: [u'I-Person']
# Filename: weonetest_141.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/07/15/sexy-larissa-riquelme/paraguay-beauty-i-wanted-to-be-famous-at-world-cup.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# textrazor:alchemy: Movie
#  [u'Award']
# URL: http://www.welt.de/international/article3989333/Facts-on-U-S-drone-attacks-in-Pakistan.html#reqRSS
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/07/19/cap-dagde/naturists-can-swing-freely-with-bay-of-pigs-dirty-fun.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/07/20/will-smith-and-clan-visit-bild/worlds-coolest-family-in-berlin-jaden-jada.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# semantria: List
# Filename: weonetest_393.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: weonetest_157.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# bitext: 4
# Filename: weonetest_676.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# textrazor: [u'Device', u'Weapon']
# textrazor: [u'Device', u'Weapon']
# textrazor: [u'Device', u'Weapon']
# textrazor: [u'Device', u'Weapon']
# Filename: weonetest_738.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.simple
# URL: http://www.welt.de/english-news/article3718970/Kylie-dreams-of-carving-out-a-career-in-film.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.basistech
# Filename: weonetest_055.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.retresco
# meaningcloud:textrazor:alchemy: Top>Event
#  Movie
#  [u'Award']
# alchemy: Movie
# textrazor: [u'Award']
# URL: http://www.welt.de/international/article3929662/Police-beat-protesters-in-Georgian-capital.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_240.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# semaeval.engine.basistech
# URL: http://www.welt.de/international/article4049710/U-S-drone-strike-kills-at-least-10-in-Pakistan.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: weonetest_872.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.alchemy
# semaeval.engine.simple
# Filename: weonetest_092.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: weonetest_737.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: weonetest_317.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.basistech
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# meaningcloud: Top>Process>IntentionalProcess
# Filename: weonetest_842.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.basistech
# URL: http://www.welt.de/international/article4057282/Massive-demand-for-Jackson-memorial-tickets.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: weonetest_711.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# meaningcloud: Top>Process>IntentionalProcess

# %%
eval.store_articles(articles_enriched,"en")
# Out:
# Storing file:  output/en/bicotest_443_alchemy.yml
# Storing file:  output/en/bicotest_443_txtrazor.yml
# Storing file:  output/en/bicotest_443_retresco.yml
# Storing file:  output/en/bicotest_443_semant.yml
# Storing file:  output/en/bicotest_443_meaningcloud.yml
# Storing file:  output/en/bicotest_443_basistech.yml
# Storing file:  output/en/bicotest_443_bitext.yml
# Storing file:  output/en/bicotest_443_simple.yml
# Storing file:  output/en/weonetest_549_alchemy.yml
# Storing file:  output/en/weonetest_549_txtrazor.yml
# Storing file:  output/en/weonetest_549_retresco.yml
# Storing file:  output/en/weonetest_549_semant.yml
# Storing file:  output/en/weonetest_549_meaningcloud.yml
# Storing file:  output/en/weonetest_549_basistech.yml
# Storing file:  output/en/weonetest_549_bitext.yml
# Storing file:  output/en/weonetest_549_simple.yml
# Storing file:  output/en/bicotest_566_alchemy.yml
# Storing file:  output/en/bicotest_566_txtrazor.yml
# Storing file:  output/en/bicotest_566_retresco.yml
# Storing file:  output/en/bicotest_566_semant.yml
# Storing file:  output/en/bicotest_566_meaningcloud.yml
# Storing file:  output/en/bicotest_566_basistech.yml
# Storing file:  output/en/bicotest_566_bitext.yml
# Storing file:  output/en/bicotest_566_simple.yml
# Storing file:  output/en/weonetest_982_alchemy.yml
# Storing file:  output/en/weonetest_982_txtrazor.yml
# Storing file:  output/en/weonetest_982_retresco.yml
# Storing file:  output/en/weonetest_982_semant.yml
# Storing file:  output/en/weonetest_982_meaningcloud.yml
# Storing file:  output/en/weonetest_982_basistech.yml
# Storing file:  output/en/weonetest_982_bitext.yml
# Storing file:  output/en/weonetest_982_simple.yml
# Storing file:  output/en/weonetest_923_alchemy.yml
# Storing file:  output/en/weonetest_923_txtrazor.yml
# Storing file:  output/en/weonetest_923_retresco.yml
# Storing file:  output/en/weonetest_923_semant.yml
# Storing file:  output/en/weonetest_923_meaningcloud.yml
# Storing file:  output/en/weonetest_923_basistech.yml
# Storing file:  output/en/weonetest_923_bitext.yml
# Storing file:  output/en/weonetest_923_simple.yml
# Storing file:  output/en/bicotest_195_alchemy.yml
# Storing file:  output/en/bicotest_195_txtrazor.yml
# Storing file:  output/en/bicotest_195_retresco.yml
# Storing file:  output/en/bicotest_195_semant.yml
# Storing file:  output/en/bicotest_195_meaningcloud.yml
# Storing file:  output/en/bicotest_195_basistech.yml
# Storing file:  output/en/bicotest_195_bitext.yml
# Storing file:  output/en/bicotest_195_simple.yml
# Storing file:  output/en/bicotest_583_alchemy.yml
# Storing file:  output/en/bicotest_583_txtrazor.yml
# Storing file:  output/en/bicotest_583_retresco.yml
# Storing file:  output/en/bicotest_583_semant.yml
# Storing file:  output/en/bicotest_583_meaningcloud.yml
# Storing file:  output/en/bicotest_583_basistech.yml
# Storing file:  output/en/bicotest_583_bitext.yml
# Storing file:  output/en/bicotest_583_simple.yml
# Storing file:  output/en/weonetest_889_alchemy.yml
# Storing file:  output/en/weonetest_889_txtrazor.yml
# Storing file:  output/en/weonetest_889_retresco.yml
# Storing file:  output/en/weonetest_889_semant.yml
# Storing file:  output/en/weonetest_889_meaningcloud.yml
# Storing file:  output/en/weonetest_889_basistech.yml
# Storing file:  output/en/weonetest_889_bitext.yml
# Storing file:  output/en/weonetest_889_simple.yml
# Storing file:  output/en/bicotest_416_alchemy.yml
# Storing file:  output/en/bicotest_416_txtrazor.yml
# Storing file:  output/en/bicotest_416_retresco.yml
# Storing file:  output/en/bicotest_416_semant.yml
# Storing file:  output/en/bicotest_416_meaningcloud.yml
# Storing file:  output/en/bicotest_416_basistech.yml
# Storing file:  output/en/bicotest_416_bitext.yml
# Storing file:  output/en/bicotest_416_simple.yml
# Storing file:  output/en/bicotest_192_alchemy.yml
# Storing file:  output/en/bicotest_192_txtrazor.yml
# Storing file:  output/en/bicotest_192_retresco.yml
# Storing file:  output/en/bicotest_192_semant.yml
# Storing file:  output/en/bicotest_192_meaningcloud.yml
# Storing file:  output/en/bicotest_192_basistech.yml
# Storing file:  output/en/bicotest_192_bitext.yml
# Storing file:  output/en/bicotest_192_simple.yml
# Storing file:  output/en/weonetest_659_alchemy.yml
# Storing file:  output/en/weonetest_659_txtrazor.yml
# Storing file:  output/en/weonetest_659_retresco.yml
# Storing file:  output/en/weonetest_659_semant.yml
# Storing file:  output/en/weonetest_659_meaningcloud.yml
# Storing file:  output/en/weonetest_659_basistech.yml
# Storing file:  output/en/weonetest_659_bitext.yml
# Storing file:  output/en/weonetest_659_simple.yml
# Storing file:  output/en/weonetest_1029_alchemy.yml
# Storing file:  output/en/weonetest_1029_txtrazor.yml
# Storing file:  output/en/weonetest_1029_retresco.yml
# Storing file:  output/en/weonetest_1029_semant.yml
# Storing file:  output/en/weonetest_1029_meaningcloud.yml
# Storing file:  output/en/weonetest_1029_basistech.yml
# Storing file:  output/en/weonetest_1029_bitext.yml
# Storing file:  output/en/weonetest_1029_simple.yml
# Storing file:  output/en/weonetest_769_alchemy.yml
# Storing file:  output/en/weonetest_769_txtrazor.yml
# Storing file:  output/en/weonetest_769_retresco.yml
# Storing file:  output/en/weonetest_769_semant.yml
# Storing file:  output/en/weonetest_769_meaningcloud.yml
# Storing file:  output/en/weonetest_769_basistech.yml
# Storing file:  output/en/weonetest_769_bitext.yml
# Storing file:  output/en/weonetest_769_simple.yml
# Storing file:  output/en/weonetest_744_alchemy.yml
# Storing file:  output/en/weonetest_744_txtrazor.yml
# Storing file:  output/en/weonetest_744_retresco.yml
# Storing file:  output/en/weonetest_744_semant.yml
# Storing file:  output/en/weonetest_744_meaningcloud.yml
# Storing file:  output/en/weonetest_744_basistech.yml
# Storing file:  output/en/weonetest_744_bitext.yml
# Storing file:  output/en/weonetest_744_simple.yml
# Storing file:  output/en/weonetest_835_alchemy.yml
# Storing file:  output/en/weonetest_835_txtrazor.yml
# Storing file:  output/en/weonetest_835_retresco.yml
# Storing file:  output/en/weonetest_835_semant.yml
# Storing file:  output/en/weonetest_835_meaningcloud.yml
# Storing file:  output/en/weonetest_835_basistech.yml
# Storing file:  output/en/weonetest_835_bitext.yml
# Storing file:  output/en/weonetest_835_simple.yml
# Storing file:  output/en/bicotest_536_alchemy.yml
# Storing file:  output/en/bicotest_536_txtrazor.yml
# Storing file:  output/en/bicotest_536_retresco.yml
# Storing file:  output/en/bicotest_536_semant.yml
# Storing file:  output/en/bicotest_536_meaningcloud.yml
# Storing file:  output/en/bicotest_536_basistech.yml
# Storing file:  output/en/bicotest_536_bitext.yml
# Storing file:  output/en/bicotest_536_simple.yml
# Storing file:  output/en/weonetest_702_alchemy.yml
# Storing file:  output/en/weonetest_702_txtrazor.yml
# Storing file:  output/en/weonetest_702_retresco.yml
# Storing file:  output/en/weonetest_702_semant.yml
# Storing file:  output/en/weonetest_702_meaningcloud.yml
# Storing file:  output/en/weonetest_702_basistech.yml
# Storing file:  output/en/weonetest_702_bitext.yml
# Storing file:  output/en/weonetest_702_simple.yml
# Storing file:  output/en/weonetest_359_alchemy.yml
# Storing file:  output/en/weonetest_359_txtrazor.yml
# Storing file:  output/en/weonetest_359_retresco.yml
# Storing file:  output/en/weonetest_359_semant.yml
# Storing file:  output/en/weonetest_359_meaningcloud.yml
# Storing file:  output/en/weonetest_359_basistech.yml
# Storing file:  output/en/weonetest_359_bitext.yml
# Storing file:  output/en/weonetest_359_simple.yml
# Storing file:  output/en/weonetest_943_alchemy.yml
# Storing file:  output/en/weonetest_943_txtrazor.yml
# Storing file:  output/en/weonetest_943_retresco.yml
# Storing file:  output/en/weonetest_943_semant.yml
# Storing file:  output/en/weonetest_943_meaningcloud.yml
# Storing file:  output/en/weonetest_943_basistech.yml
# Storing file:  output/en/weonetest_943_bitext.yml
# Storing file:  output/en/weonetest_943_simple.yml
# Storing file:  output/en/weonetest_430_alchemy.yml
# Storing file:  output/en/weonetest_430_txtrazor.yml
# Storing file:  output/en/weonetest_430_retresco.yml
# Storing file:  output/en/weonetest_430_semant.yml
# Storing file:  output/en/weonetest_430_meaningcloud.yml
# Storing file:  output/en/weonetest_430_basistech.yml
# Storing file:  output/en/weonetest_430_bitext.yml
# Storing file:  output/en/weonetest_430_simple.yml
# Storing file:  output/en/weonetest_198_alchemy.yml
# Storing file:  output/en/weonetest_198_txtrazor.yml
# Storing file:  output/en/weonetest_198_retresco.yml
# Storing file:  output/en/weonetest_198_semant.yml
# Storing file:  output/en/weonetest_198_meaningcloud.yml
# Storing file:  output/en/weonetest_198_basistech.yml
# Storing file:  output/en/weonetest_198_bitext.yml
# Storing file:  output/en/weonetest_198_simple.yml
# Storing file:  output/en/bicotest_588_alchemy.yml
# Storing file:  output/en/bicotest_588_txtrazor.yml
# Storing file:  output/en/bicotest_588_retresco.yml
# Storing file:  output/en/bicotest_588_semant.yml
# Storing file:  output/en/bicotest_588_meaningcloud.yml
# Storing file:  output/en/bicotest_588_basistech.yml
# Storing file:  output/en/bicotest_588_bitext.yml
# Storing file:  output/en/bicotest_588_simple.yml
# Storing file:  output/en/bicotest_457_alchemy.yml
# Storing file:  output/en/bicotest_457_txtrazor.yml
# Storing file:  output/en/bicotest_457_retresco.yml
# Storing file:  output/en/bicotest_457_semant.yml
# Storing file:  output/en/bicotest_457_meaningcloud.yml
# Storing file:  output/en/bicotest_457_basistech.yml
# Storing file:  output/en/bicotest_457_bitext.yml
# Storing file:  output/en/bicotest_457_simple.yml
# Storing file:  output/en/bicotest_533_alchemy.yml
# Storing file:  output/en/bicotest_533_txtrazor.yml
# Storing file:  output/en/bicotest_533_retresco.yml
# Storing file:  output/en/bicotest_533_semant.yml
# Storing file:  output/en/bicotest_533_meaningcloud.yml
# Storing file:  output/en/bicotest_533_basistech.yml
# Storing file:  output/en/bicotest_533_bitext.yml
# Storing file:  output/en/bicotest_533_simple.yml
# Storing file:  output/en/weonetest_1187_alchemy.yml
# Storing file:  output/en/weonetest_1187_txtrazor.yml
# Storing file:  output/en/weonetest_1187_retresco.yml
# Storing file:  output/en/weonetest_1187_semant.yml
# Storing file:  output/en/weonetest_1187_meaningcloud.yml
# Storing file:  output/en/weonetest_1187_basistech.yml
# Storing file:  output/en/weonetest_1187_bitext.yml
# Storing file:  output/en/weonetest_1187_simple.yml
# Storing file:  output/en/bicotest_548_alchemy.yml
# Storing file:  output/en/bicotest_548_txtrazor.yml
# Storing file:  output/en/bicotest_548_retresco.yml
# Storing file:  output/en/bicotest_548_semant.yml
# Storing file:  output/en/bicotest_548_meaningcloud.yml
# Storing file:  output/en/bicotest_548_basistech.yml
# Storing file:  output/en/bicotest_548_bitext.yml
# Storing file:  output/en/bicotest_548_simple.yml
# Storing file:  output/en/weonetest_506_alchemy.yml
# Storing file:  output/en/weonetest_506_txtrazor.yml
# Storing file:  output/en/weonetest_506_retresco.yml
# Storing file:  output/en/weonetest_506_semant.yml
# Storing file:  output/en/weonetest_506_meaningcloud.yml
# Storing file:  output/en/weonetest_506_basistech.yml
# Storing file:  output/en/weonetest_506_bitext.yml
# Storing file:  output/en/weonetest_506_simple.yml
# Storing file:  output/en/weonetest_1205_alchemy.yml
# Storing file:  output/en/weonetest_1205_txtrazor.yml
# Storing file:  output/en/weonetest_1205_retresco.yml
# Storing file:  output/en/weonetest_1205_semant.yml
# Storing file:  output/en/weonetest_1205_meaningcloud.yml
# Storing file:  output/en/weonetest_1205_basistech.yml
# Storing file:  output/en/weonetest_1205_bitext.yml
# Storing file:  output/en/weonetest_1205_simple.yml
# Storing file:  output/en/bicotest_153_alchemy.yml
# Storing file:  output/en/bicotest_153_txtrazor.yml
# Storing file:  output/en/bicotest_153_retresco.yml
# Storing file:  output/en/bicotest_153_semant.yml
# Storing file:  output/en/bicotest_153_meaningcloud.yml
# Storing file:  output/en/bicotest_153_basistech.yml
# Storing file:  output/en/bicotest_153_bitext.yml
# Storing file:  output/en/bicotest_153_simple.yml
# Storing file:  output/en/weonetest_141_alchemy.yml
# Storing file:  output/en/weonetest_141_txtrazor.yml
# Storing file:  output/en/weonetest_141_retresco.yml
# Storing file:  output/en/weonetest_141_semant.yml
# Storing file:  output/en/weonetest_141_meaningcloud.yml
# Storing file:  output/en/weonetest_141_basistech.yml
# Storing file:  output/en/weonetest_141_bitext.yml
# Storing file:  output/en/weonetest_141_simple.yml
# Storing file:  output/en/bicotest_490_alchemy.yml
# Storing file:  output/en/bicotest_490_txtrazor.yml
# Storing file:  output/en/bicotest_490_retresco.yml
# Storing file:  output/en/bicotest_490_semant.yml
# Storing file:  output/en/bicotest_490_meaningcloud.yml
# Storing file:  output/en/bicotest_490_basistech.yml
# Storing file:  output/en/bicotest_490_bitext.yml
# Storing file:  output/en/bicotest_490_simple.yml
# Storing file:  output/en/weonetest_1081_alchemy.yml
# Storing file:  output/en/weonetest_1081_txtrazor.yml
# Storing file:  output/en/weonetest_1081_retresco.yml
# Storing file:  output/en/weonetest_1081_semant.yml
# Storing file:  output/en/weonetest_1081_meaningcloud.yml
# Storing file:  output/en/weonetest_1081_basistech.yml
# Storing file:  output/en/weonetest_1081_bitext.yml
# Storing file:  output/en/weonetest_1081_simple.yml
# Storing file:  output/en/bicotest_505_alchemy.yml
# Storing file:  output/en/bicotest_505_txtrazor.yml
# Storing file:  output/en/bicotest_505_retresco.yml
# Storing file:  output/en/bicotest_505_semant.yml
# Storing file:  output/en/bicotest_505_meaningcloud.yml
# Storing file:  output/en/bicotest_505_basistech.yml
# Storing file:  output/en/bicotest_505_bitext.yml
# Storing file:  output/en/bicotest_505_simple.yml
# Storing file:  output/en/bicotest_515_alchemy.yml
# Storing file:  output/en/bicotest_515_txtrazor.yml
# Storing file:  output/en/bicotest_515_retresco.yml
# Storing file:  output/en/bicotest_515_semant.yml
# Storing file:  output/en/bicotest_515_meaningcloud.yml
# Storing file:  output/en/bicotest_515_basistech.yml
# Storing file:  output/en/bicotest_515_bitext.yml
# Storing file:  output/en/bicotest_515_simple.yml
# Storing file:  output/en/weonetest_393_alchemy.yml
# Storing file:  output/en/weonetest_393_txtrazor.yml
# Storing file:  output/en/weonetest_393_retresco.yml
# Storing file:  output/en/weonetest_393_semant.yml
# Storing file:  output/en/weonetest_393_meaningcloud.yml
# Storing file:  output/en/weonetest_393_basistech.yml
# Storing file:  output/en/weonetest_393_bitext.yml
# Storing file:  output/en/weonetest_393_simple.yml
# Storing file:  output/en/weonetest_157_alchemy.yml
# Storing file:  output/en/weonetest_157_txtrazor.yml
# Storing file:  output/en/weonetest_157_retresco.yml
# Storing file:  output/en/weonetest_157_semant.yml
# Storing file:  output/en/weonetest_157_meaningcloud.yml
# Storing file:  output/en/weonetest_157_basistech.yml
# Storing file:  output/en/weonetest_157_bitext.yml
# Storing file:  output/en/weonetest_157_simple.yml
# Storing file:  output/en/weonetest_676_alchemy.yml
# Storing file:  output/en/weonetest_676_txtrazor.yml
# Storing file:  output/en/weonetest_676_retresco.yml
# Storing file:  output/en/weonetest_676_semant.yml
# Storing file:  output/en/weonetest_676_meaningcloud.yml
# Storing file:  output/en/weonetest_676_basistech.yml
# Storing file:  output/en/weonetest_676_bitext.yml
# Storing file:  output/en/weonetest_676_simple.yml
# Storing file:  output/en/weonetest_738_alchemy.yml
# Storing file:  output/en/weonetest_738_txtrazor.yml
# Storing file:  output/en/weonetest_738_retresco.yml
# Storing file:  output/en/weonetest_738_semant.yml
# Storing file:  output/en/weonetest_738_meaningcloud.yml
# Storing file:  output/en/weonetest_738_basistech.yml
# Storing file:  output/en/weonetest_738_bitext.yml
# Storing file:  output/en/weonetest_738_simple.yml
# Storing file:  output/en/weonetest_734_alchemy.yml
# Storing file:  output/en/weonetest_734_txtrazor.yml
# Storing file:  output/en/weonetest_734_retresco.yml
# Storing file:  output/en/weonetest_734_semant.yml
# Storing file:  output/en/weonetest_734_meaningcloud.yml
# Storing file:  output/en/weonetest_734_basistech.yml
# Storing file:  output/en/weonetest_734_bitext.yml
# Storing file:  output/en/weonetest_734_simple.yml
# Storing file:  output/en/weonetest_055_alchemy.yml
# Storing file:  output/en/weonetest_055_txtrazor.yml
# Storing file:  output/en/weonetest_055_retresco.yml
# Storing file:  output/en/weonetest_055_semant.yml
# Storing file:  output/en/weonetest_055_meaningcloud.yml
# Storing file:  output/en/weonetest_055_basistech.yml
# Storing file:  output/en/weonetest_055_bitext.yml
# Storing file:  output/en/weonetest_055_simple.yml
# Storing file:  output/en/weonetest_1044_alchemy.yml
# Storing file:  output/en/weonetest_1044_txtrazor.yml
# Storing file:  output/en/weonetest_1044_retresco.yml
# Storing file:  output/en/weonetest_1044_semant.yml
# Storing file:  output/en/weonetest_1044_meaningcloud.yml
# Storing file:  output/en/weonetest_1044_basistech.yml
# Storing file:  output/en/weonetest_1044_bitext.yml
# Storing file:  output/en/weonetest_1044_simple.yml
# Storing file:  output/en/weonetest_240_alchemy.yml
# Storing file:  output/en/weonetest_240_txtrazor.yml
# Storing file:  output/en/weonetest_240_retresco.yml
# Storing file:  output/en/weonetest_240_semant.yml
# Storing file:  output/en/weonetest_240_meaningcloud.yml
# Storing file:  output/en/weonetest_240_basistech.yml
# Storing file:  output/en/weonetest_240_bitext.yml
# Storing file:  output/en/weonetest_240_simple.yml
# Storing file:  output/en/weonetest_1124_alchemy.yml
# Storing file:  output/en/weonetest_1124_txtrazor.yml
# Storing file:  output/en/weonetest_1124_retresco.yml
# Storing file:  output/en/weonetest_1124_semant.yml
# Storing file:  output/en/weonetest_1124_meaningcloud.yml
# Storing file:  output/en/weonetest_1124_basistech.yml
# Storing file:  output/en/weonetest_1124_bitext.yml
# Storing file:  output/en/weonetest_1124_simple.yml
# Storing file:  output/en/weonetest_872_alchemy.yml
# Storing file:  output/en/weonetest_872_txtrazor.yml
# Storing file:  output/en/weonetest_872_retresco.yml
# Storing file:  output/en/weonetest_872_semant.yml
# Storing file:  output/en/weonetest_872_meaningcloud.yml
# Storing file:  output/en/weonetest_872_basistech.yml
# Storing file:  output/en/weonetest_872_bitext.yml
# Storing file:  output/en/weonetest_872_simple.yml
# Storing file:  output/en/weonetest_092_alchemy.yml
# Storing file:  output/en/weonetest_092_txtrazor.yml
# Storing file:  output/en/weonetest_092_retresco.yml
# Storing file:  output/en/weonetest_092_semant.yml
# Storing file:  output/en/weonetest_092_meaningcloud.yml
# Storing file:  output/en/weonetest_092_basistech.yml
# Storing file:  output/en/weonetest_092_bitext.yml
# Storing file:  output/en/weonetest_092_simple.yml
# Storing file:  output/en/weonetest_737_alchemy.yml
# Storing file:  output/en/weonetest_737_txtrazor.yml
# Storing file:  output/en/weonetest_737_retresco.yml
# Storing file:  output/en/weonetest_737_semant.yml
# Storing file:  output/en/weonetest_737_meaningcloud.yml
# Storing file:  output/en/weonetest_737_basistech.yml
# Storing file:  output/en/weonetest_737_bitext.yml
# Storing file:  output/en/weonetest_737_simple.yml
# Storing file:  output/en/weonetest_317_alchemy.yml
# Storing file:  output/en/weonetest_317_txtrazor.yml
# Storing file:  output/en/weonetest_317_retresco.yml
# Storing file:  output/en/weonetest_317_semant.yml
# Storing file:  output/en/weonetest_317_meaningcloud.yml
# Storing file:  output/en/weonetest_317_basistech.yml
# Storing file:  output/en/weonetest_317_bitext.yml
# Storing file:  output/en/weonetest_317_simple.yml
# Storing file:  output/en/weonetest_842_alchemy.yml
# Storing file:  output/en/weonetest_842_txtrazor.yml
# Storing file:  output/en/weonetest_842_retresco.yml
# Storing file:  output/en/weonetest_842_semant.yml
# Storing file:  output/en/weonetest_842_meaningcloud.yml
# Storing file:  output/en/weonetest_842_basistech.yml
# Storing file:  output/en/weonetest_842_bitext.yml
# Storing file:  output/en/weonetest_842_simple.yml
# Storing file:  output/en/weonetest_1132_alchemy.yml
# Storing file:  output/en/weonetest_1132_txtrazor.yml
# Storing file:  output/en/weonetest_1132_retresco.yml
# Storing file:  output/en/weonetest_1132_semant.yml
# Storing file:  output/en/weonetest_1132_meaningcloud.yml
# Storing file:  output/en/weonetest_1132_basistech.yml
# Storing file:  output/en/weonetest_1132_bitext.yml
# Storing file:  output/en/weonetest_1132_simple.yml
# Storing file:  output/en/weonetest_711_alchemy.yml
# Storing file:  output/en/weonetest_711_txtrazor.yml
# Storing file:  output/en/weonetest_711_retresco.yml
# Storing file:  output/en/weonetest_711_semant.yml
# Storing file:  output/en/weonetest_711_meaningcloud.yml
# Storing file:  output/en/weonetest_711_basistech.yml
# Storing file:  output/en/weonetest_711_bitext.yml
# Storing file:  output/en/weonetest_711_simple.yml

# %%
import semaeval.statistics as stats

# %%
data=stats.collect_data(articles_enriched)
# Out:
# alchemy bicotest_443.yml float division by zero
# alchemy bicotest_443.yml float division by zero
# txtrazor bicotest_443.yml float division by zero
# txtrazor bicotest_443.yml float division by zero
# retresco bicotest_443.yml float division by zero
# retresco bicotest_443.yml float division by zero
# semant bicotest_443.yml float division by zero
# semant bicotest_443.yml float division by zero
# meaningcloud bicotest_443.yml float division by zero
# meaningcloud bicotest_443.yml float division by zero
# basistech bicotest_443.yml float division by zero
# basistech bicotest_443.yml float division by zero
# bitext bicotest_443.yml float division by zero
# bitext bicotest_443.yml float division by zero
# simple bicotest_443.yml float division by zero
# simple bicotest_443.yml float division by zero
# txtrazor weonetest_549.yml float division by zero
# retresco weonetest_549.yml float division by zero
# semant weonetest_549.yml float division by zero
# meaningcloud weonetest_549.yml float division by zero
# alchemy bicotest_566.yml float division by zero
# semant bicotest_566.yml float division by zero
# meaningcloud bicotest_566.yml float division by zero
# bitext bicotest_566.yml float division by zero
# simple bicotest_566.yml float division by zero
# semant weonetest_982.yml float division by zero
# txtrazor weonetest_923.yml float division by zero
# retresco weonetest_923.yml float division by zero
# semant weonetest_923.yml float division by zero
# meaningcloud weonetest_923.yml float division by zero
# bitext weonetest_923.yml float division by zero
# alchemy bicotest_195.yml float division by zero
# txtrazor bicotest_195.yml float division by zero
# semant bicotest_195.yml float division by zero
# meaningcloud bicotest_195.yml float division by zero
# bitext bicotest_195.yml float division by zero
# alchemy bicotest_583.yml float division by zero
# txtrazor bicotest_583.yml float division by zero
# retresco bicotest_583.yml float division by zero
# semant bicotest_583.yml float division by zero
# meaningcloud bicotest_583.yml float division by zero
# simple bicotest_583.yml float division by zero
# retresco weonetest_889.yml float division by zero
# semant weonetest_889.yml float division by zero
# meaningcloud weonetest_889.yml float division by zero
# meaningcloud bicotest_416.yml float division by zero
# txtrazor bicotest_192.yml float division by zero
# retresco bicotest_192.yml float division by zero
# semant bicotest_192.yml float division by zero
# meaningcloud bicotest_192.yml float division by zero
# semant weonetest_659.yml float division by zero
# meaningcloud weonetest_659.yml float division by zero
# meaningcloud weonetest_659.yml float division by zero
# bitext weonetest_659.yml float division by zero
# bitext weonetest_659.yml float division by zero
# txtrazor weonetest_1029.yml float division by zero
# retresco weonetest_1029.yml float division by zero
# retresco weonetest_1029.yml float division by zero
# semant weonetest_1029.yml float division by zero
# meaningcloud weonetest_1029.yml float division by zero
# bitext weonetest_1029.yml float division by zero
# semant weonetest_769.yml float division by zero
# meaningcloud weonetest_769.yml float division by zero
# meaningcloud weonetest_769.yml float division by zero
# semant weonetest_744.yml float division by zero
# bitext weonetest_744.yml float division by zero
# meaningcloud weonetest_835.yml float division by zero
# retresco bicotest_536.yml float division by zero
# meaningcloud bicotest_536.yml float division by zero
# bitext bicotest_536.yml float division by zero
# simple bicotest_536.yml float division by zero
# txtrazor weonetest_702.yml float division by zero
# retresco weonetest_702.yml float division by zero
# meaningcloud weonetest_702.yml float division by zero
# bitext weonetest_702.yml float division by zero
# semant weonetest_359.yml float division by zero
# txtrazor weonetest_943.yml float division by zero
# retresco weonetest_943.yml float division by zero
# meaningcloud weonetest_943.yml float division by zero
# bitext weonetest_943.yml float division by zero
# semant weonetest_430.yml float division by zero
# meaningcloud weonetest_430.yml float division by zero
# alchemy weonetest_198.yml float division by zero
# txtrazor weonetest_198.yml float division by zero
# retresco weonetest_198.yml float division by zero
# retresco weonetest_198.yml float division by zero
# retresco weonetest_198.yml float division by zero
# semant weonetest_198.yml float division by zero
# semant weonetest_198.yml float division by zero
# meaningcloud weonetest_198.yml float division by zero
# meaningcloud weonetest_198.yml float division by zero
# basistech weonetest_198.yml float division by zero
# bitext weonetest_198.yml float division by zero
# simple weonetest_198.yml float division by zero
# retresco bicotest_588.yml float division by zero
# semant bicotest_588.yml float division by zero
# meaningcloud bicotest_588.yml float division by zero
# bitext bicotest_588.yml float division by zero
# alchemy bicotest_457.yml float division by zero
# txtrazor bicotest_457.yml float division by zero
# retresco bicotest_457.yml float division by zero
# retresco bicotest_457.yml float division by zero
# semant bicotest_457.yml float division by zero
# semant bicotest_457.yml float division by zero
# meaningcloud bicotest_457.yml float division by zero
# txtrazor bicotest_533.yml float division by zero
# retresco bicotest_533.yml float division by zero
# semant bicotest_533.yml float division by zero
# meaningcloud bicotest_533.yml float division by zero
# bitext bicotest_533.yml float division by zero
# semant weonetest_1187.yml float division by zero
# alchemy bicotest_548.yml float division by zero
# alchemy bicotest_548.yml float division by zero
# txtrazor bicotest_548.yml float division by zero
# txtrazor bicotest_548.yml float division by zero
# retresco bicotest_548.yml float division by zero
# retresco bicotest_548.yml float division by zero
# semant bicotest_548.yml float division by zero
# semant bicotest_548.yml float division by zero
# meaningcloud bicotest_548.yml float division by zero
# meaningcloud bicotest_548.yml float division by zero
# basistech bicotest_548.yml float division by zero
# basistech bicotest_548.yml float division by zero
# bitext bicotest_548.yml float division by zero
# bitext bicotest_548.yml float division by zero
# simple bicotest_548.yml float division by zero
# simple bicotest_548.yml float division by zero
# retresco weonetest_506.yml float division by zero
# retresco weonetest_506.yml float division by zero
# semant weonetest_506.yml float division by zero
# bitext weonetest_506.yml float division by zero
# simple weonetest_506.yml float division by zero
# semant weonetest_1205.yml float division by zero
# semant weonetest_1205.yml float division by zero
# semant bicotest_153.yml float division by zero
# meaningcloud bicotest_153.yml float division by zero
# basistech bicotest_153.yml float division by zero
# bitext bicotest_153.yml float division by zero
# txtrazor weonetest_141.yml float division by zero
# retresco weonetest_141.yml float division by zero
# semant weonetest_141.yml float division by zero
# meaningcloud weonetest_141.yml float division by zero
# alchemy bicotest_490.yml float division by zero
# txtrazor bicotest_490.yml float division by zero
# retresco bicotest_490.yml float division by zero
# semant bicotest_490.yml float division by zero
# meaningcloud bicotest_490.yml float division by zero
# basistech bicotest_490.yml float division by zero
# bitext bicotest_490.yml float division by zero
# simple bicotest_490.yml float division by zero
# semant weonetest_1081.yml float division by zero
# meaningcloud weonetest_1081.yml float division by zero
# meaningcloud weonetest_1081.yml float division by zero
# meaningcloud weonetest_1081.yml float division by zero
# alchemy bicotest_505.yml float division by zero
# retresco bicotest_505.yml float division by zero
# semant bicotest_505.yml float division by zero
# meaningcloud bicotest_505.yml float division by zero
# meaningcloud bicotest_505.yml float division by zero
# basistech bicotest_505.yml float division by zero
# bitext bicotest_505.yml float division by zero
# txtrazor bicotest_515.yml float division by zero
# meaningcloud bicotest_515.yml float division by zero
# txtrazor weonetest_393.yml float division by zero
# semant weonetest_393.yml float division by zero
# meaningcloud weonetest_393.yml float division by zero
# txtrazor weonetest_157.yml float division by zero
# semant weonetest_157.yml float division by zero
# meaningcloud weonetest_157.yml float division by zero
# alchemy weonetest_676.yml float division by zero
# txtrazor weonetest_676.yml float division by zero
# retresco weonetest_676.yml float division by zero
# retresco weonetest_676.yml float division by zero
# semant weonetest_676.yml float division by zero
# semant weonetest_676.yml float division by zero
# meaningcloud weonetest_676.yml float division by zero
# basistech weonetest_676.yml float division by zero
# bitext weonetest_676.yml float division by zero
# bitext weonetest_676.yml float division by zero
# txtrazor weonetest_738.yml float division by zero
# retresco weonetest_738.yml float division by zero
# semant weonetest_738.yml float division by zero
# semant weonetest_734.yml float division by zero
# retresco weonetest_1044.yml float division by zero
# semant weonetest_1044.yml float division by zero
# semant weonetest_240.yml float division by zero
# semant weonetest_1124.yml float division by zero
# meaningcloud weonetest_1124.yml float division by zero
# bitext weonetest_1124.yml float division by zero
# alchemy weonetest_872.yml float division by zero
# retresco weonetest_872.yml float division by zero
# semant weonetest_872.yml float division by zero
# meaningcloud weonetest_872.yml float division by zero
# meaningcloud weonetest_872.yml float division by zero
# bitext weonetest_872.yml float division by zero
# meaningcloud weonetest_737.yml float division by zero
# txtrazor weonetest_317.yml float division by zero
# retresco weonetest_317.yml float division by zero
# semant weonetest_317.yml float division by zero
# meaningcloud weonetest_317.yml float division by zero
# bitext weonetest_317.yml float division by zero
# simple weonetest_317.yml float division by zero
# semant weonetest_842.yml float division by zero
# meaningcloud weonetest_1132.yml float division by zero
# semant weonetest_711.yml float division by zero

# %%
results=stats.aggregate_result(data)

# %%
results.extend(stats.compute_total(results))

# %%
# %matplotlib inline

# %%
stats.plot_results(results)

# %%
stats.store_results(results,"en")
# Out:
# Storing file:  en_results.yml
