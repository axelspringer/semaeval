# %%
import semaeval.util as util
util.clean_storage("en")
# Out:
# Deleting: input/en/bicotest_038.yml
# Deleting: input/en/bicotest_067.yml
# Deleting: input/en/bicotest_074.yml
# Deleting: input/en/bicotest_077.yml
# Deleting: input/en/bicotest_101.yml
# Deleting: input/en/bicotest_113.yml
# Deleting: input/en/bicotest_119.yml
# Deleting: input/en/bicotest_126.yml
# Deleting: input/en/bicotest_167.yml
# Deleting: input/en/bicotest_184.yml
# Deleting: input/en/bicotest_216.yml
# Deleting: input/en/bicotest_226.yml
# Deleting: input/en/bicotest_238.yml
# Deleting: input/en/bicotest_248.yml
# Deleting: input/en/bicotest_342.yml
# Deleting: input/en/bicotest_354.yml
# Deleting: input/en/bicotest_357.yml
# Deleting: input/en/bicotest_388.yml
# Deleting: input/en/bicotest_494.yml
# Deleting: input/en/bicotest_575.yml
# Deleting: input/en/bicotest_585.yml
# Deleting: input/en/weonetest_047.yml
# Deleting: input/en/weonetest_077.yml
# Deleting: input/en/weonetest_080.yml
# Deleting: input/en/weonetest_1000.yml
# Deleting: input/en/weonetest_1020.yml
# Deleting: input/en/weonetest_1037.yml
# Deleting: input/en/weonetest_1112.yml
# Deleting: input/en/weonetest_1219.yml
# Deleting: input/en/weonetest_156.yml
# Deleting: input/en/weonetest_176.yml
# Deleting: input/en/weonetest_220.yml
# Deleting: input/en/weonetest_291.yml
# Deleting: input/en/weonetest_354.yml
# Deleting: input/en/weonetest_357.yml
# Deleting: input/en/weonetest_390.yml
# Deleting: input/en/weonetest_471.yml
# Deleting: input/en/weonetest_481.yml
# Deleting: input/en/weonetest_487.yml
# Deleting: input/en/weonetest_494.yml
# Deleting: input/en/weonetest_615.yml
# Deleting: input/en/weonetest_666.yml
# Deleting: input/en/weonetest_687.yml
# Deleting: input/en/weonetest_703.yml
# Deleting: input/en/weonetest_754.yml
# Deleting: input/en/weonetest_806.yml
# Deleting: input/en/weonetest_911.yml
# Deleting: input/en/weonetest_932.yml
# Deleting: input/en/weonetest_957.yml
# Deleting: input/en/weonetest_959.yml
# [Errno 2] No such file or directory: 'result/en'

# %%
import semaeval.source.syndication as synd

# %%
help(synd)
# Out:
# Help on module semaeval.source.syndication in semaeval.source:
#
# NAME
#     semaeval.source.syndication - # -*- coding: utf-8 -*-
#
# FILE
#     /Users/amaier1/git/semaeval/semaeval/source/syndication.py
#
# FUNCTIONS
#     article_from_path(path)
#
#     articles_from_dir(dir)
#
#     load_articles(prefix)
#
#     store_articles(articles, prefix)
#
# DATA
#     store_dir = 'input/'
#     url_regex = <_sre.SRE_Pattern object>

# %%
bild = synd.articles_from_dir("/Users/amaier1/Documents/semeval/bicotest")

# %%
welt = synd.articles_from_dir("/Users/amaier1/Documents/semeval/weonetest")

# %%
wild = bild + welt

# %%
import random
articles = random.sample(wild,50)

# %%
synd.store_articles(articles,"en")
# Out:
# Storing file:  input/en/bicotest_182.yml
# Storing file:  input/en/weonetest_439.yml
# Storing file:  input/en/bicotest_191.yml
# Storing file:  input/en/weonetest_897.yml
# Storing file:  input/en/weonetest_556.yml
# Storing file:  input/en/weonetest_711.yml
# Storing file:  input/en/weonetest_1157.yml
# Storing file:  input/en/bicotest_546.yml
# Storing file:  input/en/bicotest_399.yml
# Storing file:  input/en/bicotest_065.yml
# Storing file:  input/en/weonetest_661.yml
# Storing file:  input/en/weonetest_409.yml
# Storing file:  input/en/bicotest_235.yml
# Storing file:  input/en/weonetest_481.yml
# Storing file:  input/en/bicotest_286.yml
# Storing file:  input/en/weonetest_1125.yml
# Storing file:  input/en/weonetest_674.yml
# Storing file:  input/en/weonetest_895.yml
# Storing file:  input/en/weonetest_082.yml
# Storing file:  input/en/weonetest_1217.yml
# Storing file:  input/en/weonetest_611.yml
# Storing file:  input/en/weonetest_802.yml
# Storing file:  input/en/weonetest_1149.yml
# Storing file:  input/en/bicotest_587.yml
# Storing file:  input/en/weonetest_776.yml
# Storing file:  input/en/bicotest_279.yml
# Storing file:  input/en/weonetest_685.yml
# Storing file:  input/en/bicotest_551.yml
# Storing file:  input/en/weonetest_583.yml
# Storing file:  input/en/bicotest_360.yml
# Storing file:  input/en/weonetest_887.yml
# Storing file:  input/en/weonetest_509.yml
# Storing file:  input/en/weonetest_982.yml
# Storing file:  input/en/weonetest_751.yml
# Storing file:  input/en/weonetest_821.yml
# Storing file:  input/en/bicotest_234.yml
# Storing file:  input/en/weonetest_772.yml
# Storing file:  input/en/bicotest_475.yml
# Storing file:  input/en/weonetest_626.yml
# Storing file:  input/en/weonetest_105.yml
# Storing file:  input/en/weonetest_177.yml
# Storing file:  input/en/weonetest_755.yml
# Storing file:  input/en/weonetest_1076.yml
# Storing file:  input/en/bicotest_054.yml
# Storing file:  input/en/weonetest_826.yml
# Storing file:  input/en/weonetest_188.yml
# Storing file:  input/en/weonetest_873.yml
# Storing file:  input/en/bicotest_059.yml
# Storing file:  input/en/bicotest_331.yml
# Storing file:  input/en/weonetest_980.yml

# %%
import semaeval.evaluate as eval

# %%
articles_enriched = eval.detect_entities(articles,"en")
# Out:
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-football/2010/04/30/qatar-2022-bid/sheikh-ing-up-world-cup-with-air-conditioned-stadiums.html
# Collecting results:
# Filename: weonetest_439.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/05/05/woman-in-peru-tortured-by-gigantism/breasts-swelled-to-12-kilos.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.alchemy
# Filename: weonetest_897.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_556.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Timeout Error
# Ignoring results for this document.
# Filename: weonetest_711.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.linguasys
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# textrazor:bitext: [u'Date']
#  11
# textrazor: [u'Date']
# URL: http://www.welt.de/international/article4080394/South-Korea-on-edge-following-cyber-attacks.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# meaningcloud: Top>Process>IntentionalProcess
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/07/28/names-secret-agents-00blonde/us-uncovers-yet-another-sexy-russian-spy.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.linguasys
# semaeval.engine.semant
# semaeval.engine.simple
# semaeval.engine.retresco
# semaeval.engine.alchemy
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/06/28/holland-2-1-slovakia/arjen-robben-fires-dutch-into-quarter-finals.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.meaningcloud
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.alchemy
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/03/25/angela-merkel-statement-on-greek-financial-crisis/greece-to-get-money-only-in-extreme-emergency.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_661.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.bitext
# semaeval.engine.retresco
# semaeval.engine.simple
# textrazor: [u'Flag']
# Filename: weonetest_409.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/05/21/muslim-turkish-german-teen/melda-my-life-between-miniskirt-and-mosque.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semantria:alchemy: FinancialMarketIndex
#  vehicle
# Filename: weonetest_481.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/06/07/germany-budget-cuts/austerity-deal-calls-for-80bn-saving-by-2014.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.linguasys
# URL: http://www.welt.de/international/article4049808/Custody-battle-looms-over-memorial-service-plans.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_674.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# bitext: 11
# bitext: 130
# bitext: 130
# Filename: weonetest_895.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# alchemy: GeographicFeature
# alchemy: GeographicFeature
# alchemy: Crime
# Filename: weonetest_082.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# textrazor:alchemy: [u'MeanOfTransportation', u'Aircraft']
#  GeographicFeature
# textrazor: [u'MeanOfTransportation', u'Aircraft']
# alchemy: GeographicFeature
# textrazor: [u'MeanOfTransportation', u'Aircraft']
# textrazor: [u'MeanOfTransportation', u'Aircraft']
# textrazor: [u'MeanOfTransportation', u'Aircraft']
# URL: http://www.welt.de/international/article4145524/Hardliners-hit-back-at-Rafsanjani-for-criticism.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.alchemy
# Filename: weonetest_611.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# linguasys: team
# Filename: weonetest_802.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# meaningcloud: Top>Event>War
# URL: http://www.welt.de/international/article4073365/Uighurs-launch-fresh-protests-in-Xinjiang.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# textrazor:alchemy: Crime
#  [u'UnitOfWork', u'Case', u'LegalCase', u'SupremeCourtOfTheUnitedStatesCase']
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-football/2010/08/10/germanys-big-captain-question/has-jogi-loew-already-decided-against-ballack.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_776.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# linguasys: team
# linguasys: team
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/06/03/lindsay-lohan-pain-medication/did-star-trick-judge-with-wisdom-teeth-op.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# linguasys:alchemy: GeographicFeature
#  team
# Filename: weonetest_685.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# bitext: 130
# bitext: 130
# Timeout Error
# Ignoring results for this document.
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/07/29/katie-price-new-novel/busty-book-launch-with-jordan-now-thats-paradise.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# textrazor:meaningcloud: [u'MeanOfTransportation', u'Aircraft']
#  Top>Event>War
# Filename: weonetest_583.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/06/21/chile-1-0-switzerland/swiss-coach-hitzfeld-rages-at-card-happy-ref.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.linguasys
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_887.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_509.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# alchemy: GeographicFeature
# URL: http://www.welt.de/english-news/article3843754/Chances-of-finding-survivors-from-missing-jet-tiny.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_751.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# textrazor:alchemy: GeographicFeature
#  [u'MeanOfTransportation', u'Aircraft']
# textrazor: [u'MeanOfTransportation', u'Aircraft']
# textrazor: [u'MeanOfTransportation', u'Aircraft']
# textrazor: [u'MeanOfTransportation', u'Aircraft']
# textrazor: [u'MeanOfTransportation', u'Aircraft']
# textrazor: [u'MeanOfTransportation', u'Aircraft']
# Filename: weonetest_821.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# URL: http://www.bild.de/BILD/news/bild-english/world-news/2010/05/21/paris-museum-robbery/did-100m-art-thief-have-inside-accomplice.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.linguasys
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.simple
# Filename: weonetest_772.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# alchemy: Crime
# alchemy: Crime
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/07/12/iker-casillas-sara-carbonero/keepers-live-smooch-attack-on-tv-reporter-girlfriend.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.linguasys
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_626.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_105.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semantria: vehicle
# Filename: weonetest_177.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_755.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.simple
# alchemy: GeographicFeature
# alchemy: GeographicFeature
# URL: http://www.welt.de/international/article3979410/Irans-Revolutionary-Guards-threaten-crackdown.html#reqRSS
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/celebrity-gossip/2010/03/22/lindsay-lohan-britney-spears/bare-boob-look-who-is-hottest-bra-less-beauty.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# meaningcloud: Top>OtherEntity>MethodSystem
# Filename: weonetest_826.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: weonetest_188.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# meaningcloud: Top>Process>Motion
# Filename: weonetest_873.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/more-sport/2010/03/23/vitali-vs-wladimir/klitschko-brothers-boxing-fight-everyone-wants-to-see.html
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.simple
# bitext:alchemy: 4
#  TelevisionStation
# URL: http://www.bild.de/BILD/news/bild-english/sport-news/football/world-cup-2010-south-africa/06/15/kaiser-franz-beckenbauer/germany-star-mesut-oezil-passes-it-like-messi.html
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# bitext: 11
# URL: http://www.welt.de/english-news/article3845933/Military-turn-to-internet-fad-for-Afghan-hard-news.html#reqRSS
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.linguasys
# semaeval.engine.simple
# semaeval.engine.retresco
# linguasys: team
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.linguasys
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# meaningcloud: Top>OtherEntity>MethodSystem

# %%
eval.store_articles(articles_enriched,"en")
# Out:
# Storing file:  output/en/bicotest_182_retresco.yml
# Storing file:  output/en/bicotest_182_meaningcloud.yml
# Storing file:  output/en/bicotest_182_txtrazor.yml
# Storing file:  output/en/bicotest_182_simple.yml
# Storing file:  output/en/bicotest_182_semant.yml
# Storing file:  output/en/bicotest_182_linguasys.yml
# Storing file:  output/en/bicotest_182_bitext.yml
# Storing file:  output/en/bicotest_182_alchemy.yml
# Storing file:  output/en/weonetest_439_retresco.yml
# Storing file:  output/en/weonetest_439_meaningcloud.yml
# Storing file:  output/en/weonetest_439_txtrazor.yml
# Storing file:  output/en/weonetest_439_simple.yml
# Storing file:  output/en/weonetest_439_semant.yml
# Storing file:  output/en/weonetest_439_linguasys.yml
# Storing file:  output/en/weonetest_439_bitext.yml
# Storing file:  output/en/weonetest_439_alchemy.yml
# Storing file:  output/en/bicotest_191_retresco.yml
# Storing file:  output/en/bicotest_191_meaningcloud.yml
# Storing file:  output/en/bicotest_191_txtrazor.yml
# Storing file:  output/en/bicotest_191_simple.yml
# Storing file:  output/en/bicotest_191_semant.yml
# Storing file:  output/en/bicotest_191_linguasys.yml
# Storing file:  output/en/bicotest_191_bitext.yml
# Storing file:  output/en/bicotest_191_alchemy.yml
# Storing file:  output/en/weonetest_897_retresco.yml
# Storing file:  output/en/weonetest_897_meaningcloud.yml
# Storing file:  output/en/weonetest_897_txtrazor.yml
# Storing file:  output/en/weonetest_897_simple.yml
# Storing file:  output/en/weonetest_897_semant.yml
# Storing file:  output/en/weonetest_897_linguasys.yml
# Storing file:  output/en/weonetest_897_bitext.yml
# Storing file:  output/en/weonetest_897_alchemy.yml
# Storing file:  output/en/weonetest_711_retresco.yml
# Storing file:  output/en/weonetest_711_meaningcloud.yml
# Storing file:  output/en/weonetest_711_txtrazor.yml
# Storing file:  output/en/weonetest_711_simple.yml
# Storing file:  output/en/weonetest_711_semant.yml
# Storing file:  output/en/weonetest_711_linguasys.yml
# Storing file:  output/en/weonetest_711_bitext.yml
# Storing file:  output/en/weonetest_711_alchemy.yml
# Storing file:  output/en/weonetest_1157_retresco.yml
# Storing file:  output/en/weonetest_1157_meaningcloud.yml
# Storing file:  output/en/weonetest_1157_txtrazor.yml
# Storing file:  output/en/weonetest_1157_simple.yml
# Storing file:  output/en/weonetest_1157_semant.yml
# Storing file:  output/en/weonetest_1157_linguasys.yml
# Storing file:  output/en/weonetest_1157_bitext.yml
# Storing file:  output/en/weonetest_1157_alchemy.yml
# Storing file:  output/en/bicotest_546_retresco.yml
# Storing file:  output/en/bicotest_546_meaningcloud.yml
# Storing file:  output/en/bicotest_546_txtrazor.yml
# Storing file:  output/en/bicotest_546_simple.yml
# Storing file:  output/en/bicotest_546_semant.yml
# Storing file:  output/en/bicotest_546_linguasys.yml
# Storing file:  output/en/bicotest_546_bitext.yml
# Storing file:  output/en/bicotest_546_alchemy.yml
# Storing file:  output/en/bicotest_399_retresco.yml
# Storing file:  output/en/bicotest_399_meaningcloud.yml
# Storing file:  output/en/bicotest_399_txtrazor.yml
# Storing file:  output/en/bicotest_399_simple.yml
# Storing file:  output/en/bicotest_399_semant.yml
# Storing file:  output/en/bicotest_399_linguasys.yml
# Storing file:  output/en/bicotest_399_bitext.yml
# Storing file:  output/en/bicotest_399_alchemy.yml
# Storing file:  output/en/bicotest_065_retresco.yml
# Storing file:  output/en/bicotest_065_meaningcloud.yml
# Storing file:  output/en/bicotest_065_txtrazor.yml
# Storing file:  output/en/bicotest_065_simple.yml
# Storing file:  output/en/bicotest_065_semant.yml
# Storing file:  output/en/bicotest_065_linguasys.yml
# Storing file:  output/en/bicotest_065_bitext.yml
# Storing file:  output/en/bicotest_065_alchemy.yml
# Storing file:  output/en/weonetest_661_retresco.yml
# Storing file:  output/en/weonetest_661_meaningcloud.yml
# Storing file:  output/en/weonetest_661_txtrazor.yml
# Storing file:  output/en/weonetest_661_simple.yml
# Storing file:  output/en/weonetest_661_semant.yml
# Storing file:  output/en/weonetest_661_linguasys.yml
# Storing file:  output/en/weonetest_661_bitext.yml
# Storing file:  output/en/weonetest_661_alchemy.yml
# Storing file:  output/en/weonetest_409_retresco.yml
# Storing file:  output/en/weonetest_409_meaningcloud.yml
# Storing file:  output/en/weonetest_409_txtrazor.yml
# Storing file:  output/en/weonetest_409_simple.yml
# Storing file:  output/en/weonetest_409_semant.yml
# Storing file:  output/en/weonetest_409_linguasys.yml
# Storing file:  output/en/weonetest_409_bitext.yml
# Storing file:  output/en/weonetest_409_alchemy.yml
# Storing file:  output/en/bicotest_235_retresco.yml
# Storing file:  output/en/bicotest_235_meaningcloud.yml
# Storing file:  output/en/bicotest_235_txtrazor.yml
# Storing file:  output/en/bicotest_235_simple.yml
# Storing file:  output/en/bicotest_235_semant.yml
# Storing file:  output/en/bicotest_235_linguasys.yml
# Storing file:  output/en/bicotest_235_bitext.yml
# Storing file:  output/en/bicotest_235_alchemy.yml
# Storing file:  output/en/weonetest_481_retresco.yml
# Storing file:  output/en/weonetest_481_meaningcloud.yml
# Storing file:  output/en/weonetest_481_txtrazor.yml
# Storing file:  output/en/weonetest_481_simple.yml
# Storing file:  output/en/weonetest_481_semant.yml
# Storing file:  output/en/weonetest_481_linguasys.yml
# Storing file:  output/en/weonetest_481_bitext.yml
# Storing file:  output/en/weonetest_481_alchemy.yml
# Storing file:  output/en/bicotest_286_retresco.yml
# Storing file:  output/en/bicotest_286_meaningcloud.yml
# Storing file:  output/en/bicotest_286_txtrazor.yml
# Storing file:  output/en/bicotest_286_simple.yml
# Storing file:  output/en/bicotest_286_semant.yml
# Storing file:  output/en/bicotest_286_linguasys.yml
# Storing file:  output/en/bicotest_286_bitext.yml
# Storing file:  output/en/bicotest_286_alchemy.yml
# Storing file:  output/en/weonetest_1125_retresco.yml
# Storing file:  output/en/weonetest_1125_meaningcloud.yml
# Storing file:  output/en/weonetest_1125_txtrazor.yml
# Storing file:  output/en/weonetest_1125_simple.yml
# Storing file:  output/en/weonetest_1125_semant.yml
# Storing file:  output/en/weonetest_1125_linguasys.yml
# Storing file:  output/en/weonetest_1125_bitext.yml
# Storing file:  output/en/weonetest_1125_alchemy.yml
# Storing file:  output/en/weonetest_674_retresco.yml
# Storing file:  output/en/weonetest_674_meaningcloud.yml
# Storing file:  output/en/weonetest_674_txtrazor.yml
# Storing file:  output/en/weonetest_674_simple.yml
# Storing file:  output/en/weonetest_674_semant.yml
# Storing file:  output/en/weonetest_674_linguasys.yml
# Storing file:  output/en/weonetest_674_bitext.yml
# Storing file:  output/en/weonetest_674_alchemy.yml
# Storing file:  output/en/weonetest_895_retresco.yml
# Storing file:  output/en/weonetest_895_meaningcloud.yml
# Storing file:  output/en/weonetest_895_txtrazor.yml
# Storing file:  output/en/weonetest_895_simple.yml
# Storing file:  output/en/weonetest_895_semant.yml
# Storing file:  output/en/weonetest_895_linguasys.yml
# Storing file:  output/en/weonetest_895_bitext.yml
# Storing file:  output/en/weonetest_895_alchemy.yml
# Storing file:  output/en/weonetest_082_retresco.yml
# Storing file:  output/en/weonetest_082_meaningcloud.yml
# Storing file:  output/en/weonetest_082_txtrazor.yml
# Storing file:  output/en/weonetest_082_simple.yml
# Storing file:  output/en/weonetest_082_semant.yml
# Storing file:  output/en/weonetest_082_linguasys.yml
# Storing file:  output/en/weonetest_082_bitext.yml
# Storing file:  output/en/weonetest_082_alchemy.yml
# Storing file:  output/en/weonetest_1217_retresco.yml
# Storing file:  output/en/weonetest_1217_meaningcloud.yml
# Storing file:  output/en/weonetest_1217_txtrazor.yml
# Storing file:  output/en/weonetest_1217_simple.yml
# Storing file:  output/en/weonetest_1217_semant.yml
# Storing file:  output/en/weonetest_1217_linguasys.yml
# Storing file:  output/en/weonetest_1217_bitext.yml
# Storing file:  output/en/weonetest_1217_alchemy.yml
# Storing file:  output/en/weonetest_611_retresco.yml
# Storing file:  output/en/weonetest_611_meaningcloud.yml
# Storing file:  output/en/weonetest_611_txtrazor.yml
# Storing file:  output/en/weonetest_611_simple.yml
# Storing file:  output/en/weonetest_611_semant.yml
# Storing file:  output/en/weonetest_611_linguasys.yml
# Storing file:  output/en/weonetest_611_bitext.yml
# Storing file:  output/en/weonetest_611_alchemy.yml
# Storing file:  output/en/weonetest_802_retresco.yml
# Storing file:  output/en/weonetest_802_meaningcloud.yml
# Storing file:  output/en/weonetest_802_txtrazor.yml
# Storing file:  output/en/weonetest_802_simple.yml
# Storing file:  output/en/weonetest_802_semant.yml
# Storing file:  output/en/weonetest_802_linguasys.yml
# Storing file:  output/en/weonetest_802_bitext.yml
# Storing file:  output/en/weonetest_802_alchemy.yml
# Storing file:  output/en/weonetest_1149_retresco.yml
# Storing file:  output/en/weonetest_1149_meaningcloud.yml
# Storing file:  output/en/weonetest_1149_txtrazor.yml
# Storing file:  output/en/weonetest_1149_simple.yml
# Storing file:  output/en/weonetest_1149_semant.yml
# Storing file:  output/en/weonetest_1149_linguasys.yml
# Storing file:  output/en/weonetest_1149_bitext.yml
# Storing file:  output/en/weonetest_1149_alchemy.yml
# Storing file:  output/en/bicotest_587_retresco.yml
# Storing file:  output/en/bicotest_587_meaningcloud.yml
# Storing file:  output/en/bicotest_587_txtrazor.yml
# Storing file:  output/en/bicotest_587_simple.yml
# Storing file:  output/en/bicotest_587_semant.yml
# Storing file:  output/en/bicotest_587_linguasys.yml
# Storing file:  output/en/bicotest_587_bitext.yml
# Storing file:  output/en/bicotest_587_alchemy.yml
# Storing file:  output/en/weonetest_776_retresco.yml
# Storing file:  output/en/weonetest_776_meaningcloud.yml
# Storing file:  output/en/weonetest_776_txtrazor.yml
# Storing file:  output/en/weonetest_776_simple.yml
# Storing file:  output/en/weonetest_776_semant.yml
# Storing file:  output/en/weonetest_776_linguasys.yml
# Storing file:  output/en/weonetest_776_bitext.yml
# Storing file:  output/en/weonetest_776_alchemy.yml
# Storing file:  output/en/bicotest_279_retresco.yml
# Storing file:  output/en/bicotest_279_meaningcloud.yml
# Storing file:  output/en/bicotest_279_txtrazor.yml
# Storing file:  output/en/bicotest_279_simple.yml
# Storing file:  output/en/bicotest_279_semant.yml
# Storing file:  output/en/bicotest_279_linguasys.yml
# Storing file:  output/en/bicotest_279_bitext.yml
# Storing file:  output/en/bicotest_279_alchemy.yml
# Storing file:  output/en/bicotest_551_retresco.yml
# Storing file:  output/en/bicotest_551_meaningcloud.yml
# Storing file:  output/en/bicotest_551_txtrazor.yml
# Storing file:  output/en/bicotest_551_simple.yml
# Storing file:  output/en/bicotest_551_semant.yml
# Storing file:  output/en/bicotest_551_linguasys.yml
# Storing file:  output/en/bicotest_551_bitext.yml
# Storing file:  output/en/bicotest_551_alchemy.yml
# Storing file:  output/en/weonetest_583_retresco.yml
# Storing file:  output/en/weonetest_583_meaningcloud.yml
# Storing file:  output/en/weonetest_583_txtrazor.yml
# Storing file:  output/en/weonetest_583_simple.yml
# Storing file:  output/en/weonetest_583_semant.yml
# Storing file:  output/en/weonetest_583_linguasys.yml
# Storing file:  output/en/weonetest_583_bitext.yml
# Storing file:  output/en/weonetest_583_alchemy.yml
# Storing file:  output/en/bicotest_360_retresco.yml
# Storing file:  output/en/bicotest_360_meaningcloud.yml
# Storing file:  output/en/bicotest_360_txtrazor.yml
# Storing file:  output/en/bicotest_360_simple.yml
# Storing file:  output/en/bicotest_360_semant.yml
# Storing file:  output/en/bicotest_360_linguasys.yml
# Storing file:  output/en/bicotest_360_bitext.yml
# Storing file:  output/en/bicotest_360_alchemy.yml
# Storing file:  output/en/weonetest_887_retresco.yml
# Storing file:  output/en/weonetest_887_meaningcloud.yml
# Storing file:  output/en/weonetest_887_txtrazor.yml
# Storing file:  output/en/weonetest_887_simple.yml
# Storing file:  output/en/weonetest_887_semant.yml
# Storing file:  output/en/weonetest_887_linguasys.yml
# Storing file:  output/en/weonetest_887_bitext.yml
# Storing file:  output/en/weonetest_887_alchemy.yml
# Storing file:  output/en/weonetest_509_retresco.yml
# Storing file:  output/en/weonetest_509_meaningcloud.yml
# Storing file:  output/en/weonetest_509_txtrazor.yml
# Storing file:  output/en/weonetest_509_simple.yml
# Storing file:  output/en/weonetest_509_semant.yml
# Storing file:  output/en/weonetest_509_linguasys.yml
# Storing file:  output/en/weonetest_509_bitext.yml
# Storing file:  output/en/weonetest_509_alchemy.yml
# Storing file:  output/en/weonetest_982_retresco.yml
# Storing file:  output/en/weonetest_982_meaningcloud.yml
# Storing file:  output/en/weonetest_982_txtrazor.yml
# Storing file:  output/en/weonetest_982_simple.yml
# Storing file:  output/en/weonetest_982_semant.yml
# Storing file:  output/en/weonetest_982_linguasys.yml
# Storing file:  output/en/weonetest_982_bitext.yml
# Storing file:  output/en/weonetest_982_alchemy.yml
# Storing file:  output/en/weonetest_751_retresco.yml
# Storing file:  output/en/weonetest_751_meaningcloud.yml
# Storing file:  output/en/weonetest_751_txtrazor.yml
# Storing file:  output/en/weonetest_751_simple.yml
# Storing file:  output/en/weonetest_751_semant.yml
# Storing file:  output/en/weonetest_751_linguasys.yml
# Storing file:  output/en/weonetest_751_bitext.yml
# Storing file:  output/en/weonetest_751_alchemy.yml
# Storing file:  output/en/weonetest_821_retresco.yml
# Storing file:  output/en/weonetest_821_meaningcloud.yml
# Storing file:  output/en/weonetest_821_txtrazor.yml
# Storing file:  output/en/weonetest_821_simple.yml
# Storing file:  output/en/weonetest_821_semant.yml
# Storing file:  output/en/weonetest_821_linguasys.yml
# Storing file:  output/en/weonetest_821_bitext.yml
# Storing file:  output/en/weonetest_821_alchemy.yml
# Storing file:  output/en/bicotest_234_retresco.yml
# Storing file:  output/en/bicotest_234_meaningcloud.yml
# Storing file:  output/en/bicotest_234_txtrazor.yml
# Storing file:  output/en/bicotest_234_simple.yml
# Storing file:  output/en/bicotest_234_semant.yml
# Storing file:  output/en/bicotest_234_linguasys.yml
# Storing file:  output/en/bicotest_234_bitext.yml
# Storing file:  output/en/bicotest_234_alchemy.yml
# Storing file:  output/en/weonetest_772_retresco.yml
# Storing file:  output/en/weonetest_772_meaningcloud.yml
# Storing file:  output/en/weonetest_772_txtrazor.yml
# Storing file:  output/en/weonetest_772_simple.yml
# Storing file:  output/en/weonetest_772_semant.yml
# Storing file:  output/en/weonetest_772_linguasys.yml
# Storing file:  output/en/weonetest_772_bitext.yml
# Storing file:  output/en/weonetest_772_alchemy.yml
# Storing file:  output/en/bicotest_475_retresco.yml
# Storing file:  output/en/bicotest_475_meaningcloud.yml
# Storing file:  output/en/bicotest_475_txtrazor.yml
# Storing file:  output/en/bicotest_475_simple.yml
# Storing file:  output/en/bicotest_475_semant.yml
# Storing file:  output/en/bicotest_475_linguasys.yml
# Storing file:  output/en/bicotest_475_bitext.yml
# Storing file:  output/en/bicotest_475_alchemy.yml
# Storing file:  output/en/weonetest_626_retresco.yml
# Storing file:  output/en/weonetest_626_meaningcloud.yml
# Storing file:  output/en/weonetest_626_txtrazor.yml
# Storing file:  output/en/weonetest_626_simple.yml
# Storing file:  output/en/weonetest_626_semant.yml
# Storing file:  output/en/weonetest_626_linguasys.yml
# Storing file:  output/en/weonetest_626_bitext.yml
# Storing file:  output/en/weonetest_626_alchemy.yml
# Storing file:  output/en/weonetest_105_retresco.yml
# Storing file:  output/en/weonetest_105_meaningcloud.yml
# Storing file:  output/en/weonetest_105_txtrazor.yml
# Storing file:  output/en/weonetest_105_simple.yml
# Storing file:  output/en/weonetest_105_semant.yml
# Storing file:  output/en/weonetest_105_linguasys.yml
# Storing file:  output/en/weonetest_105_bitext.yml
# Storing file:  output/en/weonetest_105_alchemy.yml
# Storing file:  output/en/weonetest_177_retresco.yml
# Storing file:  output/en/weonetest_177_meaningcloud.yml
# Storing file:  output/en/weonetest_177_txtrazor.yml
# Storing file:  output/en/weonetest_177_simple.yml
# Storing file:  output/en/weonetest_177_semant.yml
# Storing file:  output/en/weonetest_177_linguasys.yml
# Storing file:  output/en/weonetest_177_bitext.yml
# Storing file:  output/en/weonetest_177_alchemy.yml
# Storing file:  output/en/weonetest_755_retresco.yml
# Storing file:  output/en/weonetest_755_meaningcloud.yml
# Storing file:  output/en/weonetest_755_txtrazor.yml
# Storing file:  output/en/weonetest_755_simple.yml
# Storing file:  output/en/weonetest_755_semant.yml
# Storing file:  output/en/weonetest_755_linguasys.yml
# Storing file:  output/en/weonetest_755_bitext.yml
# Storing file:  output/en/weonetest_755_alchemy.yml
# Storing file:  output/en/weonetest_1076_retresco.yml
# Storing file:  output/en/weonetest_1076_meaningcloud.yml
# Storing file:  output/en/weonetest_1076_txtrazor.yml
# Storing file:  output/en/weonetest_1076_simple.yml
# Storing file:  output/en/weonetest_1076_semant.yml
# Storing file:  output/en/weonetest_1076_linguasys.yml
# Storing file:  output/en/weonetest_1076_bitext.yml
# Storing file:  output/en/weonetest_1076_alchemy.yml
# Storing file:  output/en/bicotest_054_retresco.yml
# Storing file:  output/en/bicotest_054_meaningcloud.yml
# Storing file:  output/en/bicotest_054_txtrazor.yml
# Storing file:  output/en/bicotest_054_simple.yml
# Storing file:  output/en/bicotest_054_semant.yml
# Storing file:  output/en/bicotest_054_linguasys.yml
# Storing file:  output/en/bicotest_054_bitext.yml
# Storing file:  output/en/bicotest_054_alchemy.yml
# Storing file:  output/en/weonetest_826_retresco.yml
# Storing file:  output/en/weonetest_826_meaningcloud.yml
# Storing file:  output/en/weonetest_826_txtrazor.yml
# Storing file:  output/en/weonetest_826_simple.yml
# Storing file:  output/en/weonetest_826_semant.yml
# Storing file:  output/en/weonetest_826_linguasys.yml
# Storing file:  output/en/weonetest_826_bitext.yml
# Storing file:  output/en/weonetest_826_alchemy.yml
# Storing file:  output/en/weonetest_188_retresco.yml
# Storing file:  output/en/weonetest_188_meaningcloud.yml
# Storing file:  output/en/weonetest_188_txtrazor.yml
# Storing file:  output/en/weonetest_188_simple.yml
# Storing file:  output/en/weonetest_188_semant.yml
# Storing file:  output/en/weonetest_188_linguasys.yml
# Storing file:  output/en/weonetest_188_bitext.yml
# Storing file:  output/en/weonetest_188_alchemy.yml
# Storing file:  output/en/weonetest_873_retresco.yml
# Storing file:  output/en/weonetest_873_meaningcloud.yml
# Storing file:  output/en/weonetest_873_txtrazor.yml
# Storing file:  output/en/weonetest_873_simple.yml
# Storing file:  output/en/weonetest_873_semant.yml
# Storing file:  output/en/weonetest_873_linguasys.yml
# Storing file:  output/en/weonetest_873_bitext.yml
# Storing file:  output/en/weonetest_873_alchemy.yml
# Storing file:  output/en/bicotest_059_retresco.yml
# Storing file:  output/en/bicotest_059_meaningcloud.yml
# Storing file:  output/en/bicotest_059_txtrazor.yml
# Storing file:  output/en/bicotest_059_simple.yml
# Storing file:  output/en/bicotest_059_semant.yml
# Storing file:  output/en/bicotest_059_linguasys.yml
# Storing file:  output/en/bicotest_059_bitext.yml
# Storing file:  output/en/bicotest_059_alchemy.yml
# Storing file:  output/en/bicotest_331_retresco.yml
# Storing file:  output/en/bicotest_331_meaningcloud.yml
# Storing file:  output/en/bicotest_331_txtrazor.yml
# Storing file:  output/en/bicotest_331_simple.yml
# Storing file:  output/en/bicotest_331_semant.yml
# Storing file:  output/en/bicotest_331_linguasys.yml
# Storing file:  output/en/bicotest_331_bitext.yml
# Storing file:  output/en/bicotest_331_alchemy.yml
# Storing file:  output/en/weonetest_980_retresco.yml
# Storing file:  output/en/weonetest_980_meaningcloud.yml
# Storing file:  output/en/weonetest_980_txtrazor.yml
# Storing file:  output/en/weonetest_980_simple.yml
# Storing file:  output/en/weonetest_980_semant.yml
# Storing file:  output/en/weonetest_980_linguasys.yml
# Storing file:  output/en/weonetest_980_bitext.yml
# Storing file:  output/en/weonetest_980_alchemy.yml

# %%
import semaeval.statistics as stats

# %%
data=stats.collect_data(articles_enriched)
# Out:
# retresco bicotest_182.yml float division by zero
# meaningcloud bicotest_182.yml float division by zero
# txtrazor bicotest_182.yml float division by zero
# txtrazor bicotest_182.yml float division by zero
# semant bicotest_182.yml float division by zero
# linguasys bicotest_182.yml float division by zero
# linguasys bicotest_182.yml float division by zero
# bitext bicotest_182.yml float division by zero
# bitext bicotest_182.yml float division by zero
# alchemy bicotest_182.yml float division by zero
# retresco weonetest_439.yml float division by zero
# meaningcloud weonetest_439.yml float division by zero
# meaningcloud weonetest_439.yml float division by zero
# txtrazor weonetest_439.yml float division by zero
# semant weonetest_439.yml float division by zero
# linguasys weonetest_439.yml float division by zero
# retresco bicotest_191.yml float division by zero
# retresco bicotest_191.yml float division by zero
# meaningcloud bicotest_191.yml float division by zero
# txtrazor bicotest_191.yml float division by zero
# simple bicotest_191.yml float division by zero
# semant bicotest_191.yml float division by zero
# linguasys bicotest_191.yml float division by zero
# bitext bicotest_191.yml float division by zero
# alchemy bicotest_191.yml float division by zero
# meaningcloud weonetest_897.yml float division by zero
# semant weonetest_711.yml float division by zero
# retresco weonetest_1157.yml float division by zero
# meaningcloud weonetest_1157.yml float division by zero
# txtrazor weonetest_1157.yml float division by zero
# simple weonetest_1157.yml float division by zero
# semant weonetest_1157.yml float division by zero
# linguasys weonetest_1157.yml float division by zero
# bitext weonetest_1157.yml float division by zero
# alchemy weonetest_1157.yml float division by zero
# retresco bicotest_546.yml float division by zero
# meaningcloud bicotest_546.yml float division by zero
# txtrazor bicotest_546.yml float division by zero
# simple bicotest_546.yml float division by zero
# semant bicotest_546.yml float division by zero
# linguasys bicotest_546.yml float division by zero
# linguasys bicotest_546.yml float division by zero
# bitext bicotest_546.yml float division by zero
# alchemy bicotest_546.yml float division by zero
# meaningcloud bicotest_399.yml float division by zero
# txtrazor bicotest_399.yml float division by zero
# semant bicotest_399.yml float division by zero
# linguasys bicotest_399.yml float division by zero
# bitext bicotest_399.yml float division by zero
# alchemy bicotest_399.yml float division by zero
# meaningcloud bicotest_065.yml float division by zero
# semant bicotest_065.yml float division by zero
# bitext bicotest_065.yml float division by zero
# retresco weonetest_661.yml float division by zero
# retresco weonetest_661.yml float division by zero
# meaningcloud weonetest_661.yml float division by zero
# txtrazor weonetest_661.yml float division by zero
# txtrazor weonetest_661.yml float division by zero
# simple weonetest_661.yml float division by zero
# semant weonetest_661.yml float division by zero
# linguasys weonetest_661.yml float division by zero
# bitext weonetest_661.yml float division by zero
# alchemy weonetest_661.yml float division by zero
# semant weonetest_409.yml float division by zero
# retresco bicotest_235.yml float division by zero
# meaningcloud bicotest_235.yml float division by zero
# txtrazor bicotest_235.yml float division by zero
# semant bicotest_235.yml float division by zero
# semant bicotest_235.yml float division by zero
# semant bicotest_235.yml float division by zero
# linguasys bicotest_235.yml float division by zero
# bitext bicotest_235.yml float division by zero
# retresco weonetest_481.yml float division by zero
# retresco weonetest_481.yml float division by zero
# meaningcloud weonetest_481.yml float division by zero
# txtrazor weonetest_481.yml float division by zero
# txtrazor weonetest_481.yml float division by zero
# semant weonetest_481.yml float division by zero
# semant weonetest_481.yml float division by zero
# semant weonetest_481.yml float division by zero
# linguasys weonetest_481.yml float division by zero
# linguasys weonetest_481.yml float division by zero
# bitext weonetest_481.yml float division by zero
# meaningcloud bicotest_286.yml float division by zero
# semant bicotest_286.yml float division by zero
# semant bicotest_286.yml float division by zero
# meaningcloud weonetest_1125.yml float division by zero
# semant weonetest_1125.yml float division by zero
# bitext weonetest_1125.yml float division by zero
# retresco weonetest_674.yml float division by zero
# retresco weonetest_674.yml float division by zero
# meaningcloud weonetest_674.yml float division by zero
# meaningcloud weonetest_674.yml float division by zero
# txtrazor weonetest_674.yml float division by zero
# simple weonetest_674.yml float division by zero
# semant weonetest_674.yml float division by zero
# semant weonetest_674.yml float division by zero
# linguasys weonetest_674.yml float division by zero
# linguasys weonetest_674.yml float division by zero
# bitext weonetest_674.yml float division by zero
# bitext weonetest_674.yml float division by zero
# alchemy weonetest_674.yml float division by zero
# alchemy weonetest_674.yml float division by zero
# semant weonetest_895.yml float division by zero
# meaningcloud weonetest_082.yml float division by zero
# txtrazor weonetest_082.yml float division by zero
# semant weonetest_082.yml float division by zero
# linguasys weonetest_082.yml float division by zero
# bitext weonetest_082.yml float division by zero
# meaningcloud weonetest_1217.yml float division by zero
# semant weonetest_1217.yml float division by zero
# retresco weonetest_611.yml float division by zero
# txtrazor weonetest_611.yml float division by zero
# semant weonetest_611.yml float division by zero
# bitext weonetest_611.yml float division by zero
# retresco weonetest_802.yml float division by zero
# retresco weonetest_802.yml float division by zero
# meaningcloud weonetest_802.yml float division by zero
# txtrazor weonetest_802.yml float division by zero
# semant weonetest_802.yml float division by zero
# semant weonetest_802.yml float division by zero
# linguasys weonetest_802.yml float division by zero
# meaningcloud bicotest_587.yml float division by zero
# semant bicotest_587.yml float division by zero
# semant bicotest_587.yml float division by zero
# linguasys bicotest_587.yml float division by zero
# bitext bicotest_587.yml float division by zero
# meaningcloud weonetest_776.yml float division by zero
# meaningcloud weonetest_776.yml float division by zero
# semant weonetest_776.yml float division by zero
# linguasys weonetest_776.yml float division by zero
# bitext weonetest_776.yml float division by zero
# bitext weonetest_776.yml float division by zero
# meaningcloud bicotest_279.yml float division by zero
# retresco bicotest_551.yml float division by zero
# meaningcloud bicotest_551.yml float division by zero
# txtrazor bicotest_551.yml float division by zero
# simple bicotest_551.yml float division by zero
# semant bicotest_551.yml float division by zero
# linguasys bicotest_551.yml float division by zero
# bitext bicotest_551.yml float division by zero
# alchemy bicotest_551.yml float division by zero
# meaningcloud weonetest_583.yml float division by zero
# retresco bicotest_360.yml float division by zero
# meaningcloud bicotest_360.yml float division by zero
# txtrazor bicotest_360.yml float division by zero
# simple bicotest_360.yml float division by zero
# semant bicotest_360.yml float division by zero
# linguasys bicotest_360.yml float division by zero
# bitext bicotest_360.yml float division by zero
# alchemy bicotest_360.yml float division by zero
# meaningcloud weonetest_887.yml float division by zero
# meaningcloud weonetest_887.yml float division by zero
# semant weonetest_887.yml float division by zero
# linguasys weonetest_887.yml float division by zero
# bitext weonetest_887.yml float division by zero
# bitext weonetest_887.yml float division by zero
# semant weonetest_509.yml float division by zero
# semant weonetest_982.yml float division by zero
# retresco weonetest_751.yml float division by zero
# meaningcloud weonetest_751.yml float division by zero
# linguasys weonetest_751.yml float division by zero
# bitext weonetest_751.yml float division by zero
# retresco weonetest_821.yml float division by zero
# retresco bicotest_234.yml float division by zero
# meaningcloud bicotest_234.yml float division by zero
# txtrazor bicotest_234.yml float division by zero
# semant bicotest_234.yml float division by zero
# semant bicotest_234.yml float division by zero
# linguasys bicotest_234.yml float division by zero
# bitext bicotest_234.yml float division by zero
# meaningcloud weonetest_772.yml float division by zero
# semant weonetest_772.yml float division by zero
# retresco bicotest_475.yml float division by zero
# meaningcloud bicotest_475.yml float division by zero
# simple bicotest_475.yml float division by zero
# semant bicotest_475.yml float division by zero
# semant bicotest_475.yml float division by zero
# alchemy bicotest_475.yml float division by zero
# semant weonetest_626.yml float division by zero
# retresco weonetest_105.yml float division by zero
# meaningcloud weonetest_105.yml float division by zero
# semant weonetest_105.yml float division by zero
# retresco weonetest_177.yml float division by zero
# meaningcloud weonetest_177.yml float division by zero
# semant weonetest_177.yml float division by zero
# semant weonetest_755.yml float division by zero
# retresco bicotest_054.yml float division by zero
# meaningcloud bicotest_054.yml float division by zero
# txtrazor bicotest_054.yml float division by zero
# txtrazor bicotest_054.yml float division by zero
# simple bicotest_054.yml float division by zero
# semant bicotest_054.yml float division by zero
# semant bicotest_054.yml float division by zero
# linguasys bicotest_054.yml float division by zero
# bitext bicotest_054.yml float division by zero
# bitext bicotest_054.yml float division by zero
# alchemy bicotest_054.yml float division by zero
# retresco weonetest_826.yml float division by zero
# meaningcloud weonetest_826.yml float division by zero
# semant weonetest_826.yml float division by zero
# semant weonetest_188.yml float division by zero
# meaningcloud weonetest_873.yml float division by zero
# semant weonetest_873.yml float division by zero
# bitext weonetest_873.yml float division by zero
# retresco bicotest_059.yml float division by zero
# meaningcloud bicotest_059.yml float division by zero
# meaningcloud bicotest_059.yml float division by zero
# txtrazor bicotest_059.yml float division by zero
# txtrazor bicotest_059.yml float division by zero
# simple bicotest_059.yml float division by zero
# semant bicotest_059.yml float division by zero
# semant bicotest_059.yml float division by zero
# linguasys bicotest_059.yml float division by zero
# bitext bicotest_059.yml float division by zero
# bitext bicotest_059.yml float division by zero
# alchemy bicotest_059.yml float division by zero
# meaningcloud bicotest_331.yml float division by zero
# meaningcloud weonetest_980.yml float division by zero
# meaningcloud weonetest_980.yml float division by zero

# %%
results=stats.aggregate_result(data)

# %%
results.extend(stats.compute_total(results))

# %%
# %matplotlib inline

# %%
stats.plot_results(results)

# %%
stats.store_results(results,"en")
# Out:
# Storing file:  en_results.yml
