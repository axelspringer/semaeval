# %%
import semaeval.util as util
util.clean_storage("de")
# Out:
# Deleting: input/de/article125397600.yml
# Deleting: input/de/article125407288.yml
# Deleting: input/de/article125409377.yml
# Deleting: input/de/article125410545.yml
# Deleting: input/de/article125410611.yml
# Deleting: input/de/article125410683.yml
# Deleting: input/de/article125410701.yml
# Deleting: input/de/article125410849.yml
# Deleting: input/de/article125411133.yml
# Deleting: input/de/article125411523.yml
# Deleting: input/de/article125411758.yml
# Deleting: input/de/article125411855.yml
# Deleting: input/de/article125411879.yml
# Deleting: input/de/article125411892.yml
# Deleting: input/de/article125412072.yml
# Deleting: input/de/article125412309.yml
# Deleting: input/de/article125412598.yml
# Deleting: input/de/article125412733.yml
# Deleting: input/de/article125412900.yml
# Deleting: input/de/article125413599.yml
# Deleting: input/de/article125413715.yml
# Deleting: input/de/article125414274.yml
# Deleting: input/de/article125414637.yml
# Deleting: input/de/article125414811.yml
# Deleting: input/de/article125414830.yml
# Deleting: input/de/article125414913.yml
# Deleting: input/de/article125416040.yml
# Deleting: input/de/article125416433.yml
# Deleting: input/de/article125416743.yml
# Deleting: input/de/article125417594.yml
# Deleting: input/de/article125418264.yml
# Deleting: input/de/article125418383.yml
# Deleting: input/de/article125419006.yml
# Deleting: input/de/article125419459.yml
# Deleting: input/de/article125419555.yml
# Deleting: input/de/article125419734.yml
# Deleting: input/de/article125419838.yml
# Deleting: input/de/article125419949.yml
# Deleting: input/de/article125420088.yml
# Deleting: input/de/article125421093.yml
# Deleting: input/de/article125421480.yml
# Deleting: input/de/article125422405.yml
# Deleting: input/de/article125422572.yml
# Deleting: input/de/article125422595.yml
# Deleting: input/de/article125423156.yml
# Deleting: input/de/article125423592.yml
# Deleting: input/de/article125423635.yml
# Deleting: input/de/article125423641.yml
# Deleting: input/de/article125423712.yml
# Deleting: input/de/article125424107.yml
# Deleting: output/de/article125397600_alchemy.yml
# Deleting: output/de/article125397600_meaningcloud.yml
# Deleting: output/de/article125397600_retresco.yml
# Deleting: output/de/article125397600_semant.yml
# Deleting: output/de/article125397600_simple.yml
# Deleting: output/de/article125397600_txtrazor.yml
# Deleting: output/de/article125407288_alchemy.yml
# Deleting: output/de/article125407288_meaningcloud.yml
# Deleting: output/de/article125407288_retresco.yml
# Deleting: output/de/article125407288_semant.yml
# Deleting: output/de/article125407288_simple.yml
# Deleting: output/de/article125407288_txtrazor.yml
# Deleting: output/de/article125409377_alchemy.yml
# Deleting: output/de/article125409377_meaningcloud.yml
# Deleting: output/de/article125409377_retresco.yml
# Deleting: output/de/article125409377_semant.yml
# Deleting: output/de/article125409377_simple.yml
# Deleting: output/de/article125409377_txtrazor.yml
# Deleting: output/de/article125410545_alchemy.yml
# Deleting: output/de/article125410545_meaningcloud.yml
# Deleting: output/de/article125410545_retresco.yml
# Deleting: output/de/article125410545_semant.yml
# Deleting: output/de/article125410545_simple.yml
# Deleting: output/de/article125410545_txtrazor.yml
# Deleting: output/de/article125410611_alchemy.yml
# Deleting: output/de/article125410611_meaningcloud.yml
# Deleting: output/de/article125410611_retresco.yml
# Deleting: output/de/article125410611_semant.yml
# Deleting: output/de/article125410611_simple.yml
# Deleting: output/de/article125410611_txtrazor.yml
# Deleting: output/de/article125410683_alchemy.yml
# Deleting: output/de/article125410683_meaningcloud.yml
# Deleting: output/de/article125410683_retresco.yml
# Deleting: output/de/article125410683_semant.yml
# Deleting: output/de/article125410683_simple.yml
# Deleting: output/de/article125410683_txtrazor.yml
# Deleting: output/de/article125410701_alchemy.yml
# Deleting: output/de/article125410701_meaningcloud.yml
# Deleting: output/de/article125410701_retresco.yml
# Deleting: output/de/article125410701_semant.yml
# Deleting: output/de/article125410701_simple.yml
# Deleting: output/de/article125410701_txtrazor.yml
# Deleting: output/de/article125410849_alchemy.yml
# Deleting: output/de/article125410849_meaningcloud.yml
# Deleting: output/de/article125410849_retresco.yml
# Deleting: output/de/article125410849_semant.yml
# Deleting: output/de/article125410849_simple.yml
# Deleting: output/de/article125410849_txtrazor.yml
# Deleting: output/de/article125411133_alchemy.yml
# Deleting: output/de/article125411133_meaningcloud.yml
# Deleting: output/de/article125411133_retresco.yml
# Deleting: output/de/article125411133_semant.yml
# Deleting: output/de/article125411133_simple.yml
# Deleting: output/de/article125411133_txtrazor.yml
# Deleting: output/de/article125411523_alchemy.yml
# Deleting: output/de/article125411523_meaningcloud.yml
# Deleting: output/de/article125411523_retresco.yml
# Deleting: output/de/article125411523_semant.yml
# Deleting: output/de/article125411523_simple.yml
# Deleting: output/de/article125411523_txtrazor.yml
# Deleting: output/de/article125411758_alchemy.yml
# Deleting: output/de/article125411758_meaningcloud.yml
# Deleting: output/de/article125411758_retresco.yml
# Deleting: output/de/article125411758_semant.yml
# Deleting: output/de/article125411758_simple.yml
# Deleting: output/de/article125411758_txtrazor.yml
# Deleting: output/de/article125411855_alchemy.yml
# Deleting: output/de/article125411855_meaningcloud.yml
# Deleting: output/de/article125411855_retresco.yml
# Deleting: output/de/article125411855_semant.yml
# Deleting: output/de/article125411855_simple.yml
# Deleting: output/de/article125411855_txtrazor.yml
# Deleting: output/de/article125411879_alchemy.yml
# Deleting: output/de/article125411879_meaningcloud.yml
# Deleting: output/de/article125411879_retresco.yml
# Deleting: output/de/article125411879_semant.yml
# Deleting: output/de/article125411879_simple.yml
# Deleting: output/de/article125411879_txtrazor.yml
# Deleting: output/de/article125411892_alchemy.yml
# Deleting: output/de/article125411892_meaningcloud.yml
# Deleting: output/de/article125411892_retresco.yml
# Deleting: output/de/article125411892_semant.yml
# Deleting: output/de/article125411892_simple.yml
# Deleting: output/de/article125411892_txtrazor.yml
# Deleting: output/de/article125412072_alchemy.yml
# Deleting: output/de/article125412072_meaningcloud.yml
# Deleting: output/de/article125412072_retresco.yml
# Deleting: output/de/article125412072_semant.yml
# Deleting: output/de/article125412072_simple.yml
# Deleting: output/de/article125412072_txtrazor.yml
# Deleting: output/de/article125412309_alchemy.yml
# Deleting: output/de/article125412309_meaningcloud.yml
# Deleting: output/de/article125412309_retresco.yml
# Deleting: output/de/article125412309_semant.yml
# Deleting: output/de/article125412309_simple.yml
# Deleting: output/de/article125412309_txtrazor.yml
# Deleting: output/de/article125412598_alchemy.yml
# Deleting: output/de/article125412598_meaningcloud.yml
# Deleting: output/de/article125412598_retresco.yml
# Deleting: output/de/article125412598_semant.yml
# Deleting: output/de/article125412598_simple.yml
# Deleting: output/de/article125412598_txtrazor.yml
# Deleting: output/de/article125412733_alchemy.yml
# Deleting: output/de/article125412733_meaningcloud.yml
# Deleting: output/de/article125412733_retresco.yml
# Deleting: output/de/article125412733_semant.yml
# Deleting: output/de/article125412733_simple.yml
# Deleting: output/de/article125412733_txtrazor.yml
# Deleting: output/de/article125412900_alchemy.yml
# Deleting: output/de/article125412900_meaningcloud.yml
# Deleting: output/de/article125412900_retresco.yml
# Deleting: output/de/article125412900_semant.yml
# Deleting: output/de/article125412900_simple.yml
# Deleting: output/de/article125412900_txtrazor.yml
# Deleting: output/de/article125413599_alchemy.yml
# Deleting: output/de/article125413599_meaningcloud.yml
# Deleting: output/de/article125413599_retresco.yml
# Deleting: output/de/article125413599_semant.yml
# Deleting: output/de/article125413599_simple.yml
# Deleting: output/de/article125413599_txtrazor.yml
# Deleting: output/de/article125413715_alchemy.yml
# Deleting: output/de/article125413715_meaningcloud.yml
# Deleting: output/de/article125413715_retresco.yml
# Deleting: output/de/article125413715_semant.yml
# Deleting: output/de/article125413715_simple.yml
# Deleting: output/de/article125413715_txtrazor.yml
# Deleting: output/de/article125414274_alchemy.yml
# Deleting: output/de/article125414274_meaningcloud.yml
# Deleting: output/de/article125414274_retresco.yml
# Deleting: output/de/article125414274_semant.yml
# Deleting: output/de/article125414274_simple.yml
# Deleting: output/de/article125414274_txtrazor.yml
# Deleting: output/de/article125414637_alchemy.yml
# Deleting: output/de/article125414637_meaningcloud.yml
# Deleting: output/de/article125414637_retresco.yml
# Deleting: output/de/article125414637_semant.yml
# Deleting: output/de/article125414637_simple.yml
# Deleting: output/de/article125414637_txtrazor.yml
# Deleting: output/de/article125414811_alchemy.yml
# Deleting: output/de/article125414811_meaningcloud.yml
# Deleting: output/de/article125414811_retresco.yml
# Deleting: output/de/article125414811_semant.yml
# Deleting: output/de/article125414811_simple.yml
# Deleting: output/de/article125414811_txtrazor.yml
# Deleting: output/de/article125414830_alchemy.yml
# Deleting: output/de/article125414830_meaningcloud.yml
# Deleting: output/de/article125414830_retresco.yml
# Deleting: output/de/article125414830_semant.yml
# Deleting: output/de/article125414830_simple.yml
# Deleting: output/de/article125414830_txtrazor.yml
# Deleting: output/de/article125414913_alchemy.yml
# Deleting: output/de/article125414913_meaningcloud.yml
# Deleting: output/de/article125414913_retresco.yml
# Deleting: output/de/article125414913_semant.yml
# Deleting: output/de/article125414913_simple.yml
# Deleting: output/de/article125414913_txtrazor.yml
# Deleting: output/de/article125416040_alchemy.yml
# Deleting: output/de/article125416040_meaningcloud.yml
# Deleting: output/de/article125416040_retresco.yml
# Deleting: output/de/article125416040_semant.yml
# Deleting: output/de/article125416040_simple.yml
# Deleting: output/de/article125416040_txtrazor.yml
# Deleting: output/de/article125416433_alchemy.yml
# Deleting: output/de/article125416433_meaningcloud.yml
# Deleting: output/de/article125416433_retresco.yml
# Deleting: output/de/article125416433_semant.yml
# Deleting: output/de/article125416433_simple.yml
# Deleting: output/de/article125416433_txtrazor.yml
# Deleting: output/de/article125416743_alchemy.yml
# Deleting: output/de/article125416743_meaningcloud.yml
# Deleting: output/de/article125416743_retresco.yml
# Deleting: output/de/article125416743_semant.yml
# Deleting: output/de/article125416743_simple.yml
# Deleting: output/de/article125416743_txtrazor.yml
# Deleting: output/de/article125417594_alchemy.yml
# Deleting: output/de/article125417594_meaningcloud.yml
# Deleting: output/de/article125417594_retresco.yml
# Deleting: output/de/article125417594_semant.yml
# Deleting: output/de/article125417594_simple.yml
# Deleting: output/de/article125417594_txtrazor.yml
# Deleting: output/de/article125418264_alchemy.yml
# Deleting: output/de/article125418264_meaningcloud.yml
# Deleting: output/de/article125418264_retresco.yml
# Deleting: output/de/article125418264_semant.yml
# Deleting: output/de/article125418264_simple.yml
# Deleting: output/de/article125418264_txtrazor.yml
# Deleting: output/de/article125418383_alchemy.yml
# Deleting: output/de/article125418383_meaningcloud.yml
# Deleting: output/de/article125418383_retresco.yml
# Deleting: output/de/article125418383_semant.yml
# Deleting: output/de/article125418383_simple.yml
# Deleting: output/de/article125418383_txtrazor.yml
# Deleting: output/de/article125419006_alchemy.yml
# Deleting: output/de/article125419006_meaningcloud.yml
# Deleting: output/de/article125419006_retresco.yml
# Deleting: output/de/article125419006_semant.yml
# Deleting: output/de/article125419006_simple.yml
# Deleting: output/de/article125419006_txtrazor.yml
# Deleting: output/de/article125419459_alchemy.yml
# Deleting: output/de/article125419459_meaningcloud.yml
# Deleting: output/de/article125419459_retresco.yml
# Deleting: output/de/article125419459_semant.yml
# Deleting: output/de/article125419459_simple.yml
# Deleting: output/de/article125419459_txtrazor.yml
# Deleting: output/de/article125419555_alchemy.yml
# Deleting: output/de/article125419555_meaningcloud.yml
# Deleting: output/de/article125419555_retresco.yml
# Deleting: output/de/article125419555_semant.yml
# Deleting: output/de/article125419555_simple.yml
# Deleting: output/de/article125419555_txtrazor.yml
# Deleting: output/de/article125419734_alchemy.yml
# Deleting: output/de/article125419734_meaningcloud.yml
# Deleting: output/de/article125419734_retresco.yml
# Deleting: output/de/article125419734_semant.yml
# Deleting: output/de/article125419734_simple.yml
# Deleting: output/de/article125419734_txtrazor.yml
# Deleting: output/de/article125419838_alchemy.yml
# Deleting: output/de/article125419838_meaningcloud.yml
# Deleting: output/de/article125419838_retresco.yml
# Deleting: output/de/article125419838_semant.yml
# Deleting: output/de/article125419838_simple.yml
# Deleting: output/de/article125419838_txtrazor.yml
# Deleting: output/de/article125419949_alchemy.yml
# Deleting: output/de/article125419949_meaningcloud.yml
# Deleting: output/de/article125419949_retresco.yml
# Deleting: output/de/article125419949_semant.yml
# Deleting: output/de/article125419949_simple.yml
# Deleting: output/de/article125419949_txtrazor.yml
# Deleting: output/de/article125420088_alchemy.yml
# Deleting: output/de/article125420088_meaningcloud.yml
# Deleting: output/de/article125420088_retresco.yml
# Deleting: output/de/article125420088_semant.yml
# Deleting: output/de/article125420088_simple.yml
# Deleting: output/de/article125420088_txtrazor.yml
# Deleting: output/de/article125421093_alchemy.yml
# Deleting: output/de/article125421093_meaningcloud.yml
# Deleting: output/de/article125421093_retresco.yml
# Deleting: output/de/article125421093_semant.yml
# Deleting: output/de/article125421093_simple.yml
# Deleting: output/de/article125421093_txtrazor.yml
# Deleting: output/de/article125421480_alchemy.yml
# Deleting: output/de/article125421480_meaningcloud.yml
# Deleting: output/de/article125421480_retresco.yml
# Deleting: output/de/article125421480_semant.yml
# Deleting: output/de/article125421480_simple.yml
# Deleting: output/de/article125421480_txtrazor.yml
# Deleting: output/de/article125422405_alchemy.yml
# Deleting: output/de/article125422405_meaningcloud.yml
# Deleting: output/de/article125422405_retresco.yml
# Deleting: output/de/article125422405_semant.yml
# Deleting: output/de/article125422405_simple.yml
# Deleting: output/de/article125422405_txtrazor.yml
# Deleting: output/de/article125422572_alchemy.yml
# Deleting: output/de/article125422572_meaningcloud.yml
# Deleting: output/de/article125422572_retresco.yml
# Deleting: output/de/article125422572_semant.yml
# Deleting: output/de/article125422572_simple.yml
# Deleting: output/de/article125422572_txtrazor.yml
# Deleting: output/de/article125422595_alchemy.yml
# Deleting: output/de/article125422595_meaningcloud.yml
# Deleting: output/de/article125422595_retresco.yml
# Deleting: output/de/article125422595_semant.yml
# Deleting: output/de/article125422595_simple.yml
# Deleting: output/de/article125422595_txtrazor.yml
# Deleting: output/de/article125423156_alchemy.yml
# Deleting: output/de/article125423156_meaningcloud.yml
# Deleting: output/de/article125423156_retresco.yml
# Deleting: output/de/article125423156_semant.yml
# Deleting: output/de/article125423156_simple.yml
# Deleting: output/de/article125423156_txtrazor.yml
# Deleting: output/de/article125423592_alchemy.yml
# Deleting: output/de/article125423592_meaningcloud.yml
# Deleting: output/de/article125423592_retresco.yml
# Deleting: output/de/article125423592_semant.yml
# Deleting: output/de/article125423592_simple.yml
# Deleting: output/de/article125423592_txtrazor.yml
# Deleting: output/de/article125423635_alchemy.yml
# Deleting: output/de/article125423635_meaningcloud.yml
# Deleting: output/de/article125423635_retresco.yml
# Deleting: output/de/article125423635_semant.yml
# Deleting: output/de/article125423635_simple.yml
# Deleting: output/de/article125423635_txtrazor.yml
# Deleting: output/de/article125423641_alchemy.yml
# Deleting: output/de/article125423641_meaningcloud.yml
# Deleting: output/de/article125423641_retresco.yml
# Deleting: output/de/article125423641_semant.yml
# Deleting: output/de/article125423641_simple.yml
# Deleting: output/de/article125423641_txtrazor.yml
# Deleting: output/de/article125423712_alchemy.yml
# Deleting: output/de/article125423712_meaningcloud.yml
# Deleting: output/de/article125423712_retresco.yml
# Deleting: output/de/article125423712_semant.yml
# Deleting: output/de/article125423712_simple.yml
# Deleting: output/de/article125423712_txtrazor.yml
# Deleting: output/de/article125424107_alchemy.yml
# Deleting: output/de/article125424107_meaningcloud.yml
# Deleting: output/de/article125424107_retresco.yml
# Deleting: output/de/article125424107_semant.yml
# Deleting: output/de/article125424107_simple.yml
# Deleting: output/de/article125424107_txtrazor.yml
# [Errno 2] No such file or directory: 'result/de'

# %%
import semaeval.source.welt as welt

# %%
urls = open("urls_welt_de.txt").readlines()

# %%
articles = []
for url in urls:
    articles.append(welt.article_from_url(url))

# %%
len(articles)
# Out:
# 50

# %%
welt.store_articles(articles,"de")
# Out:
# Storing file:  input/de/article125423592.yml
# Storing file:  input/de/article125423156.yml
# Storing file:  input/de/article125423712.yml
# Storing file:  input/de/article125423641.yml
# Storing file:  input/de/article125424107.yml
# Storing file:  input/de/article125422595.yml
# Storing file:  input/de/article125422405.yml
# Storing file:  input/de/article125418383.yml
# Storing file:  input/de/article125411892.yml
# Storing file:  input/de/article125423635.yml
# Storing file:  input/de/article125421480.yml
# Storing file:  input/de/article125422572.yml
# Storing file:  input/de/article125419459.yml
# Storing file:  input/de/article125421093.yml
# Storing file:  input/de/article125419006.yml
# Storing file:  input/de/article125419838.yml
# Storing file:  input/de/article125420088.yml
# Storing file:  input/de/article125419555.yml
# Storing file:  input/de/article125419734.yml
# Storing file:  input/de/article125419949.yml
# Storing file:  input/de/article125411523.yml
# Storing file:  input/de/article125418264.yml
# Storing file:  input/de/article125417594.yml
# Storing file:  input/de/article125416040.yml
# Storing file:  input/de/article125416743.yml
# Storing file:  input/de/article125416433.yml
# Storing file:  input/de/article125414274.yml
# Storing file:  input/de/article125414811.yml
# Storing file:  input/de/article125411879.yml
# Storing file:  input/de/article125414637.yml
# Storing file:  input/de/article125411855.yml
# Storing file:  input/de/article125414830.yml
# Storing file:  input/de/article125412072.yml
# Storing file:  input/de/article125414913.yml
# Storing file:  input/de/article125413715.yml
# Storing file:  input/de/article125413599.yml
# Storing file:  input/de/article125412900.yml
# Storing file:  input/de/article125407288.yml
# Storing file:  input/de/article125412733.yml
# Storing file:  input/de/article125411758.yml
# Storing file:  input/de/article125412598.yml
# Storing file:  input/de/article125412309.yml
# Storing file:  input/de/article125397600.yml
# Storing file:  input/de/article125411133.yml
# Storing file:  input/de/article125410849.yml
# Storing file:  input/de/article125409377.yml
# Storing file:  input/de/article125410611.yml
# Storing file:  input/de/article125410545.yml
# Storing file:  input/de/article125410683.yml
# Storing file:  input/de/article125410701.yml

# %%
import semaeval.evaluate as eval

# %%
articles_enriched = eval.detect_entities(articles, "de")
# Out:
# URL: http://www.welt.de/regionales/koeln/article125423592/Wie-Deutschland-andere-Menschen-zum-Hungern-bringt.html
#
# Collecting results:
# URL: http://www.welt.de/wirtschaft/webwelt/article125423156/Google-Sea-View-zeigt-neue-spektakulaere-Aufnahmen.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/wirtschaft/webwelt/article125423712/Europaeische-Suchmaschine-verspricht-Datenschutz.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/motor/article125423641/Boese-Schlappe-fuer-BMW-bei-der-Autowahl.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/vermischtes/weltgeschehen/article125424107/Zehntausende-krank-nach-Waldbraenden-auf-Sumatra.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/sport/article125422595/Ein-Sportfest-nur-450-km-von-der-Krim-enfernt.html
#
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/reise/staedtereisen/article125422405/Naechster-Stopp-1966-ein-Besuch-im-Geisterbahnhof.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/regionales/duesseldorf/article125418383/Ministerpraesidentin-Kraft-zu-Besuch-in-Israel.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/sport/fitness/article125411892/Maenner-duerfen-mehr-Fleisch-essen-Frauen-nicht.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/sport/boxen/article125423635/Abraham-kuemmert-sich-um-benachteiligte-Jugendliche.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/debatte/kommentare/article125421480/Warum-wir-Despoten-staendig-unterschaetzen.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/debatte/kommentare/article125422572/Wo-bleibt-die-deutsche-Friedensbewegung.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/regionales/duesseldorf/article125419459/Toetete-Yanqing-T-drei-Menschen-aus-Geldnot.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/wirtschaft/webwelt/article125421093/Schweiz-will-kuenftig-Daten-statt-Geld-bunkern.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.bitext
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/vermischtes/article125419006/Miley-Cyrus-droht-israelischem-Soldaten-mit-Klage.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error:alchemy: GeographicFeature
#  No JSON object could be decoded
# alchemy: FinancialMarketIndex
# Bitext Response: Internal process error.
# URL: http://www.welt.de/sport/fussball/wm-2014/article125419838/Loew-hat-noch-acht-Plaetze-im-WM-Kader-frei.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/spiele/article125420088/Dracula-kehrt-in-Castlevania-als-Hauptfigur-zurueck.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/politik/deutschland/article125419555/Langzeitarbeitslose-werden-kaum-vermittelbar.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/sport/fussball/article125419734/In-der-Bundesliga-bricht-der-Trainer-Notstand-aus.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/vermischtes/prominente/article125419949/Pistorius-Schreie-klingen-wie-die-einer-Frau.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/wirtschaft/article125411523/Oekonomen-warnen-vor-Zeitalter-des-Protektionismus.html
#
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/politik/ausland/article125418264/Moderatorin-im-russischen-TV-verurteilt-Krim-Besetzung.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error:alchemy: GeographicFeature
#  No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/politik/ausland/article125417594/Putin-will-Russen-mit-allen-Mitteln-schuetzen.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/wissenschaft/umwelt/article125416040/Plattwurm-aus-Asien-erstmals-in-der-EU-aufgetaucht.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/motor/news/article125416743/Genfer-Automobilsalon-2014.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/wirtschaft/article125416433/Beiersdorf-enttaeuscht-Aktionaere-trotz-Gewinnsprung.html
#
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.simple
# semaeval.engine.retresco
# Bitext API Error:semantria: No JSON object could be decoded
#  Fahrzeug
# Bitext Response: Internal process error.
# semantria: Fahrzeug
# URL: http://www.welt.de/regionales/duesseldorf/article125414274/Wind-erfasst-Auto-und-schleudert-es-gegen-Bus.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/regionales/duesseldorf/article125414811/Absaetze-an-Kinderfuessen-sind-nicht-verhandelbar.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/politik/deutschland/article125411879/Das-hat-Tebartz-van-Elst-nicht-verdient.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.semant
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/wissenschaft/umwelt/article125414637/Viele-Arten-fluechten-aus-dem-Aequator-Gebiet.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/regionales/koeln/article125411855/Diese-Apps-machen-uns-zum-glaesernen-Menschen.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# Bitext API Error:alchemy: GeographicFeature
#  No JSON object could be decoded
# alchemy: GeographicFeature
# Bitext Response: Internal process error.
# URL: http://www.welt.de/gesundheit/article125414830/Bei-Laktose-Intoleranz-Verdacht-zum-Arzt-gehen.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/gesundheit/article125412072/Die-kleinen-Viren-Schleudern-aus-der-Kita.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/motor/boote-yachten/article125414913/Wer-wird-das-Bayern-Muenchen-der-Segler.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/regionales/muenchen/article125413715/Fuenf-Backstreet-Boys-auf-Tour-durch-Deutschland.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/wirtschaft/article125413599/Feinstaubbelastung-seit-2005-um-ein-Fuenftel-gefallen.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.alchemy
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/politik/ausland/article125412900/Steinmeier-warnt-vor-neuem-Blutvergiessen.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/gesundheit/article125407288/Finden-Sie-die-beste-Therapie-bei-schwerer-Krankheit.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error:alchemy: GeographicFeature
#  No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/kultur/kunst-und-architektur/article125412733/Er-war-der-Forrest-Gump-der-Fotografie.html
#
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.semant
# semaeval.engine.simple
# Bitext API Error:alchemy: No JSON object could be decoded
#  GeographicFeature
# Bitext Response: Internal process error.
# URL: http://www.welt.de/wirtschaft/article125411758/Krankmeldungen-auf-hoechstem-Stand-seit-1999.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/kultur/kunst-und-architektur/article125412598/Es-gibt-ein-Leben-nach-der-Waldschloesschenbruecke.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.alchemy
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/motor/news/article125412309/Facelift-fuer-den-Nissan-Juke.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error:alchemy: GeographicFeature
#  No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/sport/fussball/bundesliga/1-fsv-mainz/article125397600/Mainzer-Karnevalslied-wurde-deutsche-Fussballhymne.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/sport/formel1/article125411133/Weltmeister-Vettel-rechnet-mit-einem-Debakel.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.txtrazor
# Bitext API Error:alchemy: Movie
#  No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/reise/Fern/article125410849/Vorstoss-im-Kampf-gegen-die-welthoechste-Muellkippe.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error:alchemy: Product
#  No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/wirtschaft/article125409377/Arbeitslosigkeit-in-Spanien-sinkt-erstmals-seit-2007.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error:alchemy: GeographicFeature
#  No JSON object could be decoded
# alchemy: GeographicFeature
# Bitext Response: Internal process error.
# URL: http://www.welt.de/vermischtes/article125410611/Polizeiauto-umgekippt-Gefangener-schwer-verletzt.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/vermischtes/article125410545/Das-Dorf-der-ausgestossenen-Sexualverbrecher.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/vermischtes/article125410683/Riesiger-Schneemann-als-Denkmal-fuer-harten-Winter.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error: No JSON object could be decoded
# Bitext Response: Internal process error.
# URL: http://www.welt.de/motor/news/article125410701/Mazda-Hazumi.html
#
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error:TextRazor API: TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
#  No JSON object could be decoded
#
# Bitext Response: Internal process error.
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Bitext API Error:TextRazor API: No JSON object could be decoded
#  TextRazor returned HTTP Code 401: {"ok":false, "time":0, "error":"You have reached your daily TextRazor request limit. Please contact support@textrazor.com for more information, or visit https://www.textrazor.com to upgrade your account."}
#
# Bitext Response: Internal process error.

# %%
eval.store_articles(articles_enriched, "de")
# Out:
# Storing file:  output/de/article125423592_meaningcloud.yml
# Storing file:  output/de/article125423592_bitext.yml
# Storing file:  output/de/article125423592_retresco.yml
# Storing file:  output/de/article125423592_simple.yml
# Storing file:  output/de/article125423592_txtrazor.yml
# Storing file:  output/de/article125423592_alchemy.yml
# Storing file:  output/de/article125423592_semant.yml
# Storing file:  output/de/article125423156_meaningcloud.yml
# Storing file:  output/de/article125423156_bitext.yml
# Storing file:  output/de/article125423156_retresco.yml
# Storing file:  output/de/article125423156_simple.yml
# Storing file:  output/de/article125423156_txtrazor.yml
# Storing file:  output/de/article125423156_alchemy.yml
# Storing file:  output/de/article125423156_semant.yml
# Storing file:  output/de/article125423712_meaningcloud.yml
# Storing file:  output/de/article125423712_bitext.yml
# Storing file:  output/de/article125423712_retresco.yml
# Storing file:  output/de/article125423712_simple.yml
# Storing file:  output/de/article125423712_txtrazor.yml
# Storing file:  output/de/article125423712_alchemy.yml
# Storing file:  output/de/article125423712_semant.yml
# Storing file:  output/de/article125423641_meaningcloud.yml
# Storing file:  output/de/article125423641_bitext.yml
# Storing file:  output/de/article125423641_retresco.yml
# Storing file:  output/de/article125423641_simple.yml
# Storing file:  output/de/article125423641_txtrazor.yml
# Storing file:  output/de/article125423641_alchemy.yml
# Storing file:  output/de/article125423641_semant.yml
# Storing file:  output/de/article125424107_meaningcloud.yml
# Storing file:  output/de/article125424107_bitext.yml
# Storing file:  output/de/article125424107_retresco.yml
# Storing file:  output/de/article125424107_simple.yml
# Storing file:  output/de/article125424107_txtrazor.yml
# Storing file:  output/de/article125424107_alchemy.yml
# Storing file:  output/de/article125424107_semant.yml
# Storing file:  output/de/article125422595_meaningcloud.yml
# Storing file:  output/de/article125422595_bitext.yml
# Storing file:  output/de/article125422595_retresco.yml
# Storing file:  output/de/article125422595_simple.yml
# Storing file:  output/de/article125422595_txtrazor.yml
# Storing file:  output/de/article125422595_alchemy.yml
# Storing file:  output/de/article125422595_semant.yml
# Storing file:  output/de/article125422405_meaningcloud.yml
# Storing file:  output/de/article125422405_bitext.yml
# Storing file:  output/de/article125422405_retresco.yml
# Storing file:  output/de/article125422405_simple.yml
# Storing file:  output/de/article125422405_txtrazor.yml
# Storing file:  output/de/article125422405_alchemy.yml
# Storing file:  output/de/article125422405_semant.yml
# Storing file:  output/de/article125418383_meaningcloud.yml
# Storing file:  output/de/article125418383_bitext.yml
# Storing file:  output/de/article125418383_retresco.yml
# Storing file:  output/de/article125418383_simple.yml
# Storing file:  output/de/article125418383_txtrazor.yml
# Storing file:  output/de/article125418383_alchemy.yml
# Storing file:  output/de/article125418383_semant.yml
# Storing file:  output/de/article125411892_meaningcloud.yml
# Storing file:  output/de/article125411892_bitext.yml
# Storing file:  output/de/article125411892_retresco.yml
# Storing file:  output/de/article125411892_simple.yml
# Storing file:  output/de/article125411892_txtrazor.yml
# Storing file:  output/de/article125411892_alchemy.yml
# Storing file:  output/de/article125411892_semant.yml
# Storing file:  output/de/article125423635_meaningcloud.yml
# Storing file:  output/de/article125423635_bitext.yml
# Storing file:  output/de/article125423635_retresco.yml
# Storing file:  output/de/article125423635_simple.yml
# Storing file:  output/de/article125423635_txtrazor.yml
# Storing file:  output/de/article125423635_alchemy.yml
# Storing file:  output/de/article125423635_semant.yml
# Storing file:  output/de/article125421480_meaningcloud.yml
# Storing file:  output/de/article125421480_bitext.yml
# Storing file:  output/de/article125421480_retresco.yml
# Storing file:  output/de/article125421480_simple.yml
# Storing file:  output/de/article125421480_txtrazor.yml
# Storing file:  output/de/article125421480_alchemy.yml
# Storing file:  output/de/article125421480_semant.yml
# Storing file:  output/de/article125422572_meaningcloud.yml
# Storing file:  output/de/article125422572_bitext.yml
# Storing file:  output/de/article125422572_retresco.yml
# Storing file:  output/de/article125422572_simple.yml
# Storing file:  output/de/article125422572_txtrazor.yml
# Storing file:  output/de/article125422572_alchemy.yml
# Storing file:  output/de/article125422572_semant.yml
# Storing file:  output/de/article125419459_meaningcloud.yml
# Storing file:  output/de/article125419459_bitext.yml
# Storing file:  output/de/article125419459_retresco.yml
# Storing file:  output/de/article125419459_simple.yml
# Storing file:  output/de/article125419459_txtrazor.yml
# Storing file:  output/de/article125419459_alchemy.yml
# Storing file:  output/de/article125419459_semant.yml
# Storing file:  output/de/article125421093_meaningcloud.yml
# Storing file:  output/de/article125421093_bitext.yml
# Storing file:  output/de/article125421093_retresco.yml
# Storing file:  output/de/article125421093_simple.yml
# Storing file:  output/de/article125421093_txtrazor.yml
# Storing file:  output/de/article125421093_alchemy.yml
# Storing file:  output/de/article125421093_semant.yml
# Storing file:  output/de/article125419006_meaningcloud.yml
# Storing file:  output/de/article125419006_bitext.yml
# Storing file:  output/de/article125419006_retresco.yml
# Storing file:  output/de/article125419006_simple.yml
# Storing file:  output/de/article125419006_txtrazor.yml
# Storing file:  output/de/article125419006_alchemy.yml
# Storing file:  output/de/article125419006_semant.yml
# Storing file:  output/de/article125419838_meaningcloud.yml
# Storing file:  output/de/article125419838_bitext.yml
# Storing file:  output/de/article125419838_retresco.yml
# Storing file:  output/de/article125419838_simple.yml
# Storing file:  output/de/article125419838_txtrazor.yml
# Storing file:  output/de/article125419838_alchemy.yml
# Storing file:  output/de/article125419838_semant.yml
# Storing file:  output/de/article125420088_meaningcloud.yml
# Storing file:  output/de/article125420088_bitext.yml
# Storing file:  output/de/article125420088_retresco.yml
# Storing file:  output/de/article125420088_simple.yml
# Storing file:  output/de/article125420088_txtrazor.yml
# Storing file:  output/de/article125420088_alchemy.yml
# Storing file:  output/de/article125420088_semant.yml
# Storing file:  output/de/article125419555_meaningcloud.yml
# Storing file:  output/de/article125419555_bitext.yml
# Storing file:  output/de/article125419555_retresco.yml
# Storing file:  output/de/article125419555_simple.yml
# Storing file:  output/de/article125419555_txtrazor.yml
# Storing file:  output/de/article125419555_alchemy.yml
# Storing file:  output/de/article125419555_semant.yml
# Storing file:  output/de/article125419734_meaningcloud.yml
# Storing file:  output/de/article125419734_bitext.yml
# Storing file:  output/de/article125419734_retresco.yml
# Storing file:  output/de/article125419734_simple.yml
# Storing file:  output/de/article125419734_txtrazor.yml
# Storing file:  output/de/article125419734_alchemy.yml
# Storing file:  output/de/article125419734_semant.yml
# Storing file:  output/de/article125419949_meaningcloud.yml
# Storing file:  output/de/article125419949_bitext.yml
# Storing file:  output/de/article125419949_retresco.yml
# Storing file:  output/de/article125419949_simple.yml
# Storing file:  output/de/article125419949_txtrazor.yml
# Storing file:  output/de/article125419949_alchemy.yml
# Storing file:  output/de/article125419949_semant.yml
# Storing file:  output/de/article125411523_meaningcloud.yml
# Storing file:  output/de/article125411523_bitext.yml
# Storing file:  output/de/article125411523_retresco.yml
# Storing file:  output/de/article125411523_simple.yml
# Storing file:  output/de/article125411523_txtrazor.yml
# Storing file:  output/de/article125411523_alchemy.yml
# Storing file:  output/de/article125411523_semant.yml
# Storing file:  output/de/article125418264_meaningcloud.yml
# Storing file:  output/de/article125418264_bitext.yml
# Storing file:  output/de/article125418264_retresco.yml
# Storing file:  output/de/article125418264_simple.yml
# Storing file:  output/de/article125418264_txtrazor.yml
# Storing file:  output/de/article125418264_alchemy.yml
# Storing file:  output/de/article125418264_semant.yml
# Storing file:  output/de/article125417594_meaningcloud.yml
# Storing file:  output/de/article125417594_bitext.yml
# Storing file:  output/de/article125417594_retresco.yml
# Storing file:  output/de/article125417594_simple.yml
# Storing file:  output/de/article125417594_txtrazor.yml
# Storing file:  output/de/article125417594_alchemy.yml
# Storing file:  output/de/article125417594_semant.yml
# Storing file:  output/de/article125416040_meaningcloud.yml
# Storing file:  output/de/article125416040_bitext.yml
# Storing file:  output/de/article125416040_retresco.yml
# Storing file:  output/de/article125416040_simple.yml
# Storing file:  output/de/article125416040_txtrazor.yml
# Storing file:  output/de/article125416040_alchemy.yml
# Storing file:  output/de/article125416040_semant.yml
# Storing file:  output/de/article125416743_meaningcloud.yml
# Storing file:  output/de/article125416743_bitext.yml
# Storing file:  output/de/article125416743_retresco.yml
# Storing file:  output/de/article125416743_simple.yml
# Storing file:  output/de/article125416743_txtrazor.yml
# Storing file:  output/de/article125416743_alchemy.yml
# Storing file:  output/de/article125416743_semant.yml
# Storing file:  output/de/article125416433_meaningcloud.yml
# Storing file:  output/de/article125416433_bitext.yml
# Storing file:  output/de/article125416433_retresco.yml
# Storing file:  output/de/article125416433_simple.yml
# Storing file:  output/de/article125416433_txtrazor.yml
# Storing file:  output/de/article125416433_alchemy.yml
# Storing file:  output/de/article125416433_semant.yml
# Storing file:  output/de/article125414274_meaningcloud.yml
# Storing file:  output/de/article125414274_bitext.yml
# Storing file:  output/de/article125414274_retresco.yml
# Storing file:  output/de/article125414274_simple.yml
# Storing file:  output/de/article125414274_txtrazor.yml
# Storing file:  output/de/article125414274_alchemy.yml
# Storing file:  output/de/article125414274_semant.yml
# Storing file:  output/de/article125414811_meaningcloud.yml
# Storing file:  output/de/article125414811_bitext.yml
# Storing file:  output/de/article125414811_retresco.yml
# Storing file:  output/de/article125414811_simple.yml
# Storing file:  output/de/article125414811_txtrazor.yml
# Storing file:  output/de/article125414811_alchemy.yml
# Storing file:  output/de/article125414811_semant.yml
# Storing file:  output/de/article125411879_meaningcloud.yml
# Storing file:  output/de/article125411879_bitext.yml
# Storing file:  output/de/article125411879_retresco.yml
# Storing file:  output/de/article125411879_simple.yml
# Storing file:  output/de/article125411879_txtrazor.yml
# Storing file:  output/de/article125411879_alchemy.yml
# Storing file:  output/de/article125411879_semant.yml
# Storing file:  output/de/article125414637_meaningcloud.yml
# Storing file:  output/de/article125414637_bitext.yml
# Storing file:  output/de/article125414637_retresco.yml
# Storing file:  output/de/article125414637_simple.yml
# Storing file:  output/de/article125414637_txtrazor.yml
# Storing file:  output/de/article125414637_alchemy.yml
# Storing file:  output/de/article125414637_semant.yml
# Storing file:  output/de/article125411855_meaningcloud.yml
# Storing file:  output/de/article125411855_bitext.yml
# Storing file:  output/de/article125411855_retresco.yml
# Storing file:  output/de/article125411855_simple.yml
# Storing file:  output/de/article125411855_txtrazor.yml
# Storing file:  output/de/article125411855_alchemy.yml
# Storing file:  output/de/article125411855_semant.yml
# Storing file:  output/de/article125414830_meaningcloud.yml
# Storing file:  output/de/article125414830_bitext.yml
# Storing file:  output/de/article125414830_retresco.yml
# Storing file:  output/de/article125414830_simple.yml
# Storing file:  output/de/article125414830_txtrazor.yml
# Storing file:  output/de/article125414830_alchemy.yml
# Storing file:  output/de/article125414830_semant.yml
# Storing file:  output/de/article125412072_meaningcloud.yml
# Storing file:  output/de/article125412072_bitext.yml
# Storing file:  output/de/article125412072_retresco.yml
# Storing file:  output/de/article125412072_simple.yml
# Storing file:  output/de/article125412072_txtrazor.yml
# Storing file:  output/de/article125412072_alchemy.yml
# Storing file:  output/de/article125412072_semant.yml
# Storing file:  output/de/article125414913_meaningcloud.yml
# Storing file:  output/de/article125414913_bitext.yml
# Storing file:  output/de/article125414913_retresco.yml
# Storing file:  output/de/article125414913_simple.yml
# Storing file:  output/de/article125414913_txtrazor.yml
# Storing file:  output/de/article125414913_alchemy.yml
# Storing file:  output/de/article125414913_semant.yml
# Storing file:  output/de/article125413715_meaningcloud.yml
# Storing file:  output/de/article125413715_bitext.yml
# Storing file:  output/de/article125413715_retresco.yml
# Storing file:  output/de/article125413715_simple.yml
# Storing file:  output/de/article125413715_txtrazor.yml
# Storing file:  output/de/article125413715_alchemy.yml
# Storing file:  output/de/article125413715_semant.yml
# Storing file:  output/de/article125413599_meaningcloud.yml
# Storing file:  output/de/article125413599_bitext.yml
# Storing file:  output/de/article125413599_retresco.yml
# Storing file:  output/de/article125413599_simple.yml
# Storing file:  output/de/article125413599_txtrazor.yml
# Storing file:  output/de/article125413599_alchemy.yml
# Storing file:  output/de/article125413599_semant.yml
# Storing file:  output/de/article125412900_meaningcloud.yml
# Storing file:  output/de/article125412900_bitext.yml
# Storing file:  output/de/article125412900_retresco.yml
# Storing file:  output/de/article125412900_simple.yml
# Storing file:  output/de/article125412900_txtrazor.yml
# Storing file:  output/de/article125412900_alchemy.yml
# Storing file:  output/de/article125412900_semant.yml
# Storing file:  output/de/article125407288_meaningcloud.yml
# Storing file:  output/de/article125407288_bitext.yml
# Storing file:  output/de/article125407288_retresco.yml
# Storing file:  output/de/article125407288_simple.yml
# Storing file:  output/de/article125407288_txtrazor.yml
# Storing file:  output/de/article125407288_alchemy.yml
# Storing file:  output/de/article125407288_semant.yml
# Storing file:  output/de/article125412733_meaningcloud.yml
# Storing file:  output/de/article125412733_bitext.yml
# Storing file:  output/de/article125412733_retresco.yml
# Storing file:  output/de/article125412733_simple.yml
# Storing file:  output/de/article125412733_txtrazor.yml
# Storing file:  output/de/article125412733_alchemy.yml
# Storing file:  output/de/article125412733_semant.yml
# Storing file:  output/de/article125411758_meaningcloud.yml
# Storing file:  output/de/article125411758_bitext.yml
# Storing file:  output/de/article125411758_retresco.yml
# Storing file:  output/de/article125411758_simple.yml
# Storing file:  output/de/article125411758_txtrazor.yml
# Storing file:  output/de/article125411758_alchemy.yml
# Storing file:  output/de/article125411758_semant.yml
# Storing file:  output/de/article125412598_meaningcloud.yml
# Storing file:  output/de/article125412598_bitext.yml
# Storing file:  output/de/article125412598_retresco.yml
# Storing file:  output/de/article125412598_simple.yml
# Storing file:  output/de/article125412598_txtrazor.yml
# Storing file:  output/de/article125412598_alchemy.yml
# Storing file:  output/de/article125412598_semant.yml
# Storing file:  output/de/article125412309_meaningcloud.yml
# Storing file:  output/de/article125412309_bitext.yml
# Storing file:  output/de/article125412309_retresco.yml
# Storing file:  output/de/article125412309_simple.yml
# Storing file:  output/de/article125412309_txtrazor.yml
# Storing file:  output/de/article125412309_alchemy.yml
# Storing file:  output/de/article125412309_semant.yml
# Storing file:  output/de/article125397600_meaningcloud.yml
# Storing file:  output/de/article125397600_bitext.yml
# Storing file:  output/de/article125397600_retresco.yml
# Storing file:  output/de/article125397600_simple.yml
# Storing file:  output/de/article125397600_txtrazor.yml
# Storing file:  output/de/article125397600_alchemy.yml
# Storing file:  output/de/article125397600_semant.yml
# Storing file:  output/de/article125411133_meaningcloud.yml
# Storing file:  output/de/article125411133_bitext.yml
# Storing file:  output/de/article125411133_retresco.yml
# Storing file:  output/de/article125411133_simple.yml
# Storing file:  output/de/article125411133_txtrazor.yml
# Storing file:  output/de/article125411133_alchemy.yml
# Storing file:  output/de/article125411133_semant.yml
# Storing file:  output/de/article125410849_meaningcloud.yml
# Storing file:  output/de/article125410849_bitext.yml
# Storing file:  output/de/article125410849_retresco.yml
# Storing file:  output/de/article125410849_simple.yml
# Storing file:  output/de/article125410849_txtrazor.yml
# Storing file:  output/de/article125410849_alchemy.yml
# Storing file:  output/de/article125410849_semant.yml
# Storing file:  output/de/article125409377_meaningcloud.yml
# Storing file:  output/de/article125409377_bitext.yml
# Storing file:  output/de/article125409377_retresco.yml
# Storing file:  output/de/article125409377_simple.yml
# Storing file:  output/de/article125409377_txtrazor.yml
# Storing file:  output/de/article125409377_alchemy.yml
# Storing file:  output/de/article125409377_semant.yml
# Storing file:  output/de/article125410611_meaningcloud.yml
# Storing file:  output/de/article125410611_bitext.yml
# Storing file:  output/de/article125410611_retresco.yml
# Storing file:  output/de/article125410611_simple.yml
# Storing file:  output/de/article125410611_txtrazor.yml
# Storing file:  output/de/article125410611_alchemy.yml
# Storing file:  output/de/article125410611_semant.yml
# Storing file:  output/de/article125410545_meaningcloud.yml
# Storing file:  output/de/article125410545_bitext.yml
# Storing file:  output/de/article125410545_retresco.yml
# Storing file:  output/de/article125410545_simple.yml
# Storing file:  output/de/article125410545_txtrazor.yml
# Storing file:  output/de/article125410545_alchemy.yml
# Storing file:  output/de/article125410545_semant.yml
# Storing file:  output/de/article125410683_meaningcloud.yml
# Storing file:  output/de/article125410683_bitext.yml
# Storing file:  output/de/article125410683_retresco.yml
# Storing file:  output/de/article125410683_simple.yml
# Storing file:  output/de/article125410683_txtrazor.yml
# Storing file:  output/de/article125410683_alchemy.yml
# Storing file:  output/de/article125410683_semant.yml
# Storing file:  output/de/article125410701_meaningcloud.yml
# Storing file:  output/de/article125410701_bitext.yml
# Storing file:  output/de/article125410701_retresco.yml
# Storing file:  output/de/article125410701_simple.yml
# Storing file:  output/de/article125410701_txtrazor.yml
# Storing file:  output/de/article125410701_alchemy.yml
# Storing file:  output/de/article125410701_semant.yml

# %%
import semaeval.statistics as stats

# %%
articles=stats.load_articles("de")

# %%
data=stats.collect_data(articles)
# Out:
# alchemy article125397600.yml float division by zero
# bitext article125397600.yml float division by zero
# bitext article125397600.yml float division by zero
# bitext article125397600.yml float division by zero
# meaningcloud article125397600.yml float division by zero
# meaningcloud article125397600.yml float division by zero
# meaningcloud article125397600.yml float division by zero
# semant article125397600.yml float division by zero
# simple article125397600.yml float division by zero
# bitext article125407288.yml float division by zero
# bitext article125407288.yml float division by zero
# bitext article125407288.yml float division by zero
# meaningcloud article125407288.yml float division by zero
# meaningcloud article125407288.yml float division by zero
# meaningcloud article125407288.yml float division by zero
# semant article125407288.yml float division by zero
# alchemy article125409377.yml float division by zero
# bitext article125409377.yml float division by zero
# bitext article125409377.yml float division by zero
# bitext article125409377.yml float division by zero
# meaningcloud article125409377.yml float division by zero
# meaningcloud article125409377.yml float division by zero
# meaningcloud article125409377.yml float division by zero
# retresco article125409377.yml float division by zero
# semant article125409377.yml float division by zero
# semant article125409377.yml float division by zero
# simple article125409377.yml float division by zero
# simple article125409377.yml float division by zero
# txtrazor article125409377.yml float division by zero
# txtrazor article125409377.yml float division by zero
# bitext article125410545.yml float division by zero
# bitext article125410545.yml float division by zero
# bitext article125410545.yml float division by zero
# meaningcloud article125410545.yml float division by zero
# meaningcloud article125410545.yml float division by zero
# meaningcloud article125410545.yml float division by zero
# semant article125410545.yml float division by zero
# simple article125410545.yml float division by zero
# alchemy article125410611.yml float division by zero
# bitext article125410611.yml float division by zero
# bitext article125410611.yml float division by zero
# bitext article125410611.yml float division by zero
# meaningcloud article125410611.yml float division by zero
# meaningcloud article125410611.yml float division by zero
# meaningcloud article125410611.yml float division by zero
# retresco article125410611.yml float division by zero
# semant article125410611.yml float division by zero
# semant article125410611.yml float division by zero
# simple article125410611.yml float division by zero
# simple article125410611.yml float division by zero
# txtrazor article125410611.yml float division by zero
# txtrazor article125410611.yml float division by zero
# alchemy article125410683.yml float division by zero
# bitext article125410683.yml float division by zero
# bitext article125410683.yml float division by zero
# bitext article125410683.yml float division by zero
# meaningcloud article125410683.yml float division by zero
# meaningcloud article125410683.yml float division by zero
# meaningcloud article125410683.yml float division by zero
# retresco article125410683.yml float division by zero
# semant article125410683.yml float division by zero
# simple article125410683.yml float division by zero
# simple article125410683.yml float division by zero
# simple article125410683.yml float division by zero
# txtrazor article125410683.yml float division by zero
# txtrazor article125410683.yml float division by zero
# txtrazor article125410683.yml float division by zero
# alchemy article125410701.yml float division by zero
# alchemy article125410701.yml float division by zero
# alchemy article125410701.yml float division by zero
# bitext article125410701.yml float division by zero
# bitext article125410701.yml float division by zero
# bitext article125410701.yml float division by zero
# meaningcloud article125410701.yml float division by zero
# meaningcloud article125410701.yml float division by zero
# meaningcloud article125410701.yml float division by zero
# retresco article125410701.yml float division by zero
# retresco article125410701.yml float division by zero
# retresco article125410701.yml float division by zero
# semant article125410701.yml float division by zero
# semant article125410701.yml float division by zero
# semant article125410701.yml float division by zero
# simple article125410701.yml float division by zero
# simple article125410701.yml float division by zero
# simple article125410701.yml float division by zero
# txtrazor article125410701.yml float division by zero
# txtrazor article125410701.yml float division by zero
# txtrazor article125410701.yml float division by zero
# alchemy article125410849.yml float division by zero
# bitext article125410849.yml float division by zero
# bitext article125410849.yml float division by zero
# bitext article125410849.yml float division by zero
# meaningcloud article125410849.yml float division by zero
# meaningcloud article125410849.yml float division by zero
# meaningcloud article125410849.yml float division by zero
# retresco article125410849.yml float division by zero
# semant article125410849.yml float division by zero
# simple article125410849.yml float division by zero
# txtrazor article125410849.yml float division by zero
# bitext article125411133.yml float division by zero
# bitext article125411133.yml float division by zero
# bitext article125411133.yml float division by zero
# meaningcloud article125411133.yml float division by zero
# meaningcloud article125411133.yml float division by zero
# meaningcloud article125411133.yml float division by zero
# txtrazor article125411133.yml float division by zero
# bitext article125411523.yml float division by zero
# bitext article125411523.yml float division by zero
# bitext article125411523.yml float division by zero
# meaningcloud article125411523.yml float division by zero
# meaningcloud article125411523.yml float division by zero
# meaningcloud article125411523.yml float division by zero
# semant article125411523.yml float division by zero
# semant article125411523.yml float division by zero
# txtrazor article125411523.yml float division by zero
# alchemy article125411758.yml float division by zero
# alchemy article125411758.yml float division by zero
# alchemy article125411758.yml float division by zero
# bitext article125411758.yml float division by zero
# bitext article125411758.yml float division by zero
# bitext article125411758.yml float division by zero
# meaningcloud article125411758.yml float division by zero
# meaningcloud article125411758.yml float division by zero
# meaningcloud article125411758.yml float division by zero
# retresco article125411758.yml float division by zero
# retresco article125411758.yml float division by zero
# retresco article125411758.yml float division by zero
# semant article125411758.yml float division by zero
# semant article125411758.yml float division by zero
# semant article125411758.yml float division by zero
# simple article125411758.yml float division by zero
# simple article125411758.yml float division by zero
# txtrazor article125411758.yml float division by zero
# txtrazor article125411758.yml float division by zero
# bitext article125411855.yml float division by zero
# bitext article125411855.yml float division by zero
# bitext article125411855.yml float division by zero
# meaningcloud article125411855.yml float division by zero
# meaningcloud article125411855.yml float division by zero
# meaningcloud article125411855.yml float division by zero
# semant article125411855.yml float division by zero
# txtrazor article125411855.yml float division by zero
# alchemy article125411879.yml float division by zero
# bitext article125411879.yml float division by zero
# bitext article125411879.yml float division by zero
# bitext article125411879.yml float division by zero
# meaningcloud article125411879.yml float division by zero
# meaningcloud article125411879.yml float division by zero
# meaningcloud article125411879.yml float division by zero
# retresco article125411879.yml float division by zero
# semant article125411879.yml float division by zero
# simple article125411879.yml float division by zero
# txtrazor article125411879.yml float division by zero
# alchemy article125411892.yml float division by zero
# alchemy article125411892.yml float division by zero
# bitext article125411892.yml float division by zero
# bitext article125411892.yml float division by zero
# bitext article125411892.yml float division by zero
# meaningcloud article125411892.yml float division by zero
# meaningcloud article125411892.yml float division by zero
# meaningcloud article125411892.yml float division by zero
# retresco article125411892.yml float division by zero
# retresco article125411892.yml float division by zero
# retresco article125411892.yml float division by zero
# semant article125411892.yml float division by zero
# semant article125411892.yml float division by zero
# semant article125411892.yml float division by zero
# simple article125411892.yml float division by zero
# simple article125411892.yml float division by zero
# txtrazor article125411892.yml float division by zero
# bitext article125412072.yml float division by zero
# bitext article125412072.yml float division by zero
# bitext article125412072.yml float division by zero
# meaningcloud article125412072.yml float division by zero
# meaningcloud article125412072.yml float division by zero
# meaningcloud article125412072.yml float division by zero
# retresco article125412072.yml float division by zero
# semant article125412072.yml float division by zero
# txtrazor article125412072.yml float division by zero
# alchemy article125412309.yml float division by zero
# alchemy article125412309.yml float division by zero
# alchemy article125412309.yml float division by zero
# bitext article125412309.yml float division by zero
# bitext article125412309.yml float division by zero
# bitext article125412309.yml float division by zero
# meaningcloud article125412309.yml float division by zero
# meaningcloud article125412309.yml float division by zero
# meaningcloud article125412309.yml float division by zero
# retresco article125412309.yml float division by zero
# retresco article125412309.yml float division by zero
# retresco article125412309.yml float division by zero
# semant article125412309.yml float division by zero
# semant article125412309.yml float division by zero
# semant article125412309.yml float division by zero
# simple article125412309.yml float division by zero
# simple article125412309.yml float division by zero
# simple article125412309.yml float division by zero
# txtrazor article125412309.yml float division by zero
# txtrazor article125412309.yml float division by zero
# txtrazor article125412309.yml float division by zero
# bitext article125412598.yml float division by zero
# bitext article125412598.yml float division by zero
# bitext article125412598.yml float division by zero
# meaningcloud article125412598.yml float division by zero
# meaningcloud article125412598.yml float division by zero
# meaningcloud article125412598.yml float division by zero
# semant article125412598.yml float division by zero
# alchemy article125412733.yml float division by zero
# bitext article125412733.yml float division by zero
# bitext article125412733.yml float division by zero
# bitext article125412733.yml float division by zero
# meaningcloud article125412733.yml float division by zero
# meaningcloud article125412733.yml float division by zero
# meaningcloud article125412733.yml float division by zero
# simple article125412733.yml float division by zero
# txtrazor article125412733.yml float division by zero
# bitext article125412900.yml float division by zero
# bitext article125412900.yml float division by zero
# bitext article125412900.yml float division by zero
# meaningcloud article125412900.yml float division by zero
# meaningcloud article125412900.yml float division by zero
# meaningcloud article125412900.yml float division by zero
# semant article125412900.yml float division by zero
# semant article125412900.yml float division by zero
# alchemy article125413599.yml float division by zero
# alchemy article125413599.yml float division by zero
# bitext article125413599.yml float division by zero
# bitext article125413599.yml float division by zero
# bitext article125413599.yml float division by zero
# meaningcloud article125413599.yml float division by zero
# meaningcloud article125413599.yml float division by zero
# meaningcloud article125413599.yml float division by zero
# retresco article125413599.yml float division by zero
# semant article125413599.yml float division by zero
# semant article125413599.yml float division by zero
# simple article125413599.yml float division by zero
# txtrazor article125413599.yml float division by zero
# alchemy article125413715.yml float division by zero
# bitext article125413715.yml float division by zero
# bitext article125413715.yml float division by zero
# bitext article125413715.yml float division by zero
# meaningcloud article125413715.yml float division by zero
# meaningcloud article125413715.yml float division by zero
# meaningcloud article125413715.yml float division by zero
# semant article125413715.yml float division by zero
# simple article125413715.yml float division by zero
# alchemy article125414274.yml float division by zero
# alchemy article125414274.yml float division by zero
# bitext article125414274.yml float division by zero
# bitext article125414274.yml float division by zero
# bitext article125414274.yml float division by zero
# meaningcloud article125414274.yml float division by zero
# meaningcloud article125414274.yml float division by zero
# meaningcloud article125414274.yml float division by zero
# retresco article125414274.yml float division by zero
# semant article125414274.yml float division by zero
# semant article125414274.yml float division by zero
# simple article125414274.yml float division by zero
# simple article125414274.yml float division by zero
# txtrazor article125414274.yml float division by zero
# txtrazor article125414274.yml float division by zero
# alchemy article125414637.yml float division by zero
# alchemy article125414637.yml float division by zero
# bitext article125414637.yml float division by zero
# bitext article125414637.yml float division by zero
# bitext article125414637.yml float division by zero
# meaningcloud article125414637.yml float division by zero
# meaningcloud article125414637.yml float division by zero
# meaningcloud article125414637.yml float division by zero
# retresco article125414637.yml float division by zero
# semant article125414637.yml float division by zero
# simple article125414637.yml float division by zero
# simple article125414637.yml float division by zero
# alchemy article125414811.yml float division by zero
# bitext article125414811.yml float division by zero
# bitext article125414811.yml float division by zero
# bitext article125414811.yml float division by zero
# meaningcloud article125414811.yml float division by zero
# meaningcloud article125414811.yml float division by zero
# meaningcloud article125414811.yml float division by zero
# retresco article125414811.yml float division by zero
# semant article125414811.yml float division by zero
# simple article125414811.yml float division by zero
# txtrazor article125414811.yml float division by zero
# alchemy article125414830.yml float division by zero
# alchemy article125414830.yml float division by zero
# bitext article125414830.yml float division by zero
# bitext article125414830.yml float division by zero
# bitext article125414830.yml float division by zero
# meaningcloud article125414830.yml float division by zero
# meaningcloud article125414830.yml float division by zero
# meaningcloud article125414830.yml float division by zero
# retresco article125414830.yml float division by zero
# retresco article125414830.yml float division by zero
# semant article125414830.yml float division by zero
# semant article125414830.yml float division by zero
# simple article125414830.yml float division by zero
# simple article125414830.yml float division by zero
# txtrazor article125414830.yml float division by zero
# txtrazor article125414830.yml float division by zero
# bitext article125414913.yml float division by zero
# bitext article125414913.yml float division by zero
# bitext article125414913.yml float division by zero
# meaningcloud article125414913.yml float division by zero
# meaningcloud article125414913.yml float division by zero
# meaningcloud article125414913.yml float division by zero
# semant article125414913.yml float division by zero
# alchemy article125416040.yml float division by zero
# bitext article125416040.yml float division by zero
# bitext article125416040.yml float division by zero
# bitext article125416040.yml float division by zero
# meaningcloud article125416040.yml float division by zero
# meaningcloud article125416040.yml float division by zero
# meaningcloud article125416040.yml float division by zero
# retresco article125416040.yml float division by zero
# semant article125416040.yml float division by zero
# semant article125416040.yml float division by zero
# simple article125416040.yml float division by zero
# simple article125416040.yml float division by zero
# txtrazor article125416040.yml float division by zero
# bitext article125416433.yml float division by zero
# bitext article125416433.yml float division by zero
# bitext article125416433.yml float division by zero
# meaningcloud article125416433.yml float division by zero
# meaningcloud article125416433.yml float division by zero
# meaningcloud article125416433.yml float division by zero
# simple article125416433.yml float division by zero
# txtrazor article125416433.yml float division by zero
# alchemy article125416743.yml float division by zero
# bitext article125416743.yml float division by zero
# bitext article125416743.yml float division by zero
# bitext article125416743.yml float division by zero
# meaningcloud article125416743.yml float division by zero
# meaningcloud article125416743.yml float division by zero
# meaningcloud article125416743.yml float division by zero
# retresco article125416743.yml float division by zero
# semant article125416743.yml float division by zero
# simple article125416743.yml float division by zero
# bitext article125417594.yml float division by zero
# bitext article125417594.yml float division by zero
# bitext article125417594.yml float division by zero
# meaningcloud article125417594.yml float division by zero
# meaningcloud article125417594.yml float division by zero
# meaningcloud article125417594.yml float division by zero
# semant article125417594.yml float division by zero
# simple article125417594.yml float division by zero
# txtrazor article125417594.yml float division by zero
# txtrazor article125417594.yml float division by zero
# bitext article125418264.yml float division by zero
# bitext article125418264.yml float division by zero
# bitext article125418264.yml float division by zero
# meaningcloud article125418264.yml float division by zero
# meaningcloud article125418264.yml float division by zero
# meaningcloud article125418264.yml float division by zero
# semant article125418264.yml float division by zero
# simple article125418264.yml float division by zero
# alchemy article125418383.yml float division by zero
# bitext article125418383.yml float division by zero
# bitext article125418383.yml float division by zero
# bitext article125418383.yml float division by zero
# meaningcloud article125418383.yml float division by zero
# meaningcloud article125418383.yml float division by zero
# meaningcloud article125418383.yml float division by zero
# retresco article125418383.yml float division by zero
# semant article125418383.yml float division by zero
# simple article125418383.yml float division by zero
# txtrazor article125418383.yml float division by zero
# alchemy article125419006.yml float division by zero
# bitext article125419006.yml float division by zero
# bitext article125419006.yml float division by zero
# bitext article125419006.yml float division by zero
# meaningcloud article125419006.yml float division by zero
# meaningcloud article125419006.yml float division by zero
# meaningcloud article125419006.yml float division by zero
# retresco article125419006.yml float division by zero
# semant article125419006.yml float division by zero
# simple article125419006.yml float division by zero
# simple article125419006.yml float division by zero
# txtrazor article125419006.yml float division by zero
# txtrazor article125419006.yml float division by zero
# alchemy article125419459.yml float division by zero
# alchemy article125419459.yml float division by zero
# bitext article125419459.yml float division by zero
# bitext article125419459.yml float division by zero
# bitext article125419459.yml float division by zero
# meaningcloud article125419459.yml float division by zero
# meaningcloud article125419459.yml float division by zero
# meaningcloud article125419459.yml float division by zero
# retresco article125419459.yml float division by zero
# semant article125419459.yml float division by zero
# simple article125419459.yml float division by zero
# txtrazor article125419459.yml float division by zero
# alchemy article125419555.yml float division by zero
# bitext article125419555.yml float division by zero
# bitext article125419555.yml float division by zero
# bitext article125419555.yml float division by zero
# meaningcloud article125419555.yml float division by zero
# meaningcloud article125419555.yml float division by zero
# meaningcloud article125419555.yml float division by zero
# retresco article125419555.yml float division by zero
# semant article125419555.yml float division by zero
# semant article125419555.yml float division by zero
# simple article125419555.yml float division by zero
# txtrazor article125419555.yml float division by zero
# txtrazor article125419555.yml float division by zero
# txtrazor article125419555.yml float division by zero
# bitext article125419734.yml float division by zero
# bitext article125419734.yml float division by zero
# bitext article125419734.yml float division by zero
# meaningcloud article125419734.yml float division by zero
# meaningcloud article125419734.yml float division by zero
# meaningcloud article125419734.yml float division by zero
# semant article125419734.yml float division by zero
# bitext article125419838.yml float division by zero
# bitext article125419838.yml float division by zero
# bitext article125419838.yml float division by zero
# meaningcloud article125419838.yml float division by zero
# meaningcloud article125419838.yml float division by zero
# meaningcloud article125419838.yml float division by zero
# semant article125419838.yml float division by zero
# alchemy article125419949.yml float division by zero
# bitext article125419949.yml float division by zero
# bitext article125419949.yml float division by zero
# bitext article125419949.yml float division by zero
# meaningcloud article125419949.yml float division by zero
# meaningcloud article125419949.yml float division by zero
# meaningcloud article125419949.yml float division by zero
# retresco article125419949.yml float division by zero
# semant article125419949.yml float division by zero
# semant article125419949.yml float division by zero
# simple article125419949.yml float division by zero
# txtrazor article125419949.yml float division by zero
# alchemy article125420088.yml float division by zero
# bitext article125420088.yml float division by zero
# bitext article125420088.yml float division by zero
# bitext article125420088.yml float division by zero
# meaningcloud article125420088.yml float division by zero
# meaningcloud article125420088.yml float division by zero
# meaningcloud article125420088.yml float division by zero
# retresco article125420088.yml float division by zero
# semant article125420088.yml float division by zero
# simple article125420088.yml float division by zero
# txtrazor article125420088.yml float division by zero
# bitext article125421093.yml float division by zero
# bitext article125421093.yml float division by zero
# bitext article125421093.yml float division by zero
# meaningcloud article125421093.yml float division by zero
# meaningcloud article125421093.yml float division by zero
# meaningcloud article125421093.yml float division by zero
# retresco article125421093.yml float division by zero
# semant article125421093.yml float division by zero
# bitext article125421480.yml float division by zero
# bitext article125421480.yml float division by zero
# bitext article125421480.yml float division by zero
# meaningcloud article125421480.yml float division by zero
# meaningcloud article125421480.yml float division by zero
# meaningcloud article125421480.yml float division by zero
# semant article125421480.yml float division by zero
# txtrazor article125421480.yml float division by zero
# bitext article125422405.yml float division by zero
# bitext article125422405.yml float division by zero
# bitext article125422405.yml float division by zero
# meaningcloud article125422405.yml float division by zero
# meaningcloud article125422405.yml float division by zero
# meaningcloud article125422405.yml float division by zero
# retresco article125422405.yml float division by zero
# semant article125422405.yml float division by zero
# simple article125422405.yml float division by zero
# txtrazor article125422405.yml float division by zero
# bitext article125422572.yml float division by zero
# bitext article125422572.yml float division by zero
# bitext article125422572.yml float division by zero
# meaningcloud article125422572.yml float division by zero
# meaningcloud article125422572.yml float division by zero
# meaningcloud article125422572.yml float division by zero
# semant article125422572.yml float division by zero
# semant article125422572.yml float division by zero
# txtrazor article125422572.yml float division by zero
# bitext article125422595.yml float division by zero
# bitext article125422595.yml float division by zero
# bitext article125422595.yml float division by zero
# meaningcloud article125422595.yml float division by zero
# meaningcloud article125422595.yml float division by zero
# meaningcloud article125422595.yml float division by zero
# semant article125422595.yml float division by zero
# alchemy article125423156.yml float division by zero
# alchemy article125423156.yml float division by zero
# bitext article125423156.yml float division by zero
# bitext article125423156.yml float division by zero
# bitext article125423156.yml float division by zero
# meaningcloud article125423156.yml float division by zero
# meaningcloud article125423156.yml float division by zero
# meaningcloud article125423156.yml float division by zero
# retresco article125423156.yml float division by zero
# retresco article125423156.yml float division by zero
# semant article125423156.yml float division by zero
# semant article125423156.yml float division by zero
# simple article125423156.yml float division by zero
# simple article125423156.yml float division by zero
# txtrazor article125423156.yml float division by zero
# txtrazor article125423156.yml float division by zero
# bitext article125423592.yml float division by zero
# bitext article125423592.yml float division by zero
# bitext article125423592.yml float division by zero
# meaningcloud article125423592.yml float division by zero
# meaningcloud article125423592.yml float division by zero
# meaningcloud article125423592.yml float division by zero
# semant article125423592.yml float division by zero
# semant article125423592.yml float division by zero
# txtrazor article125423592.yml float division by zero
# alchemy article125423635.yml float division by zero
# bitext article125423635.yml float division by zero
# bitext article125423635.yml float division by zero
# bitext article125423635.yml float division by zero
# meaningcloud article125423635.yml float division by zero
# meaningcloud article125423635.yml float division by zero
# meaningcloud article125423635.yml float division by zero
# retresco article125423635.yml float division by zero
# semant article125423635.yml float division by zero
# semant article125423635.yml float division by zero
# simple article125423635.yml float division by zero
# txtrazor article125423635.yml float division by zero
# bitext article125423641.yml float division by zero
# bitext article125423641.yml float division by zero
# bitext article125423641.yml float division by zero
# meaningcloud article125423641.yml float division by zero
# meaningcloud article125423641.yml float division by zero
# meaningcloud article125423641.yml float division by zero
# semant article125423641.yml float division by zero
# alchemy article125423712.yml float division by zero
# bitext article125423712.yml float division by zero
# bitext article125423712.yml float division by zero
# bitext article125423712.yml float division by zero
# meaningcloud article125423712.yml float division by zero
# meaningcloud article125423712.yml float division by zero
# meaningcloud article125423712.yml float division by zero
# retresco article125423712.yml float division by zero
# semant article125423712.yml float division by zero
# simple article125423712.yml float division by zero
# alchemy article125424107.yml float division by zero
# bitext article125424107.yml float division by zero
# bitext article125424107.yml float division by zero
# bitext article125424107.yml float division by zero
# meaningcloud article125424107.yml float division by zero
# meaningcloud article125424107.yml float division by zero
# meaningcloud article125424107.yml float division by zero
# retresco article125424107.yml float division by zero
# semant article125424107.yml float division by zero
# semant article125424107.yml float division by zero
# simple article125424107.yml float division by zero
# simple article125424107.yml float division by zero
# txtrazor article125424107.yml float division by zero
# txtrazor article125424107.yml float division by zero

# %%
results=stats.aggregate_result(data)

# %%
results.extend(stats.compute_total(results))

# %%
# %matplotlib inline

# %%
stats.plot_results(results)

# %%
stats.store_results(results,"de")
# Out:
# Storing file:  de_results.yml
