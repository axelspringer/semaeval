# %%
import semaeval.util as util
util.clean_storage("fr")
# Out:
# Deleting: input/fr/pmematest_095.yml
# Deleting: input/fr/pmematest_1048.yml
# Deleting: input/fr/pmematest_1074.yml
# Deleting: input/fr/pmematest_1087.yml
# Deleting: input/fr/pmematest_1237.yml
# Deleting: input/fr/pmematest_126.yml
# Deleting: input/fr/pmematest_1285.yml
# Deleting: input/fr/pmematest_1299.yml
# Deleting: input/fr/pmematest_1383.yml
# Deleting: input/fr/pmematest_1385.yml
# Deleting: input/fr/pmematest_1402.yml
# Deleting: input/fr/pmematest_1421.yml
# Deleting: input/fr/pmematest_150.yml
# Deleting: input/fr/pmematest_1589.yml
# Deleting: input/fr/pmematest_1600.yml
# Deleting: input/fr/pmematest_1881.yml
# Deleting: input/fr/pmematest_1901.yml
# Deleting: input/fr/pmematest_1993.yml
# Deleting: input/fr/pmematest_2048.yml
# Deleting: input/fr/pmematest_2115.yml
# Deleting: input/fr/pmematest_2210.yml
# Deleting: input/fr/pmematest_2250.yml
# Deleting: input/fr/pmematest_2261.yml
# Deleting: input/fr/pmematest_2270.yml
# Deleting: input/fr/pmematest_239.yml
# Deleting: input/fr/pmematest_242.yml
# Deleting: input/fr/pmematest_2493.yml
# Deleting: input/fr/pmematest_2612.yml
# Deleting: input/fr/pmematest_265.yml
# Deleting: input/fr/pmematest_2716.yml
# Deleting: input/fr/pmematest_2735.yml
# Deleting: input/fr/pmematest_2852.yml
# Deleting: input/fr/pmematest_2879.yml
# Deleting: input/fr/pmematest_2900.yml
# Deleting: input/fr/pmematest_3022.yml
# Deleting: input/fr/pmematest_3043.yml
# Deleting: input/fr/pmematest_3066.yml
# Deleting: input/fr/pmematest_3067.yml
# Deleting: input/fr/pmematest_3159.yml
# Deleting: input/fr/pmematest_320.yml
# Deleting: input/fr/pmematest_3245.yml
# Deleting: input/fr/pmematest_3249.yml
# Deleting: input/fr/pmematest_336.yml
# Deleting: input/fr/pmematest_3466.yml
# Deleting: input/fr/pmematest_3510.yml
# Deleting: input/fr/pmematest_3537.yml
# Deleting: input/fr/pmematest_555.yml
# Deleting: input/fr/pmematest_580.yml
# Deleting: input/fr/pmematest_683.yml
# Deleting: input/fr/pmematest_745.yml
# [Errno 2] No such file or directory: 'result/fr'

# %%
import semaeval.source.syndication as synd

# %%
help(synd)
# Out:
# Help on module semaeval.source.syndication in semaeval.source:
#
# NAME
#     semaeval.source.syndication - # -*- coding: utf-8 -*-
#
# FILE
#     /Users/amaier1/git/semaeval/semaeval/source/syndication.py
#
# FUNCTIONS
#     article_from_path(path)
#
#     articles_from_dir(dir)
#
#     load_articles(prefix)
#
#     store_articles(articles, prefix)
#
# DATA
#     store_dir = 'input/'
#     url_regex = <_sre.SRE_Pattern object>

# %%
pme = synd.articles_from_dir("/Users/amaier1/Documents/semeval/pmematest")

# %%
import random
articles = random.sample(pme,50)

# %%
synd.store_articles(articles,"fr")
# Out:
# Storing file:  input/fr/pmematest_2994.yml
# Storing file:  input/fr/pmematest_791.yml
# Storing file:  input/fr/pmematest_2906.yml
# Storing file:  input/fr/pmematest_901.yml
# Storing file:  input/fr/pmematest_3511.yml
# Storing file:  input/fr/pmematest_3098.yml
# Storing file:  input/fr/pmematest_456.yml
# Storing file:  input/fr/pmematest_1486.yml
# Storing file:  input/fr/pmematest_1699.yml
# Storing file:  input/fr/pmematest_618.yml
# Storing file:  input/fr/pmematest_1953.yml
# Storing file:  input/fr/pmematest_2112.yml
# Storing file:  input/fr/pmematest_2726.yml
# Storing file:  input/fr/pmematest_2084.yml
# Storing file:  input/fr/pmematest_3113.yml
# Storing file:  input/fr/pmematest_2851.yml
# Storing file:  input/fr/pmematest_1839.yml
# Storing file:  input/fr/pmematest_641.yml
# Storing file:  input/fr/pmematest_2094.yml
# Storing file:  input/fr/pmematest_894.yml
# Storing file:  input/fr/pmematest_3472.yml
# Storing file:  input/fr/pmematest_1630.yml
# Storing file:  input/fr/pmematest_1034.yml
# Storing file:  input/fr/pmematest_1722.yml
# Storing file:  input/fr/pmematest_912.yml
# Storing file:  input/fr/pmematest_1508.yml
# Storing file:  input/fr/pmematest_1834.yml
# Storing file:  input/fr/pmematest_1678.yml
# Storing file:  input/fr/pmematest_2766.yml
# Storing file:  input/fr/pmematest_1582.yml
# Storing file:  input/fr/pmematest_2124.yml
# Storing file:  input/fr/pmematest_1587.yml
# Storing file:  input/fr/pmematest_2981.yml
# Storing file:  input/fr/pmematest_341.yml
# Storing file:  input/fr/pmematest_2583.yml
# Storing file:  input/fr/pmematest_1697.yml
# Storing file:  input/fr/pmematest_3274.yml
# Storing file:  input/fr/pmematest_576.yml
# Storing file:  input/fr/pmematest_2310.yml
# Storing file:  input/fr/pmematest_1089.yml
# Storing file:  input/fr/pmematest_644.yml
# Storing file:  input/fr/pmematest_1589.yml
# Storing file:  input/fr/pmematest_560.yml
# Storing file:  input/fr/pmematest_118.yml
# Storing file:  input/fr/pmematest_2511.yml
# Storing file:  input/fr/pmematest_334.yml
# Storing file:  input/fr/pmematest_3485.yml
# Storing file:  input/fr/pmematest_2720.yml
# Storing file:  input/fr/pmematest_3362.yml
# Storing file:  input/fr/pmematest_2850.yml

# %%
import semaeval.evaluate as eval
reload(eval)
# Out:
# <module 'semaeval.evaluate' from 'semaeval/evaluate.pyc'>

# %%
articles_enriched = eval.detect_entities(articles,"fr")
# Out:
# Filename: pmematest_2994.yml
# Collecting results:
# Filename: pmematest_791.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_2906.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# semaeval.engine.basistech
# textrazor: [u'Device', u'InformationAppliance']
# Filename: pmematest_901.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.meaningcloud
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_3511.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_3098.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_456.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.basistech
# semantria: Regex
# semantria: Regex
# semantria: Regex
# Filename: pmematest_1486.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semantria: Regex
# Filename: pmematest_1699.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_618.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.semant
# semaeval.engine.simple
# semaeval.engine.basistech
# Filename: pmematest_1953.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# bitext:textrazor:basistech: 5
#  IDENTIFIER:EMAIL
#  [u'Email']
# Filename: pmematest_2112.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_2726.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_2084.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.basistech
# Filename: pmematest_3113.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_2851.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.retresco
# Filename: pmematest_1839.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_641.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.basistech
# textrazor:alchemy: OperatingSystem
#  [u'Instrument']
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# Filename: pmematest_2094.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_894.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_3472.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_1630.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# alchemy: NaturalDisaster
# Filename: pmematest_1034.yml
# Collecting results:
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_1722.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.basistech
# Filename: pmematest_912.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_1508.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.alchemy
# semaeval.engine.simple
# Filename: pmematest_1834.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_1678.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_2766.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# textrazor:alchemy: Product
#  [u'Device', u'InformationAppliance']
# alchemy: Product
# textrazor: [u'Device', u'InformationAppliance']
# alchemy: TelevisionShow
# textrazor: [u'Device', u'InformationAppliance']
# Filename: pmematest_1582.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_2124.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.basistech
# Filename: pmematest_1587.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2981.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_341.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.meaningcloud
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_2583.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_1697.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.semant
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_3274.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# textrazor:alchemy: Product
#  [u'Device', u'InformationAppliance']
# alchemy: Product
# textrazor: [u'Device', u'InformationAppliance']
# alchemy: OperatingSystem
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# Filename: pmematest_576.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.alchemy
# semaeval.engine.simple
# textrazor:semantria: Regex
#  [u'Device', u'InformationAppliance']
# semantria: Regex
# semantria: Regex
# Filename: pmematest_2310.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_1089.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_644.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# textrazor: [u'Colour']
# Filename: pmematest_1589.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.meaningcloud
# semaeval.engine.retresco
# semaeval.engine.semant
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_560.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_118.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2511.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# textrazor:basistech: IDENTIFIER:EMAIL
#  [u'Email']
# Filename: pmematest_334.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_3485.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_2720.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_3362.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.alchemy
# semaeval.engine.simple
# alchemy: TelevisionShow
# alchemy: OperatingSystem
# Filename: pmematest_2850.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.basistech
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple

# %%
eval.store_articles(articles_enriched,"fr")
# Out:
# Storing file:  output/fr/pmematest_2994_retresco.yml
# Storing file:  output/fr/pmematest_2994_txtrazor.yml
# Storing file:  output/fr/pmematest_2994_simple.yml
# Storing file:  output/fr/pmematest_2994_semant.yml
# Storing file:  output/fr/pmematest_2994_basistech.yml
# Storing file:  output/fr/pmematest_2994_meaningcloud.yml
# Storing file:  output/fr/pmematest_2994_bitext.yml
# Storing file:  output/fr/pmematest_2994_alchemy.yml
# Storing file:  output/fr/pmematest_791_retresco.yml
# Storing file:  output/fr/pmematest_791_txtrazor.yml
# Storing file:  output/fr/pmematest_791_simple.yml
# Storing file:  output/fr/pmematest_791_semant.yml
# Storing file:  output/fr/pmematest_791_basistech.yml
# Storing file:  output/fr/pmematest_791_meaningcloud.yml
# Storing file:  output/fr/pmematest_791_bitext.yml
# Storing file:  output/fr/pmematest_791_alchemy.yml
# Storing file:  output/fr/pmematest_2906_retresco.yml
# Storing file:  output/fr/pmematest_2906_txtrazor.yml
# Storing file:  output/fr/pmematest_2906_simple.yml
# Storing file:  output/fr/pmematest_2906_semant.yml
# Storing file:  output/fr/pmematest_2906_basistech.yml
# Storing file:  output/fr/pmematest_2906_meaningcloud.yml
# Storing file:  output/fr/pmematest_2906_bitext.yml
# Storing file:  output/fr/pmematest_2906_alchemy.yml
# Storing file:  output/fr/pmematest_901_retresco.yml
# Storing file:  output/fr/pmematest_901_txtrazor.yml
# Storing file:  output/fr/pmematest_901_simple.yml
# Storing file:  output/fr/pmematest_901_semant.yml
# Storing file:  output/fr/pmematest_901_basistech.yml
# Storing file:  output/fr/pmematest_901_meaningcloud.yml
# Storing file:  output/fr/pmematest_901_bitext.yml
# Storing file:  output/fr/pmematest_901_alchemy.yml
# Storing file:  output/fr/pmematest_3511_retresco.yml
# Storing file:  output/fr/pmematest_3511_txtrazor.yml
# Storing file:  output/fr/pmematest_3511_simple.yml
# Storing file:  output/fr/pmematest_3511_semant.yml
# Storing file:  output/fr/pmematest_3511_basistech.yml
# Storing file:  output/fr/pmematest_3511_meaningcloud.yml
# Storing file:  output/fr/pmematest_3511_bitext.yml
# Storing file:  output/fr/pmematest_3511_alchemy.yml
# Storing file:  output/fr/pmematest_3098_retresco.yml
# Storing file:  output/fr/pmematest_3098_txtrazor.yml
# Storing file:  output/fr/pmematest_3098_simple.yml
# Storing file:  output/fr/pmematest_3098_semant.yml
# Storing file:  output/fr/pmematest_3098_basistech.yml
# Storing file:  output/fr/pmematest_3098_meaningcloud.yml
# Storing file:  output/fr/pmematest_3098_bitext.yml
# Storing file:  output/fr/pmematest_3098_alchemy.yml
# Storing file:  output/fr/pmematest_456_retresco.yml
# Storing file:  output/fr/pmematest_456_txtrazor.yml
# Storing file:  output/fr/pmematest_456_simple.yml
# Storing file:  output/fr/pmematest_456_semant.yml
# Storing file:  output/fr/pmematest_456_basistech.yml
# Storing file:  output/fr/pmematest_456_meaningcloud.yml
# Storing file:  output/fr/pmematest_456_bitext.yml
# Storing file:  output/fr/pmematest_456_alchemy.yml
# Storing file:  output/fr/pmematest_1486_retresco.yml
# Storing file:  output/fr/pmematest_1486_txtrazor.yml
# Storing file:  output/fr/pmematest_1486_simple.yml
# Storing file:  output/fr/pmematest_1486_semant.yml
# Storing file:  output/fr/pmematest_1486_basistech.yml
# Storing file:  output/fr/pmematest_1486_meaningcloud.yml
# Storing file:  output/fr/pmematest_1486_bitext.yml
# Storing file:  output/fr/pmematest_1486_alchemy.yml
# Storing file:  output/fr/pmematest_1699_retresco.yml
# Storing file:  output/fr/pmematest_1699_txtrazor.yml
# Storing file:  output/fr/pmematest_1699_simple.yml
# Storing file:  output/fr/pmematest_1699_semant.yml
# Storing file:  output/fr/pmematest_1699_basistech.yml
# Storing file:  output/fr/pmematest_1699_meaningcloud.yml
# Storing file:  output/fr/pmematest_1699_bitext.yml
# Storing file:  output/fr/pmematest_1699_alchemy.yml
# Storing file:  output/fr/pmematest_618_retresco.yml
# Storing file:  output/fr/pmematest_618_txtrazor.yml
# Storing file:  output/fr/pmematest_618_simple.yml
# Storing file:  output/fr/pmematest_618_semant.yml
# Storing file:  output/fr/pmematest_618_basistech.yml
# Storing file:  output/fr/pmematest_618_meaningcloud.yml
# Storing file:  output/fr/pmematest_618_bitext.yml
# Storing file:  output/fr/pmematest_618_alchemy.yml
# Storing file:  output/fr/pmematest_1953_retresco.yml
# Storing file:  output/fr/pmematest_1953_txtrazor.yml
# Storing file:  output/fr/pmematest_1953_simple.yml
# Storing file:  output/fr/pmematest_1953_semant.yml
# Storing file:  output/fr/pmematest_1953_basistech.yml
# Storing file:  output/fr/pmematest_1953_meaningcloud.yml
# Storing file:  output/fr/pmematest_1953_bitext.yml
# Storing file:  output/fr/pmematest_1953_alchemy.yml
# Storing file:  output/fr/pmematest_2112_retresco.yml
# Storing file:  output/fr/pmematest_2112_txtrazor.yml
# Storing file:  output/fr/pmematest_2112_simple.yml
# Storing file:  output/fr/pmematest_2112_semant.yml
# Storing file:  output/fr/pmematest_2112_basistech.yml
# Storing file:  output/fr/pmematest_2112_meaningcloud.yml
# Storing file:  output/fr/pmematest_2112_bitext.yml
# Storing file:  output/fr/pmematest_2112_alchemy.yml
# Storing file:  output/fr/pmematest_2726_retresco.yml
# Storing file:  output/fr/pmematest_2726_txtrazor.yml
# Storing file:  output/fr/pmematest_2726_simple.yml
# Storing file:  output/fr/pmematest_2726_semant.yml
# Storing file:  output/fr/pmematest_2726_basistech.yml
# Storing file:  output/fr/pmematest_2726_meaningcloud.yml
# Storing file:  output/fr/pmematest_2726_bitext.yml
# Storing file:  output/fr/pmematest_2726_alchemy.yml
# Storing file:  output/fr/pmematest_2084_retresco.yml
# Storing file:  output/fr/pmematest_2084_txtrazor.yml
# Storing file:  output/fr/pmematest_2084_simple.yml
# Storing file:  output/fr/pmematest_2084_semant.yml
# Storing file:  output/fr/pmematest_2084_basistech.yml
# Storing file:  output/fr/pmematest_2084_meaningcloud.yml
# Storing file:  output/fr/pmematest_2084_bitext.yml
# Storing file:  output/fr/pmematest_2084_alchemy.yml
# Storing file:  output/fr/pmematest_3113_retresco.yml
# Storing file:  output/fr/pmematest_3113_txtrazor.yml
# Storing file:  output/fr/pmematest_3113_simple.yml
# Storing file:  output/fr/pmematest_3113_semant.yml
# Storing file:  output/fr/pmematest_3113_basistech.yml
# Storing file:  output/fr/pmematest_3113_meaningcloud.yml
# Storing file:  output/fr/pmematest_3113_bitext.yml
# Storing file:  output/fr/pmematest_3113_alchemy.yml
# Storing file:  output/fr/pmematest_2851_retresco.yml
# Storing file:  output/fr/pmematest_2851_txtrazor.yml
# Storing file:  output/fr/pmematest_2851_simple.yml
# Storing file:  output/fr/pmematest_2851_semant.yml
# Storing file:  output/fr/pmematest_2851_basistech.yml
# Storing file:  output/fr/pmematest_2851_meaningcloud.yml
# Storing file:  output/fr/pmematest_2851_bitext.yml
# Storing file:  output/fr/pmematest_2851_alchemy.yml
# Storing file:  output/fr/pmematest_1839_retresco.yml
# Storing file:  output/fr/pmematest_1839_txtrazor.yml
# Storing file:  output/fr/pmematest_1839_simple.yml
# Storing file:  output/fr/pmematest_1839_semant.yml
# Storing file:  output/fr/pmematest_1839_basistech.yml
# Storing file:  output/fr/pmematest_1839_meaningcloud.yml
# Storing file:  output/fr/pmematest_1839_bitext.yml
# Storing file:  output/fr/pmematest_1839_alchemy.yml
# Storing file:  output/fr/pmematest_641_retresco.yml
# Storing file:  output/fr/pmematest_641_txtrazor.yml
# Storing file:  output/fr/pmematest_641_simple.yml
# Storing file:  output/fr/pmematest_641_semant.yml
# Storing file:  output/fr/pmematest_641_basistech.yml
# Storing file:  output/fr/pmematest_641_meaningcloud.yml
# Storing file:  output/fr/pmematest_641_bitext.yml
# Storing file:  output/fr/pmematest_641_alchemy.yml
# Storing file:  output/fr/pmematest_2094_retresco.yml
# Storing file:  output/fr/pmematest_2094_txtrazor.yml
# Storing file:  output/fr/pmematest_2094_simple.yml
# Storing file:  output/fr/pmematest_2094_semant.yml
# Storing file:  output/fr/pmematest_2094_basistech.yml
# Storing file:  output/fr/pmematest_2094_meaningcloud.yml
# Storing file:  output/fr/pmematest_2094_bitext.yml
# Storing file:  output/fr/pmematest_2094_alchemy.yml
# Storing file:  output/fr/pmematest_894_retresco.yml
# Storing file:  output/fr/pmematest_894_txtrazor.yml
# Storing file:  output/fr/pmematest_894_simple.yml
# Storing file:  output/fr/pmematest_894_semant.yml
# Storing file:  output/fr/pmematest_894_basistech.yml
# Storing file:  output/fr/pmematest_894_meaningcloud.yml
# Storing file:  output/fr/pmematest_894_bitext.yml
# Storing file:  output/fr/pmematest_894_alchemy.yml
# Storing file:  output/fr/pmematest_3472_retresco.yml
# Storing file:  output/fr/pmematest_3472_txtrazor.yml
# Storing file:  output/fr/pmematest_3472_simple.yml
# Storing file:  output/fr/pmematest_3472_semant.yml
# Storing file:  output/fr/pmematest_3472_basistech.yml
# Storing file:  output/fr/pmematest_3472_meaningcloud.yml
# Storing file:  output/fr/pmematest_3472_bitext.yml
# Storing file:  output/fr/pmematest_3472_alchemy.yml
# Storing file:  output/fr/pmematest_1630_retresco.yml
# Storing file:  output/fr/pmematest_1630_txtrazor.yml
# Storing file:  output/fr/pmematest_1630_simple.yml
# Storing file:  output/fr/pmematest_1630_semant.yml
# Storing file:  output/fr/pmematest_1630_basistech.yml
# Storing file:  output/fr/pmematest_1630_meaningcloud.yml
# Storing file:  output/fr/pmematest_1630_bitext.yml
# Storing file:  output/fr/pmematest_1630_alchemy.yml
# Storing file:  output/fr/pmematest_1034_retresco.yml
# Storing file:  output/fr/pmematest_1034_txtrazor.yml
# Storing file:  output/fr/pmematest_1034_simple.yml
# Storing file:  output/fr/pmematest_1034_semant.yml
# Storing file:  output/fr/pmematest_1034_basistech.yml
# Storing file:  output/fr/pmematest_1034_meaningcloud.yml
# Storing file:  output/fr/pmematest_1034_bitext.yml
# Storing file:  output/fr/pmematest_1034_alchemy.yml
# Storing file:  output/fr/pmematest_1722_retresco.yml
# Storing file:  output/fr/pmematest_1722_txtrazor.yml
# Storing file:  output/fr/pmematest_1722_simple.yml
# Storing file:  output/fr/pmematest_1722_semant.yml
# Storing file:  output/fr/pmematest_1722_basistech.yml
# Storing file:  output/fr/pmematest_1722_meaningcloud.yml
# Storing file:  output/fr/pmematest_1722_bitext.yml
# Storing file:  output/fr/pmematest_1722_alchemy.yml
# Storing file:  output/fr/pmematest_912_retresco.yml
# Storing file:  output/fr/pmematest_912_txtrazor.yml
# Storing file:  output/fr/pmematest_912_simple.yml
# Storing file:  output/fr/pmematest_912_semant.yml
# Storing file:  output/fr/pmematest_912_basistech.yml
# Storing file:  output/fr/pmematest_912_meaningcloud.yml
# Storing file:  output/fr/pmematest_912_bitext.yml
# Storing file:  output/fr/pmematest_912_alchemy.yml
# Storing file:  output/fr/pmematest_1508_retresco.yml
# Storing file:  output/fr/pmematest_1508_txtrazor.yml
# Storing file:  output/fr/pmematest_1508_simple.yml
# Storing file:  output/fr/pmematest_1508_semant.yml
# Storing file:  output/fr/pmematest_1508_basistech.yml
# Storing file:  output/fr/pmematest_1508_meaningcloud.yml
# Storing file:  output/fr/pmematest_1508_bitext.yml
# Storing file:  output/fr/pmematest_1508_alchemy.yml
# Storing file:  output/fr/pmematest_1834_retresco.yml
# Storing file:  output/fr/pmematest_1834_txtrazor.yml
# Storing file:  output/fr/pmematest_1834_simple.yml
# Storing file:  output/fr/pmematest_1834_semant.yml
# Storing file:  output/fr/pmematest_1834_basistech.yml
# Storing file:  output/fr/pmematest_1834_meaningcloud.yml
# Storing file:  output/fr/pmematest_1834_bitext.yml
# Storing file:  output/fr/pmematest_1834_alchemy.yml
# Storing file:  output/fr/pmematest_1678_retresco.yml
# Storing file:  output/fr/pmematest_1678_txtrazor.yml
# Storing file:  output/fr/pmematest_1678_simple.yml
# Storing file:  output/fr/pmematest_1678_semant.yml
# Storing file:  output/fr/pmematest_1678_basistech.yml
# Storing file:  output/fr/pmematest_1678_meaningcloud.yml
# Storing file:  output/fr/pmematest_1678_bitext.yml
# Storing file:  output/fr/pmematest_1678_alchemy.yml
# Storing file:  output/fr/pmematest_2766_retresco.yml
# Storing file:  output/fr/pmematest_2766_txtrazor.yml
# Storing file:  output/fr/pmematest_2766_simple.yml
# Storing file:  output/fr/pmematest_2766_semant.yml
# Storing file:  output/fr/pmematest_2766_basistech.yml
# Storing file:  output/fr/pmematest_2766_meaningcloud.yml
# Storing file:  output/fr/pmematest_2766_bitext.yml
# Storing file:  output/fr/pmematest_2766_alchemy.yml
# Storing file:  output/fr/pmematest_1582_retresco.yml
# Storing file:  output/fr/pmematest_1582_txtrazor.yml
# Storing file:  output/fr/pmematest_1582_simple.yml
# Storing file:  output/fr/pmematest_1582_semant.yml
# Storing file:  output/fr/pmematest_1582_basistech.yml
# Storing file:  output/fr/pmematest_1582_meaningcloud.yml
# Storing file:  output/fr/pmematest_1582_bitext.yml
# Storing file:  output/fr/pmematest_1582_alchemy.yml
# Storing file:  output/fr/pmematest_2124_retresco.yml
# Storing file:  output/fr/pmematest_2124_txtrazor.yml
# Storing file:  output/fr/pmematest_2124_simple.yml
# Storing file:  output/fr/pmematest_2124_semant.yml
# Storing file:  output/fr/pmematest_2124_basistech.yml
# Storing file:  output/fr/pmematest_2124_meaningcloud.yml
# Storing file:  output/fr/pmematest_2124_bitext.yml
# Storing file:  output/fr/pmematest_2124_alchemy.yml
# Storing file:  output/fr/pmematest_1587_retresco.yml
# Storing file:  output/fr/pmematest_1587_txtrazor.yml
# Storing file:  output/fr/pmematest_1587_simple.yml
# Storing file:  output/fr/pmematest_1587_semant.yml
# Storing file:  output/fr/pmematest_1587_basistech.yml
# Storing file:  output/fr/pmematest_1587_meaningcloud.yml
# Storing file:  output/fr/pmematest_1587_bitext.yml
# Storing file:  output/fr/pmematest_1587_alchemy.yml
# Storing file:  output/fr/pmematest_2981_retresco.yml
# Storing file:  output/fr/pmematest_2981_txtrazor.yml
# Storing file:  output/fr/pmematest_2981_simple.yml
# Storing file:  output/fr/pmematest_2981_semant.yml
# Storing file:  output/fr/pmematest_2981_basistech.yml
# Storing file:  output/fr/pmematest_2981_meaningcloud.yml
# Storing file:  output/fr/pmematest_2981_bitext.yml
# Storing file:  output/fr/pmematest_2981_alchemy.yml
# Storing file:  output/fr/pmematest_341_retresco.yml
# Storing file:  output/fr/pmematest_341_txtrazor.yml
# Storing file:  output/fr/pmematest_341_simple.yml
# Storing file:  output/fr/pmematest_341_semant.yml
# Storing file:  output/fr/pmematest_341_basistech.yml
# Storing file:  output/fr/pmematest_341_meaningcloud.yml
# Storing file:  output/fr/pmematest_341_bitext.yml
# Storing file:  output/fr/pmematest_341_alchemy.yml
# Storing file:  output/fr/pmematest_2583_retresco.yml
# Storing file:  output/fr/pmematest_2583_txtrazor.yml
# Storing file:  output/fr/pmematest_2583_simple.yml
# Storing file:  output/fr/pmematest_2583_semant.yml
# Storing file:  output/fr/pmematest_2583_basistech.yml
# Storing file:  output/fr/pmematest_2583_meaningcloud.yml
# Storing file:  output/fr/pmematest_2583_bitext.yml
# Storing file:  output/fr/pmematest_2583_alchemy.yml
# Storing file:  output/fr/pmematest_1697_retresco.yml
# Storing file:  output/fr/pmematest_1697_txtrazor.yml
# Storing file:  output/fr/pmematest_1697_simple.yml
# Storing file:  output/fr/pmematest_1697_semant.yml
# Storing file:  output/fr/pmematest_1697_basistech.yml
# Storing file:  output/fr/pmematest_1697_meaningcloud.yml
# Storing file:  output/fr/pmematest_1697_bitext.yml
# Storing file:  output/fr/pmematest_1697_alchemy.yml
# Storing file:  output/fr/pmematest_3274_retresco.yml
# Storing file:  output/fr/pmematest_3274_txtrazor.yml
# Storing file:  output/fr/pmematest_3274_simple.yml
# Storing file:  output/fr/pmematest_3274_semant.yml
# Storing file:  output/fr/pmematest_3274_basistech.yml
# Storing file:  output/fr/pmematest_3274_meaningcloud.yml
# Storing file:  output/fr/pmematest_3274_bitext.yml
# Storing file:  output/fr/pmematest_3274_alchemy.yml
# Storing file:  output/fr/pmematest_576_retresco.yml
# Storing file:  output/fr/pmematest_576_txtrazor.yml
# Storing file:  output/fr/pmematest_576_simple.yml
# Storing file:  output/fr/pmematest_576_semant.yml
# Storing file:  output/fr/pmematest_576_basistech.yml
# Storing file:  output/fr/pmematest_576_meaningcloud.yml
# Storing file:  output/fr/pmematest_576_bitext.yml
# Storing file:  output/fr/pmematest_576_alchemy.yml
# Storing file:  output/fr/pmematest_2310_retresco.yml
# Storing file:  output/fr/pmematest_2310_txtrazor.yml
# Storing file:  output/fr/pmematest_2310_simple.yml
# Storing file:  output/fr/pmematest_2310_semant.yml
# Storing file:  output/fr/pmematest_2310_basistech.yml
# Storing file:  output/fr/pmematest_2310_meaningcloud.yml
# Storing file:  output/fr/pmematest_2310_bitext.yml
# Storing file:  output/fr/pmematest_2310_alchemy.yml
# Storing file:  output/fr/pmematest_1089_retresco.yml
# Storing file:  output/fr/pmematest_1089_txtrazor.yml
# Storing file:  output/fr/pmematest_1089_simple.yml
# Storing file:  output/fr/pmematest_1089_semant.yml
# Storing file:  output/fr/pmematest_1089_basistech.yml
# Storing file:  output/fr/pmematest_1089_meaningcloud.yml
# Storing file:  output/fr/pmematest_1089_bitext.yml
# Storing file:  output/fr/pmematest_1089_alchemy.yml
# Storing file:  output/fr/pmematest_644_retresco.yml
# Storing file:  output/fr/pmematest_644_txtrazor.yml
# Storing file:  output/fr/pmematest_644_simple.yml
# Storing file:  output/fr/pmematest_644_semant.yml
# Storing file:  output/fr/pmematest_644_basistech.yml
# Storing file:  output/fr/pmematest_644_meaningcloud.yml
# Storing file:  output/fr/pmematest_644_bitext.yml
# Storing file:  output/fr/pmematest_644_alchemy.yml
# Storing file:  output/fr/pmematest_1589_retresco.yml
# Storing file:  output/fr/pmematest_1589_txtrazor.yml
# Storing file:  output/fr/pmematest_1589_simple.yml
# Storing file:  output/fr/pmematest_1589_semant.yml
# Storing file:  output/fr/pmematest_1589_basistech.yml
# Storing file:  output/fr/pmematest_1589_meaningcloud.yml
# Storing file:  output/fr/pmematest_1589_bitext.yml
# Storing file:  output/fr/pmematest_1589_alchemy.yml
# Storing file:  output/fr/pmematest_560_retresco.yml
# Storing file:  output/fr/pmematest_560_txtrazor.yml
# Storing file:  output/fr/pmematest_560_simple.yml
# Storing file:  output/fr/pmematest_560_semant.yml
# Storing file:  output/fr/pmematest_560_basistech.yml
# Storing file:  output/fr/pmematest_560_meaningcloud.yml
# Storing file:  output/fr/pmematest_560_bitext.yml
# Storing file:  output/fr/pmematest_560_alchemy.yml
# Storing file:  output/fr/pmematest_118_retresco.yml
# Storing file:  output/fr/pmematest_118_txtrazor.yml
# Storing file:  output/fr/pmematest_118_simple.yml
# Storing file:  output/fr/pmematest_118_semant.yml
# Storing file:  output/fr/pmematest_118_basistech.yml
# Storing file:  output/fr/pmematest_118_meaningcloud.yml
# Storing file:  output/fr/pmematest_118_bitext.yml
# Storing file:  output/fr/pmematest_118_alchemy.yml
# Storing file:  output/fr/pmematest_2511_retresco.yml
# Storing file:  output/fr/pmematest_2511_txtrazor.yml
# Storing file:  output/fr/pmematest_2511_simple.yml
# Storing file:  output/fr/pmematest_2511_semant.yml
# Storing file:  output/fr/pmematest_2511_basistech.yml
# Storing file:  output/fr/pmematest_2511_meaningcloud.yml
# Storing file:  output/fr/pmematest_2511_bitext.yml
# Storing file:  output/fr/pmematest_2511_alchemy.yml
# Storing file:  output/fr/pmematest_334_retresco.yml
# Storing file:  output/fr/pmematest_334_txtrazor.yml
# Storing file:  output/fr/pmematest_334_simple.yml
# Storing file:  output/fr/pmematest_334_semant.yml
# Storing file:  output/fr/pmematest_334_basistech.yml
# Storing file:  output/fr/pmematest_334_meaningcloud.yml
# Storing file:  output/fr/pmematest_334_bitext.yml
# Storing file:  output/fr/pmematest_334_alchemy.yml
# Storing file:  output/fr/pmematest_3485_retresco.yml
# Storing file:  output/fr/pmematest_3485_txtrazor.yml
# Storing file:  output/fr/pmematest_3485_simple.yml
# Storing file:  output/fr/pmematest_3485_semant.yml
# Storing file:  output/fr/pmematest_3485_basistech.yml
# Storing file:  output/fr/pmematest_3485_meaningcloud.yml
# Storing file:  output/fr/pmematest_3485_bitext.yml
# Storing file:  output/fr/pmematest_3485_alchemy.yml
# Storing file:  output/fr/pmematest_2720_retresco.yml
# Storing file:  output/fr/pmematest_2720_txtrazor.yml
# Storing file:  output/fr/pmematest_2720_simple.yml
# Storing file:  output/fr/pmematest_2720_semant.yml
# Storing file:  output/fr/pmematest_2720_basistech.yml
# Storing file:  output/fr/pmematest_2720_meaningcloud.yml
# Storing file:  output/fr/pmematest_2720_bitext.yml
# Storing file:  output/fr/pmematest_2720_alchemy.yml
# Storing file:  output/fr/pmematest_3362_retresco.yml
# Storing file:  output/fr/pmematest_3362_txtrazor.yml
# Storing file:  output/fr/pmematest_3362_simple.yml
# Storing file:  output/fr/pmematest_3362_semant.yml
# Storing file:  output/fr/pmematest_3362_basistech.yml
# Storing file:  output/fr/pmematest_3362_meaningcloud.yml
# Storing file:  output/fr/pmematest_3362_bitext.yml
# Storing file:  output/fr/pmematest_3362_alchemy.yml
# Storing file:  output/fr/pmematest_2850_retresco.yml
# Storing file:  output/fr/pmematest_2850_txtrazor.yml
# Storing file:  output/fr/pmematest_2850_simple.yml
# Storing file:  output/fr/pmematest_2850_semant.yml
# Storing file:  output/fr/pmematest_2850_basistech.yml
# Storing file:  output/fr/pmematest_2850_meaningcloud.yml
# Storing file:  output/fr/pmematest_2850_bitext.yml
# Storing file:  output/fr/pmematest_2850_alchemy.yml

# %%
import semaeval.statistics as stats

# %%
data=stats.collect_data(articles_enriched)
# Out:
# semant pmematest_2994.yml float division by zero
# meaningcloud pmematest_2994.yml float division by zero
# meaningcloud pmematest_2994.yml float division by zero
# meaningcloud pmematest_2994.yml float division by zero
# retresco pmematest_791.yml float division by zero
# txtrazor pmematest_791.yml float division by zero
# txtrazor pmematest_791.yml float division by zero
# simple pmematest_791.yml float division by zero
# semant pmematest_791.yml float division by zero
# semant pmematest_791.yml float division by zero
# basistech pmematest_791.yml float division by zero
# basistech pmematest_791.yml float division by zero
# meaningcloud pmematest_791.yml float division by zero
# meaningcloud pmematest_791.yml float division by zero
# bitext pmematest_791.yml float division by zero
# alchemy pmematest_791.yml float division by zero
# alchemy pmematest_791.yml float division by zero
# retresco pmematest_2906.yml float division by zero
# retresco pmematest_2906.yml float division by zero
# retresco pmematest_2906.yml float division by zero
# txtrazor pmematest_2906.yml float division by zero
# txtrazor pmematest_2906.yml float division by zero
# simple pmematest_2906.yml float division by zero
# simple pmematest_2906.yml float division by zero
# semant pmematest_2906.yml float division by zero
# semant pmematest_2906.yml float division by zero
# basistech pmematest_2906.yml float division by zero
# meaningcloud pmematest_2906.yml float division by zero
# meaningcloud pmematest_2906.yml float division by zero
# meaningcloud pmematest_2906.yml float division by zero
# bitext pmematest_2906.yml float division by zero
# bitext pmematest_2906.yml float division by zero
# alchemy pmematest_2906.yml float division by zero
# alchemy pmematest_2906.yml float division by zero
# retresco pmematest_901.yml float division by zero
# txtrazor pmematest_901.yml float division by zero
# txtrazor pmematest_901.yml float division by zero
# simple pmematest_901.yml float division by zero
# semant pmematest_901.yml float division by zero
# semant pmematest_901.yml float division by zero
# basistech pmematest_901.yml float division by zero
# meaningcloud pmematest_901.yml float division by zero
# meaningcloud pmematest_901.yml float division by zero
# bitext pmematest_901.yml float division by zero
# bitext pmematest_901.yml float division by zero
# alchemy pmematest_901.yml float division by zero
# alchemy pmematest_901.yml float division by zero
# retresco pmematest_3511.yml float division by zero
# txtrazor pmematest_3511.yml float division by zero
# simple pmematest_3511.yml float division by zero
# simple pmematest_3511.yml float division by zero
# semant pmematest_3511.yml float division by zero
# basistech pmematest_3511.yml float division by zero
# meaningcloud pmematest_3511.yml float division by zero
# meaningcloud pmematest_3511.yml float division by zero
# bitext pmematest_3511.yml float division by zero
# alchemy pmematest_3511.yml float division by zero
# alchemy pmematest_3511.yml float division by zero
# alchemy pmematest_3511.yml float division by zero
# retresco pmematest_3098.yml float division by zero
# retresco pmematest_3098.yml float division by zero
# retresco pmematest_3098.yml float division by zero
# txtrazor pmematest_3098.yml float division by zero
# txtrazor pmematest_3098.yml float division by zero
# txtrazor pmematest_3098.yml float division by zero
# simple pmematest_3098.yml float division by zero
# simple pmematest_3098.yml float division by zero
# simple pmematest_3098.yml float division by zero
# semant pmematest_3098.yml float division by zero
# semant pmematest_3098.yml float division by zero
# semant pmematest_3098.yml float division by zero
# basistech pmematest_3098.yml float division by zero
# basistech pmematest_3098.yml float division by zero
# basistech pmematest_3098.yml float division by zero
# meaningcloud pmematest_3098.yml float division by zero
# meaningcloud pmematest_3098.yml float division by zero
# meaningcloud pmematest_3098.yml float division by zero
# bitext pmematest_3098.yml float division by zero
# bitext pmematest_3098.yml float division by zero
# bitext pmematest_3098.yml float division by zero
# alchemy pmematest_3098.yml float division by zero
# alchemy pmematest_3098.yml float division by zero
# alchemy pmematest_3098.yml float division by zero
# retresco pmematest_456.yml float division by zero
# retresco pmematest_456.yml float division by zero
# txtrazor pmematest_456.yml float division by zero
# simple pmematest_456.yml float division by zero
# semant pmematest_456.yml float division by zero
# meaningcloud pmematest_456.yml float division by zero
# meaningcloud pmematest_456.yml float division by zero
# bitext pmematest_456.yml float division by zero
# bitext pmematest_456.yml float division by zero
# alchemy pmematest_456.yml float division by zero
# alchemy pmematest_456.yml float division by zero
# retresco pmematest_1486.yml float division by zero
# retresco pmematest_1486.yml float division by zero
# retresco pmematest_1486.yml float division by zero
# txtrazor pmematest_1486.yml float division by zero
# txtrazor pmematest_1486.yml float division by zero
# txtrazor pmematest_1486.yml float division by zero
# simple pmematest_1486.yml float division by zero
# simple pmematest_1486.yml float division by zero
# simple pmematest_1486.yml float division by zero
# semant pmematest_1486.yml float division by zero
# semant pmematest_1486.yml float division by zero
# semant pmematest_1486.yml float division by zero
# basistech pmematest_1486.yml float division by zero
# basistech pmematest_1486.yml float division by zero
# meaningcloud pmematest_1486.yml float division by zero
# meaningcloud pmematest_1486.yml float division by zero
# meaningcloud pmematest_1486.yml float division by zero
# bitext pmematest_1486.yml float division by zero
# bitext pmematest_1486.yml float division by zero
# bitext pmematest_1486.yml float division by zero
# alchemy pmematest_1486.yml float division by zero
# alchemy pmematest_1486.yml float division by zero
# retresco pmematest_1699.yml float division by zero
# retresco pmematest_1699.yml float division by zero
# txtrazor pmematest_1699.yml float division by zero
# simple pmematest_1699.yml float division by zero
# simple pmematest_1699.yml float division by zero
# semant pmematest_1699.yml float division by zero
# basistech pmematest_1699.yml float division by zero
# meaningcloud pmematest_1699.yml float division by zero
# bitext pmematest_1699.yml float division by zero
# alchemy pmematest_1699.yml float division by zero
# simple pmematest_618.yml float division by zero
# meaningcloud pmematest_618.yml float division by zero
# alchemy pmematest_618.yml float division by zero
# retresco pmematest_1953.yml float division by zero
# semant pmematest_1953.yml float division by zero
# meaningcloud pmematest_1953.yml float division by zero
# alchemy pmematest_1953.yml float division by zero
# retresco pmematest_2112.yml float division by zero
# retresco pmematest_2112.yml float division by zero
# retresco pmematest_2112.yml float division by zero
# txtrazor pmematest_2112.yml float division by zero
# txtrazor pmematest_2112.yml float division by zero
# simple pmematest_2112.yml float division by zero
# simple pmematest_2112.yml float division by zero
# semant pmematest_2112.yml float division by zero
# semant pmematest_2112.yml float division by zero
# basistech pmematest_2112.yml float division by zero
# basistech pmematest_2112.yml float division by zero
# meaningcloud pmematest_2112.yml float division by zero
# meaningcloud pmematest_2112.yml float division by zero
# bitext pmematest_2112.yml float division by zero
# bitext pmematest_2112.yml float division by zero
# bitext pmematest_2112.yml float division by zero
# alchemy pmematest_2112.yml float division by zero
# alchemy pmematest_2112.yml float division by zero
# retresco pmematest_2726.yml float division by zero
# retresco pmematest_2726.yml float division by zero
# txtrazor pmematest_2726.yml float division by zero
# txtrazor pmematest_2726.yml float division by zero
# simple pmematest_2726.yml float division by zero
# simple pmematest_2726.yml float division by zero
# semant pmematest_2726.yml float division by zero
# semant pmematest_2726.yml float division by zero
# basistech pmematest_2726.yml float division by zero
# basistech pmematest_2726.yml float division by zero
# meaningcloud pmematest_2726.yml float division by zero
# meaningcloud pmematest_2726.yml float division by zero
# bitext pmematest_2726.yml float division by zero
# bitext pmematest_2726.yml float division by zero
# alchemy pmematest_2726.yml float division by zero
# alchemy pmematest_2726.yml float division by zero
# retresco pmematest_2084.yml float division by zero
# retresco pmematest_2084.yml float division by zero
# retresco pmematest_2084.yml float division by zero
# txtrazor pmematest_2084.yml float division by zero
# txtrazor pmematest_2084.yml float division by zero
# txtrazor pmematest_2084.yml float division by zero
# simple pmematest_2084.yml float division by zero
# simple pmematest_2084.yml float division by zero
# simple pmematest_2084.yml float division by zero
# semant pmematest_2084.yml float division by zero
# semant pmematest_2084.yml float division by zero
# semant pmematest_2084.yml float division by zero
# basistech pmematest_2084.yml float division by zero
# basistech pmematest_2084.yml float division by zero
# basistech pmematest_2084.yml float division by zero
# meaningcloud pmematest_2084.yml float division by zero
# meaningcloud pmematest_2084.yml float division by zero
# meaningcloud pmematest_2084.yml float division by zero
# bitext pmematest_2084.yml float division by zero
# bitext pmematest_2084.yml float division by zero
# bitext pmematest_2084.yml float division by zero
# alchemy pmematest_2084.yml float division by zero
# alchemy pmematest_2084.yml float division by zero
# alchemy pmematest_2084.yml float division by zero
# retresco pmematest_3113.yml float division by zero
# retresco pmematest_3113.yml float division by zero
# txtrazor pmematest_3113.yml float division by zero
# txtrazor pmematest_3113.yml float division by zero
# simple pmematest_3113.yml float division by zero
# semant pmematest_3113.yml float division by zero
# semant pmematest_3113.yml float division by zero
# semant pmematest_3113.yml float division by zero
# basistech pmematest_3113.yml float division by zero
# meaningcloud pmematest_3113.yml float division by zero
# meaningcloud pmematest_3113.yml float division by zero
# bitext pmematest_3113.yml float division by zero
# bitext pmematest_3113.yml float division by zero
# alchemy pmematest_3113.yml float division by zero
# alchemy pmematest_3113.yml float division by zero
# retresco pmematest_2851.yml float division by zero
# retresco pmematest_2851.yml float division by zero
# retresco pmematest_2851.yml float division by zero
# txtrazor pmematest_2851.yml float division by zero
# txtrazor pmematest_2851.yml float division by zero
# simple pmematest_2851.yml float division by zero
# simple pmematest_2851.yml float division by zero
# semant pmematest_2851.yml float division by zero
# semant pmematest_2851.yml float division by zero
# basistech pmematest_2851.yml float division by zero
# basistech pmematest_2851.yml float division by zero
# basistech pmematest_2851.yml float division by zero
# meaningcloud pmematest_2851.yml float division by zero
# meaningcloud pmematest_2851.yml float division by zero
# meaningcloud pmematest_2851.yml float division by zero
# bitext pmematest_2851.yml float division by zero
# bitext pmematest_2851.yml float division by zero
# bitext pmematest_2851.yml float division by zero
# alchemy pmematest_2851.yml float division by zero
# alchemy pmematest_2851.yml float division by zero
# retresco pmematest_1839.yml float division by zero
# retresco pmematest_1839.yml float division by zero
# txtrazor pmematest_1839.yml float division by zero
# simple pmematest_1839.yml float division by zero
# semant pmematest_1839.yml float division by zero
# semant pmematest_1839.yml float division by zero
# meaningcloud pmematest_1839.yml float division by zero
# alchemy pmematest_1839.yml float division by zero
# retresco pmematest_641.yml float division by zero
# retresco pmematest_641.yml float division by zero
# txtrazor pmematest_641.yml float division by zero
# txtrazor pmematest_641.yml float division by zero
# simple pmematest_641.yml float division by zero
# simple pmematest_641.yml float division by zero
# simple pmematest_641.yml float division by zero
# semant pmematest_641.yml float division by zero
# semant pmematest_641.yml float division by zero
# basistech pmematest_641.yml float division by zero
# basistech pmematest_641.yml float division by zero
# meaningcloud pmematest_641.yml float division by zero
# meaningcloud pmematest_641.yml float division by zero
# bitext pmematest_641.yml float division by zero
# bitext pmematest_641.yml float division by zero
# alchemy pmematest_641.yml float division by zero
# alchemy pmematest_641.yml float division by zero
# alchemy pmematest_641.yml float division by zero
# retresco pmematest_2094.yml float division by zero
# retresco pmematest_2094.yml float division by zero
# retresco pmematest_2094.yml float division by zero
# txtrazor pmematest_2094.yml float division by zero
# txtrazor pmematest_2094.yml float division by zero
# simple pmematest_2094.yml float division by zero
# semant pmematest_2094.yml float division by zero
# basistech pmematest_2094.yml float division by zero
# basistech pmematest_2094.yml float division by zero
# meaningcloud pmematest_2094.yml float division by zero
# meaningcloud pmematest_2094.yml float division by zero
# bitext pmematest_2094.yml float division by zero
# bitext pmematest_2094.yml float division by zero
# alchemy pmematest_2094.yml float division by zero
# alchemy pmematest_2094.yml float division by zero
# retresco pmematest_894.yml float division by zero
# retresco pmematest_894.yml float division by zero
# txtrazor pmematest_894.yml float division by zero
# txtrazor pmematest_894.yml float division by zero
# semant pmematest_894.yml float division by zero
# semant pmematest_894.yml float division by zero
# basistech pmematest_894.yml float division by zero
# meaningcloud pmematest_894.yml float division by zero
# meaningcloud pmematest_894.yml float division by zero
# meaningcloud pmematest_894.yml float division by zero
# bitext pmematest_894.yml float division by zero
# bitext pmematest_894.yml float division by zero
# bitext pmematest_894.yml float division by zero
# alchemy pmematest_894.yml float division by zero
# alchemy pmematest_894.yml float division by zero
# retresco pmematest_3472.yml float division by zero
# semant pmematest_3472.yml float division by zero
# meaningcloud pmematest_3472.yml float division by zero
# bitext pmematest_3472.yml float division by zero
# retresco pmematest_1630.yml float division by zero
# retresco pmematest_1630.yml float division by zero
# simple pmematest_1630.yml float division by zero
# simple pmematest_1630.yml float division by zero
# semant pmematest_1630.yml float division by zero
# meaningcloud pmematest_1630.yml float division by zero
# meaningcloud pmematest_1630.yml float division by zero
# bitext pmematest_1630.yml float division by zero
# alchemy pmematest_1630.yml float division by zero
# retresco pmematest_1034.yml float division by zero
# txtrazor pmematest_1034.yml float division by zero
# simple pmematest_1034.yml float division by zero
# semant pmematest_1034.yml float division by zero
# basistech pmematest_1034.yml float division by zero
# meaningcloud pmematest_1034.yml float division by zero
# bitext pmematest_1034.yml float division by zero
# alchemy pmematest_1034.yml float division by zero
# alchemy pmematest_1034.yml float division by zero
# retresco pmematest_1722.yml float division by zero
# txtrazor pmematest_1722.yml float division by zero
# simple pmematest_1722.yml float division by zero
# simple pmematest_1722.yml float division by zero
# simple pmematest_1722.yml float division by zero
# semant pmematest_1722.yml float division by zero
# basistech pmematest_1722.yml float division by zero
# meaningcloud pmematest_1722.yml float division by zero
# meaningcloud pmematest_1722.yml float division by zero
# bitext pmematest_1722.yml float division by zero
# alchemy pmematest_1722.yml float division by zero
# semant pmematest_912.yml float division by zero
# retresco pmematest_1508.yml float division by zero
# txtrazor pmematest_1508.yml float division by zero
# simple pmematest_1508.yml float division by zero
# simple pmematest_1508.yml float division by zero
# semant pmematest_1508.yml float division by zero
# semant pmematest_1508.yml float division by zero
# basistech pmematest_1508.yml float division by zero
# meaningcloud pmematest_1508.yml float division by zero
# meaningcloud pmematest_1508.yml float division by zero
# bitext pmematest_1508.yml float division by zero
# bitext pmematest_1508.yml float division by zero
# bitext pmematest_1508.yml float division by zero
# alchemy pmematest_1508.yml float division by zero
# alchemy pmematest_1508.yml float division by zero
# alchemy pmematest_1508.yml float division by zero
# retresco pmematest_1834.yml float division by zero
# retresco pmematest_1834.yml float division by zero
# txtrazor pmematest_1834.yml float division by zero
# simple pmematest_1834.yml float division by zero
# semant pmematest_1834.yml float division by zero
# basistech pmematest_1834.yml float division by zero
# meaningcloud pmematest_1834.yml float division by zero
# bitext pmematest_1834.yml float division by zero
# alchemy pmematest_1834.yml float division by zero
# retresco pmematest_1678.yml float division by zero
# semant pmematest_1678.yml float division by zero
# meaningcloud pmematest_1678.yml float division by zero
# retresco pmematest_2766.yml float division by zero
# retresco pmematest_2766.yml float division by zero
# simple pmematest_2766.yml float division by zero
# simple pmematest_2766.yml float division by zero
# semant pmematest_2766.yml float division by zero
# meaningcloud pmematest_2766.yml float division by zero
# meaningcloud pmematest_2766.yml float division by zero
# bitext pmematest_2766.yml float division by zero
# bitext pmematest_2766.yml float division by zero
# alchemy pmematest_2766.yml float division by zero
# alchemy pmematest_2766.yml float division by zero
# retresco pmematest_1582.yml float division by zero
# retresco pmematest_1582.yml float division by zero
# retresco pmematest_1582.yml float division by zero
# txtrazor pmematest_1582.yml float division by zero
# txtrazor pmematest_1582.yml float division by zero
# simple pmematest_1582.yml float division by zero
# simple pmematest_1582.yml float division by zero
# semant pmematest_1582.yml float division by zero
# semant pmematest_1582.yml float division by zero
# basistech pmematest_1582.yml float division by zero
# basistech pmematest_1582.yml float division by zero
# meaningcloud pmematest_1582.yml float division by zero
# meaningcloud pmematest_1582.yml float division by zero
# bitext pmematest_1582.yml float division by zero
# bitext pmematest_1582.yml float division by zero
# alchemy pmematest_1582.yml float division by zero
# alchemy pmematest_1582.yml float division by zero
# retresco pmematest_2124.yml float division by zero
# retresco pmematest_2124.yml float division by zero
# txtrazor pmematest_2124.yml float division by zero
# txtrazor pmematest_2124.yml float division by zero
# simple pmematest_2124.yml float division by zero
# simple pmematest_2124.yml float division by zero
# semant pmematest_2124.yml float division by zero
# semant pmematest_2124.yml float division by zero
# basistech pmematest_2124.yml float division by zero
# basistech pmematest_2124.yml float division by zero
# meaningcloud pmematest_2124.yml float division by zero
# meaningcloud pmematest_2124.yml float division by zero
# bitext pmematest_2124.yml float division by zero
# bitext pmematest_2124.yml float division by zero
# alchemy pmematest_2124.yml float division by zero
# alchemy pmematest_2124.yml float division by zero
# retresco pmematest_1587.yml float division by zero
# retresco pmematest_1587.yml float division by zero
# txtrazor pmematest_1587.yml float division by zero
# txtrazor pmematest_1587.yml float division by zero
# simple pmematest_1587.yml float division by zero
# semant pmematest_1587.yml float division by zero
# basistech pmematest_1587.yml float division by zero
# meaningcloud pmematest_1587.yml float division by zero
# meaningcloud pmematest_1587.yml float division by zero
# bitext pmematest_1587.yml float division by zero
# bitext pmematest_1587.yml float division by zero
# alchemy pmematest_1587.yml float division by zero
# alchemy pmematest_1587.yml float division by zero
# alchemy pmematest_1587.yml float division by zero
# retresco pmematest_2981.yml float division by zero
# retresco pmematest_2981.yml float division by zero
# txtrazor pmematest_2981.yml float division by zero
# txtrazor pmematest_2981.yml float division by zero
# simple pmematest_2981.yml float division by zero
# simple pmematest_2981.yml float division by zero
# semant pmematest_2981.yml float division by zero
# semant pmematest_2981.yml float division by zero
# semant pmematest_2981.yml float division by zero
# meaningcloud pmematest_2981.yml float division by zero
# meaningcloud pmematest_2981.yml float division by zero
# meaningcloud pmematest_2981.yml float division by zero
# bitext pmematest_2981.yml float division by zero
# bitext pmematest_2981.yml float division by zero
# bitext pmematest_2981.yml float division by zero
# alchemy pmematest_2981.yml float division by zero
# alchemy pmematest_2981.yml float division by zero
# alchemy pmematest_2981.yml float division by zero
# retresco pmematest_341.yml float division by zero
# txtrazor pmematest_341.yml float division by zero
# simple pmematest_341.yml float division by zero
# semant pmematest_341.yml float division by zero
# basistech pmematest_341.yml float division by zero
# meaningcloud pmematest_341.yml float division by zero
# meaningcloud pmematest_341.yml float division by zero
# bitext pmematest_341.yml float division by zero
# bitext pmematest_341.yml float division by zero
# bitext pmematest_341.yml float division by zero
# alchemy pmematest_341.yml float division by zero
# alchemy pmematest_341.yml float division by zero
# txtrazor pmematest_2583.yml float division by zero
# semant pmematest_2583.yml float division by zero
# basistech pmematest_2583.yml float division by zero
# meaningcloud pmematest_2583.yml float division by zero
# bitext pmematest_2583.yml float division by zero
# alchemy pmematest_2583.yml float division by zero
# retresco pmematest_1697.yml float division by zero
# retresco pmematest_1697.yml float division by zero
# txtrazor pmematest_1697.yml float division by zero
# simple pmematest_1697.yml float division by zero
# simple pmematest_1697.yml float division by zero
# semant pmematest_1697.yml float division by zero
# semant pmematest_1697.yml float division by zero
# basistech pmematest_1697.yml float division by zero
# meaningcloud pmematest_1697.yml float division by zero
# meaningcloud pmematest_1697.yml float division by zero
# meaningcloud pmematest_1697.yml float division by zero
# bitext pmematest_1697.yml float division by zero
# alchemy pmematest_1697.yml float division by zero
# alchemy pmematest_1697.yml float division by zero
# retresco pmematest_3274.yml float division by zero
# retresco pmematest_3274.yml float division by zero
# txtrazor pmematest_3274.yml float division by zero
# txtrazor pmematest_3274.yml float division by zero
# simple pmematest_3274.yml float division by zero
# simple pmematest_3274.yml float division by zero
# semant pmematest_3274.yml float division by zero
# semant pmematest_3274.yml float division by zero
# basistech pmematest_3274.yml float division by zero
# basistech pmematest_3274.yml float division by zero
# meaningcloud pmematest_3274.yml float division by zero
# meaningcloud pmematest_3274.yml float division by zero
# meaningcloud pmematest_3274.yml float division by zero
# bitext pmematest_3274.yml float division by zero
# bitext pmematest_3274.yml float division by zero
# alchemy pmematest_3274.yml float division by zero
# alchemy pmematest_3274.yml float division by zero
# retresco pmematest_576.yml float division by zero
# retresco pmematest_576.yml float division by zero
# txtrazor pmematest_576.yml float division by zero
# simple pmematest_576.yml float division by zero
# simple pmematest_576.yml float division by zero
# semant pmematest_576.yml float division by zero
# semant pmematest_576.yml float division by zero
# semant pmematest_576.yml float division by zero
# basistech pmematest_576.yml float division by zero
# meaningcloud pmematest_576.yml float division by zero
# meaningcloud pmematest_576.yml float division by zero
# bitext pmematest_576.yml float division by zero
# alchemy pmematest_576.yml float division by zero
# retresco pmematest_2310.yml float division by zero
# retresco pmematest_2310.yml float division by zero
# retresco pmematest_2310.yml float division by zero
# txtrazor pmematest_2310.yml float division by zero
# txtrazor pmematest_2310.yml float division by zero
# txtrazor pmematest_2310.yml float division by zero
# simple pmematest_2310.yml float division by zero
# simple pmematest_2310.yml float division by zero
# semant pmematest_2310.yml float division by zero
# semant pmematest_2310.yml float division by zero
# semant pmematest_2310.yml float division by zero
# basistech pmematest_2310.yml float division by zero
# basistech pmematest_2310.yml float division by zero
# basistech pmematest_2310.yml float division by zero
# meaningcloud pmematest_2310.yml float division by zero
# bitext pmematest_2310.yml float division by zero
# bitext pmematest_2310.yml float division by zero
# alchemy pmematest_2310.yml float division by zero
# alchemy pmematest_2310.yml float division by zero
# alchemy pmematest_2310.yml float division by zero
# semant pmematest_1089.yml float division by zero
# retresco pmematest_644.yml float division by zero
# txtrazor pmematest_644.yml float division by zero
# semant pmematest_644.yml float division by zero
# semant pmematest_644.yml float division by zero
# basistech pmematest_644.yml float division by zero
# basistech pmematest_644.yml float division by zero
# meaningcloud pmematest_644.yml float division by zero
# meaningcloud pmematest_644.yml float division by zero
# bitext pmematest_644.yml float division by zero
# bitext pmematest_644.yml float division by zero
# bitext pmematest_644.yml float division by zero
# alchemy pmematest_644.yml float division by zero
# alchemy pmematest_644.yml float division by zero
# retresco pmematest_1589.yml float division by zero
# retresco pmematest_1589.yml float division by zero
# txtrazor pmematest_1589.yml float division by zero
# txtrazor pmematest_1589.yml float division by zero
# simple pmematest_1589.yml float division by zero
# simple pmematest_1589.yml float division by zero
# semant pmematest_1589.yml float division by zero
# semant pmematest_1589.yml float division by zero
# semant pmematest_1589.yml float division by zero
# basistech pmematest_1589.yml float division by zero
# basistech pmematest_1589.yml float division by zero
# meaningcloud pmematest_1589.yml float division by zero
# meaningcloud pmematest_1589.yml float division by zero
# meaningcloud pmematest_1589.yml float division by zero
# bitext pmematest_1589.yml float division by zero
# bitext pmematest_1589.yml float division by zero
# bitext pmematest_1589.yml float division by zero
# alchemy pmematest_1589.yml float division by zero
# alchemy pmematest_1589.yml float division by zero
# alchemy pmematest_1589.yml float division by zero
# retresco pmematest_560.yml float division by zero
# retresco pmematest_560.yml float division by zero
# txtrazor pmematest_560.yml float division by zero
# txtrazor pmematest_560.yml float division by zero
# simple pmematest_560.yml float division by zero
# semant pmematest_560.yml float division by zero
# semant pmematest_560.yml float division by zero
# basistech pmematest_560.yml float division by zero
# basistech pmematest_560.yml float division by zero
# meaningcloud pmematest_560.yml float division by zero
# meaningcloud pmematest_560.yml float division by zero
# bitext pmematest_560.yml float division by zero
# bitext pmematest_560.yml float division by zero
# alchemy pmematest_560.yml float division by zero
# semant pmematest_118.yml float division by zero
# meaningcloud pmematest_118.yml float division by zero
# alchemy pmematest_118.yml float division by zero
# retresco pmematest_2511.yml float division by zero
# retresco pmematest_2511.yml float division by zero
# txtrazor pmematest_2511.yml float division by zero
# simple pmematest_2511.yml float division by zero
# simple pmematest_2511.yml float division by zero
# semant pmematest_2511.yml float division by zero
# semant pmematest_2511.yml float division by zero
# basistech pmematest_2511.yml float division by zero
# meaningcloud pmematest_2511.yml float division by zero
# bitext pmematest_2511.yml float division by zero
# alchemy pmematest_2511.yml float division by zero
# alchemy pmematest_2511.yml float division by zero
# retresco pmematest_334.yml float division by zero
# txtrazor pmematest_334.yml float division by zero
# simple pmematest_334.yml float division by zero
# simple pmematest_334.yml float division by zero
# semant pmematest_334.yml float division by zero
# semant pmematest_334.yml float division by zero
# basistech pmematest_334.yml float division by zero
# meaningcloud pmematest_334.yml float division by zero
# meaningcloud pmematest_334.yml float division by zero
# bitext pmematest_334.yml float division by zero
# bitext pmematest_334.yml float division by zero
# alchemy pmematest_334.yml float division by zero
# alchemy pmematest_334.yml float division by zero
# retresco pmematest_3485.yml float division by zero
# txtrazor pmematest_3485.yml float division by zero
# simple pmematest_3485.yml float division by zero
# semant pmematest_3485.yml float division by zero
# basistech pmematest_3485.yml float division by zero
# meaningcloud pmematest_3485.yml float division by zero
# bitext pmematest_3485.yml float division by zero
# alchemy pmematest_3485.yml float division by zero
# semant pmematest_2720.yml float division by zero
# retresco pmematest_3362.yml float division by zero
# retresco pmematest_3362.yml float division by zero
# retresco pmematest_3362.yml float division by zero
# txtrazor pmematest_3362.yml float division by zero
# simple pmematest_3362.yml float division by zero
# semant pmematest_3362.yml float division by zero
# semant pmematest_3362.yml float division by zero
# meaningcloud pmematest_3362.yml float division by zero
# meaningcloud pmematest_3362.yml float division by zero
# bitext pmematest_3362.yml float division by zero
# bitext pmematest_3362.yml float division by zero
# bitext pmematest_3362.yml float division by zero
# alchemy pmematest_3362.yml float division by zero
# alchemy pmematest_3362.yml float division by zero
# retresco pmematest_2850.yml float division by zero
# retresco pmematest_2850.yml float division by zero
# retresco pmematest_2850.yml float division by zero
# txtrazor pmematest_2850.yml float division by zero
# txtrazor pmematest_2850.yml float division by zero
# simple pmematest_2850.yml float division by zero
# simple pmematest_2850.yml float division by zero
# semant pmematest_2850.yml float division by zero
# basistech pmematest_2850.yml float division by zero
# basistech pmematest_2850.yml float division by zero
# meaningcloud pmematest_2850.yml float division by zero
# meaningcloud pmematest_2850.yml float division by zero
# bitext pmematest_2850.yml float division by zero
# bitext pmematest_2850.yml float division by zero
# bitext pmematest_2850.yml float division by zero
# alchemy pmematest_2850.yml float division by zero

# %%
results=stats.aggregate_result(data)

# %%
results.extend(stats.compute_total(results))

# %%
# %matplotlib inline

# %%
stats.plot_results(results)

# %%
stats.store_results(results,"fr")
# Out:
# Storing file:  fr_results.yml
