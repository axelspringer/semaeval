# %%
import semaeval.util as util
util.clean_storage("fr")
# Out:
# Deleting: input/fr/pmematest_1034.yml
# Deleting: input/fr/pmematest_1089.yml
# Deleting: input/fr/pmematest_118.yml
# Deleting: input/fr/pmematest_1486.yml
# Deleting: input/fr/pmematest_1508.yml
# Deleting: input/fr/pmematest_1582.yml
# Deleting: input/fr/pmematest_1587.yml
# Deleting: input/fr/pmematest_1589.yml
# Deleting: input/fr/pmematest_1630.yml
# Deleting: input/fr/pmematest_1678.yml
# Deleting: input/fr/pmematest_1697.yml
# Deleting: input/fr/pmematest_1699.yml
# Deleting: input/fr/pmematest_1722.yml
# Deleting: input/fr/pmematest_1834.yml
# Deleting: input/fr/pmematest_1839.yml
# Deleting: input/fr/pmematest_1953.yml
# Deleting: input/fr/pmematest_2084.yml
# Deleting: input/fr/pmematest_2094.yml
# Deleting: input/fr/pmematest_2112.yml
# Deleting: input/fr/pmematest_2124.yml
# Deleting: input/fr/pmematest_2310.yml
# Deleting: input/fr/pmematest_2511.yml
# Deleting: input/fr/pmematest_2583.yml
# Deleting: input/fr/pmematest_2720.yml
# Deleting: input/fr/pmematest_2726.yml
# Deleting: input/fr/pmematest_2766.yml
# Deleting: input/fr/pmematest_2850.yml
# Deleting: input/fr/pmematest_2851.yml
# Deleting: input/fr/pmematest_2906.yml
# Deleting: input/fr/pmematest_2981.yml
# Deleting: input/fr/pmematest_2994.yml
# Deleting: input/fr/pmematest_3098.yml
# Deleting: input/fr/pmematest_3113.yml
# Deleting: input/fr/pmematest_3274.yml
# Deleting: input/fr/pmematest_334.yml
# Deleting: input/fr/pmematest_3362.yml
# Deleting: input/fr/pmematest_341.yml
# Deleting: input/fr/pmematest_3472.yml
# Deleting: input/fr/pmematest_3485.yml
# Deleting: input/fr/pmematest_3511.yml
# Deleting: input/fr/pmematest_456.yml
# Deleting: input/fr/pmematest_560.yml
# Deleting: input/fr/pmematest_576.yml
# Deleting: input/fr/pmematest_618.yml
# Deleting: input/fr/pmematest_641.yml
# Deleting: input/fr/pmematest_644.yml
# Deleting: input/fr/pmematest_791.yml
# Deleting: input/fr/pmematest_894.yml
# Deleting: input/fr/pmematest_901.yml
# Deleting: input/fr/pmematest_912.yml
# Deleting: output/fr/pmematest_1034_alchemy.yml
# Deleting: output/fr/pmematest_1034_basistech.yml
# Deleting: output/fr/pmematest_1034_bitext.yml
# Deleting: output/fr/pmematest_1034_meaningcloud.yml
# Deleting: output/fr/pmematest_1034_retresco.yml
# Deleting: output/fr/pmematest_1034_semant.yml
# Deleting: output/fr/pmematest_1034_simple.yml
# Deleting: output/fr/pmematest_1034_txtrazor.yml
# Deleting: output/fr/pmematest_1089_alchemy.yml
# Deleting: output/fr/pmematest_1089_basistech.yml
# Deleting: output/fr/pmematest_1089_bitext.yml
# Deleting: output/fr/pmematest_1089_meaningcloud.yml
# Deleting: output/fr/pmematest_1089_retresco.yml
# Deleting: output/fr/pmematest_1089_semant.yml
# Deleting: output/fr/pmematest_1089_simple.yml
# Deleting: output/fr/pmematest_1089_txtrazor.yml
# Deleting: output/fr/pmematest_118_alchemy.yml
# Deleting: output/fr/pmematest_118_basistech.yml
# Deleting: output/fr/pmematest_118_bitext.yml
# Deleting: output/fr/pmematest_118_meaningcloud.yml
# Deleting: output/fr/pmematest_118_retresco.yml
# Deleting: output/fr/pmematest_118_semant.yml
# Deleting: output/fr/pmematest_118_simple.yml
# Deleting: output/fr/pmematest_118_txtrazor.yml
# Deleting: output/fr/pmematest_1486_alchemy.yml
# Deleting: output/fr/pmematest_1486_basistech.yml
# Deleting: output/fr/pmematest_1486_bitext.yml
# Deleting: output/fr/pmematest_1486_meaningcloud.yml
# Deleting: output/fr/pmematest_1486_retresco.yml
# Deleting: output/fr/pmematest_1486_semant.yml
# Deleting: output/fr/pmematest_1486_simple.yml
# Deleting: output/fr/pmematest_1486_txtrazor.yml
# Deleting: output/fr/pmematest_1508_alchemy.yml
# Deleting: output/fr/pmematest_1508_basistech.yml
# Deleting: output/fr/pmematest_1508_bitext.yml
# Deleting: output/fr/pmematest_1508_meaningcloud.yml
# Deleting: output/fr/pmematest_1508_retresco.yml
# Deleting: output/fr/pmematest_1508_semant.yml
# Deleting: output/fr/pmematest_1508_simple.yml
# Deleting: output/fr/pmematest_1508_txtrazor.yml
# Deleting: output/fr/pmematest_1582_alchemy.yml
# Deleting: output/fr/pmematest_1582_basistech.yml
# Deleting: output/fr/pmematest_1582_bitext.yml
# Deleting: output/fr/pmematest_1582_meaningcloud.yml
# Deleting: output/fr/pmematest_1582_retresco.yml
# Deleting: output/fr/pmematest_1582_semant.yml
# Deleting: output/fr/pmematest_1582_simple.yml
# Deleting: output/fr/pmematest_1582_txtrazor.yml
# Deleting: output/fr/pmematest_1587_alchemy.yml
# Deleting: output/fr/pmematest_1587_basistech.yml
# Deleting: output/fr/pmematest_1587_bitext.yml
# Deleting: output/fr/pmematest_1587_meaningcloud.yml
# Deleting: output/fr/pmematest_1587_retresco.yml
# Deleting: output/fr/pmematest_1587_semant.yml
# Deleting: output/fr/pmematest_1587_simple.yml
# Deleting: output/fr/pmematest_1587_txtrazor.yml
# Deleting: output/fr/pmematest_1589_alchemy.yml
# Deleting: output/fr/pmematest_1589_basistech.yml
# Deleting: output/fr/pmematest_1589_bitext.yml
# Deleting: output/fr/pmematest_1589_meaningcloud.yml
# Deleting: output/fr/pmematest_1589_retresco.yml
# Deleting: output/fr/pmematest_1589_semant.yml
# Deleting: output/fr/pmematest_1589_simple.yml
# Deleting: output/fr/pmematest_1589_txtrazor.yml
# Deleting: output/fr/pmematest_1630_alchemy.yml
# Deleting: output/fr/pmematest_1630_basistech.yml
# Deleting: output/fr/pmematest_1630_bitext.yml
# Deleting: output/fr/pmematest_1630_meaningcloud.yml
# Deleting: output/fr/pmematest_1630_retresco.yml
# Deleting: output/fr/pmematest_1630_semant.yml
# Deleting: output/fr/pmematest_1630_simple.yml
# Deleting: output/fr/pmematest_1630_txtrazor.yml
# Deleting: output/fr/pmematest_1678_alchemy.yml
# Deleting: output/fr/pmematest_1678_basistech.yml
# Deleting: output/fr/pmematest_1678_bitext.yml
# Deleting: output/fr/pmematest_1678_meaningcloud.yml
# Deleting: output/fr/pmematest_1678_retresco.yml
# Deleting: output/fr/pmematest_1678_semant.yml
# Deleting: output/fr/pmematest_1678_simple.yml
# Deleting: output/fr/pmematest_1678_txtrazor.yml
# Deleting: output/fr/pmematest_1697_alchemy.yml
# Deleting: output/fr/pmematest_1697_basistech.yml
# Deleting: output/fr/pmematest_1697_bitext.yml
# Deleting: output/fr/pmematest_1697_meaningcloud.yml
# Deleting: output/fr/pmematest_1697_retresco.yml
# Deleting: output/fr/pmematest_1697_semant.yml
# Deleting: output/fr/pmematest_1697_simple.yml
# Deleting: output/fr/pmematest_1697_txtrazor.yml
# Deleting: output/fr/pmematest_1699_alchemy.yml
# Deleting: output/fr/pmematest_1699_basistech.yml
# Deleting: output/fr/pmematest_1699_bitext.yml
# Deleting: output/fr/pmematest_1699_meaningcloud.yml
# Deleting: output/fr/pmematest_1699_retresco.yml
# Deleting: output/fr/pmematest_1699_semant.yml
# Deleting: output/fr/pmematest_1699_simple.yml
# Deleting: output/fr/pmematest_1699_txtrazor.yml
# Deleting: output/fr/pmematest_1722_alchemy.yml
# Deleting: output/fr/pmematest_1722_basistech.yml
# Deleting: output/fr/pmematest_1722_bitext.yml
# Deleting: output/fr/pmematest_1722_meaningcloud.yml
# Deleting: output/fr/pmematest_1722_retresco.yml
# Deleting: output/fr/pmematest_1722_semant.yml
# Deleting: output/fr/pmematest_1722_simple.yml
# Deleting: output/fr/pmematest_1722_txtrazor.yml
# Deleting: output/fr/pmematest_1834_alchemy.yml
# Deleting: output/fr/pmematest_1834_basistech.yml
# Deleting: output/fr/pmematest_1834_bitext.yml
# Deleting: output/fr/pmematest_1834_meaningcloud.yml
# Deleting: output/fr/pmematest_1834_retresco.yml
# Deleting: output/fr/pmematest_1834_semant.yml
# Deleting: output/fr/pmematest_1834_simple.yml
# Deleting: output/fr/pmematest_1834_txtrazor.yml
# Deleting: output/fr/pmematest_1839_alchemy.yml
# Deleting: output/fr/pmematest_1839_basistech.yml
# Deleting: output/fr/pmematest_1839_bitext.yml
# Deleting: output/fr/pmematest_1839_meaningcloud.yml
# Deleting: output/fr/pmematest_1839_retresco.yml
# Deleting: output/fr/pmematest_1839_semant.yml
# Deleting: output/fr/pmematest_1839_simple.yml
# Deleting: output/fr/pmematest_1839_txtrazor.yml
# Deleting: output/fr/pmematest_1953_alchemy.yml
# Deleting: output/fr/pmematest_1953_basistech.yml
# Deleting: output/fr/pmematest_1953_bitext.yml
# Deleting: output/fr/pmematest_1953_meaningcloud.yml
# Deleting: output/fr/pmematest_1953_retresco.yml
# Deleting: output/fr/pmematest_1953_semant.yml
# Deleting: output/fr/pmematest_1953_simple.yml
# Deleting: output/fr/pmematest_1953_txtrazor.yml
# Deleting: output/fr/pmematest_2084_alchemy.yml
# Deleting: output/fr/pmematest_2084_basistech.yml
# Deleting: output/fr/pmematest_2084_bitext.yml
# Deleting: output/fr/pmematest_2084_meaningcloud.yml
# Deleting: output/fr/pmematest_2084_retresco.yml
# Deleting: output/fr/pmematest_2084_semant.yml
# Deleting: output/fr/pmematest_2084_simple.yml
# Deleting: output/fr/pmematest_2084_txtrazor.yml
# Deleting: output/fr/pmematest_2094_alchemy.yml
# Deleting: output/fr/pmematest_2094_basistech.yml
# Deleting: output/fr/pmematest_2094_bitext.yml
# Deleting: output/fr/pmematest_2094_meaningcloud.yml
# Deleting: output/fr/pmematest_2094_retresco.yml
# Deleting: output/fr/pmematest_2094_semant.yml
# Deleting: output/fr/pmematest_2094_simple.yml
# Deleting: output/fr/pmematest_2094_txtrazor.yml
# Deleting: output/fr/pmematest_2112_alchemy.yml
# Deleting: output/fr/pmematest_2112_basistech.yml
# Deleting: output/fr/pmematest_2112_bitext.yml
# Deleting: output/fr/pmematest_2112_meaningcloud.yml
# Deleting: output/fr/pmematest_2112_retresco.yml
# Deleting: output/fr/pmematest_2112_semant.yml
# Deleting: output/fr/pmematest_2112_simple.yml
# Deleting: output/fr/pmematest_2112_txtrazor.yml
# Deleting: output/fr/pmematest_2124_alchemy.yml
# Deleting: output/fr/pmematest_2124_basistech.yml
# Deleting: output/fr/pmematest_2124_bitext.yml
# Deleting: output/fr/pmematest_2124_meaningcloud.yml
# Deleting: output/fr/pmematest_2124_retresco.yml
# Deleting: output/fr/pmematest_2124_semant.yml
# Deleting: output/fr/pmematest_2124_simple.yml
# Deleting: output/fr/pmematest_2124_txtrazor.yml
# Deleting: output/fr/pmematest_2310_alchemy.yml
# Deleting: output/fr/pmematest_2310_basistech.yml
# Deleting: output/fr/pmematest_2310_bitext.yml
# Deleting: output/fr/pmematest_2310_meaningcloud.yml
# Deleting: output/fr/pmematest_2310_retresco.yml
# Deleting: output/fr/pmematest_2310_semant.yml
# Deleting: output/fr/pmematest_2310_simple.yml
# Deleting: output/fr/pmematest_2310_txtrazor.yml
# Deleting: output/fr/pmematest_2511_alchemy.yml
# Deleting: output/fr/pmematest_2511_basistech.yml
# Deleting: output/fr/pmematest_2511_bitext.yml
# Deleting: output/fr/pmematest_2511_meaningcloud.yml
# Deleting: output/fr/pmematest_2511_retresco.yml
# Deleting: output/fr/pmematest_2511_semant.yml
# Deleting: output/fr/pmematest_2511_simple.yml
# Deleting: output/fr/pmematest_2511_txtrazor.yml
# Deleting: output/fr/pmematest_2583_alchemy.yml
# Deleting: output/fr/pmematest_2583_basistech.yml
# Deleting: output/fr/pmematest_2583_bitext.yml
# Deleting: output/fr/pmematest_2583_meaningcloud.yml
# Deleting: output/fr/pmematest_2583_retresco.yml
# Deleting: output/fr/pmematest_2583_semant.yml
# Deleting: output/fr/pmematest_2583_simple.yml
# Deleting: output/fr/pmematest_2583_txtrazor.yml
# Deleting: output/fr/pmematest_2720_alchemy.yml
# Deleting: output/fr/pmematest_2720_basistech.yml
# Deleting: output/fr/pmematest_2720_bitext.yml
# Deleting: output/fr/pmematest_2720_meaningcloud.yml
# Deleting: output/fr/pmematest_2720_retresco.yml
# Deleting: output/fr/pmematest_2720_semant.yml
# Deleting: output/fr/pmematest_2720_simple.yml
# Deleting: output/fr/pmematest_2720_txtrazor.yml
# Deleting: output/fr/pmematest_2726_alchemy.yml
# Deleting: output/fr/pmematest_2726_basistech.yml
# Deleting: output/fr/pmematest_2726_bitext.yml
# Deleting: output/fr/pmematest_2726_meaningcloud.yml
# Deleting: output/fr/pmematest_2726_retresco.yml
# Deleting: output/fr/pmematest_2726_semant.yml
# Deleting: output/fr/pmematest_2726_simple.yml
# Deleting: output/fr/pmematest_2726_txtrazor.yml
# Deleting: output/fr/pmematest_2766_alchemy.yml
# Deleting: output/fr/pmematest_2766_basistech.yml
# Deleting: output/fr/pmematest_2766_bitext.yml
# Deleting: output/fr/pmematest_2766_meaningcloud.yml
# Deleting: output/fr/pmematest_2766_retresco.yml
# Deleting: output/fr/pmematest_2766_semant.yml
# Deleting: output/fr/pmematest_2766_simple.yml
# Deleting: output/fr/pmematest_2766_txtrazor.yml
# Deleting: output/fr/pmematest_2850_alchemy.yml
# Deleting: output/fr/pmematest_2850_basistech.yml
# Deleting: output/fr/pmematest_2850_bitext.yml
# Deleting: output/fr/pmematest_2850_meaningcloud.yml
# Deleting: output/fr/pmematest_2850_retresco.yml
# Deleting: output/fr/pmematest_2850_semant.yml
# Deleting: output/fr/pmematest_2850_simple.yml
# Deleting: output/fr/pmematest_2850_txtrazor.yml
# Deleting: output/fr/pmematest_2851_alchemy.yml
# Deleting: output/fr/pmematest_2851_basistech.yml
# Deleting: output/fr/pmematest_2851_bitext.yml
# Deleting: output/fr/pmematest_2851_meaningcloud.yml
# Deleting: output/fr/pmematest_2851_retresco.yml
# Deleting: output/fr/pmematest_2851_semant.yml
# Deleting: output/fr/pmematest_2851_simple.yml
# Deleting: output/fr/pmematest_2851_txtrazor.yml
# Deleting: output/fr/pmematest_2906_alchemy.yml
# Deleting: output/fr/pmematest_2906_basistech.yml
# Deleting: output/fr/pmematest_2906_bitext.yml
# Deleting: output/fr/pmematest_2906_meaningcloud.yml
# Deleting: output/fr/pmematest_2906_retresco.yml
# Deleting: output/fr/pmematest_2906_semant.yml
# Deleting: output/fr/pmematest_2906_simple.yml
# Deleting: output/fr/pmematest_2906_txtrazor.yml
# Deleting: output/fr/pmematest_2981_alchemy.yml
# Deleting: output/fr/pmematest_2981_basistech.yml
# Deleting: output/fr/pmematest_2981_bitext.yml
# Deleting: output/fr/pmematest_2981_meaningcloud.yml
# Deleting: output/fr/pmematest_2981_retresco.yml
# Deleting: output/fr/pmematest_2981_semant.yml
# Deleting: output/fr/pmematest_2981_simple.yml
# Deleting: output/fr/pmematest_2981_txtrazor.yml
# Deleting: output/fr/pmematest_2994_alchemy.yml
# Deleting: output/fr/pmematest_2994_basistech.yml
# Deleting: output/fr/pmematest_2994_bitext.yml
# Deleting: output/fr/pmematest_2994_meaningcloud.yml
# Deleting: output/fr/pmematest_2994_retresco.yml
# Deleting: output/fr/pmematest_2994_semant.yml
# Deleting: output/fr/pmematest_2994_simple.yml
# Deleting: output/fr/pmematest_2994_txtrazor.yml
# Deleting: output/fr/pmematest_3098_alchemy.yml
# Deleting: output/fr/pmematest_3098_basistech.yml
# Deleting: output/fr/pmematest_3098_bitext.yml
# Deleting: output/fr/pmematest_3098_meaningcloud.yml
# Deleting: output/fr/pmematest_3098_retresco.yml
# Deleting: output/fr/pmematest_3098_semant.yml
# Deleting: output/fr/pmematest_3098_simple.yml
# Deleting: output/fr/pmematest_3098_txtrazor.yml
# Deleting: output/fr/pmematest_3113_alchemy.yml
# Deleting: output/fr/pmematest_3113_basistech.yml
# Deleting: output/fr/pmematest_3113_bitext.yml
# Deleting: output/fr/pmematest_3113_meaningcloud.yml
# Deleting: output/fr/pmematest_3113_retresco.yml
# Deleting: output/fr/pmematest_3113_semant.yml
# Deleting: output/fr/pmematest_3113_simple.yml
# Deleting: output/fr/pmematest_3113_txtrazor.yml
# Deleting: output/fr/pmematest_3274_alchemy.yml
# Deleting: output/fr/pmematest_3274_basistech.yml
# Deleting: output/fr/pmematest_3274_bitext.yml
# Deleting: output/fr/pmematest_3274_meaningcloud.yml
# Deleting: output/fr/pmematest_3274_retresco.yml
# Deleting: output/fr/pmematest_3274_semant.yml
# Deleting: output/fr/pmematest_3274_simple.yml
# Deleting: output/fr/pmematest_3274_txtrazor.yml
# Deleting: output/fr/pmematest_334_alchemy.yml
# Deleting: output/fr/pmematest_334_basistech.yml
# Deleting: output/fr/pmematest_334_bitext.yml
# Deleting: output/fr/pmematest_334_meaningcloud.yml
# Deleting: output/fr/pmematest_334_retresco.yml
# Deleting: output/fr/pmematest_334_semant.yml
# Deleting: output/fr/pmematest_334_simple.yml
# Deleting: output/fr/pmematest_334_txtrazor.yml
# Deleting: output/fr/pmematest_3362_alchemy.yml
# Deleting: output/fr/pmematest_3362_basistech.yml
# Deleting: output/fr/pmematest_3362_bitext.yml
# Deleting: output/fr/pmematest_3362_meaningcloud.yml
# Deleting: output/fr/pmematest_3362_retresco.yml
# Deleting: output/fr/pmematest_3362_semant.yml
# Deleting: output/fr/pmematest_3362_simple.yml
# Deleting: output/fr/pmematest_3362_txtrazor.yml
# Deleting: output/fr/pmematest_341_alchemy.yml
# Deleting: output/fr/pmematest_341_basistech.yml
# Deleting: output/fr/pmematest_341_bitext.yml
# Deleting: output/fr/pmematest_341_meaningcloud.yml
# Deleting: output/fr/pmematest_341_retresco.yml
# Deleting: output/fr/pmematest_341_semant.yml
# Deleting: output/fr/pmematest_341_simple.yml
# Deleting: output/fr/pmematest_341_txtrazor.yml
# Deleting: output/fr/pmematest_3472_alchemy.yml
# Deleting: output/fr/pmematest_3472_basistech.yml
# Deleting: output/fr/pmematest_3472_bitext.yml
# Deleting: output/fr/pmematest_3472_meaningcloud.yml
# Deleting: output/fr/pmematest_3472_retresco.yml
# Deleting: output/fr/pmematest_3472_semant.yml
# Deleting: output/fr/pmematest_3472_simple.yml
# Deleting: output/fr/pmematest_3472_txtrazor.yml
# Deleting: output/fr/pmematest_3485_alchemy.yml
# Deleting: output/fr/pmematest_3485_basistech.yml
# Deleting: output/fr/pmematest_3485_bitext.yml
# Deleting: output/fr/pmematest_3485_meaningcloud.yml
# Deleting: output/fr/pmematest_3485_retresco.yml
# Deleting: output/fr/pmematest_3485_semant.yml
# Deleting: output/fr/pmematest_3485_simple.yml
# Deleting: output/fr/pmematest_3485_txtrazor.yml
# Deleting: output/fr/pmematest_3511_alchemy.yml
# Deleting: output/fr/pmematest_3511_basistech.yml
# Deleting: output/fr/pmematest_3511_bitext.yml
# Deleting: output/fr/pmematest_3511_meaningcloud.yml
# Deleting: output/fr/pmematest_3511_retresco.yml
# Deleting: output/fr/pmematest_3511_semant.yml
# Deleting: output/fr/pmematest_3511_simple.yml
# Deleting: output/fr/pmematest_3511_txtrazor.yml
# Deleting: output/fr/pmematest_456_alchemy.yml
# Deleting: output/fr/pmematest_456_basistech.yml
# Deleting: output/fr/pmematest_456_bitext.yml
# Deleting: output/fr/pmematest_456_meaningcloud.yml
# Deleting: output/fr/pmematest_456_retresco.yml
# Deleting: output/fr/pmematest_456_semant.yml
# Deleting: output/fr/pmematest_456_simple.yml
# Deleting: output/fr/pmematest_456_txtrazor.yml
# Deleting: output/fr/pmematest_560_alchemy.yml
# Deleting: output/fr/pmematest_560_basistech.yml
# Deleting: output/fr/pmematest_560_bitext.yml
# Deleting: output/fr/pmematest_560_meaningcloud.yml
# Deleting: output/fr/pmematest_560_retresco.yml
# Deleting: output/fr/pmematest_560_semant.yml
# Deleting: output/fr/pmematest_560_simple.yml
# Deleting: output/fr/pmematest_560_txtrazor.yml
# Deleting: output/fr/pmematest_576_alchemy.yml
# Deleting: output/fr/pmematest_576_basistech.yml
# Deleting: output/fr/pmematest_576_bitext.yml
# Deleting: output/fr/pmematest_576_meaningcloud.yml
# Deleting: output/fr/pmematest_576_retresco.yml
# Deleting: output/fr/pmematest_576_semant.yml
# Deleting: output/fr/pmematest_576_simple.yml
# Deleting: output/fr/pmematest_576_txtrazor.yml
# Deleting: output/fr/pmematest_618_alchemy.yml
# Deleting: output/fr/pmematest_618_basistech.yml
# Deleting: output/fr/pmematest_618_bitext.yml
# Deleting: output/fr/pmematest_618_meaningcloud.yml
# Deleting: output/fr/pmematest_618_retresco.yml
# Deleting: output/fr/pmematest_618_semant.yml
# Deleting: output/fr/pmematest_618_simple.yml
# Deleting: output/fr/pmematest_618_txtrazor.yml
# Deleting: output/fr/pmematest_641_alchemy.yml
# Deleting: output/fr/pmematest_641_basistech.yml
# Deleting: output/fr/pmematest_641_bitext.yml
# Deleting: output/fr/pmematest_641_meaningcloud.yml
# Deleting: output/fr/pmematest_641_retresco.yml
# Deleting: output/fr/pmematest_641_semant.yml
# Deleting: output/fr/pmematest_641_simple.yml
# Deleting: output/fr/pmematest_641_txtrazor.yml
# Deleting: output/fr/pmematest_644_alchemy.yml
# Deleting: output/fr/pmematest_644_basistech.yml
# Deleting: output/fr/pmematest_644_bitext.yml
# Deleting: output/fr/pmematest_644_meaningcloud.yml
# Deleting: output/fr/pmematest_644_retresco.yml
# Deleting: output/fr/pmematest_644_semant.yml
# Deleting: output/fr/pmematest_644_simple.yml
# Deleting: output/fr/pmematest_644_txtrazor.yml
# Deleting: output/fr/pmematest_791_alchemy.yml
# Deleting: output/fr/pmematest_791_basistech.yml
# Deleting: output/fr/pmematest_791_bitext.yml
# Deleting: output/fr/pmematest_791_meaningcloud.yml
# Deleting: output/fr/pmematest_791_retresco.yml
# Deleting: output/fr/pmematest_791_semant.yml
# Deleting: output/fr/pmematest_791_simple.yml
# Deleting: output/fr/pmematest_791_txtrazor.yml
# Deleting: output/fr/pmematest_894_alchemy.yml
# Deleting: output/fr/pmematest_894_basistech.yml
# Deleting: output/fr/pmematest_894_bitext.yml
# Deleting: output/fr/pmematest_894_meaningcloud.yml
# Deleting: output/fr/pmematest_894_retresco.yml
# Deleting: output/fr/pmematest_894_semant.yml
# Deleting: output/fr/pmematest_894_simple.yml
# Deleting: output/fr/pmematest_894_txtrazor.yml
# Deleting: output/fr/pmematest_901_alchemy.yml
# Deleting: output/fr/pmematest_901_basistech.yml
# Deleting: output/fr/pmematest_901_bitext.yml
# Deleting: output/fr/pmematest_901_meaningcloud.yml
# Deleting: output/fr/pmematest_901_retresco.yml
# Deleting: output/fr/pmematest_901_semant.yml
# Deleting: output/fr/pmematest_901_simple.yml
# Deleting: output/fr/pmematest_901_txtrazor.yml
# Deleting: output/fr/pmematest_912_alchemy.yml
# Deleting: output/fr/pmematest_912_basistech.yml
# Deleting: output/fr/pmematest_912_bitext.yml
# Deleting: output/fr/pmematest_912_meaningcloud.yml
# Deleting: output/fr/pmematest_912_retresco.yml
# Deleting: output/fr/pmematest_912_semant.yml
# Deleting: output/fr/pmematest_912_simple.yml
# Deleting: output/fr/pmematest_912_txtrazor.yml
# [Errno 2] No such file or directory: 'result/fr'

# %%
import semaeval.source.syndication as synd

# %%
help(synd)
# Out:
# Help on module semaeval.source.syndication in semaeval.source:
#
# NAME
#     semaeval.source.syndication - # -*- coding: utf-8 -*-
#
# FILE
#     /Users/amaier1/git/semaeval/semaeval/source/syndication.py
#
# FUNCTIONS
#     article_from_path(path)
#
#     articles_from_dir(dir)
#
#     load_articles(prefix)
#
#     store_articles(articles, prefix)
#
# DATA
#     store_dir = 'input/'
#     url_regex = <_sre.SRE_Pattern object>

# %%
pme = synd.articles_from_dir("/Users/amaier1/Documents/semeval/pmematest")

# %%
import random
articles = random.sample(pme,50)

# %%
synd.store_articles(articles,"fr")
# Out:
# Storing file:  input/fr/pmematest_2259.yml
# Storing file:  input/fr/pmematest_552.yml
# Storing file:  input/fr/pmematest_149.yml
# Storing file:  input/fr/pmematest_3516.yml
# Storing file:  input/fr/pmematest_1737.yml
# Storing file:  input/fr/pmematest_2829.yml
# Storing file:  input/fr/pmematest_2989.yml
# Storing file:  input/fr/pmematest_016.yml
# Storing file:  input/fr/pmematest_1773.yml
# Storing file:  input/fr/pmematest_511.yml
# Storing file:  input/fr/pmematest_3073.yml
# Storing file:  input/fr/pmematest_2470.yml
# Storing file:  input/fr/pmematest_2679.yml
# Storing file:  input/fr/pmematest_3309.yml
# Storing file:  input/fr/pmematest_1353.yml
# Storing file:  input/fr/pmematest_671.yml
# Storing file:  input/fr/pmematest_2178.yml
# Storing file:  input/fr/pmematest_2634.yml
# Storing file:  input/fr/pmematest_3155.yml
# Storing file:  input/fr/pmematest_064.yml
# Storing file:  input/fr/pmematest_447.yml
# Storing file:  input/fr/pmematest_3357.yml
# Storing file:  input/fr/pmematest_3222.yml
# Storing file:  input/fr/pmematest_962.yml
# Storing file:  input/fr/pmematest_3183.yml
# Storing file:  input/fr/pmematest_2052.yml
# Storing file:  input/fr/pmematest_1996.yml
# Storing file:  input/fr/pmematest_3461.yml
# Storing file:  input/fr/pmematest_587.yml
# Storing file:  input/fr/pmematest_468.yml
# Storing file:  input/fr/pmematest_581.yml
# Storing file:  input/fr/pmematest_1666.yml
# Storing file:  input/fr/pmematest_1699.yml
# Storing file:  input/fr/pmematest_1084.yml
# Storing file:  input/fr/pmematest_1469.yml
# Storing file:  input/fr/pmematest_697.yml
# Storing file:  input/fr/pmematest_1589.yml
# Storing file:  input/fr/pmematest_3219.yml
# Storing file:  input/fr/pmematest_2805.yml
# Storing file:  input/fr/pmematest_201.yml
# Storing file:  input/fr/pmematest_2603.yml
# Storing file:  input/fr/pmematest_3175.yml
# Storing file:  input/fr/pmematest_400.yml
# Storing file:  input/fr/pmematest_2255.yml
# Storing file:  input/fr/pmematest_673.yml
# Storing file:  input/fr/pmematest_2586.yml
# Storing file:  input/fr/pmematest_401.yml
# Storing file:  input/fr/pmematest_040.yml
# Storing file:  input/fr/pmematest_1587.yml
# Storing file:  input/fr/pmematest_2379.yml

# %%
import semaeval.evaluate as eval
reload(eval)
# Out:
# <module 'semaeval.evaluate' from 'semaeval/evaluate.pyc'>

# %%
articles_enriched = eval.detect_entities(articles,"fr")
# Out:
# Filename: pmematest_2259.yml
# Collecting results:
# Filename: pmematest_552.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_149.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_3516.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_1737.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_2829.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.netowl
# Filename: pmematest_2989.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# semaeval.engine.retresco
# Filename: pmematest_016.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.simple
# Filename: pmematest_1773.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.txtrazor
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_511.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# textrazor:semantria: Regex
#  [u'Device', u'Camera', u'DigitalCamera']
# semantria: Regex
# semantria: Regex
# Filename: pmematest_3073.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_2470.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.netowl
# semaeval.engine.simple
# semaeval.engine.basistech
# alchemy: TelevisionShow
# alchemy: OperatingSystem
# Filename: pmematest_2679.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_3309.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_1353.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_671.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.netowl
# Filename: pmematest_2178.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_2634.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.bitext
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# semantria: Regex
# Filename: pmematest_3155.yml
# Collecting results:
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_064.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_447.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# NetOwl API Error: 'entity'
# NetOwl Response: {"process": {"version": "1.0"},"section": []}
# Filename: pmematest_3357.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_3222.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_962.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_3183.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_2052.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.basistech
# semaeval.engine.netowl
# Filename: pmematest_1996.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_3461.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_587.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# alchemy: Automobile
# alchemy: TelevisionShow
# Filename: pmematest_468.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# semantria: Regex
# Filename: pmematest_581.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_1666.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# semaeval.engine.basistech
# Filename: pmematest_1699.yml
# Collecting results:
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.bitext
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_1084.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_1469.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.bitext
# semaeval.engine.netowl
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.alchemy
# Filename: pmematest_697.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_1589.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# NetOwl API Error: 'entity'
# NetOwl Response: {"process": {"version": "1.0"},"section": []}
# Filename: pmematest_3219.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_2805.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_201.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.netowl
# semaeval.engine.basistech
# semaeval.engine.simple
# Filename: pmematest_2603.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_3175.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_400.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.retresco
# semaeval.engine.simple
# textrazor:alchemy: TelevisionShow
#  [u'Award']
# Filename: pmematest_2255.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# Filename: pmematest_673.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.meaningcloud
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_2586.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.simple
# semaeval.engine.netowl
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# textrazor: [u'Device', u'InformationAppliance']
# Filename: pmematest_401.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_040.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# alchemy: FinancialMarketIndex
# alchemy: FinancialMarketIndex
# alchemy: FinancialMarketIndex
# Filename: pmematest_1587.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# semantria: Regex
# Filename: pmematest_2379.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.basistech
# semaeval.engine.netowl
# semaeval.engine.simple

# %%
eval.store_articles(articles_enriched,"fr")
# Out:
# Storing file:  output/fr/pmematest_2259_meaningcloud.yml
# Storing file:  output/fr/pmematest_2259_retresco.yml
# Storing file:  output/fr/pmematest_2259_netowl.yml
# Storing file:  output/fr/pmematest_2259_bitext.yml
# Storing file:  output/fr/pmematest_2259_semant.yml
# Storing file:  output/fr/pmematest_2259_alchemy.yml
# Storing file:  output/fr/pmematest_2259_simple.yml
# Storing file:  output/fr/pmematest_2259_txtrazor.yml
# Storing file:  output/fr/pmematest_2259_basistech.yml
# Storing file:  output/fr/pmematest_552_meaningcloud.yml
# Storing file:  output/fr/pmematest_552_retresco.yml
# Storing file:  output/fr/pmematest_552_netowl.yml
# Storing file:  output/fr/pmematest_552_bitext.yml
# Storing file:  output/fr/pmematest_552_semant.yml
# Storing file:  output/fr/pmematest_552_alchemy.yml
# Storing file:  output/fr/pmematest_552_simple.yml
# Storing file:  output/fr/pmematest_552_txtrazor.yml
# Storing file:  output/fr/pmematest_552_basistech.yml
# Storing file:  output/fr/pmematest_149_meaningcloud.yml
# Storing file:  output/fr/pmematest_149_retresco.yml
# Storing file:  output/fr/pmematest_149_netowl.yml
# Storing file:  output/fr/pmematest_149_bitext.yml
# Storing file:  output/fr/pmematest_149_semant.yml
# Storing file:  output/fr/pmematest_149_alchemy.yml
# Storing file:  output/fr/pmematest_149_simple.yml
# Storing file:  output/fr/pmematest_149_txtrazor.yml
# Storing file:  output/fr/pmematest_149_basistech.yml
# Storing file:  output/fr/pmematest_3516_meaningcloud.yml
# Storing file:  output/fr/pmematest_3516_retresco.yml
# Storing file:  output/fr/pmematest_3516_netowl.yml
# Storing file:  output/fr/pmematest_3516_bitext.yml
# Storing file:  output/fr/pmematest_3516_semant.yml
# Storing file:  output/fr/pmematest_3516_alchemy.yml
# Storing file:  output/fr/pmematest_3516_simple.yml
# Storing file:  output/fr/pmematest_3516_txtrazor.yml
# Storing file:  output/fr/pmematest_3516_basistech.yml
# Storing file:  output/fr/pmematest_1737_meaningcloud.yml
# Storing file:  output/fr/pmematest_1737_retresco.yml
# Storing file:  output/fr/pmematest_1737_netowl.yml
# Storing file:  output/fr/pmematest_1737_bitext.yml
# Storing file:  output/fr/pmematest_1737_semant.yml
# Storing file:  output/fr/pmematest_1737_alchemy.yml
# Storing file:  output/fr/pmematest_1737_simple.yml
# Storing file:  output/fr/pmematest_1737_txtrazor.yml
# Storing file:  output/fr/pmematest_1737_basistech.yml
# Storing file:  output/fr/pmematest_2829_meaningcloud.yml
# Storing file:  output/fr/pmematest_2829_retresco.yml
# Storing file:  output/fr/pmematest_2829_netowl.yml
# Storing file:  output/fr/pmematest_2829_bitext.yml
# Storing file:  output/fr/pmematest_2829_semant.yml
# Storing file:  output/fr/pmematest_2829_alchemy.yml
# Storing file:  output/fr/pmematest_2829_simple.yml
# Storing file:  output/fr/pmematest_2829_txtrazor.yml
# Storing file:  output/fr/pmematest_2829_basistech.yml
# Storing file:  output/fr/pmematest_2989_meaningcloud.yml
# Storing file:  output/fr/pmematest_2989_retresco.yml
# Storing file:  output/fr/pmematest_2989_netowl.yml
# Storing file:  output/fr/pmematest_2989_bitext.yml
# Storing file:  output/fr/pmematest_2989_semant.yml
# Storing file:  output/fr/pmematest_2989_alchemy.yml
# Storing file:  output/fr/pmematest_2989_simple.yml
# Storing file:  output/fr/pmematest_2989_txtrazor.yml
# Storing file:  output/fr/pmematest_2989_basistech.yml
# Storing file:  output/fr/pmematest_016_meaningcloud.yml
# Storing file:  output/fr/pmematest_016_retresco.yml
# Storing file:  output/fr/pmematest_016_netowl.yml
# Storing file:  output/fr/pmematest_016_bitext.yml
# Storing file:  output/fr/pmematest_016_semant.yml
# Storing file:  output/fr/pmematest_016_alchemy.yml
# Storing file:  output/fr/pmematest_016_simple.yml
# Storing file:  output/fr/pmematest_016_txtrazor.yml
# Storing file:  output/fr/pmematest_016_basistech.yml
# Storing file:  output/fr/pmematest_1773_meaningcloud.yml
# Storing file:  output/fr/pmematest_1773_retresco.yml
# Storing file:  output/fr/pmematest_1773_netowl.yml
# Storing file:  output/fr/pmematest_1773_bitext.yml
# Storing file:  output/fr/pmematest_1773_semant.yml
# Storing file:  output/fr/pmematest_1773_alchemy.yml
# Storing file:  output/fr/pmematest_1773_simple.yml
# Storing file:  output/fr/pmematest_1773_txtrazor.yml
# Storing file:  output/fr/pmematest_1773_basistech.yml
# Storing file:  output/fr/pmematest_511_meaningcloud.yml
# Storing file:  output/fr/pmematest_511_retresco.yml
# Storing file:  output/fr/pmematest_511_netowl.yml
# Storing file:  output/fr/pmematest_511_bitext.yml
# Storing file:  output/fr/pmematest_511_semant.yml
# Storing file:  output/fr/pmematest_511_alchemy.yml
# Storing file:  output/fr/pmematest_511_simple.yml
# Storing file:  output/fr/pmematest_511_txtrazor.yml
# Storing file:  output/fr/pmematest_511_basistech.yml
# Storing file:  output/fr/pmematest_3073_meaningcloud.yml
# Storing file:  output/fr/pmematest_3073_retresco.yml
# Storing file:  output/fr/pmematest_3073_netowl.yml
# Storing file:  output/fr/pmematest_3073_bitext.yml
# Storing file:  output/fr/pmematest_3073_semant.yml
# Storing file:  output/fr/pmematest_3073_alchemy.yml
# Storing file:  output/fr/pmematest_3073_simple.yml
# Storing file:  output/fr/pmematest_3073_txtrazor.yml
# Storing file:  output/fr/pmematest_3073_basistech.yml
# Storing file:  output/fr/pmematest_2470_meaningcloud.yml
# Storing file:  output/fr/pmematest_2470_retresco.yml
# Storing file:  output/fr/pmematest_2470_netowl.yml
# Storing file:  output/fr/pmematest_2470_bitext.yml
# Storing file:  output/fr/pmematest_2470_semant.yml
# Storing file:  output/fr/pmematest_2470_alchemy.yml
# Storing file:  output/fr/pmematest_2470_simple.yml
# Storing file:  output/fr/pmematest_2470_txtrazor.yml
# Storing file:  output/fr/pmematest_2470_basistech.yml
# Storing file:  output/fr/pmematest_2679_meaningcloud.yml
# Storing file:  output/fr/pmematest_2679_retresco.yml
# Storing file:  output/fr/pmematest_2679_netowl.yml
# Storing file:  output/fr/pmematest_2679_bitext.yml
# Storing file:  output/fr/pmematest_2679_semant.yml
# Storing file:  output/fr/pmematest_2679_alchemy.yml
# Storing file:  output/fr/pmematest_2679_simple.yml
# Storing file:  output/fr/pmematest_2679_txtrazor.yml
# Storing file:  output/fr/pmematest_2679_basistech.yml
# Storing file:  output/fr/pmematest_3309_meaningcloud.yml
# Storing file:  output/fr/pmematest_3309_retresco.yml
# Storing file:  output/fr/pmematest_3309_netowl.yml
# Storing file:  output/fr/pmematest_3309_bitext.yml
# Storing file:  output/fr/pmematest_3309_semant.yml
# Storing file:  output/fr/pmematest_3309_alchemy.yml
# Storing file:  output/fr/pmematest_3309_simple.yml
# Storing file:  output/fr/pmematest_3309_txtrazor.yml
# Storing file:  output/fr/pmematest_3309_basistech.yml
# Storing file:  output/fr/pmematest_1353_meaningcloud.yml
# Storing file:  output/fr/pmematest_1353_retresco.yml
# Storing file:  output/fr/pmematest_1353_netowl.yml
# Storing file:  output/fr/pmematest_1353_bitext.yml
# Storing file:  output/fr/pmematest_1353_semant.yml
# Storing file:  output/fr/pmematest_1353_alchemy.yml
# Storing file:  output/fr/pmematest_1353_simple.yml
# Storing file:  output/fr/pmematest_1353_txtrazor.yml
# Storing file:  output/fr/pmematest_1353_basistech.yml
# Storing file:  output/fr/pmematest_671_meaningcloud.yml
# Storing file:  output/fr/pmematest_671_retresco.yml
# Storing file:  output/fr/pmematest_671_netowl.yml
# Storing file:  output/fr/pmematest_671_bitext.yml
# Storing file:  output/fr/pmematest_671_semant.yml
# Storing file:  output/fr/pmematest_671_alchemy.yml
# Storing file:  output/fr/pmematest_671_simple.yml
# Storing file:  output/fr/pmematest_671_txtrazor.yml
# Storing file:  output/fr/pmematest_671_basistech.yml
# Storing file:  output/fr/pmematest_2178_meaningcloud.yml
# Storing file:  output/fr/pmematest_2178_retresco.yml
# Storing file:  output/fr/pmematest_2178_netowl.yml
# Storing file:  output/fr/pmematest_2178_bitext.yml
# Storing file:  output/fr/pmematest_2178_semant.yml
# Storing file:  output/fr/pmematest_2178_alchemy.yml
# Storing file:  output/fr/pmematest_2178_simple.yml
# Storing file:  output/fr/pmematest_2178_txtrazor.yml
# Storing file:  output/fr/pmematest_2178_basistech.yml
# Storing file:  output/fr/pmematest_2634_meaningcloud.yml
# Storing file:  output/fr/pmematest_2634_retresco.yml
# Storing file:  output/fr/pmematest_2634_netowl.yml
# Storing file:  output/fr/pmematest_2634_bitext.yml
# Storing file:  output/fr/pmematest_2634_semant.yml
# Storing file:  output/fr/pmematest_2634_alchemy.yml
# Storing file:  output/fr/pmematest_2634_simple.yml
# Storing file:  output/fr/pmematest_2634_txtrazor.yml
# Storing file:  output/fr/pmematest_2634_basistech.yml
# Storing file:  output/fr/pmematest_3155_meaningcloud.yml
# Storing file:  output/fr/pmematest_3155_retresco.yml
# Storing file:  output/fr/pmematest_3155_netowl.yml
# Storing file:  output/fr/pmematest_3155_bitext.yml
# Storing file:  output/fr/pmematest_3155_semant.yml
# Storing file:  output/fr/pmematest_3155_alchemy.yml
# Storing file:  output/fr/pmematest_3155_simple.yml
# Storing file:  output/fr/pmematest_3155_txtrazor.yml
# Storing file:  output/fr/pmematest_3155_basistech.yml
# Storing file:  output/fr/pmematest_064_meaningcloud.yml
# Storing file:  output/fr/pmematest_064_retresco.yml
# Storing file:  output/fr/pmematest_064_netowl.yml
# Storing file:  output/fr/pmematest_064_bitext.yml
# Storing file:  output/fr/pmematest_064_semant.yml
# Storing file:  output/fr/pmematest_064_alchemy.yml
# Storing file:  output/fr/pmematest_064_simple.yml
# Storing file:  output/fr/pmematest_064_txtrazor.yml
# Storing file:  output/fr/pmematest_064_basistech.yml
# Storing file:  output/fr/pmematest_447_meaningcloud.yml
# Storing file:  output/fr/pmematest_447_retresco.yml
# Storing file:  output/fr/pmematest_447_netowl.yml
# Storing file:  output/fr/pmematest_447_bitext.yml
# Storing file:  output/fr/pmematest_447_semant.yml
# Storing file:  output/fr/pmematest_447_alchemy.yml
# Storing file:  output/fr/pmematest_447_simple.yml
# Storing file:  output/fr/pmematest_447_txtrazor.yml
# Storing file:  output/fr/pmematest_447_basistech.yml
# Storing file:  output/fr/pmematest_3357_meaningcloud.yml
# Storing file:  output/fr/pmematest_3357_retresco.yml
# Storing file:  output/fr/pmematest_3357_netowl.yml
# Storing file:  output/fr/pmematest_3357_bitext.yml
# Storing file:  output/fr/pmematest_3357_semant.yml
# Storing file:  output/fr/pmematest_3357_alchemy.yml
# Storing file:  output/fr/pmematest_3357_simple.yml
# Storing file:  output/fr/pmematest_3357_txtrazor.yml
# Storing file:  output/fr/pmematest_3357_basistech.yml
# Storing file:  output/fr/pmematest_3222_meaningcloud.yml
# Storing file:  output/fr/pmematest_3222_retresco.yml
# Storing file:  output/fr/pmematest_3222_netowl.yml
# Storing file:  output/fr/pmematest_3222_bitext.yml
# Storing file:  output/fr/pmematest_3222_semant.yml
# Storing file:  output/fr/pmematest_3222_alchemy.yml
# Storing file:  output/fr/pmematest_3222_simple.yml
# Storing file:  output/fr/pmematest_3222_txtrazor.yml
# Storing file:  output/fr/pmematest_3222_basistech.yml
# Storing file:  output/fr/pmematest_962_meaningcloud.yml
# Storing file:  output/fr/pmematest_962_retresco.yml
# Storing file:  output/fr/pmematest_962_netowl.yml
# Storing file:  output/fr/pmematest_962_bitext.yml
# Storing file:  output/fr/pmematest_962_semant.yml
# Storing file:  output/fr/pmematest_962_alchemy.yml
# Storing file:  output/fr/pmematest_962_simple.yml
# Storing file:  output/fr/pmematest_962_txtrazor.yml
# Storing file:  output/fr/pmematest_962_basistech.yml
# Storing file:  output/fr/pmematest_3183_meaningcloud.yml
# Storing file:  output/fr/pmematest_3183_retresco.yml
# Storing file:  output/fr/pmematest_3183_netowl.yml
# Storing file:  output/fr/pmematest_3183_bitext.yml
# Storing file:  output/fr/pmematest_3183_semant.yml
# Storing file:  output/fr/pmematest_3183_alchemy.yml
# Storing file:  output/fr/pmematest_3183_simple.yml
# Storing file:  output/fr/pmematest_3183_txtrazor.yml
# Storing file:  output/fr/pmematest_3183_basistech.yml
# Storing file:  output/fr/pmematest_2052_meaningcloud.yml
# Storing file:  output/fr/pmematest_2052_retresco.yml
# Storing file:  output/fr/pmematest_2052_netowl.yml
# Storing file:  output/fr/pmematest_2052_bitext.yml
# Storing file:  output/fr/pmematest_2052_semant.yml
# Storing file:  output/fr/pmematest_2052_alchemy.yml
# Storing file:  output/fr/pmematest_2052_simple.yml
# Storing file:  output/fr/pmematest_2052_txtrazor.yml
# Storing file:  output/fr/pmematest_2052_basistech.yml
# Storing file:  output/fr/pmematest_1996_meaningcloud.yml
# Storing file:  output/fr/pmematest_1996_retresco.yml
# Storing file:  output/fr/pmematest_1996_netowl.yml
# Storing file:  output/fr/pmematest_1996_bitext.yml
# Storing file:  output/fr/pmematest_1996_semant.yml
# Storing file:  output/fr/pmematest_1996_alchemy.yml
# Storing file:  output/fr/pmematest_1996_simple.yml
# Storing file:  output/fr/pmematest_1996_txtrazor.yml
# Storing file:  output/fr/pmematest_1996_basistech.yml
# Storing file:  output/fr/pmematest_3461_meaningcloud.yml
# Storing file:  output/fr/pmematest_3461_retresco.yml
# Storing file:  output/fr/pmematest_3461_netowl.yml
# Storing file:  output/fr/pmematest_3461_bitext.yml
# Storing file:  output/fr/pmematest_3461_semant.yml
# Storing file:  output/fr/pmematest_3461_alchemy.yml
# Storing file:  output/fr/pmematest_3461_simple.yml
# Storing file:  output/fr/pmematest_3461_txtrazor.yml
# Storing file:  output/fr/pmematest_3461_basistech.yml
# Storing file:  output/fr/pmematest_587_meaningcloud.yml
# Storing file:  output/fr/pmematest_587_retresco.yml
# Storing file:  output/fr/pmematest_587_netowl.yml
# Storing file:  output/fr/pmematest_587_bitext.yml
# Storing file:  output/fr/pmematest_587_semant.yml
# Storing file:  output/fr/pmematest_587_alchemy.yml
# Storing file:  output/fr/pmematest_587_simple.yml
# Storing file:  output/fr/pmematest_587_txtrazor.yml
# Storing file:  output/fr/pmematest_587_basistech.yml
# Storing file:  output/fr/pmematest_468_meaningcloud.yml
# Storing file:  output/fr/pmematest_468_retresco.yml
# Storing file:  output/fr/pmematest_468_netowl.yml
# Storing file:  output/fr/pmematest_468_bitext.yml
# Storing file:  output/fr/pmematest_468_semant.yml
# Storing file:  output/fr/pmematest_468_alchemy.yml
# Storing file:  output/fr/pmematest_468_simple.yml
# Storing file:  output/fr/pmematest_468_txtrazor.yml
# Storing file:  output/fr/pmematest_468_basistech.yml
# Storing file:  output/fr/pmematest_581_meaningcloud.yml
# Storing file:  output/fr/pmematest_581_retresco.yml
# Storing file:  output/fr/pmematest_581_netowl.yml
# Storing file:  output/fr/pmematest_581_bitext.yml
# Storing file:  output/fr/pmematest_581_semant.yml
# Storing file:  output/fr/pmematest_581_alchemy.yml
# Storing file:  output/fr/pmematest_581_simple.yml
# Storing file:  output/fr/pmematest_581_txtrazor.yml
# Storing file:  output/fr/pmematest_581_basistech.yml
# Storing file:  output/fr/pmematest_1666_meaningcloud.yml
# Storing file:  output/fr/pmematest_1666_retresco.yml
# Storing file:  output/fr/pmematest_1666_netowl.yml
# Storing file:  output/fr/pmematest_1666_bitext.yml
# Storing file:  output/fr/pmematest_1666_semant.yml
# Storing file:  output/fr/pmematest_1666_alchemy.yml
# Storing file:  output/fr/pmematest_1666_simple.yml
# Storing file:  output/fr/pmematest_1666_txtrazor.yml
# Storing file:  output/fr/pmematest_1666_basistech.yml
# Storing file:  output/fr/pmematest_1699_meaningcloud.yml
# Storing file:  output/fr/pmematest_1699_retresco.yml
# Storing file:  output/fr/pmematest_1699_netowl.yml
# Storing file:  output/fr/pmematest_1699_bitext.yml
# Storing file:  output/fr/pmematest_1699_semant.yml
# Storing file:  output/fr/pmematest_1699_alchemy.yml
# Storing file:  output/fr/pmematest_1699_simple.yml
# Storing file:  output/fr/pmematest_1699_txtrazor.yml
# Storing file:  output/fr/pmematest_1699_basistech.yml
# Storing file:  output/fr/pmematest_1084_meaningcloud.yml
# Storing file:  output/fr/pmematest_1084_retresco.yml
# Storing file:  output/fr/pmematest_1084_netowl.yml
# Storing file:  output/fr/pmematest_1084_bitext.yml
# Storing file:  output/fr/pmematest_1084_semant.yml
# Storing file:  output/fr/pmematest_1084_alchemy.yml
# Storing file:  output/fr/pmematest_1084_simple.yml
# Storing file:  output/fr/pmematest_1084_txtrazor.yml
# Storing file:  output/fr/pmematest_1084_basistech.yml
# Storing file:  output/fr/pmematest_1469_meaningcloud.yml
# Storing file:  output/fr/pmematest_1469_retresco.yml
# Storing file:  output/fr/pmematest_1469_netowl.yml
# Storing file:  output/fr/pmematest_1469_bitext.yml
# Storing file:  output/fr/pmematest_1469_semant.yml
# Storing file:  output/fr/pmematest_1469_alchemy.yml
# Storing file:  output/fr/pmematest_1469_simple.yml
# Storing file:  output/fr/pmematest_1469_txtrazor.yml
# Storing file:  output/fr/pmematest_1469_basistech.yml
# Storing file:  output/fr/pmematest_697_meaningcloud.yml
# Storing file:  output/fr/pmematest_697_retresco.yml
# Storing file:  output/fr/pmematest_697_netowl.yml
# Storing file:  output/fr/pmematest_697_bitext.yml
# Storing file:  output/fr/pmematest_697_semant.yml
# Storing file:  output/fr/pmematest_697_alchemy.yml
# Storing file:  output/fr/pmematest_697_simple.yml
# Storing file:  output/fr/pmematest_697_txtrazor.yml
# Storing file:  output/fr/pmematest_697_basistech.yml
# Storing file:  output/fr/pmematest_1589_meaningcloud.yml
# Storing file:  output/fr/pmematest_1589_retresco.yml
# Storing file:  output/fr/pmematest_1589_netowl.yml
# Storing file:  output/fr/pmematest_1589_bitext.yml
# Storing file:  output/fr/pmematest_1589_semant.yml
# Storing file:  output/fr/pmematest_1589_alchemy.yml
# Storing file:  output/fr/pmematest_1589_simple.yml
# Storing file:  output/fr/pmematest_1589_txtrazor.yml
# Storing file:  output/fr/pmematest_1589_basistech.yml
# Storing file:  output/fr/pmematest_3219_meaningcloud.yml
# Storing file:  output/fr/pmematest_3219_retresco.yml
# Storing file:  output/fr/pmematest_3219_netowl.yml
# Storing file:  output/fr/pmematest_3219_bitext.yml
# Storing file:  output/fr/pmematest_3219_semant.yml
# Storing file:  output/fr/pmematest_3219_alchemy.yml
# Storing file:  output/fr/pmematest_3219_simple.yml
# Storing file:  output/fr/pmematest_3219_txtrazor.yml
# Storing file:  output/fr/pmematest_3219_basistech.yml
# Storing file:  output/fr/pmematest_2805_meaningcloud.yml
# Storing file:  output/fr/pmematest_2805_retresco.yml
# Storing file:  output/fr/pmematest_2805_netowl.yml
# Storing file:  output/fr/pmematest_2805_bitext.yml
# Storing file:  output/fr/pmematest_2805_semant.yml
# Storing file:  output/fr/pmematest_2805_alchemy.yml
# Storing file:  output/fr/pmematest_2805_simple.yml
# Storing file:  output/fr/pmematest_2805_txtrazor.yml
# Storing file:  output/fr/pmematest_2805_basistech.yml
# Storing file:  output/fr/pmematest_201_meaningcloud.yml
# Storing file:  output/fr/pmematest_201_retresco.yml
# Storing file:  output/fr/pmematest_201_netowl.yml
# Storing file:  output/fr/pmematest_201_bitext.yml
# Storing file:  output/fr/pmematest_201_semant.yml
# Storing file:  output/fr/pmematest_201_alchemy.yml
# Storing file:  output/fr/pmematest_201_simple.yml
# Storing file:  output/fr/pmematest_201_txtrazor.yml
# Storing file:  output/fr/pmematest_201_basistech.yml
# Storing file:  output/fr/pmematest_2603_meaningcloud.yml
# Storing file:  output/fr/pmematest_2603_retresco.yml
# Storing file:  output/fr/pmematest_2603_netowl.yml
# Storing file:  output/fr/pmematest_2603_bitext.yml
# Storing file:  output/fr/pmematest_2603_semant.yml
# Storing file:  output/fr/pmematest_2603_alchemy.yml
# Storing file:  output/fr/pmematest_2603_simple.yml
# Storing file:  output/fr/pmematest_2603_txtrazor.yml
# Storing file:  output/fr/pmematest_2603_basistech.yml
# Storing file:  output/fr/pmematest_3175_meaningcloud.yml
# Storing file:  output/fr/pmematest_3175_retresco.yml
# Storing file:  output/fr/pmematest_3175_netowl.yml
# Storing file:  output/fr/pmematest_3175_bitext.yml
# Storing file:  output/fr/pmematest_3175_semant.yml
# Storing file:  output/fr/pmematest_3175_alchemy.yml
# Storing file:  output/fr/pmematest_3175_simple.yml
# Storing file:  output/fr/pmematest_3175_txtrazor.yml
# Storing file:  output/fr/pmematest_3175_basistech.yml
# Storing file:  output/fr/pmematest_400_meaningcloud.yml
# Storing file:  output/fr/pmematest_400_retresco.yml
# Storing file:  output/fr/pmematest_400_netowl.yml
# Storing file:  output/fr/pmematest_400_bitext.yml
# Storing file:  output/fr/pmematest_400_semant.yml
# Storing file:  output/fr/pmematest_400_alchemy.yml
# Storing file:  output/fr/pmematest_400_simple.yml
# Storing file:  output/fr/pmematest_400_txtrazor.yml
# Storing file:  output/fr/pmematest_400_basistech.yml
# Storing file:  output/fr/pmematest_2255_meaningcloud.yml
# Storing file:  output/fr/pmematest_2255_retresco.yml
# Storing file:  output/fr/pmematest_2255_netowl.yml
# Storing file:  output/fr/pmematest_2255_bitext.yml
# Storing file:  output/fr/pmematest_2255_semant.yml
# Storing file:  output/fr/pmematest_2255_alchemy.yml
# Storing file:  output/fr/pmematest_2255_simple.yml
# Storing file:  output/fr/pmematest_2255_txtrazor.yml
# Storing file:  output/fr/pmematest_2255_basistech.yml
# Storing file:  output/fr/pmematest_673_meaningcloud.yml
# Storing file:  output/fr/pmematest_673_retresco.yml
# Storing file:  output/fr/pmematest_673_netowl.yml
# Storing file:  output/fr/pmematest_673_bitext.yml
# Storing file:  output/fr/pmematest_673_semant.yml
# Storing file:  output/fr/pmematest_673_alchemy.yml
# Storing file:  output/fr/pmematest_673_simple.yml
# Storing file:  output/fr/pmematest_673_txtrazor.yml
# Storing file:  output/fr/pmematest_673_basistech.yml
# Storing file:  output/fr/pmematest_2586_meaningcloud.yml
# Storing file:  output/fr/pmematest_2586_retresco.yml
# Storing file:  output/fr/pmematest_2586_netowl.yml
# Storing file:  output/fr/pmematest_2586_bitext.yml
# Storing file:  output/fr/pmematest_2586_semant.yml
# Storing file:  output/fr/pmematest_2586_alchemy.yml
# Storing file:  output/fr/pmematest_2586_simple.yml
# Storing file:  output/fr/pmematest_2586_txtrazor.yml
# Storing file:  output/fr/pmematest_2586_basistech.yml
# Storing file:  output/fr/pmematest_401_meaningcloud.yml
# Storing file:  output/fr/pmematest_401_retresco.yml
# Storing file:  output/fr/pmematest_401_netowl.yml
# Storing file:  output/fr/pmematest_401_bitext.yml
# Storing file:  output/fr/pmematest_401_semant.yml
# Storing file:  output/fr/pmematest_401_alchemy.yml
# Storing file:  output/fr/pmematest_401_simple.yml
# Storing file:  output/fr/pmematest_401_txtrazor.yml
# Storing file:  output/fr/pmematest_401_basistech.yml
# Storing file:  output/fr/pmematest_040_meaningcloud.yml
# Storing file:  output/fr/pmematest_040_retresco.yml
# Storing file:  output/fr/pmematest_040_netowl.yml
# Storing file:  output/fr/pmematest_040_bitext.yml
# Storing file:  output/fr/pmematest_040_semant.yml
# Storing file:  output/fr/pmematest_040_alchemy.yml
# Storing file:  output/fr/pmematest_040_simple.yml
# Storing file:  output/fr/pmematest_040_txtrazor.yml
# Storing file:  output/fr/pmematest_040_basistech.yml
# Storing file:  output/fr/pmematest_1587_meaningcloud.yml
# Storing file:  output/fr/pmematest_1587_retresco.yml
# Storing file:  output/fr/pmematest_1587_netowl.yml
# Storing file:  output/fr/pmematest_1587_bitext.yml
# Storing file:  output/fr/pmematest_1587_semant.yml
# Storing file:  output/fr/pmematest_1587_alchemy.yml
# Storing file:  output/fr/pmematest_1587_simple.yml
# Storing file:  output/fr/pmematest_1587_txtrazor.yml
# Storing file:  output/fr/pmematest_1587_basistech.yml
# Storing file:  output/fr/pmematest_2379_meaningcloud.yml
# Storing file:  output/fr/pmematest_2379_retresco.yml
# Storing file:  output/fr/pmematest_2379_netowl.yml
# Storing file:  output/fr/pmematest_2379_bitext.yml
# Storing file:  output/fr/pmematest_2379_semant.yml
# Storing file:  output/fr/pmematest_2379_alchemy.yml
# Storing file:  output/fr/pmematest_2379_simple.yml
# Storing file:  output/fr/pmematest_2379_txtrazor.yml
# Storing file:  output/fr/pmematest_2379_basistech.yml

# %%
import semaeval.statistics as stats

# %%
data=stats.collect_data(articles_enriched)
# Out:
# meaningcloud pmematest_2259.yml float division by zero
# meaningcloud pmematest_2259.yml float division by zero
# meaningcloud pmematest_2259.yml float division by zero
# retresco pmematest_2259.yml float division by zero
# retresco pmematest_2259.yml float division by zero
# retresco pmematest_2259.yml float division by zero
# netowl pmematest_2259.yml float division by zero
# netowl pmematest_2259.yml float division by zero
# bitext pmematest_2259.yml float division by zero
# bitext pmematest_2259.yml float division by zero
# semant pmematest_2259.yml float division by zero
# semant pmematest_2259.yml float division by zero
# alchemy pmematest_2259.yml float division by zero
# alchemy pmematest_2259.yml float division by zero
# simple pmematest_2259.yml float division by zero
# simple pmematest_2259.yml float division by zero
# txtrazor pmematest_2259.yml float division by zero
# txtrazor pmematest_2259.yml float division by zero
# basistech pmematest_2259.yml float division by zero
# basistech pmematest_2259.yml float division by zero
# meaningcloud pmematest_552.yml float division by zero
# retresco pmematest_552.yml float division by zero
# retresco pmematest_552.yml float division by zero
# netowl pmematest_552.yml float division by zero
# bitext pmematest_552.yml float division by zero
# bitext pmematest_552.yml float division by zero
# semant pmematest_552.yml float division by zero
# semant pmematest_552.yml float division by zero
# alchemy pmematest_552.yml float division by zero
# simple pmematest_552.yml float division by zero
# simple pmematest_552.yml float division by zero
# simple pmematest_552.yml float division by zero
# txtrazor pmematest_552.yml float division by zero
# txtrazor pmematest_552.yml float division by zero
# txtrazor pmematest_552.yml float division by zero
# basistech pmematest_552.yml float division by zero
# meaningcloud pmematest_149.yml float division by zero
# meaningcloud pmematest_149.yml float division by zero
# retresco pmematest_149.yml float division by zero
# retresco pmematest_149.yml float division by zero
# retresco pmematest_149.yml float division by zero
# netowl pmematest_149.yml float division by zero
# netowl pmematest_149.yml float division by zero
# bitext pmematest_149.yml float division by zero
# bitext pmematest_149.yml float division by zero
# semant pmematest_149.yml float division by zero
# semant pmematest_149.yml float division by zero
# alchemy pmematest_149.yml float division by zero
# alchemy pmematest_149.yml float division by zero
# simple pmematest_149.yml float division by zero
# txtrazor pmematest_149.yml float division by zero
# basistech pmematest_149.yml float division by zero
# basistech pmematest_149.yml float division by zero
# meaningcloud pmematest_3516.yml float division by zero
# meaningcloud pmematest_3516.yml float division by zero
# retresco pmematest_3516.yml float division by zero
# retresco pmematest_3516.yml float division by zero
# netowl pmematest_3516.yml float division by zero
# bitext pmematest_3516.yml float division by zero
# bitext pmematest_3516.yml float division by zero
# semant pmematest_3516.yml float division by zero
# semant pmematest_3516.yml float division by zero
# alchemy pmematest_3516.yml float division by zero
# alchemy pmematest_3516.yml float division by zero
# simple pmematest_3516.yml float division by zero
# txtrazor pmematest_3516.yml float division by zero
# txtrazor pmematest_3516.yml float division by zero
# basistech pmematest_3516.yml float division by zero
# basistech pmematest_3516.yml float division by zero
# meaningcloud pmematest_1737.yml float division by zero
# meaningcloud pmematest_1737.yml float division by zero
# retresco pmematest_1737.yml float division by zero
# netowl pmematest_1737.yml float division by zero
# bitext pmematest_1737.yml float division by zero
# semant pmematest_1737.yml float division by zero
# alchemy pmematest_1737.yml float division by zero
# alchemy pmematest_1737.yml float division by zero
# simple pmematest_1737.yml float division by zero
# simple pmematest_1737.yml float division by zero
# simple pmematest_1737.yml float division by zero
# basistech pmematest_1737.yml float division by zero
# meaningcloud pmematest_2829.yml float division by zero
# meaningcloud pmematest_2829.yml float division by zero
# meaningcloud pmematest_2829.yml float division by zero
# retresco pmematest_2829.yml float division by zero
# retresco pmematest_2829.yml float division by zero
# netowl pmematest_2829.yml float division by zero
# netowl pmematest_2829.yml float division by zero
# bitext pmematest_2829.yml float division by zero
# bitext pmematest_2829.yml float division by zero
# semant pmematest_2829.yml float division by zero
# semant pmematest_2829.yml float division by zero
# semant pmematest_2829.yml float division by zero
# alchemy pmematest_2829.yml float division by zero
# txtrazor pmematest_2829.yml float division by zero
# txtrazor pmematest_2829.yml float division by zero
# meaningcloud pmematest_2989.yml float division by zero
# meaningcloud pmematest_2989.yml float division by zero
# meaningcloud pmematest_2989.yml float division by zero
# retresco pmematest_2989.yml float division by zero
# retresco pmematest_2989.yml float division by zero
# retresco pmematest_2989.yml float division by zero
# netowl pmematest_2989.yml float division by zero
# netowl pmematest_2989.yml float division by zero
# netowl pmematest_2989.yml float division by zero
# bitext pmematest_2989.yml float division by zero
# bitext pmematest_2989.yml float division by zero
# bitext pmematest_2989.yml float division by zero
# semant pmematest_2989.yml float division by zero
# semant pmematest_2989.yml float division by zero
# semant pmematest_2989.yml float division by zero
# alchemy pmematest_2989.yml float division by zero
# alchemy pmematest_2989.yml float division by zero
# alchemy pmematest_2989.yml float division by zero
# simple pmematest_2989.yml float division by zero
# simple pmematest_2989.yml float division by zero
# simple pmematest_2989.yml float division by zero
# txtrazor pmematest_2989.yml float division by zero
# txtrazor pmematest_2989.yml float division by zero
# txtrazor pmematest_2989.yml float division by zero
# basistech pmematest_2989.yml float division by zero
# basistech pmematest_2989.yml float division by zero
# basistech pmematest_2989.yml float division by zero
# meaningcloud pmematest_016.yml float division by zero
# retresco pmematest_016.yml float division by zero
# retresco pmematest_016.yml float division by zero
# retresco pmematest_016.yml float division by zero
# bitext pmematest_016.yml float division by zero
# bitext pmematest_016.yml float division by zero
# semant pmematest_016.yml float division by zero
# alchemy pmematest_016.yml float division by zero
# alchemy pmematest_016.yml float division by zero
# alchemy pmematest_016.yml float division by zero
# basistech pmematest_016.yml float division by zero
# meaningcloud pmematest_1773.yml float division by zero
# meaningcloud pmematest_1773.yml float division by zero
# meaningcloud pmematest_1773.yml float division by zero
# retresco pmematest_1773.yml float division by zero
# retresco pmematest_1773.yml float division by zero
# netowl pmematest_1773.yml float division by zero
# netowl pmematest_1773.yml float division by zero
# bitext pmematest_1773.yml float division by zero
# bitext pmematest_1773.yml float division by zero
# semant pmematest_1773.yml float division by zero
# semant pmematest_1773.yml float division by zero
# semant pmematest_1773.yml float division by zero
# alchemy pmematest_1773.yml float division by zero
# alchemy pmematest_1773.yml float division by zero
# simple pmematest_1773.yml float division by zero
# txtrazor pmematest_1773.yml float division by zero
# txtrazor pmematest_1773.yml float division by zero
# basistech pmematest_1773.yml float division by zero
# bitext pmematest_511.yml float division by zero
# semant pmematest_511.yml float division by zero
# alchemy pmematest_511.yml float division by zero
# simple pmematest_511.yml float division by zero
# semant pmematest_3073.yml float division by zero
# semant pmematest_3073.yml float division by zero
# meaningcloud pmematest_2470.yml float division by zero
# meaningcloud pmematest_2470.yml float division by zero
# retresco pmematest_2470.yml float division by zero
# retresco pmematest_2470.yml float division by zero
# netowl pmematest_2470.yml float division by zero
# bitext pmematest_2470.yml float division by zero
# bitext pmematest_2470.yml float division by zero
# semant pmematest_2470.yml float division by zero
# semant pmematest_2470.yml float division by zero
# alchemy pmematest_2470.yml float division by zero
# alchemy pmematest_2470.yml float division by zero
# simple pmematest_2470.yml float division by zero
# simple pmematest_2470.yml float division by zero
# txtrazor pmematest_2470.yml float division by zero
# txtrazor pmematest_2470.yml float division by zero
# basistech pmematest_2470.yml float division by zero
# basistech pmematest_2470.yml float division by zero
# meaningcloud pmematest_2679.yml float division by zero
# retresco pmematest_2679.yml float division by zero
# bitext pmematest_2679.yml float division by zero
# bitext pmematest_2679.yml float division by zero
# semant pmematest_2679.yml float division by zero
# meaningcloud pmematest_3309.yml float division by zero
# meaningcloud pmematest_3309.yml float division by zero
# retresco pmematest_3309.yml float division by zero
# retresco pmematest_3309.yml float division by zero
# retresco pmematest_3309.yml float division by zero
# netowl pmematest_3309.yml float division by zero
# bitext pmematest_3309.yml float division by zero
# alchemy pmematest_3309.yml float division by zero
# alchemy pmematest_3309.yml float division by zero
# simple pmematest_3309.yml float division by zero
# simple pmematest_3309.yml float division by zero
# retresco pmematest_1353.yml float division by zero
# semant pmematest_1353.yml float division by zero
# meaningcloud pmematest_671.yml float division by zero
# retresco pmematest_671.yml float division by zero
# retresco pmematest_671.yml float division by zero
# netowl pmematest_671.yml float division by zero
# bitext pmematest_671.yml float division by zero
# semant pmematest_671.yml float division by zero
# semant pmematest_671.yml float division by zero
# alchemy pmematest_671.yml float division by zero
# simple pmematest_671.yml float division by zero
# txtrazor pmematest_671.yml float division by zero
# txtrazor pmematest_671.yml float division by zero
# basistech pmematest_671.yml float division by zero
# meaningcloud pmematest_2178.yml float division by zero
# meaningcloud pmematest_2178.yml float division by zero
# meaningcloud pmematest_2178.yml float division by zero
# retresco pmematest_2178.yml float division by zero
# retresco pmematest_2178.yml float division by zero
# netowl pmematest_2178.yml float division by zero
# netowl pmematest_2178.yml float division by zero
# bitext pmematest_2178.yml float division by zero
# bitext pmematest_2178.yml float division by zero
# semant pmematest_2178.yml float division by zero
# semant pmematest_2178.yml float division by zero
# alchemy pmematest_2178.yml float division by zero
# alchemy pmematest_2178.yml float division by zero
# simple pmematest_2178.yml float division by zero
# simple pmematest_2178.yml float division by zero
# txtrazor pmematest_2178.yml float division by zero
# txtrazor pmematest_2178.yml float division by zero
# txtrazor pmematest_2178.yml float division by zero
# basistech pmematest_2178.yml float division by zero
# basistech pmematest_2178.yml float division by zero
# retresco pmematest_2634.yml float division by zero
# semant pmematest_2634.yml float division by zero
# meaningcloud pmematest_3155.yml float division by zero
# meaningcloud pmematest_3155.yml float division by zero
# meaningcloud pmematest_3155.yml float division by zero
# bitext pmematest_3155.yml float division by zero
# semant pmematest_3155.yml float division by zero
# alchemy pmematest_3155.yml float division by zero
# alchemy pmematest_3155.yml float division by zero
# meaningcloud pmematest_064.yml float division by zero
# meaningcloud pmematest_064.yml float division by zero
# meaningcloud pmematest_064.yml float division by zero
# retresco pmematest_064.yml float division by zero
# retresco pmematest_064.yml float division by zero
# retresco pmematest_064.yml float division by zero
# netowl pmematest_064.yml float division by zero
# netowl pmematest_064.yml float division by zero
# netowl pmematest_064.yml float division by zero
# bitext pmematest_064.yml float division by zero
# bitext pmematest_064.yml float division by zero
# bitext pmematest_064.yml float division by zero
# semant pmematest_064.yml float division by zero
# semant pmematest_064.yml float division by zero
# semant pmematest_064.yml float division by zero
# alchemy pmematest_064.yml float division by zero
# alchemy pmematest_064.yml float division by zero
# alchemy pmematest_064.yml float division by zero
# simple pmematest_064.yml float division by zero
# simple pmematest_064.yml float division by zero
# simple pmematest_064.yml float division by zero
# txtrazor pmematest_064.yml float division by zero
# txtrazor pmematest_064.yml float division by zero
# txtrazor pmematest_064.yml float division by zero
# basistech pmematest_064.yml float division by zero
# basistech pmematest_064.yml float division by zero
# basistech pmematest_064.yml float division by zero
# meaningcloud pmematest_447.yml float division by zero
# meaningcloud pmematest_447.yml float division by zero
# retresco pmematest_447.yml float division by zero
# retresco pmematest_447.yml float division by zero
# retresco pmematest_447.yml float division by zero
# netowl pmematest_447.yml float division by zero
# bitext pmematest_447.yml float division by zero
# bitext pmematest_447.yml float division by zero
# semant pmematest_447.yml float division by zero
# semant pmematest_447.yml float division by zero
# alchemy pmematest_447.yml float division by zero
# simple pmematest_447.yml float division by zero
# simple pmematest_447.yml float division by zero
# simple pmematest_447.yml float division by zero
# txtrazor pmematest_447.yml float division by zero
# basistech pmematest_447.yml float division by zero
# meaningcloud pmematest_3357.yml float division by zero
# meaningcloud pmematest_3357.yml float division by zero
# retresco pmematest_3357.yml float division by zero
# bitext pmematest_3357.yml float division by zero
# semant pmematest_3357.yml float division by zero
# alchemy pmematest_3357.yml float division by zero
# alchemy pmematest_3357.yml float division by zero
# simple pmematest_3357.yml float division by zero
# simple pmematest_3357.yml float division by zero
# meaningcloud pmematest_3222.yml float division by zero
# meaningcloud pmematest_3222.yml float division by zero
# retresco pmematest_3222.yml float division by zero
# retresco pmematest_3222.yml float division by zero
# netowl pmematest_3222.yml float division by zero
# bitext pmematest_3222.yml float division by zero
# bitext pmematest_3222.yml float division by zero
# semant pmematest_3222.yml float division by zero
# semant pmematest_3222.yml float division by zero
# alchemy pmematest_3222.yml float division by zero
# alchemy pmematest_3222.yml float division by zero
# simple pmematest_3222.yml float division by zero
# txtrazor pmematest_3222.yml float division by zero
# meaningcloud pmematest_962.yml float division by zero
# meaningcloud pmematest_962.yml float division by zero
# retresco pmematest_962.yml float division by zero
# netowl pmematest_962.yml float division by zero
# netowl pmematest_962.yml float division by zero
# netowl pmematest_962.yml float division by zero
# bitext pmematest_962.yml float division by zero
# bitext pmematest_962.yml float division by zero
# semant pmematest_962.yml float division by zero
# semant pmematest_962.yml float division by zero
# alchemy pmematest_962.yml float division by zero
# alchemy pmematest_962.yml float division by zero
# simple pmematest_962.yml float division by zero
# txtrazor pmematest_962.yml float division by zero
# basistech pmematest_962.yml float division by zero
# meaningcloud pmematest_3183.yml float division by zero
# meaningcloud pmematest_3183.yml float division by zero
# retresco pmematest_3183.yml float division by zero
# retresco pmematest_3183.yml float division by zero
# netowl pmematest_3183.yml float division by zero
# bitext pmematest_3183.yml float division by zero
# bitext pmematest_3183.yml float division by zero
# semant pmematest_3183.yml float division by zero
# semant pmematest_3183.yml float division by zero
# alchemy pmematest_3183.yml float division by zero
# basistech pmematest_3183.yml float division by zero
# meaningcloud pmematest_2052.yml float division by zero
# meaningcloud pmematest_2052.yml float division by zero
# retresco pmematest_2052.yml float division by zero
# retresco pmematest_2052.yml float division by zero
# netowl pmematest_2052.yml float division by zero
# netowl pmematest_2052.yml float division by zero
# bitext pmematest_2052.yml float division by zero
# bitext pmematest_2052.yml float division by zero
# bitext pmematest_2052.yml float division by zero
# semant pmematest_2052.yml float division by zero
# semant pmematest_2052.yml float division by zero
# alchemy pmematest_2052.yml float division by zero
# alchemy pmematest_2052.yml float division by zero
# simple pmematest_2052.yml float division by zero
# simple pmematest_2052.yml float division by zero
# txtrazor pmematest_2052.yml float division by zero
# txtrazor pmematest_2052.yml float division by zero
# basistech pmematest_2052.yml float division by zero
# basistech pmematest_2052.yml float division by zero
# meaningcloud pmematest_1996.yml float division by zero
# meaningcloud pmematest_1996.yml float division by zero
# retresco pmematest_1996.yml float division by zero
# retresco pmematest_1996.yml float division by zero
# retresco pmematest_1996.yml float division by zero
# netowl pmematest_1996.yml float division by zero
# netowl pmematest_1996.yml float division by zero
# bitext pmematest_1996.yml float division by zero
# bitext pmematest_1996.yml float division by zero
# bitext pmematest_1996.yml float division by zero
# semant pmematest_1996.yml float division by zero
# semant pmematest_1996.yml float division by zero
# alchemy pmematest_1996.yml float division by zero
# alchemy pmematest_1996.yml float division by zero
# alchemy pmematest_1996.yml float division by zero
# simple pmematest_1996.yml float division by zero
# simple pmematest_1996.yml float division by zero
# simple pmematest_1996.yml float division by zero
# txtrazor pmematest_1996.yml float division by zero
# txtrazor pmematest_1996.yml float division by zero
# basistech pmematest_1996.yml float division by zero
# basistech pmematest_1996.yml float division by zero
# meaningcloud pmematest_3461.yml float division by zero
# bitext pmematest_3461.yml float division by zero
# semant pmematest_3461.yml float division by zero
# meaningcloud pmematest_587.yml float division by zero
# meaningcloud pmematest_587.yml float division by zero
# meaningcloud pmematest_587.yml float division by zero
# retresco pmematest_587.yml float division by zero
# retresco pmematest_587.yml float division by zero
# retresco pmematest_587.yml float division by zero
# netowl pmematest_587.yml float division by zero
# netowl pmematest_587.yml float division by zero
# netowl pmematest_587.yml float division by zero
# bitext pmematest_587.yml float division by zero
# bitext pmematest_587.yml float division by zero
# semant pmematest_587.yml float division by zero
# semant pmematest_587.yml float division by zero
# alchemy pmematest_587.yml float division by zero
# alchemy pmematest_587.yml float division by zero
# alchemy pmematest_587.yml float division by zero
# simple pmematest_587.yml float division by zero
# simple pmematest_587.yml float division by zero
# txtrazor pmematest_587.yml float division by zero
# txtrazor pmematest_587.yml float division by zero
# txtrazor pmematest_587.yml float division by zero
# basistech pmematest_587.yml float division by zero
# basistech pmematest_587.yml float division by zero
# meaningcloud pmematest_468.yml float division by zero
# retresco pmematest_468.yml float division by zero
# netowl pmematest_468.yml float division by zero
# bitext pmematest_468.yml float division by zero
# semant pmematest_468.yml float division by zero
# alchemy pmematest_468.yml float division by zero
# alchemy pmematest_468.yml float division by zero
# simple pmematest_468.yml float division by zero
# simple pmematest_468.yml float division by zero
# meaningcloud pmematest_581.yml float division by zero
# meaningcloud pmematest_581.yml float division by zero
# meaningcloud pmematest_581.yml float division by zero
# retresco pmematest_581.yml float division by zero
# retresco pmematest_581.yml float division by zero
# netowl pmematest_581.yml float division by zero
# netowl pmematest_581.yml float division by zero
# bitext pmematest_581.yml float division by zero
# bitext pmematest_581.yml float division by zero
# semant pmematest_581.yml float division by zero
# semant pmematest_581.yml float division by zero
# alchemy pmematest_581.yml float division by zero
# alchemy pmematest_581.yml float division by zero
# simple pmematest_581.yml float division by zero
# simple pmematest_581.yml float division by zero
# txtrazor pmematest_581.yml float division by zero
# txtrazor pmematest_581.yml float division by zero
# basistech pmematest_581.yml float division by zero
# basistech pmematest_581.yml float division by zero
# meaningcloud pmematest_1666.yml float division by zero
# meaningcloud pmematest_1666.yml float division by zero
# retresco pmematest_1666.yml float division by zero
# netowl pmematest_1666.yml float division by zero
# netowl pmematest_1666.yml float division by zero
# bitext pmematest_1666.yml float division by zero
# bitext pmematest_1666.yml float division by zero
# semant pmematest_1666.yml float division by zero
# alchemy pmematest_1666.yml float division by zero
# alchemy pmematest_1666.yml float division by zero
# simple pmematest_1666.yml float division by zero
# txtrazor pmematest_1666.yml float division by zero
# txtrazor pmematest_1666.yml float division by zero
# basistech pmematest_1666.yml float division by zero
# basistech pmematest_1666.yml float division by zero
# meaningcloud pmematest_1699.yml float division by zero
# retresco pmematest_1699.yml float division by zero
# retresco pmematest_1699.yml float division by zero
# netowl pmematest_1699.yml float division by zero
# bitext pmematest_1699.yml float division by zero
# semant pmematest_1699.yml float division by zero
# alchemy pmematest_1699.yml float division by zero
# simple pmematest_1699.yml float division by zero
# simple pmematest_1699.yml float division by zero
# txtrazor pmematest_1699.yml float division by zero
# basistech pmematest_1699.yml float division by zero
# meaningcloud pmematest_1084.yml float division by zero
# meaningcloud pmematest_1084.yml float division by zero
# meaningcloud pmematest_1084.yml float division by zero
# retresco pmematest_1084.yml float division by zero
# retresco pmematest_1084.yml float division by zero
# retresco pmematest_1084.yml float division by zero
# netowl pmematest_1084.yml float division by zero
# netowl pmematest_1084.yml float division by zero
# bitext pmematest_1084.yml float division by zero
# bitext pmematest_1084.yml float division by zero
# semant pmematest_1084.yml float division by zero
# semant pmematest_1084.yml float division by zero
# alchemy pmematest_1084.yml float division by zero
# alchemy pmematest_1084.yml float division by zero
# alchemy pmematest_1084.yml float division by zero
# simple pmematest_1084.yml float division by zero
# simple pmematest_1084.yml float division by zero
# txtrazor pmematest_1084.yml float division by zero
# txtrazor pmematest_1084.yml float division by zero
# txtrazor pmematest_1084.yml float division by zero
# basistech pmematest_1084.yml float division by zero
# meaningcloud pmematest_1469.yml float division by zero
# meaningcloud pmematest_1469.yml float division by zero
# meaningcloud pmematest_1469.yml float division by zero
# retresco pmematest_1469.yml float division by zero
# retresco pmematest_1469.yml float division by zero
# retresco pmematest_1469.yml float division by zero
# netowl pmematest_1469.yml float division by zero
# netowl pmematest_1469.yml float division by zero
# netowl pmematest_1469.yml float division by zero
# bitext pmematest_1469.yml float division by zero
# bitext pmematest_1469.yml float division by zero
# bitext pmematest_1469.yml float division by zero
# semant pmematest_1469.yml float division by zero
# semant pmematest_1469.yml float division by zero
# semant pmematest_1469.yml float division by zero
# alchemy pmematest_1469.yml float division by zero
# alchemy pmematest_1469.yml float division by zero
# alchemy pmematest_1469.yml float division by zero
# simple pmematest_1469.yml float division by zero
# simple pmematest_1469.yml float division by zero
# simple pmematest_1469.yml float division by zero
# txtrazor pmematest_1469.yml float division by zero
# txtrazor pmematest_1469.yml float division by zero
# txtrazor pmematest_1469.yml float division by zero
# basistech pmematest_1469.yml float division by zero
# basistech pmematest_1469.yml float division by zero
# basistech pmematest_1469.yml float division by zero
# meaningcloud pmematest_697.yml float division by zero
# meaningcloud pmematest_697.yml float division by zero
# meaningcloud pmematest_697.yml float division by zero
# retresco pmematest_697.yml float division by zero
# retresco pmematest_697.yml float division by zero
# retresco pmematest_697.yml float division by zero
# netowl pmematest_697.yml float division by zero
# netowl pmematest_697.yml float division by zero
# netowl pmematest_697.yml float division by zero
# bitext pmematest_697.yml float division by zero
# bitext pmematest_697.yml float division by zero
# bitext pmematest_697.yml float division by zero
# semant pmematest_697.yml float division by zero
# semant pmematest_697.yml float division by zero
# semant pmematest_697.yml float division by zero
# alchemy pmematest_697.yml float division by zero
# alchemy pmematest_697.yml float division by zero
# alchemy pmematest_697.yml float division by zero
# simple pmematest_697.yml float division by zero
# simple pmematest_697.yml float division by zero
# simple pmematest_697.yml float division by zero
# txtrazor pmematest_697.yml float division by zero
# txtrazor pmematest_697.yml float division by zero
# txtrazor pmematest_697.yml float division by zero
# basistech pmematest_697.yml float division by zero
# basistech pmematest_697.yml float division by zero
# basistech pmematest_697.yml float division by zero
# meaningcloud pmematest_1589.yml float division by zero
# meaningcloud pmematest_1589.yml float division by zero
# meaningcloud pmematest_1589.yml float division by zero
# retresco pmematest_1589.yml float division by zero
# retresco pmematest_1589.yml float division by zero
# netowl pmematest_1589.yml float division by zero
# netowl pmematest_1589.yml float division by zero
# bitext pmematest_1589.yml float division by zero
# bitext pmematest_1589.yml float division by zero
# bitext pmematest_1589.yml float division by zero
# semant pmematest_1589.yml float division by zero
# semant pmematest_1589.yml float division by zero
# semant pmematest_1589.yml float division by zero
# alchemy pmematest_1589.yml float division by zero
# alchemy pmematest_1589.yml float division by zero
# alchemy pmematest_1589.yml float division by zero
# simple pmematest_1589.yml float division by zero
# simple pmematest_1589.yml float division by zero
# txtrazor pmematest_1589.yml float division by zero
# txtrazor pmematest_1589.yml float division by zero
# basistech pmematest_1589.yml float division by zero
# basistech pmematest_1589.yml float division by zero
# meaningcloud pmematest_3219.yml float division by zero
# retresco pmematest_3219.yml float division by zero
# bitext pmematest_3219.yml float division by zero
# semant pmematest_3219.yml float division by zero
# alchemy pmematest_3219.yml float division by zero
# alchemy pmematest_3219.yml float division by zero
# simple pmematest_3219.yml float division by zero
# simple pmematest_3219.yml float division by zero
# txtrazor pmematest_3219.yml float division by zero
# meaningcloud pmematest_2805.yml float division by zero
# retresco pmematest_2805.yml float division by zero
# retresco pmematest_2805.yml float division by zero
# netowl pmematest_2805.yml float division by zero
# netowl pmematest_2805.yml float division by zero
# bitext pmematest_2805.yml float division by zero
# bitext pmematest_2805.yml float division by zero
# bitext pmematest_2805.yml float division by zero
# semant pmematest_2805.yml float division by zero
# semant pmematest_2805.yml float division by zero
# semant pmematest_2805.yml float division by zero
# alchemy pmematest_2805.yml float division by zero
# alchemy pmematest_2805.yml float division by zero
# simple pmematest_2805.yml float division by zero
# simple pmematest_2805.yml float division by zero
# txtrazor pmematest_2805.yml float division by zero
# txtrazor pmematest_2805.yml float division by zero
# basistech pmematest_2805.yml float division by zero
# basistech pmematest_2805.yml float division by zero
# basistech pmematest_2805.yml float division by zero
# meaningcloud pmematest_201.yml float division by zero
# meaningcloud pmematest_201.yml float division by zero
# bitext pmematest_201.yml float division by zero
# semant pmematest_201.yml float division by zero
# alchemy pmematest_201.yml float division by zero
# alchemy pmematest_201.yml float division by zero
# txtrazor pmematest_201.yml float division by zero
# basistech pmematest_201.yml float division by zero
# meaningcloud pmematest_2603.yml float division by zero
# retresco pmematest_2603.yml float division by zero
# netowl pmematest_2603.yml float division by zero
# bitext pmematest_2603.yml float division by zero
# semant pmematest_2603.yml float division by zero
# semant pmematest_2603.yml float division by zero
# alchemy pmematest_2603.yml float division by zero
# alchemy pmematest_2603.yml float division by zero
# alchemy pmematest_2603.yml float division by zero
# simple pmematest_2603.yml float division by zero
# simple pmematest_2603.yml float division by zero
# txtrazor pmematest_2603.yml float division by zero
# basistech pmematest_2603.yml float division by zero
# meaningcloud pmematest_3175.yml float division by zero
# semant pmematest_3175.yml float division by zero
# semant pmematest_400.yml float division by zero
# meaningcloud pmematest_2255.yml float division by zero
# meaningcloud pmematest_2255.yml float division by zero
# meaningcloud pmematest_2255.yml float division by zero
# retresco pmematest_2255.yml float division by zero
# retresco pmematest_2255.yml float division by zero
# netowl pmematest_2255.yml float division by zero
# netowl pmematest_2255.yml float division by zero
# bitext pmematest_2255.yml float division by zero
# bitext pmematest_2255.yml float division by zero
# semant pmematest_2255.yml float division by zero
# semant pmematest_2255.yml float division by zero
# alchemy pmematest_2255.yml float division by zero
# alchemy pmematest_2255.yml float division by zero
# simple pmematest_2255.yml float division by zero
# simple pmematest_2255.yml float division by zero
# txtrazor pmematest_2255.yml float division by zero
# basistech pmematest_2255.yml float division by zero
# basistech pmematest_2255.yml float division by zero
# meaningcloud pmematest_673.yml float division by zero
# meaningcloud pmematest_673.yml float division by zero
# retresco pmematest_673.yml float division by zero
# retresco pmematest_673.yml float division by zero
# retresco pmematest_673.yml float division by zero
# netowl pmematest_673.yml float division by zero
# bitext pmematest_673.yml float division by zero
# txtrazor pmematest_673.yml float division by zero
# basistech pmematest_673.yml float division by zero
# meaningcloud pmematest_2586.yml float division by zero
# meaningcloud pmematest_2586.yml float division by zero
# meaningcloud pmematest_2586.yml float division by zero
# retresco pmematest_2586.yml float division by zero
# retresco pmematest_2586.yml float division by zero
# retresco pmematest_2586.yml float division by zero
# netowl pmematest_2586.yml float division by zero
# netowl pmematest_2586.yml float division by zero
# netowl pmematest_2586.yml float division by zero
# bitext pmematest_2586.yml float division by zero
# bitext pmematest_2586.yml float division by zero
# bitext pmematest_2586.yml float division by zero
# semant pmematest_2586.yml float division by zero
# semant pmematest_2586.yml float division by zero
# semant pmematest_2586.yml float division by zero
# alchemy pmematest_2586.yml float division by zero
# alchemy pmematest_2586.yml float division by zero
# alchemy pmematest_2586.yml float division by zero
# simple pmematest_2586.yml float division by zero
# simple pmematest_2586.yml float division by zero
# txtrazor pmematest_2586.yml float division by zero
# txtrazor pmematest_2586.yml float division by zero
# txtrazor pmematest_2586.yml float division by zero
# basistech pmematest_2586.yml float division by zero
# basistech pmematest_2586.yml float division by zero
# retresco pmematest_401.yml float division by zero
# simple pmematest_401.yml float division by zero
# meaningcloud pmematest_040.yml float division by zero
# meaningcloud pmematest_040.yml float division by zero
# meaningcloud pmematest_040.yml float division by zero
# retresco pmematest_040.yml float division by zero
# retresco pmematest_040.yml float division by zero
# retresco pmematest_040.yml float division by zero
# netowl pmematest_040.yml float division by zero
# netowl pmematest_040.yml float division by zero
# bitext pmematest_040.yml float division by zero
# bitext pmematest_040.yml float division by zero
# bitext pmematest_040.yml float division by zero
# semant pmematest_040.yml float division by zero
# semant pmematest_040.yml float division by zero
# semant pmematest_040.yml float division by zero
# alchemy pmematest_040.yml float division by zero
# alchemy pmematest_040.yml float division by zero
# alchemy pmematest_040.yml float division by zero
# simple pmematest_040.yml float division by zero
# simple pmematest_040.yml float division by zero
# txtrazor pmematest_040.yml float division by zero
# txtrazor pmematest_040.yml float division by zero
# txtrazor pmematest_040.yml float division by zero
# basistech pmematest_040.yml float division by zero
# basistech pmematest_040.yml float division by zero
# meaningcloud pmematest_1587.yml float division by zero
# meaningcloud pmematest_1587.yml float division by zero
# retresco pmematest_1587.yml float division by zero
# retresco pmematest_1587.yml float division by zero
# netowl pmematest_1587.yml float division by zero
# bitext pmematest_1587.yml float division by zero
# bitext pmematest_1587.yml float division by zero
# semant pmematest_1587.yml float division by zero
# alchemy pmematest_1587.yml float division by zero
# alchemy pmematest_1587.yml float division by zero
# alchemy pmematest_1587.yml float division by zero
# simple pmematest_1587.yml float division by zero
# txtrazor pmematest_1587.yml float division by zero
# txtrazor pmematest_1587.yml float division by zero
# basistech pmematest_1587.yml float division by zero
# retresco pmematest_2379.yml float division by zero
# retresco pmematest_2379.yml float division by zero
# bitext pmematest_2379.yml float division by zero
# semant pmematest_2379.yml float division by zero
# semant pmematest_2379.yml float division by zero

# %%
results=stats.aggregate_result(data)

# %%
results.extend(stats.compute_total(results))

# %%
# %matplotlib inline

# %%
stats.plot_results(results)

# %%
stats.store_results(results,"fr")
# Out:
# Storing file:  fr_results.yml
