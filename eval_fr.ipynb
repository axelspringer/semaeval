# %%
import semaeval.util as util
util.clean_storage("fr")
# Out:
# Deleting: input/fr/pmematest_037.yml
# Deleting: input/fr/pmematest_1063.yml
# Deleting: input/fr/pmematest_1082.yml
# Deleting: input/fr/pmematest_1090.yml
# Deleting: input/fr/pmematest_1107.yml
# Deleting: input/fr/pmematest_1115.yml
# Deleting: input/fr/pmematest_1170.yml
# Deleting: input/fr/pmematest_1448.yml
# Deleting: input/fr/pmematest_1576.yml
# Deleting: input/fr/pmematest_1630.yml
# Deleting: input/fr/pmematest_1695.yml
# Deleting: input/fr/pmematest_1721.yml
# Deleting: input/fr/pmematest_2015.yml
# Deleting: input/fr/pmematest_2100.yml
# Deleting: input/fr/pmematest_2196.yml
# Deleting: input/fr/pmematest_2239.yml
# Deleting: input/fr/pmematest_2404.yml
# Deleting: input/fr/pmematest_2436.yml
# Deleting: input/fr/pmematest_2483.yml
# Deleting: input/fr/pmematest_2487.yml
# Deleting: input/fr/pmematest_2495.yml
# Deleting: input/fr/pmematest_2575.yml
# Deleting: input/fr/pmematest_2622.yml
# Deleting: input/fr/pmematest_2642.yml
# Deleting: input/fr/pmematest_2668.yml
# Deleting: input/fr/pmematest_2728.yml
# Deleting: input/fr/pmematest_2751.yml
# Deleting: input/fr/pmematest_2774.yml
# Deleting: input/fr/pmematest_2835.yml
# Deleting: input/fr/pmematest_2862.yml
# Deleting: input/fr/pmematest_2886.yml
# Deleting: input/fr/pmematest_3061.yml
# Deleting: input/fr/pmematest_3170.yml
# Deleting: input/fr/pmematest_3186.yml
# Deleting: input/fr/pmematest_3201.yml
# Deleting: input/fr/pmematest_3341.yml
# Deleting: input/fr/pmematest_3344.yml
# Deleting: input/fr/pmematest_337.yml
# Deleting: input/fr/pmematest_3370.yml
# Deleting: input/fr/pmematest_3528.yml
# Deleting: input/fr/pmematest_394.yml
# Deleting: input/fr/pmematest_468.yml
# Deleting: input/fr/pmematest_470.yml
# Deleting: input/fr/pmematest_593.yml
# Deleting: input/fr/pmematest_642.yml
# Deleting: input/fr/pmematest_859.yml
# Deleting: input/fr/pmematest_885.yml
# Deleting: input/fr/pmematest_902.yml
# Deleting: input/fr/pmematest_938.yml
# Deleting: input/fr/pmematest_998.yml
# Deleting: output/fr/pmematest_037_alchemy.yml
# Deleting: output/fr/pmematest_037_meaningcloud.yml
# Deleting: output/fr/pmematest_037_retresco.yml
# Deleting: output/fr/pmematest_037_semant.yml
# Deleting: output/fr/pmematest_037_simple.yml
# Deleting: output/fr/pmematest_037_txtrazor.yml
# Deleting: output/fr/pmematest_1063_alchemy.yml
# Deleting: output/fr/pmematest_1063_meaningcloud.yml
# Deleting: output/fr/pmematest_1063_retresco.yml
# Deleting: output/fr/pmematest_1063_semant.yml
# Deleting: output/fr/pmematest_1063_simple.yml
# Deleting: output/fr/pmematest_1063_txtrazor.yml
# Deleting: output/fr/pmematest_1082_alchemy.yml
# Deleting: output/fr/pmematest_1082_meaningcloud.yml
# Deleting: output/fr/pmematest_1082_retresco.yml
# Deleting: output/fr/pmematest_1082_semant.yml
# Deleting: output/fr/pmematest_1082_simple.yml
# Deleting: output/fr/pmematest_1082_txtrazor.yml
# Deleting: output/fr/pmematest_1090_alchemy.yml
# Deleting: output/fr/pmematest_1090_meaningcloud.yml
# Deleting: output/fr/pmematest_1090_retresco.yml
# Deleting: output/fr/pmematest_1090_semant.yml
# Deleting: output/fr/pmematest_1090_simple.yml
# Deleting: output/fr/pmematest_1090_txtrazor.yml
# Deleting: output/fr/pmematest_1107_alchemy.yml
# Deleting: output/fr/pmematest_1107_meaningcloud.yml
# Deleting: output/fr/pmematest_1107_retresco.yml
# Deleting: output/fr/pmematest_1107_semant.yml
# Deleting: output/fr/pmematest_1107_simple.yml
# Deleting: output/fr/pmematest_1107_txtrazor.yml
# Deleting: output/fr/pmematest_1115_alchemy.yml
# Deleting: output/fr/pmematest_1115_meaningcloud.yml
# Deleting: output/fr/pmematest_1115_retresco.yml
# Deleting: output/fr/pmematest_1115_semant.yml
# Deleting: output/fr/pmematest_1115_simple.yml
# Deleting: output/fr/pmematest_1115_txtrazor.yml
# Deleting: output/fr/pmematest_1170_alchemy.yml
# Deleting: output/fr/pmematest_1170_meaningcloud.yml
# Deleting: output/fr/pmematest_1170_retresco.yml
# Deleting: output/fr/pmematest_1170_semant.yml
# Deleting: output/fr/pmematest_1170_simple.yml
# Deleting: output/fr/pmematest_1170_txtrazor.yml
# Deleting: output/fr/pmematest_1448_alchemy.yml
# Deleting: output/fr/pmematest_1448_meaningcloud.yml
# Deleting: output/fr/pmematest_1448_retresco.yml
# Deleting: output/fr/pmematest_1448_semant.yml
# Deleting: output/fr/pmematest_1448_simple.yml
# Deleting: output/fr/pmematest_1448_txtrazor.yml
# Deleting: output/fr/pmematest_1576_alchemy.yml
# Deleting: output/fr/pmematest_1576_meaningcloud.yml
# Deleting: output/fr/pmematest_1576_retresco.yml
# Deleting: output/fr/pmematest_1576_semant.yml
# Deleting: output/fr/pmematest_1576_simple.yml
# Deleting: output/fr/pmematest_1576_txtrazor.yml
# Deleting: output/fr/pmematest_1630_alchemy.yml
# Deleting: output/fr/pmematest_1630_meaningcloud.yml
# Deleting: output/fr/pmematest_1630_retresco.yml
# Deleting: output/fr/pmematest_1630_semant.yml
# Deleting: output/fr/pmematest_1630_simple.yml
# Deleting: output/fr/pmematest_1630_txtrazor.yml
# Deleting: output/fr/pmematest_1695_alchemy.yml
# Deleting: output/fr/pmematest_1695_meaningcloud.yml
# Deleting: output/fr/pmematest_1695_retresco.yml
# Deleting: output/fr/pmematest_1695_semant.yml
# Deleting: output/fr/pmematest_1695_simple.yml
# Deleting: output/fr/pmematest_1695_txtrazor.yml
# Deleting: output/fr/pmematest_1721_alchemy.yml
# Deleting: output/fr/pmematest_1721_meaningcloud.yml
# Deleting: output/fr/pmematest_1721_retresco.yml
# Deleting: output/fr/pmematest_1721_semant.yml
# Deleting: output/fr/pmematest_1721_simple.yml
# Deleting: output/fr/pmematest_1721_txtrazor.yml
# Deleting: output/fr/pmematest_2015_alchemy.yml
# Deleting: output/fr/pmematest_2015_meaningcloud.yml
# Deleting: output/fr/pmematest_2015_retresco.yml
# Deleting: output/fr/pmematest_2015_semant.yml
# Deleting: output/fr/pmematest_2015_simple.yml
# Deleting: output/fr/pmematest_2015_txtrazor.yml
# Deleting: output/fr/pmematest_2100_alchemy.yml
# Deleting: output/fr/pmematest_2100_meaningcloud.yml
# Deleting: output/fr/pmematest_2100_retresco.yml
# Deleting: output/fr/pmematest_2100_semant.yml
# Deleting: output/fr/pmematest_2100_simple.yml
# Deleting: output/fr/pmematest_2100_txtrazor.yml
# Deleting: output/fr/pmematest_2196_alchemy.yml
# Deleting: output/fr/pmematest_2196_meaningcloud.yml
# Deleting: output/fr/pmematest_2196_retresco.yml
# Deleting: output/fr/pmematest_2196_semant.yml
# Deleting: output/fr/pmematest_2196_simple.yml
# Deleting: output/fr/pmematest_2196_txtrazor.yml
# Deleting: output/fr/pmematest_2239_alchemy.yml
# Deleting: output/fr/pmematest_2239_meaningcloud.yml
# Deleting: output/fr/pmematest_2239_retresco.yml
# Deleting: output/fr/pmematest_2239_semant.yml
# Deleting: output/fr/pmematest_2239_simple.yml
# Deleting: output/fr/pmematest_2239_txtrazor.yml
# Deleting: output/fr/pmematest_2404_alchemy.yml
# Deleting: output/fr/pmematest_2404_meaningcloud.yml
# Deleting: output/fr/pmematest_2404_retresco.yml
# Deleting: output/fr/pmematest_2404_semant.yml
# Deleting: output/fr/pmematest_2404_simple.yml
# Deleting: output/fr/pmematest_2404_txtrazor.yml
# Deleting: output/fr/pmematest_2436_alchemy.yml
# Deleting: output/fr/pmematest_2436_meaningcloud.yml
# Deleting: output/fr/pmematest_2436_retresco.yml
# Deleting: output/fr/pmematest_2436_semant.yml
# Deleting: output/fr/pmematest_2436_simple.yml
# Deleting: output/fr/pmematest_2436_txtrazor.yml
# Deleting: output/fr/pmematest_2483_alchemy.yml
# Deleting: output/fr/pmematest_2483_meaningcloud.yml
# Deleting: output/fr/pmematest_2483_retresco.yml
# Deleting: output/fr/pmematest_2483_semant.yml
# Deleting: output/fr/pmematest_2483_simple.yml
# Deleting: output/fr/pmematest_2483_txtrazor.yml
# Deleting: output/fr/pmematest_2487_alchemy.yml
# Deleting: output/fr/pmematest_2487_meaningcloud.yml
# Deleting: output/fr/pmematest_2487_retresco.yml
# Deleting: output/fr/pmematest_2487_semant.yml
# Deleting: output/fr/pmematest_2487_simple.yml
# Deleting: output/fr/pmematest_2487_txtrazor.yml
# Deleting: output/fr/pmematest_2495_alchemy.yml
# Deleting: output/fr/pmematest_2495_meaningcloud.yml
# Deleting: output/fr/pmematest_2495_retresco.yml
# Deleting: output/fr/pmematest_2495_semant.yml
# Deleting: output/fr/pmematest_2495_simple.yml
# Deleting: output/fr/pmematest_2495_txtrazor.yml
# Deleting: output/fr/pmematest_2575_alchemy.yml
# Deleting: output/fr/pmematest_2575_meaningcloud.yml
# Deleting: output/fr/pmematest_2575_retresco.yml
# Deleting: output/fr/pmematest_2575_semant.yml
# Deleting: output/fr/pmematest_2575_simple.yml
# Deleting: output/fr/pmematest_2575_txtrazor.yml
# Deleting: output/fr/pmematest_2622_alchemy.yml
# Deleting: output/fr/pmematest_2622_meaningcloud.yml
# Deleting: output/fr/pmematest_2622_retresco.yml
# Deleting: output/fr/pmematest_2622_semant.yml
# Deleting: output/fr/pmematest_2622_simple.yml
# Deleting: output/fr/pmematest_2622_txtrazor.yml
# Deleting: output/fr/pmematest_2642_alchemy.yml
# Deleting: output/fr/pmematest_2642_meaningcloud.yml
# Deleting: output/fr/pmematest_2642_retresco.yml
# Deleting: output/fr/pmematest_2642_semant.yml
# Deleting: output/fr/pmematest_2642_simple.yml
# Deleting: output/fr/pmematest_2642_txtrazor.yml
# Deleting: output/fr/pmematest_2668_alchemy.yml
# Deleting: output/fr/pmematest_2668_meaningcloud.yml
# Deleting: output/fr/pmematest_2668_retresco.yml
# Deleting: output/fr/pmematest_2668_semant.yml
# Deleting: output/fr/pmematest_2668_simple.yml
# Deleting: output/fr/pmematest_2668_txtrazor.yml
# Deleting: output/fr/pmematest_2728_alchemy.yml
# Deleting: output/fr/pmematest_2728_meaningcloud.yml
# Deleting: output/fr/pmematest_2728_retresco.yml
# Deleting: output/fr/pmematest_2728_semant.yml
# Deleting: output/fr/pmematest_2728_simple.yml
# Deleting: output/fr/pmematest_2728_txtrazor.yml
# Deleting: output/fr/pmematest_2751_alchemy.yml
# Deleting: output/fr/pmematest_2751_meaningcloud.yml
# Deleting: output/fr/pmematest_2751_retresco.yml
# Deleting: output/fr/pmematest_2751_semant.yml
# Deleting: output/fr/pmematest_2751_simple.yml
# Deleting: output/fr/pmematest_2751_txtrazor.yml
# Deleting: output/fr/pmematest_2774_alchemy.yml
# Deleting: output/fr/pmematest_2774_meaningcloud.yml
# Deleting: output/fr/pmematest_2774_retresco.yml
# Deleting: output/fr/pmematest_2774_semant.yml
# Deleting: output/fr/pmematest_2774_simple.yml
# Deleting: output/fr/pmematest_2774_txtrazor.yml
# Deleting: output/fr/pmematest_2835_alchemy.yml
# Deleting: output/fr/pmematest_2835_meaningcloud.yml
# Deleting: output/fr/pmematest_2835_retresco.yml
# Deleting: output/fr/pmematest_2835_semant.yml
# Deleting: output/fr/pmematest_2835_simple.yml
# Deleting: output/fr/pmematest_2835_txtrazor.yml
# Deleting: output/fr/pmematest_2862_alchemy.yml
# Deleting: output/fr/pmematest_2862_meaningcloud.yml
# Deleting: output/fr/pmematest_2862_retresco.yml
# Deleting: output/fr/pmematest_2862_semant.yml
# Deleting: output/fr/pmematest_2862_simple.yml
# Deleting: output/fr/pmematest_2862_txtrazor.yml
# Deleting: output/fr/pmematest_2886_alchemy.yml
# Deleting: output/fr/pmematest_2886_meaningcloud.yml
# Deleting: output/fr/pmematest_2886_retresco.yml
# Deleting: output/fr/pmematest_2886_semant.yml
# Deleting: output/fr/pmematest_2886_simple.yml
# Deleting: output/fr/pmematest_2886_txtrazor.yml
# Deleting: output/fr/pmematest_3061_alchemy.yml
# Deleting: output/fr/pmematest_3061_meaningcloud.yml
# Deleting: output/fr/pmematest_3061_retresco.yml
# Deleting: output/fr/pmematest_3061_semant.yml
# Deleting: output/fr/pmematest_3061_simple.yml
# Deleting: output/fr/pmematest_3061_txtrazor.yml
# Deleting: output/fr/pmematest_3170_alchemy.yml
# Deleting: output/fr/pmematest_3170_meaningcloud.yml
# Deleting: output/fr/pmematest_3170_retresco.yml
# Deleting: output/fr/pmematest_3170_semant.yml
# Deleting: output/fr/pmematest_3170_simple.yml
# Deleting: output/fr/pmematest_3170_txtrazor.yml
# Deleting: output/fr/pmematest_3186_alchemy.yml
# Deleting: output/fr/pmematest_3186_meaningcloud.yml
# Deleting: output/fr/pmematest_3186_retresco.yml
# Deleting: output/fr/pmematest_3186_semant.yml
# Deleting: output/fr/pmematest_3186_simple.yml
# Deleting: output/fr/pmematest_3186_txtrazor.yml
# Deleting: output/fr/pmematest_3201_alchemy.yml
# Deleting: output/fr/pmematest_3201_meaningcloud.yml
# Deleting: output/fr/pmematest_3201_retresco.yml
# Deleting: output/fr/pmematest_3201_semant.yml
# Deleting: output/fr/pmematest_3201_simple.yml
# Deleting: output/fr/pmematest_3201_txtrazor.yml
# Deleting: output/fr/pmematest_3341_alchemy.yml
# Deleting: output/fr/pmematest_3341_meaningcloud.yml
# Deleting: output/fr/pmematest_3341_retresco.yml
# Deleting: output/fr/pmematest_3341_semant.yml
# Deleting: output/fr/pmematest_3341_simple.yml
# Deleting: output/fr/pmematest_3341_txtrazor.yml
# Deleting: output/fr/pmematest_3344_alchemy.yml
# Deleting: output/fr/pmematest_3344_meaningcloud.yml
# Deleting: output/fr/pmematest_3344_retresco.yml
# Deleting: output/fr/pmematest_3344_semant.yml
# Deleting: output/fr/pmematest_3344_simple.yml
# Deleting: output/fr/pmematest_3344_txtrazor.yml
# Deleting: output/fr/pmematest_3370_alchemy.yml
# Deleting: output/fr/pmematest_3370_meaningcloud.yml
# Deleting: output/fr/pmematest_3370_retresco.yml
# Deleting: output/fr/pmematest_3370_semant.yml
# Deleting: output/fr/pmematest_3370_simple.yml
# Deleting: output/fr/pmematest_3370_txtrazor.yml
# Deleting: output/fr/pmematest_337_alchemy.yml
# Deleting: output/fr/pmematest_337_meaningcloud.yml
# Deleting: output/fr/pmematest_337_retresco.yml
# Deleting: output/fr/pmematest_337_semant.yml
# Deleting: output/fr/pmematest_337_simple.yml
# Deleting: output/fr/pmematest_337_txtrazor.yml
# Deleting: output/fr/pmematest_3528_alchemy.yml
# Deleting: output/fr/pmematest_3528_meaningcloud.yml
# Deleting: output/fr/pmematest_3528_retresco.yml
# Deleting: output/fr/pmematest_3528_semant.yml
# Deleting: output/fr/pmematest_3528_simple.yml
# Deleting: output/fr/pmematest_3528_txtrazor.yml
# Deleting: output/fr/pmematest_394_alchemy.yml
# Deleting: output/fr/pmematest_394_meaningcloud.yml
# Deleting: output/fr/pmematest_394_retresco.yml
# Deleting: output/fr/pmematest_394_semant.yml
# Deleting: output/fr/pmematest_394_simple.yml
# Deleting: output/fr/pmematest_394_txtrazor.yml
# Deleting: output/fr/pmematest_468_alchemy.yml
# Deleting: output/fr/pmematest_468_meaningcloud.yml
# Deleting: output/fr/pmematest_468_retresco.yml
# Deleting: output/fr/pmematest_468_semant.yml
# Deleting: output/fr/pmematest_468_simple.yml
# Deleting: output/fr/pmematest_468_txtrazor.yml
# Deleting: output/fr/pmematest_470_alchemy.yml
# Deleting: output/fr/pmematest_470_meaningcloud.yml
# Deleting: output/fr/pmematest_470_retresco.yml
# Deleting: output/fr/pmematest_470_semant.yml
# Deleting: output/fr/pmematest_470_simple.yml
# Deleting: output/fr/pmematest_470_txtrazor.yml
# Deleting: output/fr/pmematest_593_alchemy.yml
# Deleting: output/fr/pmematest_593_meaningcloud.yml
# Deleting: output/fr/pmematest_593_retresco.yml
# Deleting: output/fr/pmematest_593_semant.yml
# Deleting: output/fr/pmematest_593_simple.yml
# Deleting: output/fr/pmematest_593_txtrazor.yml
# Deleting: output/fr/pmematest_642_alchemy.yml
# Deleting: output/fr/pmematest_642_meaningcloud.yml
# Deleting: output/fr/pmematest_642_retresco.yml
# Deleting: output/fr/pmematest_642_semant.yml
# Deleting: output/fr/pmematest_642_simple.yml
# Deleting: output/fr/pmematest_642_txtrazor.yml
# Deleting: output/fr/pmematest_859_alchemy.yml
# Deleting: output/fr/pmematest_859_meaningcloud.yml
# Deleting: output/fr/pmematest_859_retresco.yml
# Deleting: output/fr/pmematest_859_semant.yml
# Deleting: output/fr/pmematest_859_simple.yml
# Deleting: output/fr/pmematest_859_txtrazor.yml
# Deleting: output/fr/pmematest_885_alchemy.yml
# Deleting: output/fr/pmematest_885_meaningcloud.yml
# Deleting: output/fr/pmematest_885_retresco.yml
# Deleting: output/fr/pmematest_885_semant.yml
# Deleting: output/fr/pmematest_885_simple.yml
# Deleting: output/fr/pmematest_885_txtrazor.yml
# Deleting: output/fr/pmematest_902_alchemy.yml
# Deleting: output/fr/pmematest_902_meaningcloud.yml
# Deleting: output/fr/pmematest_902_retresco.yml
# Deleting: output/fr/pmematest_902_semant.yml
# Deleting: output/fr/pmematest_902_simple.yml
# Deleting: output/fr/pmematest_902_txtrazor.yml
# Deleting: output/fr/pmematest_938_alchemy.yml
# Deleting: output/fr/pmematest_938_meaningcloud.yml
# Deleting: output/fr/pmematest_938_retresco.yml
# Deleting: output/fr/pmematest_938_semant.yml
# Deleting: output/fr/pmematest_938_simple.yml
# Deleting: output/fr/pmematest_938_txtrazor.yml
# Deleting: output/fr/pmematest_998_alchemy.yml
# Deleting: output/fr/pmematest_998_meaningcloud.yml
# Deleting: output/fr/pmematest_998_retresco.yml
# Deleting: output/fr/pmematest_998_semant.yml
# Deleting: output/fr/pmematest_998_simple.yml
# Deleting: output/fr/pmematest_998_txtrazor.yml
# [Errno 2] No such file or directory: 'result/fr'

# %%
import semaeval.source.syndication as synd

# %%
help(synd)
# Out:
# Help on module semaeval.source.syndication in semaeval.source:
#
# NAME
#     semaeval.source.syndication - # -*- coding: utf-8 -*-
#
# FILE
#     /Users/amaier1/git/semaeval/semaeval/source/syndication.py
#
# FUNCTIONS
#     article_from_path(path)
#
#     articles_from_dir(dir)
#
#     load_articles(prefix)
#
#     store_articles(articles, prefix)
#
# DATA
#     store_dir = 'input/'
#     url_regex = <_sre.SRE_Pattern object>

# %%
pme = synd.articles_from_dir("/Users/amaier1/Documents/semeval/pmematest")

# %%
import random
articles = random.sample(pme,50)

# %%
synd.store_articles(articles,"fr")
# Out:
# Storing file:  input/fr/pmematest_851.yml
# Storing file:  input/fr/pmematest_3228.yml
# Storing file:  input/fr/pmematest_2241.yml
# Storing file:  input/fr/pmematest_3308.yml
# Storing file:  input/fr/pmematest_2967.yml
# Storing file:  input/fr/pmematest_2221.yml
# Storing file:  input/fr/pmematest_2817.yml
# Storing file:  input/fr/pmematest_3043.yml
# Storing file:  input/fr/pmematest_2136.yml
# Storing file:  input/fr/pmematest_043.yml
# Storing file:  input/fr/pmematest_2388.yml
# Storing file:  input/fr/pmematest_1576.yml
# Storing file:  input/fr/pmematest_2042.yml
# Storing file:  input/fr/pmematest_3360.yml
# Storing file:  input/fr/pmematest_1603.yml
# Storing file:  input/fr/pmematest_3030.yml
# Storing file:  input/fr/pmematest_1051.yml
# Storing file:  input/fr/pmematest_288.yml
# Storing file:  input/fr/pmematest_220.yml
# Storing file:  input/fr/pmematest_752.yml
# Storing file:  input/fr/pmematest_3091.yml
# Storing file:  input/fr/pmematest_3051.yml
# Storing file:  input/fr/pmematest_2541.yml
# Storing file:  input/fr/pmematest_3340.yml
# Storing file:  input/fr/pmematest_1181.yml
# Storing file:  input/fr/pmematest_2500.yml
# Storing file:  input/fr/pmematest_2429.yml
# Storing file:  input/fr/pmematest_2091.yml
# Storing file:  input/fr/pmematest_2981.yml
# Storing file:  input/fr/pmematest_2806.yml
# Storing file:  input/fr/pmematest_344.yml
# Storing file:  input/fr/pmematest_2911.yml
# Storing file:  input/fr/pmematest_1808.yml
# Storing file:  input/fr/pmematest_2271.yml
# Storing file:  input/fr/pmematest_3390.yml
# Storing file:  input/fr/pmematest_2116.yml
# Storing file:  input/fr/pmematest_996.yml
# Storing file:  input/fr/pmematest_3335.yml
# Storing file:  input/fr/pmematest_1296.yml
# Storing file:  input/fr/pmematest_2748.yml
# Storing file:  input/fr/pmematest_1612.yml
# Storing file:  input/fr/pmematest_924.yml
# Storing file:  input/fr/pmematest_1986.yml
# Storing file:  input/fr/pmematest_2586.yml
# Storing file:  input/fr/pmematest_2535.yml
# Storing file:  input/fr/pmematest_2227.yml
# Storing file:  input/fr/pmematest_2847.yml
# Storing file:  input/fr/pmematest_1032.yml
# Storing file:  input/fr/pmematest_1269.yml
# Storing file:  input/fr/pmematest_1125.yml

# %%
import semaeval.evaluate as eval
reload(eval)
# Out:
# <module 'semaeval.evaluate' from 'semaeval/evaluate.pyc'>

# %%
articles_enriched = eval.detect_entities(articles,"fr")
# Out:
# Filename: pmematest_851.yml
# Collecting results:
# Filename: pmematest_3228.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_2241.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.semant
# alchemy: TelevisionShow
# Filename: pmematest_3308.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# bitext: 11
# Filename: pmematest_2967.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2221.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# Filename: pmematest_2817.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_3043.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2136.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_043.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2388.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_1576.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2042.yml
# Collecting results:
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_3360.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# Filename: pmematest_1603.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_3030.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_1051.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_288.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# Filename: pmematest_220.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_752.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# alchemy: GeographicFeature
# Filename: pmematest_3091.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_3051.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2541.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.semant
# Filename: pmematest_3340.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_1181.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.simple
# semaeval.engine.retresco
# semaeval.engine.alchemy
# bitext: 11
# Filename: pmematest_2500.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# meaningcloud:alchemy: Top>Event
#  GeographicFeature
# Filename: pmematest_2429.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.txtrazor
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2091.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.txtrazor
# semaeval.engine.simple
# textrazor: [u'MeanOfTransportation', u'Rocket']
# Filename: pmematest_2981.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2806.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_344.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2911.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_1808.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semantria: Regex
# Filename: pmematest_2271.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_3390.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2116.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_996.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_3335.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_1296.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2748.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.alchemy
# Filename: pmematest_1612.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_924.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_1986.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.simple
# semaeval.engine.retresco
# Filename: pmematest_2586.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.bitext
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# alchemy: TelevisionShow
# Filename: pmematest_2535.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.bitext
# semaeval.engine.simple
# semaeval.engine.txtrazor
# alchemy: TelevisionShow
# Filename: pmematest_2227.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_2847.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_1032.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.bitext
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_1269.yml
# Collecting results:
# semaeval.engine.bitext
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# Filename: pmematest_1125.yml
# Collecting results:
# semaeval.engine.meaningcloud
# semaeval.engine.bitext
# semaeval.engine.txtrazor
# semaeval.engine.semant
# semaeval.engine.alchemy
# semaeval.engine.retresco
# semaeval.engine.simple
# semaeval.engine.meaningcloud
# semaeval.engine.txtrazor
# semaeval.engine.alchemy
# semaeval.engine.semant
# semaeval.engine.simple
# semaeval.engine.retresco
# semaeval.engine.bitext
# alchemy: TelevisionShow

# %%
eval.store_articles(articles_enriched,"fr")
# Out:
# Storing file:  output/fr/pmematest_851_alchemy.yml
# Storing file:  output/fr/pmematest_851_txtrazor.yml
# Storing file:  output/fr/pmematest_851_simple.yml
# Storing file:  output/fr/pmematest_851_semant.yml
# Storing file:  output/fr/pmematest_851_meaningcloud.yml
# Storing file:  output/fr/pmematest_851_bitext.yml
# Storing file:  output/fr/pmematest_851_retresco.yml
# Storing file:  output/fr/pmematest_3228_alchemy.yml
# Storing file:  output/fr/pmematest_3228_txtrazor.yml
# Storing file:  output/fr/pmematest_3228_simple.yml
# Storing file:  output/fr/pmematest_3228_semant.yml
# Storing file:  output/fr/pmematest_3228_meaningcloud.yml
# Storing file:  output/fr/pmematest_3228_bitext.yml
# Storing file:  output/fr/pmematest_3228_retresco.yml
# Storing file:  output/fr/pmematest_2241_alchemy.yml
# Storing file:  output/fr/pmematest_2241_txtrazor.yml
# Storing file:  output/fr/pmematest_2241_simple.yml
# Storing file:  output/fr/pmematest_2241_semant.yml
# Storing file:  output/fr/pmematest_2241_meaningcloud.yml
# Storing file:  output/fr/pmematest_2241_bitext.yml
# Storing file:  output/fr/pmematest_2241_retresco.yml
# Storing file:  output/fr/pmematest_3308_alchemy.yml
# Storing file:  output/fr/pmematest_3308_txtrazor.yml
# Storing file:  output/fr/pmematest_3308_simple.yml
# Storing file:  output/fr/pmematest_3308_semant.yml
# Storing file:  output/fr/pmematest_3308_meaningcloud.yml
# Storing file:  output/fr/pmematest_3308_bitext.yml
# Storing file:  output/fr/pmematest_3308_retresco.yml
# Storing file:  output/fr/pmematest_2967_alchemy.yml
# Storing file:  output/fr/pmematest_2967_txtrazor.yml
# Storing file:  output/fr/pmematest_2967_simple.yml
# Storing file:  output/fr/pmematest_2967_semant.yml
# Storing file:  output/fr/pmematest_2967_meaningcloud.yml
# Storing file:  output/fr/pmematest_2967_bitext.yml
# Storing file:  output/fr/pmematest_2967_retresco.yml
# Storing file:  output/fr/pmematest_2221_alchemy.yml
# Storing file:  output/fr/pmematest_2221_txtrazor.yml
# Storing file:  output/fr/pmematest_2221_simple.yml
# Storing file:  output/fr/pmematest_2221_semant.yml
# Storing file:  output/fr/pmematest_2221_meaningcloud.yml
# Storing file:  output/fr/pmematest_2221_bitext.yml
# Storing file:  output/fr/pmematest_2221_retresco.yml
# Storing file:  output/fr/pmematest_2817_alchemy.yml
# Storing file:  output/fr/pmematest_2817_txtrazor.yml
# Storing file:  output/fr/pmematest_2817_simple.yml
# Storing file:  output/fr/pmematest_2817_semant.yml
# Storing file:  output/fr/pmematest_2817_meaningcloud.yml
# Storing file:  output/fr/pmematest_2817_bitext.yml
# Storing file:  output/fr/pmematest_2817_retresco.yml
# Storing file:  output/fr/pmematest_3043_alchemy.yml
# Storing file:  output/fr/pmematest_3043_txtrazor.yml
# Storing file:  output/fr/pmematest_3043_simple.yml
# Storing file:  output/fr/pmematest_3043_semant.yml
# Storing file:  output/fr/pmematest_3043_meaningcloud.yml
# Storing file:  output/fr/pmematest_3043_bitext.yml
# Storing file:  output/fr/pmematest_3043_retresco.yml
# Storing file:  output/fr/pmematest_2136_alchemy.yml
# Storing file:  output/fr/pmematest_2136_txtrazor.yml
# Storing file:  output/fr/pmematest_2136_simple.yml
# Storing file:  output/fr/pmematest_2136_semant.yml
# Storing file:  output/fr/pmematest_2136_meaningcloud.yml
# Storing file:  output/fr/pmematest_2136_bitext.yml
# Storing file:  output/fr/pmematest_2136_retresco.yml
# Storing file:  output/fr/pmematest_043_alchemy.yml
# Storing file:  output/fr/pmematest_043_txtrazor.yml
# Storing file:  output/fr/pmematest_043_simple.yml
# Storing file:  output/fr/pmematest_043_semant.yml
# Storing file:  output/fr/pmematest_043_meaningcloud.yml
# Storing file:  output/fr/pmematest_043_bitext.yml
# Storing file:  output/fr/pmematest_043_retresco.yml
# Storing file:  output/fr/pmematest_2388_alchemy.yml
# Storing file:  output/fr/pmematest_2388_txtrazor.yml
# Storing file:  output/fr/pmematest_2388_simple.yml
# Storing file:  output/fr/pmematest_2388_semant.yml
# Storing file:  output/fr/pmematest_2388_meaningcloud.yml
# Storing file:  output/fr/pmematest_2388_bitext.yml
# Storing file:  output/fr/pmematest_2388_retresco.yml
# Storing file:  output/fr/pmematest_1576_alchemy.yml
# Storing file:  output/fr/pmematest_1576_txtrazor.yml
# Storing file:  output/fr/pmematest_1576_simple.yml
# Storing file:  output/fr/pmematest_1576_semant.yml
# Storing file:  output/fr/pmematest_1576_meaningcloud.yml
# Storing file:  output/fr/pmematest_1576_bitext.yml
# Storing file:  output/fr/pmematest_1576_retresco.yml
# Storing file:  output/fr/pmematest_2042_alchemy.yml
# Storing file:  output/fr/pmematest_2042_txtrazor.yml
# Storing file:  output/fr/pmematest_2042_simple.yml
# Storing file:  output/fr/pmematest_2042_semant.yml
# Storing file:  output/fr/pmematest_2042_meaningcloud.yml
# Storing file:  output/fr/pmematest_2042_bitext.yml
# Storing file:  output/fr/pmematest_2042_retresco.yml
# Storing file:  output/fr/pmematest_3360_alchemy.yml
# Storing file:  output/fr/pmematest_3360_txtrazor.yml
# Storing file:  output/fr/pmematest_3360_simple.yml
# Storing file:  output/fr/pmematest_3360_semant.yml
# Storing file:  output/fr/pmematest_3360_meaningcloud.yml
# Storing file:  output/fr/pmematest_3360_bitext.yml
# Storing file:  output/fr/pmematest_3360_retresco.yml
# Storing file:  output/fr/pmematest_1603_alchemy.yml
# Storing file:  output/fr/pmematest_1603_txtrazor.yml
# Storing file:  output/fr/pmematest_1603_simple.yml
# Storing file:  output/fr/pmematest_1603_semant.yml
# Storing file:  output/fr/pmematest_1603_meaningcloud.yml
# Storing file:  output/fr/pmematest_1603_bitext.yml
# Storing file:  output/fr/pmematest_1603_retresco.yml
# Storing file:  output/fr/pmematest_3030_alchemy.yml
# Storing file:  output/fr/pmematest_3030_txtrazor.yml
# Storing file:  output/fr/pmematest_3030_simple.yml
# Storing file:  output/fr/pmematest_3030_semant.yml
# Storing file:  output/fr/pmematest_3030_meaningcloud.yml
# Storing file:  output/fr/pmematest_3030_bitext.yml
# Storing file:  output/fr/pmematest_3030_retresco.yml
# Storing file:  output/fr/pmematest_1051_alchemy.yml
# Storing file:  output/fr/pmematest_1051_txtrazor.yml
# Storing file:  output/fr/pmematest_1051_simple.yml
# Storing file:  output/fr/pmematest_1051_semant.yml
# Storing file:  output/fr/pmematest_1051_meaningcloud.yml
# Storing file:  output/fr/pmematest_1051_bitext.yml
# Storing file:  output/fr/pmematest_1051_retresco.yml
# Storing file:  output/fr/pmematest_288_alchemy.yml
# Storing file:  output/fr/pmematest_288_txtrazor.yml
# Storing file:  output/fr/pmematest_288_simple.yml
# Storing file:  output/fr/pmematest_288_semant.yml
# Storing file:  output/fr/pmematest_288_meaningcloud.yml
# Storing file:  output/fr/pmematest_288_bitext.yml
# Storing file:  output/fr/pmematest_288_retresco.yml
# Storing file:  output/fr/pmematest_220_alchemy.yml
# Storing file:  output/fr/pmematest_220_txtrazor.yml
# Storing file:  output/fr/pmematest_220_simple.yml
# Storing file:  output/fr/pmematest_220_semant.yml
# Storing file:  output/fr/pmematest_220_meaningcloud.yml
# Storing file:  output/fr/pmematest_220_bitext.yml
# Storing file:  output/fr/pmematest_220_retresco.yml
# Storing file:  output/fr/pmematest_752_alchemy.yml
# Storing file:  output/fr/pmematest_752_txtrazor.yml
# Storing file:  output/fr/pmematest_752_simple.yml
# Storing file:  output/fr/pmematest_752_semant.yml
# Storing file:  output/fr/pmematest_752_meaningcloud.yml
# Storing file:  output/fr/pmematest_752_bitext.yml
# Storing file:  output/fr/pmematest_752_retresco.yml
# Storing file:  output/fr/pmematest_3091_alchemy.yml
# Storing file:  output/fr/pmematest_3091_txtrazor.yml
# Storing file:  output/fr/pmematest_3091_simple.yml
# Storing file:  output/fr/pmematest_3091_semant.yml
# Storing file:  output/fr/pmematest_3091_meaningcloud.yml
# Storing file:  output/fr/pmematest_3091_bitext.yml
# Storing file:  output/fr/pmematest_3091_retresco.yml
# Storing file:  output/fr/pmematest_3051_alchemy.yml
# Storing file:  output/fr/pmematest_3051_txtrazor.yml
# Storing file:  output/fr/pmematest_3051_simple.yml
# Storing file:  output/fr/pmematest_3051_semant.yml
# Storing file:  output/fr/pmematest_3051_meaningcloud.yml
# Storing file:  output/fr/pmematest_3051_bitext.yml
# Storing file:  output/fr/pmematest_3051_retresco.yml
# Storing file:  output/fr/pmematest_2541_alchemy.yml
# Storing file:  output/fr/pmematest_2541_txtrazor.yml
# Storing file:  output/fr/pmematest_2541_simple.yml
# Storing file:  output/fr/pmematest_2541_semant.yml
# Storing file:  output/fr/pmematest_2541_meaningcloud.yml
# Storing file:  output/fr/pmematest_2541_bitext.yml
# Storing file:  output/fr/pmematest_2541_retresco.yml
# Storing file:  output/fr/pmematest_3340_alchemy.yml
# Storing file:  output/fr/pmematest_3340_txtrazor.yml
# Storing file:  output/fr/pmematest_3340_simple.yml
# Storing file:  output/fr/pmematest_3340_semant.yml
# Storing file:  output/fr/pmematest_3340_meaningcloud.yml
# Storing file:  output/fr/pmematest_3340_bitext.yml
# Storing file:  output/fr/pmematest_3340_retresco.yml
# Storing file:  output/fr/pmematest_1181_alchemy.yml
# Storing file:  output/fr/pmematest_1181_txtrazor.yml
# Storing file:  output/fr/pmematest_1181_simple.yml
# Storing file:  output/fr/pmematest_1181_semant.yml
# Storing file:  output/fr/pmematest_1181_meaningcloud.yml
# Storing file:  output/fr/pmematest_1181_bitext.yml
# Storing file:  output/fr/pmematest_1181_retresco.yml
# Storing file:  output/fr/pmematest_2500_alchemy.yml
# Storing file:  output/fr/pmematest_2500_txtrazor.yml
# Storing file:  output/fr/pmematest_2500_simple.yml
# Storing file:  output/fr/pmematest_2500_semant.yml
# Storing file:  output/fr/pmematest_2500_meaningcloud.yml
# Storing file:  output/fr/pmematest_2500_bitext.yml
# Storing file:  output/fr/pmematest_2500_retresco.yml
# Storing file:  output/fr/pmematest_2429_alchemy.yml
# Storing file:  output/fr/pmematest_2429_txtrazor.yml
# Storing file:  output/fr/pmematest_2429_simple.yml
# Storing file:  output/fr/pmematest_2429_semant.yml
# Storing file:  output/fr/pmematest_2429_meaningcloud.yml
# Storing file:  output/fr/pmematest_2429_bitext.yml
# Storing file:  output/fr/pmematest_2429_retresco.yml
# Storing file:  output/fr/pmematest_2091_alchemy.yml
# Storing file:  output/fr/pmematest_2091_txtrazor.yml
# Storing file:  output/fr/pmematest_2091_simple.yml
# Storing file:  output/fr/pmematest_2091_semant.yml
# Storing file:  output/fr/pmematest_2091_meaningcloud.yml
# Storing file:  output/fr/pmematest_2091_bitext.yml
# Storing file:  output/fr/pmematest_2091_retresco.yml
# Storing file:  output/fr/pmematest_2981_alchemy.yml
# Storing file:  output/fr/pmematest_2981_txtrazor.yml
# Storing file:  output/fr/pmematest_2981_simple.yml
# Storing file:  output/fr/pmematest_2981_semant.yml
# Storing file:  output/fr/pmematest_2981_meaningcloud.yml
# Storing file:  output/fr/pmematest_2981_bitext.yml
# Storing file:  output/fr/pmematest_2981_retresco.yml
# Storing file:  output/fr/pmematest_2806_alchemy.yml
# Storing file:  output/fr/pmematest_2806_txtrazor.yml
# Storing file:  output/fr/pmematest_2806_simple.yml
# Storing file:  output/fr/pmematest_2806_semant.yml
# Storing file:  output/fr/pmematest_2806_meaningcloud.yml
# Storing file:  output/fr/pmematest_2806_bitext.yml
# Storing file:  output/fr/pmematest_2806_retresco.yml
# Storing file:  output/fr/pmematest_344_alchemy.yml
# Storing file:  output/fr/pmematest_344_txtrazor.yml
# Storing file:  output/fr/pmematest_344_simple.yml
# Storing file:  output/fr/pmematest_344_semant.yml
# Storing file:  output/fr/pmematest_344_meaningcloud.yml
# Storing file:  output/fr/pmematest_344_bitext.yml
# Storing file:  output/fr/pmematest_344_retresco.yml
# Storing file:  output/fr/pmematest_2911_alchemy.yml
# Storing file:  output/fr/pmematest_2911_txtrazor.yml
# Storing file:  output/fr/pmematest_2911_simple.yml
# Storing file:  output/fr/pmematest_2911_semant.yml
# Storing file:  output/fr/pmematest_2911_meaningcloud.yml
# Storing file:  output/fr/pmematest_2911_bitext.yml
# Storing file:  output/fr/pmematest_2911_retresco.yml
# Storing file:  output/fr/pmematest_1808_alchemy.yml
# Storing file:  output/fr/pmematest_1808_txtrazor.yml
# Storing file:  output/fr/pmematest_1808_simple.yml
# Storing file:  output/fr/pmematest_1808_semant.yml
# Storing file:  output/fr/pmematest_1808_meaningcloud.yml
# Storing file:  output/fr/pmematest_1808_bitext.yml
# Storing file:  output/fr/pmematest_1808_retresco.yml
# Storing file:  output/fr/pmematest_2271_alchemy.yml
# Storing file:  output/fr/pmematest_2271_txtrazor.yml
# Storing file:  output/fr/pmematest_2271_simple.yml
# Storing file:  output/fr/pmematest_2271_semant.yml
# Storing file:  output/fr/pmematest_2271_meaningcloud.yml
# Storing file:  output/fr/pmematest_2271_bitext.yml
# Storing file:  output/fr/pmematest_2271_retresco.yml
# Storing file:  output/fr/pmematest_3390_alchemy.yml
# Storing file:  output/fr/pmematest_3390_txtrazor.yml
# Storing file:  output/fr/pmematest_3390_simple.yml
# Storing file:  output/fr/pmematest_3390_semant.yml
# Storing file:  output/fr/pmematest_3390_meaningcloud.yml
# Storing file:  output/fr/pmematest_3390_bitext.yml
# Storing file:  output/fr/pmematest_3390_retresco.yml
# Storing file:  output/fr/pmematest_2116_alchemy.yml
# Storing file:  output/fr/pmematest_2116_txtrazor.yml
# Storing file:  output/fr/pmematest_2116_simple.yml
# Storing file:  output/fr/pmematest_2116_semant.yml
# Storing file:  output/fr/pmematest_2116_meaningcloud.yml
# Storing file:  output/fr/pmematest_2116_bitext.yml
# Storing file:  output/fr/pmematest_2116_retresco.yml
# Storing file:  output/fr/pmematest_996_alchemy.yml
# Storing file:  output/fr/pmematest_996_txtrazor.yml
# Storing file:  output/fr/pmematest_996_simple.yml
# Storing file:  output/fr/pmematest_996_semant.yml
# Storing file:  output/fr/pmematest_996_meaningcloud.yml
# Storing file:  output/fr/pmematest_996_bitext.yml
# Storing file:  output/fr/pmematest_996_retresco.yml
# Storing file:  output/fr/pmematest_3335_alchemy.yml
# Storing file:  output/fr/pmematest_3335_txtrazor.yml
# Storing file:  output/fr/pmematest_3335_simple.yml
# Storing file:  output/fr/pmematest_3335_semant.yml
# Storing file:  output/fr/pmematest_3335_meaningcloud.yml
# Storing file:  output/fr/pmematest_3335_bitext.yml
# Storing file:  output/fr/pmematest_3335_retresco.yml
# Storing file:  output/fr/pmematest_1296_alchemy.yml
# Storing file:  output/fr/pmematest_1296_txtrazor.yml
# Storing file:  output/fr/pmematest_1296_simple.yml
# Storing file:  output/fr/pmematest_1296_semant.yml
# Storing file:  output/fr/pmematest_1296_meaningcloud.yml
# Storing file:  output/fr/pmematest_1296_bitext.yml
# Storing file:  output/fr/pmematest_1296_retresco.yml
# Storing file:  output/fr/pmematest_2748_alchemy.yml
# Storing file:  output/fr/pmematest_2748_txtrazor.yml
# Storing file:  output/fr/pmematest_2748_simple.yml
# Storing file:  output/fr/pmematest_2748_semant.yml
# Storing file:  output/fr/pmematest_2748_meaningcloud.yml
# Storing file:  output/fr/pmematest_2748_bitext.yml
# Storing file:  output/fr/pmematest_2748_retresco.yml
# Storing file:  output/fr/pmematest_1612_alchemy.yml
# Storing file:  output/fr/pmematest_1612_txtrazor.yml
# Storing file:  output/fr/pmematest_1612_simple.yml
# Storing file:  output/fr/pmematest_1612_semant.yml
# Storing file:  output/fr/pmematest_1612_meaningcloud.yml
# Storing file:  output/fr/pmematest_1612_bitext.yml
# Storing file:  output/fr/pmematest_1612_retresco.yml
# Storing file:  output/fr/pmematest_924_alchemy.yml
# Storing file:  output/fr/pmematest_924_txtrazor.yml
# Storing file:  output/fr/pmematest_924_simple.yml
# Storing file:  output/fr/pmematest_924_semant.yml
# Storing file:  output/fr/pmematest_924_meaningcloud.yml
# Storing file:  output/fr/pmematest_924_bitext.yml
# Storing file:  output/fr/pmematest_924_retresco.yml
# Storing file:  output/fr/pmematest_1986_alchemy.yml
# Storing file:  output/fr/pmematest_1986_txtrazor.yml
# Storing file:  output/fr/pmematest_1986_simple.yml
# Storing file:  output/fr/pmematest_1986_semant.yml
# Storing file:  output/fr/pmematest_1986_meaningcloud.yml
# Storing file:  output/fr/pmematest_1986_bitext.yml
# Storing file:  output/fr/pmematest_1986_retresco.yml
# Storing file:  output/fr/pmematest_2586_alchemy.yml
# Storing file:  output/fr/pmematest_2586_txtrazor.yml
# Storing file:  output/fr/pmematest_2586_simple.yml
# Storing file:  output/fr/pmematest_2586_semant.yml
# Storing file:  output/fr/pmematest_2586_meaningcloud.yml
# Storing file:  output/fr/pmematest_2586_bitext.yml
# Storing file:  output/fr/pmematest_2586_retresco.yml
# Storing file:  output/fr/pmematest_2535_alchemy.yml
# Storing file:  output/fr/pmematest_2535_txtrazor.yml
# Storing file:  output/fr/pmematest_2535_simple.yml
# Storing file:  output/fr/pmematest_2535_semant.yml
# Storing file:  output/fr/pmematest_2535_meaningcloud.yml
# Storing file:  output/fr/pmematest_2535_bitext.yml
# Storing file:  output/fr/pmematest_2535_retresco.yml
# Storing file:  output/fr/pmematest_2227_alchemy.yml
# Storing file:  output/fr/pmematest_2227_txtrazor.yml
# Storing file:  output/fr/pmematest_2227_simple.yml
# Storing file:  output/fr/pmematest_2227_semant.yml
# Storing file:  output/fr/pmematest_2227_meaningcloud.yml
# Storing file:  output/fr/pmematest_2227_bitext.yml
# Storing file:  output/fr/pmematest_2227_retresco.yml
# Storing file:  output/fr/pmematest_2847_alchemy.yml
# Storing file:  output/fr/pmematest_2847_txtrazor.yml
# Storing file:  output/fr/pmematest_2847_simple.yml
# Storing file:  output/fr/pmematest_2847_semant.yml
# Storing file:  output/fr/pmematest_2847_meaningcloud.yml
# Storing file:  output/fr/pmematest_2847_bitext.yml
# Storing file:  output/fr/pmematest_2847_retresco.yml
# Storing file:  output/fr/pmematest_1032_alchemy.yml
# Storing file:  output/fr/pmematest_1032_txtrazor.yml
# Storing file:  output/fr/pmematest_1032_simple.yml
# Storing file:  output/fr/pmematest_1032_semant.yml
# Storing file:  output/fr/pmematest_1032_meaningcloud.yml
# Storing file:  output/fr/pmematest_1032_bitext.yml
# Storing file:  output/fr/pmematest_1032_retresco.yml
# Storing file:  output/fr/pmematest_1269_alchemy.yml
# Storing file:  output/fr/pmematest_1269_txtrazor.yml
# Storing file:  output/fr/pmematest_1269_simple.yml
# Storing file:  output/fr/pmematest_1269_semant.yml
# Storing file:  output/fr/pmematest_1269_meaningcloud.yml
# Storing file:  output/fr/pmematest_1269_bitext.yml
# Storing file:  output/fr/pmematest_1269_retresco.yml
# Storing file:  output/fr/pmematest_1125_alchemy.yml
# Storing file:  output/fr/pmematest_1125_txtrazor.yml
# Storing file:  output/fr/pmematest_1125_simple.yml
# Storing file:  output/fr/pmematest_1125_semant.yml
# Storing file:  output/fr/pmematest_1125_meaningcloud.yml
# Storing file:  output/fr/pmematest_1125_bitext.yml
# Storing file:  output/fr/pmematest_1125_retresco.yml

# %%
import semaeval.statistics as stats

# %%
data=stats.collect_data(articles_enriched)
# Out:
# alchemy pmematest_851.yml float division by zero
# alchemy pmematest_851.yml float division by zero
# txtrazor pmematest_851.yml float division by zero
# txtrazor pmematest_851.yml float division by zero
# simple pmematest_851.yml float division by zero
# simple pmematest_851.yml float division by zero
# semant pmematest_851.yml float division by zero
# semant pmematest_851.yml float division by zero
# meaningcloud pmematest_851.yml float division by zero
# meaningcloud pmematest_851.yml float division by zero
# bitext pmematest_851.yml float division by zero
# bitext pmematest_851.yml float division by zero
# bitext pmematest_851.yml float division by zero
# retresco pmematest_851.yml float division by zero
# retresco pmematest_851.yml float division by zero
# retresco pmematest_851.yml float division by zero
# txtrazor pmematest_3228.yml float division by zero
# txtrazor pmematest_3228.yml float division by zero
# simple pmematest_3228.yml float division by zero
# semant pmematest_3228.yml float division by zero
# semant pmematest_3228.yml float division by zero
# semant pmematest_3228.yml float division by zero
# meaningcloud pmematest_3228.yml float division by zero
# meaningcloud pmematest_3228.yml float division by zero
# bitext pmematest_3228.yml float division by zero
# bitext pmematest_3228.yml float division by zero
# bitext pmematest_3228.yml float division by zero
# retresco pmematest_3228.yml float division by zero
# retresco pmematest_3228.yml float division by zero
# alchemy pmematest_2241.yml float division by zero
# txtrazor pmematest_2241.yml float division by zero
# simple pmematest_2241.yml float division by zero
# semant pmematest_2241.yml float division by zero
# meaningcloud pmematest_2241.yml float division by zero
# bitext pmematest_2241.yml float division by zero
# retresco pmematest_2241.yml float division by zero
# alchemy pmematest_3308.yml float division by zero
# alchemy pmematest_3308.yml float division by zero
# txtrazor pmematest_3308.yml float division by zero
# txtrazor pmematest_3308.yml float division by zero
# simple pmematest_3308.yml float division by zero
# simple pmematest_3308.yml float division by zero
# semant pmematest_3308.yml float division by zero
# semant pmematest_3308.yml float division by zero
# semant pmematest_3308.yml float division by zero
# meaningcloud pmematest_3308.yml float division by zero
# meaningcloud pmematest_3308.yml float division by zero
# meaningcloud pmematest_3308.yml float division by zero
# bitext pmematest_3308.yml float division by zero
# bitext pmematest_3308.yml float division by zero
# bitext pmematest_3308.yml float division by zero
# retresco pmematest_3308.yml float division by zero
# retresco pmematest_3308.yml float division by zero
# retresco pmematest_3308.yml float division by zero
# alchemy pmematest_2967.yml float division by zero
# alchemy pmematest_2967.yml float division by zero
# txtrazor pmematest_2967.yml float division by zero
# simple pmematest_2967.yml float division by zero
# semant pmematest_2967.yml float division by zero
# bitext pmematest_2967.yml float division by zero
# alchemy pmematest_2221.yml float division by zero
# alchemy pmematest_2221.yml float division by zero
# alchemy pmematest_2221.yml float division by zero
# txtrazor pmematest_2221.yml float division by zero
# simple pmematest_2221.yml float division by zero
# simple pmematest_2221.yml float division by zero
# semant pmematest_2221.yml float division by zero
# semant pmematest_2221.yml float division by zero
# meaningcloud pmematest_2221.yml float division by zero
# bitext pmematest_2221.yml float division by zero
# retresco pmematest_2221.yml float division by zero
# alchemy pmematest_2817.yml float division by zero
# simple pmematest_2817.yml float division by zero
# simple pmematest_2817.yml float division by zero
# meaningcloud pmematest_2817.yml float division by zero
# retresco pmematest_2817.yml float division by zero
# txtrazor pmematest_3043.yml float division by zero
# txtrazor pmematest_3043.yml float division by zero
# meaningcloud pmematest_3043.yml float division by zero
# bitext pmematest_3043.yml float division by zero
# bitext pmematest_3043.yml float division by zero
# retresco pmematest_3043.yml float division by zero
# alchemy pmematest_2136.yml float division by zero
# alchemy pmematest_2136.yml float division by zero
# alchemy pmematest_2136.yml float division by zero
# txtrazor pmematest_2136.yml float division by zero
# txtrazor pmematest_2136.yml float division by zero
# txtrazor pmematest_2136.yml float division by zero
# simple pmematest_2136.yml float division by zero
# simple pmematest_2136.yml float division by zero
# simple pmematest_2136.yml float division by zero
# semant pmematest_2136.yml float division by zero
# semant pmematest_2136.yml float division by zero
# meaningcloud pmematest_2136.yml float division by zero
# meaningcloud pmematest_2136.yml float division by zero
# bitext pmematest_2136.yml float division by zero
# bitext pmematest_2136.yml float division by zero
# bitext pmematest_2136.yml float division by zero
# retresco pmematest_2136.yml float division by zero
# retresco pmematest_2136.yml float division by zero
# retresco pmematest_2136.yml float division by zero
# txtrazor pmematest_043.yml float division by zero
# semant pmematest_043.yml float division by zero
# meaningcloud pmematest_043.yml float division by zero
# bitext pmematest_043.yml float division by zero
# retresco pmematest_043.yml float division by zero
# alchemy pmematest_2388.yml float division by zero
# alchemy pmematest_2388.yml float division by zero
# txtrazor pmematest_2388.yml float division by zero
# simple pmematest_2388.yml float division by zero
# simple pmematest_2388.yml float division by zero
# semant pmematest_2388.yml float division by zero
# semant pmematest_2388.yml float division by zero
# meaningcloud pmematest_2388.yml float division by zero
# meaningcloud pmematest_2388.yml float division by zero
# bitext pmematest_2388.yml float division by zero
# bitext pmematest_2388.yml float division by zero
# retresco pmematest_2388.yml float division by zero
# retresco pmematest_2388.yml float division by zero
# txtrazor pmematest_1576.yml float division by zero
# simple pmematest_1576.yml float division by zero
# meaningcloud pmematest_1576.yml float division by zero
# meaningcloud pmematest_1576.yml float division by zero
# bitext pmematest_1576.yml float division by zero
# retresco pmematest_1576.yml float division by zero
# alchemy pmematest_2042.yml float division by zero
# txtrazor pmematest_2042.yml float division by zero
# txtrazor pmematest_2042.yml float division by zero
# simple pmematest_2042.yml float division by zero
# semant pmematest_2042.yml float division by zero
# meaningcloud pmematest_2042.yml float division by zero
# bitext pmematest_2042.yml float division by zero
# bitext pmematest_2042.yml float division by zero
# retresco pmematest_2042.yml float division by zero
# retresco pmematest_2042.yml float division by zero
# alchemy pmematest_3360.yml float division by zero
# alchemy pmematest_3360.yml float division by zero
# alchemy pmematest_3360.yml float division by zero
# txtrazor pmematest_3360.yml float division by zero
# txtrazor pmematest_3360.yml float division by zero
# simple pmematest_3360.yml float division by zero
# simple pmematest_3360.yml float division by zero
# semant pmematest_3360.yml float division by zero
# meaningcloud pmematest_3360.yml float division by zero
# meaningcloud pmematest_3360.yml float division by zero
# meaningcloud pmematest_3360.yml float division by zero
# bitext pmematest_3360.yml float division by zero
# retresco pmematest_3360.yml float division by zero
# retresco pmematest_3360.yml float division by zero
# retresco pmematest_3360.yml float division by zero
# semant pmematest_3030.yml float division by zero
# meaningcloud pmematest_3030.yml float division by zero
# bitext pmematest_3030.yml float division by zero
# retresco pmematest_3030.yml float division by zero
# alchemy pmematest_1051.yml float division by zero
# alchemy pmematest_1051.yml float division by zero
# alchemy pmematest_1051.yml float division by zero
# txtrazor pmematest_1051.yml float division by zero
# simple pmematest_1051.yml float division by zero
# semant pmematest_1051.yml float division by zero
# semant pmematest_1051.yml float division by zero
# meaningcloud pmematest_1051.yml float division by zero
# meaningcloud pmematest_1051.yml float division by zero
# bitext pmematest_1051.yml float division by zero
# bitext pmematest_1051.yml float division by zero
# retresco pmematest_1051.yml float division by zero
# retresco pmematest_1051.yml float division by zero
# alchemy pmematest_288.yml float division by zero
# alchemy pmematest_288.yml float division by zero
# txtrazor pmematest_288.yml float division by zero
# txtrazor pmematest_288.yml float division by zero
# simple pmematest_288.yml float division by zero
# simple pmematest_288.yml float division by zero
# semant pmematest_288.yml float division by zero
# semant pmematest_288.yml float division by zero
# meaningcloud pmematest_288.yml float division by zero
# meaningcloud pmematest_288.yml float division by zero
# bitext pmematest_288.yml float division by zero
# bitext pmematest_288.yml float division by zero
# retresco pmematest_288.yml float division by zero
# retresco pmematest_288.yml float division by zero
# alchemy pmematest_220.yml float division by zero
# txtrazor pmematest_220.yml float division by zero
# simple pmematest_220.yml float division by zero
# simple pmematest_220.yml float division by zero
# semant pmematest_220.yml float division by zero
# meaningcloud pmematest_220.yml float division by zero
# bitext pmematest_220.yml float division by zero
# retresco pmematest_220.yml float division by zero
# retresco pmematest_220.yml float division by zero
# alchemy pmematest_752.yml float division by zero
# alchemy pmematest_752.yml float division by zero
# alchemy pmematest_752.yml float division by zero
# txtrazor pmematest_752.yml float division by zero
# txtrazor pmematest_752.yml float division by zero
# simple pmematest_752.yml float division by zero
# simple pmematest_752.yml float division by zero
# simple pmematest_752.yml float division by zero
# semant pmematest_752.yml float division by zero
# semant pmematest_752.yml float division by zero
# meaningcloud pmematest_752.yml float division by zero
# meaningcloud pmematest_752.yml float division by zero
# bitext pmematest_752.yml float division by zero
# bitext pmematest_752.yml float division by zero
# retresco pmematest_752.yml float division by zero
# retresco pmematest_752.yml float division by zero
# alchemy pmematest_3091.yml float division by zero
# alchemy pmematest_3091.yml float division by zero
# alchemy pmematest_3091.yml float division by zero
# txtrazor pmematest_3091.yml float division by zero
# txtrazor pmematest_3091.yml float division by zero
# txtrazor pmematest_3091.yml float division by zero
# simple pmematest_3091.yml float division by zero
# simple pmematest_3091.yml float division by zero
# simple pmematest_3091.yml float division by zero
# semant pmematest_3091.yml float division by zero
# semant pmematest_3091.yml float division by zero
# semant pmematest_3091.yml float division by zero
# meaningcloud pmematest_3091.yml float division by zero
# meaningcloud pmematest_3091.yml float division by zero
# meaningcloud pmematest_3091.yml float division by zero
# bitext pmematest_3091.yml float division by zero
# bitext pmematest_3091.yml float division by zero
# bitext pmematest_3091.yml float division by zero
# retresco pmematest_3091.yml float division by zero
# retresco pmematest_3091.yml float division by zero
# retresco pmematest_3091.yml float division by zero
# alchemy pmematest_3051.yml float division by zero
# simple pmematest_3051.yml float division by zero
# meaningcloud pmematest_3051.yml float division by zero
# meaningcloud pmematest_3051.yml float division by zero
# bitext pmematest_3051.yml float division by zero
# retresco pmematest_3051.yml float division by zero
# retresco pmematest_3051.yml float division by zero
# alchemy pmematest_2541.yml float division by zero
# simple pmematest_2541.yml float division by zero
# semant pmematest_2541.yml float division by zero
# meaningcloud pmematest_2541.yml float division by zero
# bitext pmematest_2541.yml float division by zero
# bitext pmematest_2541.yml float division by zero
# retresco pmematest_2541.yml float division by zero
# txtrazor pmematest_3340.yml float division by zero
# simple pmematest_3340.yml float division by zero
# simple pmematest_3340.yml float division by zero
# semant pmematest_3340.yml float division by zero
# meaningcloud pmematest_3340.yml float division by zero
# bitext pmematest_3340.yml float division by zero
# alchemy pmematest_1181.yml float division by zero
# alchemy pmematest_1181.yml float division by zero
# alchemy pmematest_1181.yml float division by zero
# txtrazor pmematest_1181.yml float division by zero
# txtrazor pmematest_1181.yml float division by zero
# simple pmematest_1181.yml float division by zero
# simple pmematest_1181.yml float division by zero
# simple pmematest_1181.yml float division by zero
# semant pmematest_1181.yml float division by zero
# semant pmematest_1181.yml float division by zero
# semant pmematest_1181.yml float division by zero
# meaningcloud pmematest_1181.yml float division by zero
# meaningcloud pmematest_1181.yml float division by zero
# bitext pmematest_1181.yml float division by zero
# bitext pmematest_1181.yml float division by zero
# bitext pmematest_1181.yml float division by zero
# retresco pmematest_1181.yml float division by zero
# retresco pmematest_1181.yml float division by zero
# retresco pmematest_1181.yml float division by zero
# alchemy pmematest_2500.yml float division by zero
# alchemy pmematest_2500.yml float division by zero
# txtrazor pmematest_2500.yml float division by zero
# simple pmematest_2500.yml float division by zero
# semant pmematest_2500.yml float division by zero
# semant pmematest_2500.yml float division by zero
# meaningcloud pmematest_2500.yml float division by zero
# meaningcloud pmematest_2500.yml float division by zero
# bitext pmematest_2500.yml float division by zero
# bitext pmematest_2500.yml float division by zero
# retresco pmematest_2500.yml float division by zero
# retresco pmematest_2500.yml float division by zero
# alchemy pmematest_2429.yml float division by zero
# txtrazor pmematest_2429.yml float division by zero
# simple pmematest_2429.yml float division by zero
# semant pmematest_2429.yml float division by zero
# semant pmematest_2429.yml float division by zero
# meaningcloud pmematest_2429.yml float division by zero
# bitext pmematest_2429.yml float division by zero
# retresco pmematest_2429.yml float division by zero
# retresco pmematest_2429.yml float division by zero
# alchemy pmematest_2091.yml float division by zero
# txtrazor pmematest_2091.yml float division by zero
# txtrazor pmematest_2091.yml float division by zero
# simple pmematest_2091.yml float division by zero
# meaningcloud pmematest_2091.yml float division by zero
# meaningcloud pmematest_2091.yml float division by zero
# meaningcloud pmematest_2091.yml float division by zero
# bitext pmematest_2091.yml float division by zero
# retresco pmematest_2091.yml float division by zero
# alchemy pmematest_2981.yml float division by zero
# alchemy pmematest_2981.yml float division by zero
# alchemy pmematest_2981.yml float division by zero
# txtrazor pmematest_2981.yml float division by zero
# txtrazor pmematest_2981.yml float division by zero
# txtrazor pmematest_2981.yml float division by zero
# simple pmematest_2981.yml float division by zero
# simple pmematest_2981.yml float division by zero
# simple pmematest_2981.yml float division by zero
# semant pmematest_2981.yml float division by zero
# semant pmematest_2981.yml float division by zero
# semant pmematest_2981.yml float division by zero
# meaningcloud pmematest_2981.yml float division by zero
# meaningcloud pmematest_2981.yml float division by zero
# meaningcloud pmematest_2981.yml float division by zero
# bitext pmematest_2981.yml float division by zero
# bitext pmematest_2981.yml float division by zero
# bitext pmematest_2981.yml float division by zero
# retresco pmematest_2981.yml float division by zero
# retresco pmematest_2981.yml float division by zero
# retresco pmematest_2981.yml float division by zero
# alchemy pmematest_2806.yml float division by zero
# alchemy pmematest_2806.yml float division by zero
# alchemy pmematest_2806.yml float division by zero
# txtrazor pmematest_2806.yml float division by zero
# txtrazor pmematest_2806.yml float division by zero
# simple pmematest_2806.yml float division by zero
# simple pmematest_2806.yml float division by zero
# simple pmematest_2806.yml float division by zero
# semant pmematest_2806.yml float division by zero
# semant pmematest_2806.yml float division by zero
# semant pmematest_2806.yml float division by zero
# meaningcloud pmematest_2806.yml float division by zero
# meaningcloud pmematest_2806.yml float division by zero
# bitext pmematest_2806.yml float division by zero
# bitext pmematest_2806.yml float division by zero
# bitext pmematest_2806.yml float division by zero
# retresco pmematest_2806.yml float division by zero
# retresco pmematest_2806.yml float division by zero
# retresco pmematest_2806.yml float division by zero
# alchemy pmematest_344.yml float division by zero
# alchemy pmematest_344.yml float division by zero
# alchemy pmematest_344.yml float division by zero
# txtrazor pmematest_344.yml float division by zero
# txtrazor pmematest_344.yml float division by zero
# txtrazor pmematest_344.yml float division by zero
# simple pmematest_344.yml float division by zero
# simple pmematest_344.yml float division by zero
# simple pmematest_344.yml float division by zero
# semant pmematest_344.yml float division by zero
# semant pmematest_344.yml float division by zero
# semant pmematest_344.yml float division by zero
# meaningcloud pmematest_344.yml float division by zero
# meaningcloud pmematest_344.yml float division by zero
# meaningcloud pmematest_344.yml float division by zero
# bitext pmematest_344.yml float division by zero
# bitext pmematest_344.yml float division by zero
# bitext pmematest_344.yml float division by zero
# retresco pmematest_344.yml float division by zero
# retresco pmematest_344.yml float division by zero
# retresco pmematest_344.yml float division by zero
# alchemy pmematest_2911.yml float division by zero
# txtrazor pmematest_2911.yml float division by zero
# simple pmematest_2911.yml float division by zero
# simple pmematest_2911.yml float division by zero
# semant pmematest_2911.yml float division by zero
# bitext pmematest_2911.yml float division by zero
# retresco pmematest_2911.yml float division by zero
# alchemy pmematest_1808.yml float division by zero
# alchemy pmematest_1808.yml float division by zero
# txtrazor pmematest_1808.yml float division by zero
# simple pmematest_1808.yml float division by zero
# simple pmematest_1808.yml float division by zero
# semant pmematest_1808.yml float division by zero
# meaningcloud pmematest_1808.yml float division by zero
# meaningcloud pmematest_1808.yml float division by zero
# meaningcloud pmematest_1808.yml float division by zero
# bitext pmematest_1808.yml float division by zero
# bitext pmematest_1808.yml float division by zero
# bitext pmematest_1808.yml float division by zero
# retresco pmematest_1808.yml float division by zero
# retresco pmematest_1808.yml float division by zero
# simple pmematest_2271.yml float division by zero
# simple pmematest_2271.yml float division by zero
# semant pmematest_2271.yml float division by zero
# semant pmematest_2271.yml float division by zero
# meaningcloud pmematest_2271.yml float division by zero
# meaningcloud pmematest_2271.yml float division by zero
# meaningcloud pmematest_2271.yml float division by zero
# bitext pmematest_2271.yml float division by zero
# retresco pmematest_2271.yml float division by zero
# semant pmematest_3390.yml float division by zero
# semant pmematest_3390.yml float division by zero
# alchemy pmematest_2116.yml float division by zero
# alchemy pmematest_2116.yml float division by zero
# txtrazor pmematest_2116.yml float division by zero
# txtrazor pmematest_2116.yml float division by zero
# simple pmematest_2116.yml float division by zero
# simple pmematest_2116.yml float division by zero
# semant pmematest_2116.yml float division by zero
# semant pmematest_2116.yml float division by zero
# semant pmematest_2116.yml float division by zero
# meaningcloud pmematest_2116.yml float division by zero
# meaningcloud pmematest_2116.yml float division by zero
# bitext pmematest_2116.yml float division by zero
# bitext pmematest_2116.yml float division by zero
# bitext pmematest_2116.yml float division by zero
# retresco pmematest_2116.yml float division by zero
# retresco pmematest_2116.yml float division by zero
# meaningcloud pmematest_996.yml float division by zero
# meaningcloud pmematest_996.yml float division by zero
# alchemy pmematest_3335.yml float division by zero
# alchemy pmematest_3335.yml float division by zero
# alchemy pmematest_3335.yml float division by zero
# txtrazor pmematest_3335.yml float division by zero
# txtrazor pmematest_3335.yml float division by zero
# simple pmematest_3335.yml float division by zero
# simple pmematest_3335.yml float division by zero
# simple pmematest_3335.yml float division by zero
# semant pmematest_3335.yml float division by zero
# semant pmematest_3335.yml float division by zero
# meaningcloud pmematest_3335.yml float division by zero
# meaningcloud pmematest_3335.yml float division by zero
# meaningcloud pmematest_3335.yml float division by zero
# bitext pmematest_3335.yml float division by zero
# bitext pmematest_3335.yml float division by zero
# bitext pmematest_3335.yml float division by zero
# retresco pmematest_3335.yml float division by zero
# retresco pmematest_3335.yml float division by zero
# retresco pmematest_3335.yml float division by zero
# alchemy pmematest_1296.yml float division by zero
# alchemy pmematest_1296.yml float division by zero
# txtrazor pmematest_1296.yml float division by zero
# simple pmematest_1296.yml float division by zero
# simple pmematest_1296.yml float division by zero
# semant pmematest_1296.yml float division by zero
# semant pmematest_1296.yml float division by zero
# meaningcloud pmematest_1296.yml float division by zero
# meaningcloud pmematest_1296.yml float division by zero
# bitext pmematest_1296.yml float division by zero
# bitext pmematest_1296.yml float division by zero
# retresco pmematest_1296.yml float division by zero
# alchemy pmematest_2748.yml float division by zero
# alchemy pmematest_2748.yml float division by zero
# txtrazor pmematest_2748.yml float division by zero
# txtrazor pmematest_2748.yml float division by zero
# simple pmematest_2748.yml float division by zero
# simple pmematest_2748.yml float division by zero
# semant pmematest_2748.yml float division by zero
# semant pmematest_2748.yml float division by zero
# semant pmematest_2748.yml float division by zero
# meaningcloud pmematest_2748.yml float division by zero
# bitext pmematest_2748.yml float division by zero
# bitext pmematest_2748.yml float division by zero
# retresco pmematest_2748.yml float division by zero
# retresco pmematest_2748.yml float division by zero
# retresco pmematest_2748.yml float division by zero
# alchemy pmematest_1612.yml float division by zero
# alchemy pmematest_1612.yml float division by zero
# txtrazor pmematest_1612.yml float division by zero
# txtrazor pmematest_1612.yml float division by zero
# simple pmematest_1612.yml float division by zero
# simple pmematest_1612.yml float division by zero
# semant pmematest_1612.yml float division by zero
# semant pmematest_1612.yml float division by zero
# meaningcloud pmematest_1612.yml float division by zero
# meaningcloud pmematest_1612.yml float division by zero
# bitext pmematest_1612.yml float division by zero
# bitext pmematest_1612.yml float division by zero
# retresco pmematest_1612.yml float division by zero
# retresco pmematest_1612.yml float division by zero
# alchemy pmematest_924.yml float division by zero
# alchemy pmematest_924.yml float division by zero
# txtrazor pmematest_924.yml float division by zero
# txtrazor pmematest_924.yml float division by zero
# simple pmematest_924.yml float division by zero
# simple pmematest_924.yml float division by zero
# semant pmematest_924.yml float division by zero
# semant pmematest_924.yml float division by zero
# meaningcloud pmematest_924.yml float division by zero
# meaningcloud pmematest_924.yml float division by zero
# meaningcloud pmematest_924.yml float division by zero
# bitext pmematest_924.yml float division by zero
# bitext pmematest_924.yml float division by zero
# retresco pmematest_924.yml float division by zero
# retresco pmematest_924.yml float division by zero
# alchemy pmematest_1986.yml float division by zero
# alchemy pmematest_1986.yml float division by zero
# simple pmematest_1986.yml float division by zero
# simple pmematest_1986.yml float division by zero
# semant pmematest_1986.yml float division by zero
# semant pmematest_1986.yml float division by zero
# meaningcloud pmematest_1986.yml float division by zero
# bitext pmematest_1986.yml float division by zero
# bitext pmematest_1986.yml float division by zero
# retresco pmematest_1986.yml float division by zero
# alchemy pmematest_2586.yml float division by zero
# alchemy pmematest_2586.yml float division by zero
# alchemy pmematest_2586.yml float division by zero
# txtrazor pmematest_2586.yml float division by zero
# txtrazor pmematest_2586.yml float division by zero
# txtrazor pmematest_2586.yml float division by zero
# simple pmematest_2586.yml float division by zero
# simple pmematest_2586.yml float division by zero
# simple pmematest_2586.yml float division by zero
# semant pmematest_2586.yml float division by zero
# semant pmematest_2586.yml float division by zero
# semant pmematest_2586.yml float division by zero
# meaningcloud pmematest_2586.yml float division by zero
# meaningcloud pmematest_2586.yml float division by zero
# meaningcloud pmematest_2586.yml float division by zero
# bitext pmematest_2586.yml float division by zero
# bitext pmematest_2586.yml float division by zero
# bitext pmematest_2586.yml float division by zero
# retresco pmematest_2586.yml float division by zero
# retresco pmematest_2586.yml float division by zero
# retresco pmematest_2586.yml float division by zero
# alchemy pmematest_2535.yml float division by zero
# alchemy pmematest_2535.yml float division by zero
# alchemy pmematest_2535.yml float division by zero
# txtrazor pmematest_2535.yml float division by zero
# txtrazor pmematest_2535.yml float division by zero
# txtrazor pmematest_2535.yml float division by zero
# simple pmematest_2535.yml float division by zero
# simple pmematest_2535.yml float division by zero
# simple pmematest_2535.yml float division by zero
# semant pmematest_2535.yml float division by zero
# semant pmematest_2535.yml float division by zero
# semant pmematest_2535.yml float division by zero
# meaningcloud pmematest_2535.yml float division by zero
# meaningcloud pmematest_2535.yml float division by zero
# meaningcloud pmematest_2535.yml float division by zero
# bitext pmematest_2535.yml float division by zero
# bitext pmematest_2535.yml float division by zero
# bitext pmematest_2535.yml float division by zero
# retresco pmematest_2535.yml float division by zero
# retresco pmematest_2535.yml float division by zero
# retresco pmematest_2535.yml float division by zero
# alchemy pmematest_2227.yml float division by zero
# txtrazor pmematest_2227.yml float division by zero
# txtrazor pmematest_2227.yml float division by zero
# simple pmematest_2227.yml float division by zero
# semant pmematest_2227.yml float division by zero
# semant pmematest_2227.yml float division by zero
# meaningcloud pmematest_2227.yml float division by zero
# meaningcloud pmematest_2227.yml float division by zero
# bitext pmematest_2227.yml float division by zero
# bitext pmematest_2227.yml float division by zero
# retresco pmematest_2227.yml float division by zero
# retresco pmematest_2227.yml float division by zero
# retresco pmematest_2227.yml float division by zero
# alchemy pmematest_2847.yml float division by zero
# alchemy pmematest_2847.yml float division by zero
# txtrazor pmematest_2847.yml float division by zero
# txtrazor pmematest_2847.yml float division by zero
# txtrazor pmematest_2847.yml float division by zero
# simple pmematest_2847.yml float division by zero
# simple pmematest_2847.yml float division by zero
# semant pmematest_2847.yml float division by zero
# semant pmematest_2847.yml float division by zero
# meaningcloud pmematest_2847.yml float division by zero
# meaningcloud pmematest_2847.yml float division by zero
# bitext pmematest_2847.yml float division by zero
# bitext pmematest_2847.yml float division by zero
# retresco pmematest_2847.yml float division by zero
# retresco pmematest_2847.yml float division by zero
# retresco pmematest_2847.yml float division by zero
# alchemy pmematest_1032.yml float division by zero
# alchemy pmematest_1032.yml float division by zero
# alchemy pmematest_1032.yml float division by zero
# txtrazor pmematest_1032.yml float division by zero
# txtrazor pmematest_1032.yml float division by zero
# simple pmematest_1032.yml float division by zero
# simple pmematest_1032.yml float division by zero
# simple pmematest_1032.yml float division by zero
# semant pmematest_1032.yml float division by zero
# semant pmematest_1032.yml float division by zero
# meaningcloud pmematest_1032.yml float division by zero
# meaningcloud pmematest_1032.yml float division by zero
# bitext pmematest_1032.yml float division by zero
# bitext pmematest_1032.yml float division by zero
# retresco pmematest_1032.yml float division by zero
# retresco pmematest_1032.yml float division by zero
# retresco pmematest_1032.yml float division by zero
# alchemy pmematest_1269.yml float division by zero
# alchemy pmematest_1269.yml float division by zero
# txtrazor pmematest_1269.yml float division by zero
# txtrazor pmematest_1269.yml float division by zero
# simple pmematest_1269.yml float division by zero
# simple pmematest_1269.yml float division by zero
# simple pmematest_1269.yml float division by zero
# semant pmematest_1269.yml float division by zero
# semant pmematest_1269.yml float division by zero
# semant pmematest_1269.yml float division by zero
# meaningcloud pmematest_1269.yml float division by zero
# meaningcloud pmematest_1269.yml float division by zero
# meaningcloud pmematest_1269.yml float division by zero
# bitext pmematest_1269.yml float division by zero
# bitext pmematest_1269.yml float division by zero
# retresco pmematest_1269.yml float division by zero
# retresco pmematest_1269.yml float division by zero
# simple pmematest_1125.yml float division by zero
# simple pmematest_1125.yml float division by zero
# semant pmematest_1125.yml float division by zero
# meaningcloud pmematest_1125.yml float division by zero
# bitext pmematest_1125.yml float division by zero
# retresco pmematest_1125.yml float division by zero

# %%
results=stats.aggregate_result(data)

# %%
results.extend(stats.compute_total(results))

# %%
# %matplotlib inline

# %%
stats.plot_results(results)

# %%
stats.store_results(results,"fr")
# Out:
# Storing file:  fr_results.yml
